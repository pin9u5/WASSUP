# %% [markdown]
# # if문

# %%
# '돈이 있으면 택시를 타고 가고, 돈이 없으면 걸어간다.'
money = True
if money:
    print("택시를 타고 가라")
else:
    print("걸어 가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# ## 비교 연산자

# %%
x = 3
y = 2
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x == y
# Out:
# False

# %%
x != y # != 같지 않다.
# Out:
# True

# %%
# 만약 3000원 이상의 돈을 가지고 있으면 택시를 타고 가고, 그렇지 않으면 걸어가라.
money = 2000
if money >= 3000:
    print("택시를 타고 가라")
else:
    print("걸어가라")
#  난 돈이 2천원 밖에 없기에 조건문이 거짓이 되므로 "걸어가라"출력
# Out:
# 걸어가라

# %% [markdown]
# ## and, or, not

# %%
# 돈이 3000원 이상 있거나 카드가 있다면 택시를 타고 가고, 그렇지 않으면 걸어가라.
money = 2000
card = True
if money >= 3000 or card: # or 대신 | 이게 들어갈 수 있음
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# ## in, not in

# %%
1 in [1,2,3]
# Out:
# True

# %%
1 not in  [1,2,3]
# Out:
# False

# %%
'a' in ('a', 'b', 'c')
# Out:
# True

# %%
'j' not in 'python'
# Out:
# True

# %%
# 만약 주머니에 돈이 있으면 택시를 타고 가고, 없으면 걸어가라.
pocket = ['paper', 'cellphone', 'money']
if 'money' in pocket:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
# 조건문에서 아무 일도 하지 않게 설정하고 싶다면?
pocket = ['paper', 'money', 'cellphone']
if 'money' in pocket:
    pass # 참일 경우 pass가 수행되기에 아무런 결괏값도 보여 주지 않음.
else:
    print("카드를 꺼내라")
    #오류를 방지하기 위해서는 아무 동작 하지 않게 pass를 넣어주는 것도 좋다.

# %% [markdown]
# ## 다양한 조건을 판단하는 elif

# %%
# 주머니에 돈이 있으면 택시를 타고 가고, 주머니에 돈은 없지만 카드가 있으면 택시를 타고 가고, 돈도 없고 카드도 없으면 걸어가라.
pocket = ['paper', 'cellphone']
card = True
if 'money' in pocket:
    print("택시를 타고가라")
else:
    if card:
        print("택시를 타고가라")
    else:
        print("걸어가라")
# Out:
# 택시를 타고가라

# %%
# elif  사용 / 이전 조건문이 거짓일 때 수행, 개수에 제한없이 사용 가능
pocket = ['paper', 'cellphone']
card = True
if 'money' in pocket:
    print("택시를 타고가라")
elif card:
    print("택시를 타고가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고가라

# %%
# 한 줄로 써보기
pocket = ['paper', 'money', 'cellphone']
if 'money' in pocket:pass
else:print("카드를 꺼내라")

# %%
score = 59
message = "success" if score >= 60 else "failure"
print(message)
# Out:
# failure

# %% [markdown]
# # while문
# while 문은 조건문이 참인 동안 while 문에 속한 문장들이 반복해서 수행된다.

# %% [markdown]
# ## while 문의 기본 구조

# %%
treeHit = 0
while treeHit < 10:
    treeHit = treeHit +1
    print("나무를 %d번 찍었습니다." % treeHit)
    if treeHit == 10:
        print("나무 넘어갑니다.")
# Out:
# 나무를 1번 찍었습니다.
# 나무를 2번 찍었습니다.
# 나무를 3번 찍었습니다.
# 나무를 4번 찍었습니다.
# 나무를 5번 찍었습니다.
# 나무를 6번 찍었습니다.
# 나무를 7번 찍었습니다.
# 나무를 8번 찍었습니다.
# 나무를 9번 찍었습니다.
# 나무를 10번 찍었습니다.
# 나무 넘어갑니다.

# %%
treeHit = 1
while treeHit < 10:
    print("나무를 %d번 찍었습니다." % treeHit)
    treeHit = treeHit +1
    if treeHit == 10:
        print("나무를 %d번 찍었습니다." % treeHit)
        print("나무 넘어갑니다.")
# Out:
# 나무를 1번 찍었습니다.
# 나무를 2번 찍었습니다.
# 나무를 3번 찍었습니다.
# 나무를 4번 찍었습니다.
# 나무를 5번 찍었습니다.
# 나무를 6번 찍었습니다.
# 나무를 7번 찍었습니다.
# 나무를 8번 찍었습니다.
# 나무를 9번 찍었습니다.
# 나무를 10번 찍었습니다.
# 나무 넘어갑니다.

# %% [markdown]
# ## while 문 만들기

# %%
prompt = """
1. Add
2. Del
3. List
4. Quit
Enter number: """

# %%
number = 0
while number != 4:
    print(prompt)
    number = int(input())
# Out:
# 1. Add
# 2. Del
# 3. List
# 4. Quit
# Enter number:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 4
#       2 while number != 4:
#       3     print(prompt)
# ----> 4     number = int(input())
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# ## while 문 강제로 빠져나가기

# %%
coffee = 10
money = 300
while money:
    print("돈을 받았으니 커피를 줍니다.")
    coffee = coffee -1
    print("남은 커피의 양은 %d개입니다." % coffee)
    if coffee == 0:
        print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
        break
# Out:
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 9개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 8개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 7개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 6개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 5개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 4개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 3개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 2개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 1개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 0개입니다.
# 커피가 다 떨어졌습니다. 판매를 중지합니다.

# %%
# coffee.py
coffee = 10
while True:
    money = int(input("돈을 넣어주세요: "))
    if money == 300:
        print("커피를 줍니다.")
        coffee = coffee -1
        print("남은 커피의 양은 %d개 입니다." % coffee)
    elif money > 300:
        print("거스름돈 %d를 주고 커피를 줍니다." % (money -300))
        coffee = coffee -1
        print("남은 커피의 양은 %d개 입니다." % coffee)
    else:
        print("돈을 다시 돌려주고 커피를 주지 않습니다.")
        print("남은 커피의 양은 %d개 입니다." % coffee)
    if coffee ==0:
        print("커피가 다 떨어졌습니다. 판매를 중지 합니다.")
        break
# Out:
# 돈을 넣어주세요: 300
# 커피를 줍니다.
# 남은 커피의 양은 9개 입니다.
# 돈을 넣어주세요: 600
# 거스름돈 300를 주고 커피를 줍니다.
# 남은 커피의 양은 8개 입니다.
# 돈을 넣어주세요: 200
# 돈을 다시 돌려주고 커피를 주지 않습니다.
# 남은 커피의 양은 8개 입니다.
# 돈을 넣어주세요: 100
# 돈을 다시 돌려주고 커피를 주지 않습니다.
# 남은 커피의 양은 8개 입니다.
# 돈을 넣어주세요: 700
# 거스름돈 400를 주고 커피를 줍니다.
# 남은 커피의 양은 7개 입니다.
# 돈을 넣어주세요: 300
# 커피를 줍니다.
# 남은 커피의 양은 6개 입니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 4
#       2 coffee = 10
#       3 while True:
# ----> 4     money = int(input("돈을 넣어주세요: "))
#       5     if money == 300:
#       6         print("커피를 줍니다.")
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
# ...

# %% [markdown]
# ## while 문의 맨 처음으로 돌아가기

# %%
a = 0
while a < 10:
    a = a + 1
    if a % 2 == 0: continue # 나머지가 0인 짝수는 다시 처음으로 돌아간다.
    print(a) # 홀수일 경우
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
a = 1
while a < 10:
    if a % 2 == 0:
        a = a +1
        continue
    print(a)
    a = a +1
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ## 무한 루프

# %%
while True:
    print("Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# ...

# %% [markdown]
# #  for문
# for 변수 in 리스트(또는 튜플,문자열): 이 객체안에 있는 수를 뽑아서 실행해줘
#
#     수행할_문장1
#
#     수행할_문장2
#
#     ...

# %% [markdown]
# ## 전형적인 for 문

# %%
test_list = ['one', 'two', 'three']
for i in test_list: # i가 test_list에 있다면 값을 뽑아줘
    print(i)
# Out:
# one
# two
# three

# %% [markdown]
# ## 다양한 for 문의 사용

# %%
a = [(1,2), (3,4), (5,6)]
for (first, last) in a: #튜플의 (1,2) = (first, last)
    print(first + last)
# Out:
# 3
# 7
# 11

# %% [markdown]
# ## for 문의 응용
# 총 5명의 학생이 시험을 보았는데 시험 점수가 60점 이상이면 합격이고 그렇지 않으면 불합격이다. 합격인지, 불합격인지 결과를 보여 주시오.

# %%
#marks1.py
marks = [90, 25, 67, 45, 80]
number = 0 # 학생에게 붙여 줄 번호
for mark in marks:
    number = number +1
    if mark>=60:
        print("%d번 학생은 합격입니다." % number)
    else:
        print("%d번 학생은 불합격입니다." % number)
# Out:
# 1번 학생은 합격입니다.
# 2번 학생은 불합격입니다.
# 3번 학생은 합격입니다.
# 4번 학생은 불합격입니다.
# 5번 학생은 합격입니다.

# %% [markdown]
# ## for문과 continue 문
# 60점 이상인 사람에게는 축하 메시지를 보내고 나머지 사람에게는 아무런 메시지도 전하지 않는 프로그램을 IDLE 에디터로 작성해 보자.

# %%
#marks2.py
marks = [90, 25, 67, 45, 80]
number = 0 # 학생에게 붙여 줄 번호
for mark in marks:
    number = number +1
    if mark < 60:
        continue
    print("%d번 학생 축하합니다. 합격입니다." % number)
# Out:
# 1번 학생 축하합니다. 합격입니다.
# 3번 학생 축하합니다. 합격입니다.
# 5번 학생 축하합니다. 합격입니다.

# %% [markdown]
# ## for 문과 함께 자주 사용하는 range 함수

# %%
a = range(10)
a
# Out:
# range(0, 10)

# %%
a = range(1,11)
a
# Out:
# range(1, 11)

# %%
add = 0
for i in range(1, 11):
    add = add + i
print(add)
# Out:
# 55

# %%
#marks3.py
marks = [90, 25, 67, 45, 80]
for number in range(len(marks)):
    if marks[number] < 60:
        continue
    print("%d번 학생 축하합니다. 합격입니다." % (number+1))
# Out:
# 1번 학생 축하합니다. 합격입니다.
# 3번 학생 축하합니다. 합격입니다.
# 5번 학생 축하합니다. 합격입니다.

# %% [markdown]
# ## for와 range를 이용한 구구단

# %%
for x in range(2,10): # 2부터 10미만!
    for y in range (1,10):
        print(x*y, end=" ")
    print('')
# Out:
# 2 4 6 8 10 12 14 16 18
# 3 6 9 12 15 18 21 24 27
# 4 8 12 16 20 24 28 32 36
# 5 10 15 20 25 30 35 40 45
# 6 12 18 24 30 36 42 48 54
# 7 14 21 28 35 42 49 56 63
# 8 16 24 32 40 48 56 64 72
# 9 18 27 36 45 54 63 72 81

# %%
for i in range(2, 10):
    print(f'===== {i}단 시작 ====='')
    for j in range (1, 10):
          print(f'{i} * {j} = {i*j}') # 왜 안되지...?
# Out:
#   Cell In[6], line 2
#     print(f'===== {i}단 시작 ====='')
#                                 ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# ## 리스트 컴프리헨션

# %%
a = [1,2,3,4]
result = []
for num in a:
    result.append(num*3)
    
print(result)
# Out:
# [3, 6, 9, 12]

# %%
# 리스트 컴프리헨션 사용하기
# [표현식 for 항목 in 반복_가능_객체 if 조건문]
a = [1,2,3,4]
result = [num*3 for num in a] # 리스트 객체에 직접 값을 넣어버림!
print(result)
# Out:
# [3, 6, 9, 12]

# %%
# [1, 2, 3, 4] 중에서 짝수에만 3을 곱하자
a = [1,2,3,4]
result = [num*3 for num in a if num %2 == 0]
print(result)
# Out:
# [6, 12]

# %%
result = [x*y for x in range(2,10)
            for y in range (1,10)]
print(result)
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18, 3, 6, 9, 12, 15, 18, 21, 24, 27, 4, 8, 12, 16, 20, 24, 28, 32, 36, 5, 10, 15, 20, 25, 30, 35, 40, 45, 6, 12, 18, 24, 30, 36, 42, 48, 54, 7, 14, 21, 28, 35, 42, 49, 56, 63, 8, 16, 24, 32, 40, 48, 56, 64, 72, 9, 18, 27, 36, 45, 54, 63, 72, 81]

# %%
# 리스트 컴프리헨션 퍼포먼스
# 시간 측정을 위한 코드, 100만 까지 단순 추출, 2배 넘게 차이남
import time

start = time.time()
numbers = [i for i in range(1000000)]
end = time.time()
print('List Comprehension Time:', end-start)

start = time.time()
numrs = []
for i in range(1000000):
    numbers.append(i)
end = time.time()
print('For loop Time:', end-start)
# Out:
# List Comprehension Time: 0.04590582847595215
# For loop Time: 0.08577132225036621
