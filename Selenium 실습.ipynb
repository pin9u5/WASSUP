# %%
# 셀레니움 라이브러리 설치
# !pip install selenium
# Out:
# Collecting selenium
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/dc/72/96b5afa16908f9abc7c24b70adfd3a46c9740eb728ddfeab28379e38eaf9/selenium-4.16.0-py3-none-any.whl.metadata
#   Downloading selenium-4.16.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\user\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Collecting trio~=0.17 (from selenium)
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/39/46/620fbe56f41fa3ccdda2136d947fb9bacce3d1eb163f057f0262a0ddf5e0/trio-0.23.1-py3-none-any.whl.metadata
#   Downloading trio-0.23.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\user\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Obtaining dependency information for outcome from https://files.pythonhosted.org/packages/55/8b/5ab7257531a5d830fc8000c476e63c935488d74609b50f9384a643ec0a62/outcome-1.3.0.post0-py2.py3-none-any.whl.metadata
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium)
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.16.0-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.4/10.0 MB 12.8 MB/s eta 0:00:01
#    --- ------------------------------------ 1.0/10.0 MB 11.9 MB/s eta 0:00:01
#    ------ --------------------------------- 1.5/10.0 MB 11.9 MB/s eta 0:00:01
#    -------- ------------------------------- 2.0/10.0 MB 11.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.5/10.0 MB 11.5 MB/s eta 0:00:01
#    ------------ --------------------------- 3.1/10.0 MB 11.5 MB/s eta 0:00:01
#    -------------- ------------------------- 3.6/10.0 MB 12.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.1/10.0 MB 12.0 MB/s eta 0:00:01
#    ------------------ --------------------- 4.6/10.0 MB 11.8 MB/s eta 0:00:01
#    -------------------- ------------------- 5.2/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.6/10.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------ --------------- 6.2/10.0 MB 11.6 MB/s eta 0:00:01
#    --------------------------- ------------ 6.7/10.0 MB 11.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/10.0 MB 11.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.8/10.0 MB 11.6 MB/s eta 0:00:01
#    --------------------------------- ------ 8.3/10.0 MB 11.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.8/10.0 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 9.3/10.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  9.9/10.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 11.4 MB/s eta 0:00:00
# Downloading trio-0.23.1-py3-none-any.whl (448 kB)
#    ---------------------------------------- 0.0/448.3 kB ? eta -:--:--
#    ---------------------------------------- 448.3/448.3 kB 9.3 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: wsproto, sniffio, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
# Successfully installed outcome-1.3.0.post0 selenium-4.16.0 sniffio-1.3.0 trio-0.23.1 trio-websocket-0.11.1 wsproto-1.2.0

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time

#인스턴스  #클래스
options = Options() #options는 Options()의 인스턴스
# options.add_argument("--start-maximized")
# options.add_argument("--headless=new") 
options.add_experimental_option("detach", True) #특정함수안에서  드라이버 생성시 함수종료될 때 브라우저 같이 종료되는 문제 대응

# %%
url = 'http://naver.com'
driver = webdriver.Chrome(options=options) #객체 생성
driver.get(url) #실행
time.sleep(2) #렌더링이 안되어 있는데 실행되면 오류가 발생할 수 있어서 일정 시간을 둠

# %%
driver.back()

# %%
driver.forward()

# %%
driver.refresh()

# %%
title = driver.title
url = driver.current_url
handle = driver.current_window_handle
print(title, url, handle)
# Out:
# NAVER https://www.naver.com/ 89677614E3B3A12D0F6844A85A3CD8AD

# %%
driver.find_element?

# %%
driver.find_element(By.ID, "query")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_1847")>

# %% [markdown]
# # <input id="query" name="query" type="search" title="검색어를 입력해 주세요." placeholder="검색어를 입력해 주세요." maxlength="255" autocomplete="off" class="search_input" data-atcmp-element="">

# %%
# 키입력
driver.find_element(By.ID, "query").send_keys('뉴진스')

# %%
driver.find_element(By.CLASS_NAME, "search_input").send_keys('블랙핑크')

# %%
driver.find_element(By.NAME, "query").send_keys('르세라핌')

# %%
driver.find_element(By.CSS_SELECTOR, ".search_input").send_keys('세븐틴') # .은 클래스

# %%
driver.find_element(By.CSS_SELECTOR, "#query").send_keys('에스파') # #은 ID

# %%
driver.find_element(By.CSS_SELECTOR, "[title='검색어를 입력해 주세요.']").send_keys('트와이스')

# %%
driver.find_element(By.CSS_SELECTOR, "[placeholder='검색어를 입력해 주세요.']").send_keys('트와이스')

# %%
driver.find_element(By.XPATH,"//*[@id='query']").send_keys('BTS')
#CSS_SELECTOR를 가장 많이 씀 - 관계지향 / 스타일을 위해
#만약 셀렉터를 사용하기 어려울 때 -> XPATH를 사용
# XPATH는 경로를 지정해서 만들어진 구문

# %%
driver.find_element(By.LINK_TEXT, '쇼핑')
#특정 테스르를 가지고 있는 걸 실행해줘
#실행되면 찾았다!
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_11812")>

# %%
driver.find_element(By.LINK_TEXT, '쇼핑').click()

# %%
# 일부 매칭
driver.find_element(By.PARTIAL_LINK_TEXT, '쇼').click()

# %%
# 태그는 너무 요소가 많으므로, 정확하게 대상을 찾을 때에는 안씀
driver.find_element(By.TAG_NAME, 'div')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_11098")>

# %%
# 여러개의 요소를찾을 때
links = driver.find_elements(By.CSS_SELECTOR, '.link_service')
# elements! s 붙어있음 주의!

# %%
for link in links:
    print(link)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_45987")>
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_45982")>
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_45977")>
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_11812")>
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_11817")>
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_12024")>
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_48536")>
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_48537")>
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_48538")>
# <selenium.webdriver.remote.webelement.WebElement (session="5e814c9e80ce5e28db53aed81fb86195", element="BB99CA363A8B58B43298D22C7416EE0B_element_48539")>

# %%
# 해당 클래스가 속한 요소의 자식 html을 출력, URL 추출 하고 싶엉!
for link in links:
    print(link.get_attribute("outerHTML"))
    print()
# Out:
# <a href="https://mail.naver.com" class="link_service" target="_blank"><span class="service_icon type_mail"></span><span class="service_name">메일</span></a>
#
# <a href="https://cafe.naver.com" class="link_service" target="_blank"><span class="service_icon type_cafe"></span><span class="service_name">카페</span></a>
#
# <a href="https://blog.naver.com" class="link_service" target="_blank"><span class="service_icon type_blog"></span><span class="service_name">블로그</span></a>
#
# <a href="https://shopping.naver.com/home" class="link_service" target="_blank"><span class="service_icon type_shopping"></span><span class="service_name">쇼핑</span></a>
#
# <a href="https://news.naver.com/" class="link_service" target="_blank"><span class="service_icon type_news"></span><span class="service_name">뉴스</span></a>
#
# <a href="https://finance.naver.com/" class="link_service" target="_blank"><span class="service_icon type_stock"></span><span class="service_name">증권</span></a>
#
# <a href="https://land.naver.com/" class="link_service" target="_blank"><span class="service_icon type_real"></span><span class="service_name">부동산</span></a>
#
# <a href="https://map.naver.com" class="link_service" target="_blank"><span class="service_icon type_map"></span><span class="service_name">지도</span></a>
#
# <a href="https://comic.naver.com" class="link_service" target="_blank"><span class="service_icon type_webtoon"></span><span class="service_name">웹툰</span></a>
#
# <a href="#" class="link_service" role="button"><span class="service_icon type_more"></span><span class="blind">바로가기 펼침</span></a>

# %%
# 테스트용 html
url = 'file:///C:/workspace/python/WASSUP/sample/signin.html'
driver = webdriver.Chrome(options=options)
driver.get(url)

# %%
username = driver.find_element(By.NAME, "username")
username.send_keys('korea')

# %%
username = driver.find_element(By.NAME, "password")
username.send_keys('1004')

# %%
login =  driver.find_element(By.XPATH, '//*[@id="loginForm"]/input[3]')
login.click()

# %%
login =  driver.find_element(By.CSS_SELECTOR, "#loginForm > input[type=submit]:nth-child(5)")
login.click()

# %%
login =  driver.find_element(By.CSS_SELECTOR, "[value='Login']")
login.click()

# %%
# 입력창 clear 하기
# 세션끊기면 다시 접근해야함
username = driver.find_element(By.NAME, "username")
username.clear()

# %%
username.submit()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 username.submit()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:111, in WebElement.submit(self)
#      98 script = (
#      99     "/* submitForm */var form = arguments[0];\n"
#     100     'while (form.nodeName != "FORM" && form.parentNode) {\n'
#    (...)
#     107     "if (form.dispatchEvent(e)) { HTMLFormElement.prototype.submit.call(form) }\n"
#     108 )
#     110 try:
# --> 111     self._parent.execute_script(script, self)
#     112 except JavascriptException as exc:
#     113     raise WebDriverException("To submit an element, it must be nested inside a form element") from exc
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:408, in WebDriver.execute_script(self, script, *args)
#     405 converted_args = list(args)
#     406 command = Command.W3C_EXECUTE_SCRIPT
# --> 408 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#     350     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=120.0.6099.71); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF662594D02+56194]
# 	(No symbol) [0x00007FF6625004B2]
# 	(No symbol) [0x00007FF6623A76AA]
# 	(No symbol) [0x00007FF6623B79BF]
# 	(No symbol) [0x00007FF6623ADB89]
# 	(No symbol) [0x00007FF6623ADC93]
# 	(No symbol) [0x00007FF6623ABF22]
# 	(No symbol) [0x00007FF6623AF6F7]
# 	(No symbol) [0x00007FF662432FFB]
# 	(No symbol) [0x00007FF662415E7A]
# 	(No symbol) [0x00007FF662432786]
# 	(No symbol) [0x00007FF662415C23]
# 	(No symbol) [0x00007FF6623E4A45]
# 	(No symbol) [0x00007FF6623E5AD4]
# 	GetHandleVerifier [0x00007FF66290D5BB+3695675]
# 	GetHandleVerifier [0x00007FF662966197+4059159]
# 	GetHandleVerifier [0x00007FF66295DF63+4025827]
# 	GetHandleVerifier [0x00007FF66262F029+687785]
# 	(No symbol) [0x00007FF66250B508]
# 	(No symbol) [0x00007FF662507564]
# 	(No symbol) [0x00007FF6625076E9]
# 	(No symbol) [0x00007FF6624F8094]
# 	BaseThreadInitThunk [0x00007FFC5F6D7344+20]
# 	RtlUserThreadStart [0x00007FFC5FEA26B1+33]

# %%
driver.find_element(By.TAG_NAME, 'p').text
# Out:
# 'Are you sure you want to do this?'

# %%
# html 소스 가져오기
driver.page_source
# Out:
# '<html><head></head><body>\n        <h1> Sign In </h1>\n        <form action="moved.html" id="loginForm">\n            ID : <input name="username" type="text"> <br>\n            Password : <input name="password" type="password"> <br>\n\n            <input name="continue" type="submit" value="Login">\n            <input name="continue" type="button" value="Clear">\n        \n        </form>\n\n        <p>Are you sure you want to do this?</p>\n        <a href="continue.html">Continue</a>\n        <a href="cancel.html">Cancel</a>\n\n        <h1>Welcome</h1>\n        <p>Site content goes here.</p>\n        <p class="content">Site content goes here.</p>\n    \n</body></html>'

# %%
driver.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 driver.close()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:459, in WebDriver.close(self)
#     451 def close(self) -> None:
#     452     """Closes the current window.
#     453
#     454     :Usage:
#    (...)
#     457             driver.close()
#     458     """
# --> 459     self.execute(Command.CLOSE)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#     350     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=120.0.6099.71)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF662594D02+56194]
# 	(No symbol) [0x00007FF6625004B2]
# 	(No symbol) [0x00007FF6623A76AA]
# 	(No symbol) [0x00007FF66238E1E9]
# 	(No symbol) [0x00007FF66238F7CE]
# 	(No symbol) [0x00007FF6623A7CC3]
# 	(No symbol) [0x00007FF662380580]
# 	(No symbol) [0x00007FF6624235D7]
# 	(No symbol) [0x00007FF662423387]
# 	(No symbol) [0x00007FF662415E40]
# 	(No symbol) [0x00007FF6623E4A45]
# 	(No symbol) [0x00007FF6623E5AD4]
# 	GetHandleVerifier [0x00007FF66290D5BB+3695675]
# 	GetHandleVerifier [0x00007FF662966197+4059159]
# 	GetHandleVerifier [0x00007FF66295DF63+4025827]
# 	GetHandleVerifier [0x00007FF66262F029+687785]
# 	(No symbol) [0x00007FF66250B508]
# 	(No symbol) [0x00007FF662507564]
# 	(No symbol) [0x00007FF6625076E9]
# 	(No symbol) [0x00007FF6624F8094]
# 	BaseThreadInitThunk [0x00007FFC5F6D7344+20]
# 	RtlUserThreadStart [0x00007FFC5FEA26B1+33]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time

options = Options()
options.add_argument("--headless=new") #UI가 안보이는 상태에서 실행중
# options.add_argument('--window-size= x, y') #실행되는 브라우저 크기를 지정할 수 있습니다.
# options.add_argument('--start-maximized') #브라우저가 최대화된 상태로 실행됩니다.
# options.add_argument('--start-fullscreen') #브라우저가 풀스크린 모드(F11)로 실행됩니다.
# options.add_argument('--blink-settings=imagesEnabled=false') #브라우저에서 이미지 로딩을 하지 않습니다.
# options.add_argument('--mute-audio') #브라우저에 음소거 옵션을 적용합니다.
# options.add_argument('incognito') #시크릿 모드의 브라우저가 실행됩니다.
options.add_experimental_option("detach", True) #특정함수안에서  드라이버 생성시 함수종료될 때 브라우저 같이 종료되는 문제 대응

# %%
url = 'http://naver.com'
driver = webdriver.Chrome(options=options)
driver.get(url)
time.sleep(2)

# %%
print(driver.title)
# Out:
# NAVER

# %%
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time

options = Options()
# options.add_argument("--start-maximized")
# options.add_argument("--headless=new") 
options.add_experimental_option("detach", True) #

url = 'http://naver.com'
driver = webdriver.Chrome(options=options)
driver.get(url)
time.sleep(2)

# %%
size = driver.get_window_size()
width = size.get("width")
height = size.get("height")

print(str(width)+"px"+" "+str(height)+"px")
# Out:
# 1265px 1380px

# %%
driver.set_window_size(800, 600)

# %%
position = driver.get_window_position()
x = position.get('x')
y = position.get('y')

print("x : "+str(x)+" "+"y : "+str(y))
# Out:
# x : 10 y : 10

# %%
driver.set_window_position(10,10)
# Out:
# {'height': 600, 'width': 800, 'x': 10, 'y': 10}

# %%
# 창 크기 최대화
driver.maximize_window()

# %%
# 창 크기 최소화
driver.minimize_window()

# %%
# 전체 화면
driver.fullscreen_window()

# %%
# 스크린 샷
driver.save_screenshot('./image.png')
# Out:
# True

# %%
driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time, random, pandas as pd

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=953,0')
options.add_experimental_option("detach", True)

# %%
# 웹드라이버 로드
driver = webdriver.Chrome( options = options)

# %%
# 조건 설정
where = 'blog'
query = '인공지능'
dateform = '20221020to20231020'
url = f'https://search.naver.com/search.naver?where={where}&query={query}&sm=tab_op&nso=so:r,p:from{dateform}'
fname = f'{where}_{query}_{dateform}'

# %%
# url 접속
driver.get(url)
time.sleep(random.randint(2,3)) #2에서 3초사이 랜덤, 대부분 6초 주기가 업게에서는 사용, 너무 느리나 서버정책에 안걸리려고 랜덤으로 넣음

# %% [markdown]
# excute_script()
# 자바스크립트 함수(스크롤다운) 실행하기 execute_script("스크립트", 요소) 해당 페이지에 스크립트를 만들 때 사용합니다. 요소는 필수 파라미터는 아니고 요소가 있으면 요소에 스크립트가 실행되고 없으면 전체 페이지에 스크립트가 움직입니다.
#
# js코드를 인자로 넣을 수 있어 브라우저 화면을 제어 할수 있게 된다. 스크롤을 하기 위해 뿐만아니라 다른 동적이벤트를 작성할 수 있다.
#
# * 화면상 스크롤 위치 이동 : scrollTo(x,Y) ,scrollTo(x,Y+number)
# * 화면 최하단으로 스크롤 이동 : scrollTo(0, document.body.scrollHeight)
# * 화면을 움직이고 페이지 로드 기다리기 : time.sleep(second)
# * 함수 호출시 전달인자들이 배열 형태로 저장된 객체 : arguments
#     * (arguments[0].click(), sample)
#     * sample요소의 첫번째 인자에 click()을 명령

# %%
#네이버 뷰는 최대 1050까지만 노출 # 스크롤 10번
for i in range(10):
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(random.randint(2, 3))

# %%
# get_view()
views = driver.find_elements(By.CSS_SELECTOR, '.lst_view .bx')
result = []

for view in views:
    con_dict = {}
    con_dict['title'] = view.find_element(By.CSS_SELECTOR, '.title_link').text
    con_dict['text'] = view.find_element(By.CSS_SELECTOR, '.dsc_link').text
    con_dict['date'] = view.find_element(By.CSS_SELECTOR, '.sub').text
    result.append(con_dict)
    print(con_dict)
    
print('완료')
# Out:
# {'title': '엘지 휘센 인공지능스스로에어컨(FQ19P7DPAN) 누수현상 해결...', 'text': '엘지 인공지능스스로에어컨 분해방법은 해 보지 않으면 어렵고 당황스럽지만 막상 해 보면 쉽습니다. 다만 몇 가지 조심해야 할 부분이 있어 정리합니다. 먼저 엘지 휘센 인공기능스스로 에어컨의 전원 플러그는 실외기에서 공급을 받으니 실외기 쪽으로 가셔서 전원 플러글...', 'date': '2023.08.09.'}
# {'title': '로보어드바이저 수익률 비교, 인공지능 투자 성과는?', 'text': '그럼 인공지능인 로보어드바이저와 일반 펀드의 운용 성과는 어땠을까요? 2022년 펀드 운용 성과 2022년 우리나라 국민의 일반펀드 평균... 저도 그렇지만 인공지능이 운용하는 상품을 찾고 계신 분들도 의외로 많습니다. 제가 현재 가입하고 있다는 이야기를 하면 대부분의...', 'date': '2023.09.26.'}
# {'title': '[종목분석] 의료 인공지능 딥노이드 주가 전망을 살펴봅니다', 'text': '그 중에서 오늘은 인공지능 딥노이드 주가를 살펴보려고 하는데 해당 종목은 이미 많이 상승한 상태입니다. 그렇다고 버릴 수는... ▣인공지능이란 AI는 Artificial Intelligence의 약자로 인간의 지적능력을 컴퓨터를 통해 구현하는 과학기술입니다. 4차 산업혁명으로 국내 뿐만...', 'date': '2023.08.30.'}
# {'title': 'AI 인공지능 파이토치 서적으로 가볍게 시작해보죠', 'text': '인공지능이 표면적으로 한풀 꺽였다고는 하지만 관련된 서적과 툴들은 꾸준하게 발전하고 있습니다. 언어모델 개발뿐만 아니랄 이를... 10. 인공지능과 코딩 프로그래밍이라는 단어아래 후끈한 이 시장에 알고 있어야 사람을 구하고 일도 시킬 수 있어서 오늘도 공부를 해야 하네요...', 'date': '2023.10.02.'}
# {'title': 'NPU 관련주 뜻 - 인공지능 구글 텔레칩스 칩스앤미디어 주가 전망', 'text': 'NPU 관련주 뜻 - 인공지능 구글 텔레칩스 칩스앤미디어 주가 전망 NPU 뜻 NPU 는 Neural Processing Unit 의 약자로서 인간의 신경망을 따라하여 만들어진 인공신경망을 구현할 수 있는 반도체입니다. 인공지능 개발의 핵심적인 역할을 합니다. 컴퓨터의 두뇌는 CPU 로 만들어집니다....', 'date': '2023.10.09.'}
# {'title': '인공지능에 기반한 신약개발 관련 기업들에 대한 생각', 'text': '이 글에서는 그동안 단편적으로 언급했던 인공지능에 기반한 신약개발 바이오 기업들에 대한 생각을 간단히 정리하고자 합니다. 오늘... 리커전 파마슈티컬스는 보도자료를 통해 엔비디아 클라우드 서비스를 사용해 인공지능 기반 모델의 개발을 가속화할 것이라고 밝혔고...', 'date': '2023.07.13.'}
# {'title': '인공지능(AI)이 인간의 일자리를 감소시킬 것인가?', 'text': '인공지능이 인간의 일자리를 대체? 이 질문은 최근에 사람들의 관심을 끌며 치열한 논쟁을 일으키고 있습니다. ChatGPT, Bard 및 Mindjourney와... 감성지능 수준이 부족하다고 주장합니다. 일부 낙관론자들은 AI가 특정 역할에서 인간의 능력을 향상시킬 수는 있지만 대체할 수는 없다고...', 'date': '2023.07.13.'}
# {'title': '태양광 발전소 고장, 인공지능이 물샐틈없이 관리한다!', 'text': '한국에너지기술연구원 신재생시스템연구실 고석환 박사 연구진은 인공지능(AI)을 활용한 태양광 발전 고장 진단 기술을 개발했습니다. 10년 이상 태양광발전소 고장진단평가를 수행하며 수집한 I-V곡선* 정보를 데이터베이스화하고, 모델을 적용해 현장에 가지 않고도...', 'date': '2023.10.10.'}
# {'title': '인공지능 AI 스피커 삼성 갤럭시 홈미니 기능', 'text': '버들붕어입니다.^^ 이버 시간에는 인공지능 AI 스피커 삼성 갤럭시 홈미니 기능에 대해 자세하게 알아보도록 하겠습니다. 해당 제품은... 사진출처: Samsung 온라인 몰을 이용한 최저가 금액으로는 7만 원대에 AI 인공지능 스피커 구매할 수 있으며, 앞서 말한 거와 같이 MINI...', 'date': '2023.09.04.'}
# {'title': 'AI인공지능 관련주 산업의 발달은 기계가 하게되는걸까', 'text': '언젠가부터 로봇에관련된 산업들이 다시금 발전을 하고 주목을 받고있으며, 챗gdp라는 기능이 도입이 되면서 AI인공지능에 관련된... AI인공지능 관련주 주가 단순하게 생각을 해보면 일상생활을 하면서 영향을 줄수있는 산업들에도 많이 분포가 되어있겠지만, 우리들이 모르고있는...', 'date': '2023.09.05.'}
# {'title': '인공지능 AI 관련주 26종목 모음집', 'text': '*엑셈 데이터베이스 관리 기업으로 인공지능 기반 IT 운영 지능화 솔루션인 싸이옵스를 출시했음. *트루엔 인공지능 영상 솔루션... *마음AI 자체 보유한 기술을 조합해 AI 앱, AI 상담원 등 인공인간 서비스를 운영하고 있음. 삼성전자와 신한은행 등을 핵심 고객사로 보유하고...', 'date': '2023.10.09.'}
# {'title': '[주간경제동향] 무선통신 경제성장 분석 (인공지능,6g)', 'text': '지금까지 인공지능 6G관련 무선통신 경제에 대해 살펴봤습니다. 이 산업에 필요한 건 초성능, 초대역, 초공간, 초정밀 및 지능입니다. 10년 단계로 발달하는 이동통신 기술이 전 산업과 사회에서 인프라를 형성하려면 다양한 통신요구를 만족해야 할 겁니다. 5G에서 볼 수 없었던...', 'date': '2023.10.10.'}
# {'title': '빙 챗gpt 쓰려면 엣지 브라우저로! 너만 몰라 인공지능 팁', 'text': '너만 몰라 인공지능 팁 by 엔돌슨 2023. 6. 30. 빙 챗gpt 쓰려면 엣지 브라우저로! 너만 몰라 인공지능 팁 응 너만 인공지능 쓸줄 몰라! 그래서 쉽게 Microsoft Edge 브라우저에서 ChatGPT를 이용하는 방법에 대해서 설명하려고 합니다. 챗봇, AI에 대한 디지털 가이드가...', 'date': '2023.06.30.'}
# {'title': '(12편) : 인공지능과 로보틱스 (Artificial Intelligence...', 'text': 'com 지난시간에는 미국의 인플레이션 감축 법안 (Inflation Reduction Act)에 대해서 알아보았는데요 이번 시간에는 최근에 시장을 뜨겁게 달군 인공지능 및 로보틱스 테마에 대해서 알아보겠습니다. 코로나를 겪으면서 여러 산업에서 (AI)과 로봇은 모든 규모의 기업이...', 'date': '2023.08.02.'}
# {'title': '적금 가입 vs 펀드 투자, 인공지능이 운용하는 콴텍 수익률과...', 'text': "저는 작년부터 인공지능이 주식을 매매해주는 '콴텍'에 돈을 넣어 운영하고 있습니다. 다른 이유는 없습니다. 그냥 수익률이... 개설된 증권사 계좌에 입금하면 인공지능이 자동으로 매매를 시작합니다. 돈을 찾을 땐 콴텍 앱에서 상품을 해지하면 보유한 주식을 환매해 증권사...", 'date': '2023.07.03.'}
# {'title': '[테마주분석] 의료기기와 ai 인공지능 의료용로봇 관련주 정리', 'text': '다섯 번째 셀루메드 사업부문 - 의료기기와 바이오로직스, 코스메슈티컬 의료기기 - 탈회골, 합성고분자 무릎연골 연구개발 무릎인공관절 전치환술에 세루메드의 첨단 로봇을 사용하고 있다고 합니다. 지금까지 의료기기와 의료용로봇 관련주들을 알아봤습니다....', 'date': '2023.08.29.'}
# {'title': '‘상품 들고 나오면 자동 결제’...인공지능(AI) 스마트 편의점', 'text': "출처=GS리테일 GS25가 사람 없이 인공지능(AI) 솔루션 만으로 운영되는 스마트 편의점 'GS25 DX 랩(LAB) 가산스마트점'을 오픈했습니다. 서울... 출처=이마트24 지난 1월부터는 신세계아이앤씨의 ‘스파로스 인공지능(AI) 수요예측’ 시스템을 도입해 이전에 1시간 이상 소요됐던 발주...", 'date': '2023.10.10.'}
# {'title': '미국주식 엔비디아 주가 500달러 돌파 - 인공지능 챗GPT 관련주', 'text': '챗GPT 로 대변되는 생성형AI 인공지능의 최대 수혜주로 꼽히는 엔비디아가 2분기 실적을 발표했습니다. 예상보다 훨씬 상회하는... 당연하게도 인공지능용 AI 반도체 수요가 급증했기 때문입니다. 이런 추세는 3분기에도 지속될 것이며, 올해 내내 엔비디아의 실적에 영향을...', 'date': '2023.08.24.'}
# {'title': 'AI 인공지능 데이터 라벨링으로 수익 창출하는 법 (+무료교육...', 'text': 'AI 인공지능 데이터 라벨링으로 수익 창출하는 법 (+무료교육 선착순 한정) 안녕하세요. 사진&IT 크리에이터 자유분방입니다. 올해 초 Chat GPT가 출시가 되면서, 인공지능 (AI)에 대한 관심도도 상당 부분 올라갔습니다. 그렇다 보니, 관련 직군들이 주목을 받고 있는데요....', 'date': '2023.10.19.'}
# {'title': '인공지능 OpenAI 해커톤 개발 공모전 SK 텔레콤...', 'text': '해커톤은 해킹과 마라톤이 합성된 말로 일정 시간 내에 주제에 맞는 서비스를 기발하는 공모전을 뜻하는데요~ 이번에 SK 텔레콤에서 인공지능 OpenAI 개발 공모전인 Prompter Day Seoul 2023 행사가 있어 소개를 해드리려 합니다. Prompter Day Seoul 2023 기술의 발달로...', 'date': '2023.08.24.'}
# {'title': '신약 개발의 벽을 넘기 위한 도약, 인공지능 기반 신약 개발', 'text': '인공지능의 도입으로 약효를 결정하는 분자의 단순 스크리닝 과정을 효율화하고, 예상되는 문제를 사전에 예측해 신약 개발 성공 확률을... 부족한 자본을 보완하는 기술력, 인공지능의 도입 사람의 노동력으로 진행되었던 지점을 으로 대체해 효율을 높일 수 있다. 자본이...', 'date': '2023.09.18.'}
# {'title': 'AI 프로필 수면분석 통화요약 어플 SKT 에이닷 인공지능 기능', 'text': '인공지능 에이전트 서비스 SKT A.(에이닷)이 정식 출시되었습니다. 주목할 만한 신기능들도 업데이트가 되었는데요. 수면분석 도우미 A.... AI 모션프로필 AI 모션프로필은 내 사진을 업로드하면 인공지능이 알아서 멋진 AI 프로필 이미지를 만들어주는 기능입니다. A.(에이닷)어플...', 'date': '2023.09.30.'}
# {'title': '(글로벌교육과) 인공지능 시대, 공공 인재개발 전략은?', 'text': '인공지능 혁신 시대에 대응하는 공직 인재개발 체계(패러다임)를 논하는 자리가 마련됩니다. 국가공무원인재개발원(원장 김채환, 이하... ‘인공지능(AI) 혁신 시대에 대응하는 공직 인재개발 체계(패러다임)’를 주제로 열리는 올해 학술대회는 관심 있는 누구나 유튜브...', 'date': '2023.10.20.'}
# {'title': '인공지능을 이용한 산불 감시 시스템', 'text': '최근에는 인공지능을 적용하려는 시도가 이어지고 있습니다. 관련 스타트업 가운데 하나인 파노 AI (Pano AI)는 이미 캘리포니아, 오레건, 콜로라도, 워싱턴, 아이다호, 몬태나 주에서 240만 헥타르의 숲을 감시하고 있습니다. 최근 파노 AI는 화재...', 'date': '2023.08.08.'}
# {'title': '엔잡러가 원하는 인공지능 직업 데이터라벨링...', 'text': '인공지능(AI)은 주입된 수많은 데이터를 통해 학습을 하며 이때 제공받는 데이터는 인공지능이 학습할 수 있도록 가공된 형태죠. 여기서 가공을 데이터 전처리 작업이라고 표현할 수 있는데 이것이 바로 데이터 라벨링이라고 이해하시면 됩니다. 최근에는 챗GPT가 화제가 되고...', 'date': '2023.07.18.'}
# {'title': '네이버 AI 큐(Cue:), 이제 특화된 대화형 인공지능!', 'text': '네이버 AI 클로바X가 서비스된지 얼마 되지 않았는데 네이버에서 추가로 새로운 인공지능 서비스가 시작되었습니다. 바로 네이버 AI 큐(Cue... 기존 검색 사이트를 이용하는 방식과 달리 인공지능으로 원하는 정보를 좀 더 빠르게 확인할 수 있어 맘에 드네요. 앞으로의 새로운...', 'date': '2023.10.04.'}
# {'title': '윈도우 코파일럿 미리사용해본 AI 인공지능 기능! 윈도우 11...', 'text': '얼리어답터 리뷰/IT정보 윈도우 코파일럿 미리사용해본 AI 인공지능 기능! 윈도우 11 23H2 프리뷰 코파일럿 사용법 by 엔돌슨 2023. 10. 5. 윈도우 코파일럿의 기능과 사용법 리뷰 이번에는 윈도우11에 내장된 윈도우 코파일럿 입니다. 챗GPT 같은 을 윈도우에서 직접...', 'date': '2023.10.05.'}
# {'title': '[관심종목] 23년 마지막 주목받을 인공지능,반도체 산업주식 종목', 'text': '23년 8월에서 12월까지 남은 5개월을 장식할 인공지능,반도체 산업주식 종목에는 뭐가 있을까? 주식은 상황과 여건에 따라 빛나는 종목이 있습니다. 올해 초부터 인공지능에 강세를 보였고 2차전지가 중심에 있었습니다. 그리고 2차전지와 관련된 에코프로가 빛을 받았죠. 그렇다면...', 'date': '2023.08.06.'}
# {'title': 'AI 인공지능 관련주 대장주 TOP2!', 'text': 'AI 인공지능 관련주 대장주 TOP2! 주식 쉽게 하는 팁까지 공유! 오후에는 아직까지도 무더운데, 오전에는 날씨가 선선하니 좋네요. 곧... 오늘은 향후 기대되는 섹터 중 하나인, AI 인공지능 관련주와 대장주를 한 번 살펴 볼께요. AI 관련주 대장주 TOP2! © vishnumaiea...', 'date': '2023.09.10.'}
# {'title': '등 인공지능이 자동으로 기록해 주는 클로바노트 녹음하는 방법...', 'text': '회의, 인터뷰, 강의 등 인공지능이 자동으로 기록해 주는 클로바노트 녹음하는 방법입니다. 업무를 향상시켜주는 필수 어플 - 회의, 인터뷰, 강의 등 인공지능이 자동 기록해 주는 클로바노트로 녹음하는 방법 클로바 노트 회의, 인터뷰, 강의 등 녹음 내용을 눈으로 보면서 듣는...', 'date': '2023.10.01.'}
# {'title': '천안시, 빅데이터 기반 인공지능 활용 도시기본계획 수립 추진', 'text': '빅데이터 기반 인공지능 활용 2040 도시기본계획 수립용역 착수 안녕하세요. 천안시입니다. 천안시가 빅데이터 기반 인공지능을 활용한 ✔️2040 도시기본계획 수립에 본격 착수합니다. 이에 따라 국토연구원과 11개 민간기업이 참여하는 ‘국토도시 빅데이터 얼라이언스 협약’...', 'date': '2023.10.19.'}
# {'title': '네이버 생성형인공지능 클로바X(CLOVA X) 사용후기', 'text': '네이버 생성형인공지능 클로바X(CLOVA X) 사용후기 New Tech/AI(인공지능) by 마켓캐스트 2023. 9. 8. 13:59 공감 네이버 생성형인공지능 클로바X(CLOVA X)의 사용승인이 되어서 오늘 여러가지 내용으로 테스트를 해봤는데 결론적으로 너무나 실망스러운 결과 였습니다. 질문: 네이버에서...', 'date': '2023.09.08.'}
# {'title': '열(熱)의 꿈틀거림까지 감시한다! ‘인공지능 열화상 카메라’', 'text': '[이 주의 조달청 혁신제품] 재난 예방 혁신제품 해외수출 ③ 인공지능 열화상 카메라 ‘조달청 혁신제품’을 아시나요? 공공성과 기술성이... ‘인공지능 열화상 카메라’ 미국 역사상 최악의 재해로 남은 하와이 마우이섬의 산불, 한국보다도 넓은 면적을 태워버린 캐나다의 산불에...', 'date': '2023.08.23.'}
# {'title': 'AI 관련주 의료 인공지능 루닛·제이엘케이 등 주식 주가 간단...', 'text': '16%) 2023년 8월 9일 10:30 현재가 라이프시맨틱스(347700) 주가 일봉 차트 브리지텍(064480) 브리지텍(064480)은 AI(인공지능) 콜센터와 음성인식/화자인증, 보이는ARS, IP기반의 유무선(지능망서비스, 무선이동통신) 멀티미디어 서비스 관련 소프트웨어를 개발...', 'date': '2023.08.09.'}
# {'title': '인공지능 교육 - 23년 AI 교육과정 특화 맞춤형 교육생 모집', 'text': '인공지능 교육 - 23년 AI 교육과정 특화 맞춤형 교육생 모집 안녕하세요. 취업비서 인크루트 입니다. 오늘 소개해드릴 인공지능 교육 - 23년 AI 교육과정 특화 맞춤형 교육은 AI 분야 일자리에 대한 직무.직군 분석을 바탕으로 개발된 AI 커리어맵을 기반으로 교육생별 직무설계...', 'date': '2023.09.11.'}
# {'title': '국내 AI 인공지능 관련주 대장주 의료 반도체 챗GPT 종목 소개...', 'text': '국내 AI 인공지능 관련주 대장주 의료 반도체 챗GPT 종목 소개 및 현황 정리 최근 국내 증시는 테마주들이 이끌고 가고 있다고 해도 무방한 상황입니다. 그리고 현재 이러한 손바뀜이 현상이 계속 이어지고 있는 가운데 다시 국내 AI 관련주들이 관심을...', 'date': '2023.09.04.'}
# {'title': '인공지능을 이용해서 유방암 조기 진단률을 높인다.', 'text': 'Credit: Public Domain) 인공지능 붐 초기 응용이 크게 기대되던 분야 중 하나는 의료입니다. 사람들은 AI 의사가 질병의 진단과... 있는 인공지능을 개발했습니다. ScreenTrustCAD 연구에서 연구팀은 2021년 4월에서 2022년 6월까지 40-74세 사이 여성 55,500명의 유방...', 'date': '2023.09.17.'}
# {'title': '인공지능(AI) 디지털교과서 법적 지위를 얻다', 'text': '이번 개정안에는 인공지능(AI) 디지털교과서가 차질 없이 개발되고 학교 현장에서 안정적으로 사용될 수 있도록 디지털 교과서의 정의, 검정 절차별 필요 사항을 담았다. 즉, 디지털교과서를 지능정보화 기술을 활용한 학습지원 소프트웨어로 정의하고, 기술결함 조사 및 기술...', 'date': '2023.10.17.'}
# {'title': '안드로이드앱제작 인공지능을 이용해서 저렴하고 빠르게...', 'text': '2023년은 인공지능의 해 인것 같습니다. 2022년의 메타버스에 대한 이야기는 2023년이 되서 거짓말처럼 완전히 사라져서 잘 보이지도 않는 것 같아요. 그 정도로 요즘 인공지능의 발전이 눈이 부실 정도로 빠르게 진행이 되고 있습니다. 챗GPT가 출시한지 얼마 되지도 않았는데 벌써...', 'date': '2023.06.08.'}
# {'title': '[종목분석] 인공지능 ai 테마주에는 어떤 것들이 있을까', 'text': '오늘도 많은 분들이 알지 못하고 자료를 찾아야 하는 시간을 덜어드리기 위해 올해 대세로 떠오른 인공지능 ai 테마주의 종목들을 정리하겠습니다. 일일히 찾아다닐 필요 없이 오늘 소개해드리는 종목들을 보고 분석하시면 됩니다. ai 테마주 모음 종목(관련 테마)...', 'date': '2023.08.21.'}
# {'title': '인공지능 A.(에이닷) 앱, AI 친구 대화와 챗GPT 사용법', 'text': "SK텔레콤의 인공지능 에이전트 서비스 A.(에이닷) 앱이 새롭게 업데이트되었습니다. '내 손안에 AI 친구'라는 슬로건에 맞춰 추가된 기능이 눈길을 끄는데요. 감성대화가 가능한 A.프렌즈, 챗GPT 기반의 지식 대화 기능 채널인 챗T가 바로 그 주인공입니다. 과연 어떤 대화를 나눌 수...", 'date': '2023.07.22.'}
# {'title': '인공지능 AI가 글 써 주는 시대', 'text': "어제 네이버에서 한국형 초대형 인공지능(AI) 서비스라고 하는 '하이퍼클로바X'를 공개했는데, 이를 활용하여 글쓰기를 할 블로거를... ※ 이미지 출처 : 네이버 검색 인공지능 클로바를 블로그에도 도입할 생각인가 보다. 그동안 작성한 글을 바탕으로 관심사나 문체 등을 분석하여...", 'date': '2023.08.25.'}
# {'title': "송도국제도시에 'AI(인공지능) 교육센터'만든다", 'text': '송도 3공구 G5 부지 내 근린공원에 인공지능 교육센터를 유치하려나 봅니다. 아직 G5 분양계획에 대한 이야기가 없는 가운데 갑자기 공원 내... 인공지능 교육센터 위치 아래는 그동안 모아두었던 G5 부지에 대한 다양한 청사진과 자료들입니다. G5 부지의 아파트가 언제쯤이면 분양을...', 'date': '2023.09.07.'}
# {'title': '[ChatGPT 활용] 챗GPT에 달리3(DALL-E3) 인공지능(AI) 이미지...', 'text': '[챗GPT 사용법] ChatGPT 완전정복(기본편) 출간 ChatGPT-4에 인공지능(AI) 이미지 생성 기능이 추가되었습니다. ChatGPT와 바드(Bard)가 경쟁하듯... 간단히 인공지능 로봇을 그려 달라고 해보겠습니다. 생각하고 있는 로봇을 그려줘 ChatGPT는 달리-3을 이용해 4개의 이미지를...', 'date': '2023.10.07.'}
# {'title': '230526 # 미국 #증시 #엔비디아 #NVDA #인공지능 #AI 테마의...', 'text': '#엔비디아 #NVDA #인공지능 #AI 테마의 마무리 국면 미국은 통화 긴축 정책에 따라 소비가 줄고 기업이 감소하며, 기업의 이익이 줄어드는 가운데 chatGPT 붐에 힘입어 인공지능 테마 장세가 전개된 것으로 보인다. 이에 따라 과 관련된 대기업을 제외한 모든 산업이 약세를...', 'date': '2023.05.26.'}
# {'title': 'UPS 인공지능을 활용하여 택배 도난방지를 예방하다.', 'text': 'UPS 인공지능을 활용하여 택배 도난방지를 예방하다. New Tech/AI(인공지능) by 마켓캐스트 2023. 10. 9. 08:30 공감 Security.org의 최근 연구에 따르면 지난 2022년 동안 약 4,900만 명의 미국인이 최소 한 번 이상 택배 도난을 경험했다. 이러한 상황에서 도난당한...', 'date': '2023.10.09.'}
# {'title': '챗 GPT 앱 인공지능 시대에 아이폰 chatGPT 필수 어플', 'text': '얼리어답터 리뷰/어플(App) 챗 GPT 앱 인공지능 시대에 아이폰 chatGPT 필수 어플 by 엔돌슨 2023. 6. 20. 챗 GPT 앱 인공지능 시대에 아이폰 chatGPT 필수 어플 챗gpt 앱은 채팅형 인공지능 서비스입니다. 챗GPT 앱으로 아이폰, 안드로인드 스마트폰에서 쉽게 서비스를 이용할 수...', 'date': '2023.06.20.'}
# {'title': '인공지능 누끼따기 사이트, 스테이블 디퓨전 클립드롭', 'text': '인공지능 이미지 생성 사이트 스테이블 디퓨전 클립드롭의 여러 기능 중 누끼따기를 보여드릴 텐데요. 오늘 소개해 드릴 누끼따기... ▲ 클립드롭 사이트인데 메인 화면에 포함된 프롬프트 입력 창을 활용하면 인공지능 이미지를 생성해 볼 수 있습니다. 소개해 드릴...', 'date': '2023.07.15.'}
# {'title': '국내 AI 인공지능 관련주 한화에어로스페이스 네패스 등 투자...', 'text': '임플란트사업부문은 인공관절보형물인 임플란트 판매하고 있으며, 무역사업부문은 식품원료를 수입하여 판매하고 있음.... 38% ■국내 AI 인공지능 관련주 포인트 큐렉소는 의료 로봇과 지능형 로봇 개발 사업을 영위하고 있기 때문에 현재 관련주로 수혜를 받고...', 'date': '2023.08.14.'}
# {'title': '심장 판막 질환을 찾아내는 인공지능', 'text': '인공지능 붐 초기에 의료용 인공지능에 대한 관심이 높았지만, 당시 기술적 한계와 더불어 인공지능에 대한 이해 부족으로 실제 의료 현장에서 크게 활용되지는 못했습니다. 최근에는 진단 목적으로 인공지능의 활용도가 주목 받고 있는데, CT, MRI, X선...', 'date': '2023.10.19.'}
# {'title': '통신사의 생성형 인공지능(AI) 서비스', 'text': "생성형 인공지능(AI)과 관련한 기술을 개발하고, 이를 서비스에 적용하고 있습니다. KT는 자체 개발한 초거대 AI '믿음'을 다음달 공개할 예정이며, SKT는 생성형 AI 시장 공략을 위한 멀티 LLM 전략을 추진하고, LG유플러스는 메타버스와 광고 제작에 을 활용하고...", 'date': '2023.09.04.'}
# {'title': '[종목분석] 국내 인공지능 ai 대장주 루닛 주가전망과 사우디...', 'text': '지난 달 5일 의료 인공지능 ai 기업 루닛은 사우디아라비아 국가전략사업의 핵심과제 SEHA가상병원 프로젝트에 참여했습니다. 여기서... 특히 가상병원 프로젝트는 보건의료분야 최우선 과제로 이번에 참여한 인공지능 AI 의료기기를 중심으로 하는 루닛이란 기업에 좋은...', 'date': '2023.08.31.'}
# {'title': '크라우드웍스 코스닥 상장(인공지능, AI 학습데이터 전문기업)...', 'text': '인공지능 AI 학습데이터 전문기업 크라우드웍스 한국거래소는 2023년 8월 29일 주식회사 크라우드웍스의 코스닥 시장 합병 상장을... 인공지능 대표 기업으로 상장 첫날부터 관심을 받고 있네요. 크라우드웍스는 2017년 설립한 (AI) 데이터 스타트업으로 데이터...', 'date': '2023.08.31.'}
# {'title': '메타 다중언어 번역 인공지능 모델 심리스(Seamless) M4T 출시', 'text': '메타에서 심리스(Seamless) M4T라는 멀티 모달 인공지능 모델을 발표했습니다. 모델의 이름에서 M4T의 의미는 대규모 다국어 및 멀티... © steve_j, 출처 Unsplash 다중언어 번역 인공지능 멀티 모달은 두 개 이상의 다른 언어를 인식하고 이해 가능한 수단인 모달리티(Modality)를...', 'date': '2023.09.24.'}
# {'title': '40개의 엔트리 게임 인공지능 게임 만들기 ft 앤써북', 'text': '오늘은 엔트리를 이용해서 40개의 게임을 만들면서 인공지능 요소를 넣어서 프로그램 코딩하는 책을 소개합니다. 앤써북에서 만든 40개의 엔트리 게임 인공지능 게임 만들기입니다. 40개의 엔트리 게임 + 인공지능 게임은 학교나 학원 또는 방과후 수업에서 사용할 교재로...', 'date': '2023.10.20.'}
# {'title': '인공지능 프로그래밍을 위한 깃허브 코파일럿 학생 인증 무료...', 'text': '요즘은 프로그래밍을 도와주는 인공지능 코딩 툴 등이 상당히 잘 되어 있습니다. 모두 알고 계실 ChatGPT부터, 아마존의 코드 위스퍼러... 이제 나도 인공지능 프로그래밍을 할 수 있게 되는 것이죠. 인공지능 프로그래밍 하기 코파일럿은 비주얼 스튜디오, VS Code의 확장...', 'date': '2023.09.12.'}
# {'title': '모든 도로 안전은 ‘인공지능 도로 분석장치’로 통한다!', 'text': '[이 주의 조달청 혁신제품] 재난 예방 혁신제품 해외수출 ② 인공지능 도로 분석장치 ‘조달청 혁신제품’을 아시나요? 공공성과 기술성이... 모든 도로 안전은 ‘인공지능 도로 분석장치’로 통한다! 지겹게 내리던 폭우가 지나가고 맑은 하늘에 햇빛이 쨍~한 요즘입니다....', 'date': '2023.08.18.'}
# {'title': '인공지능 성우 해외 사이트 소개(부분 무료 가능)', 'text': '국내에도 인공지능 성우를 활용할 수 있는 웹사이트들이 있다. 그냥 구글링만 해도 많이 보이는데, 대부분 바로 유료 사용이 필요하다. 하지만 오늘 소개하는 웹사이트는 부분적으로 무료 사용이 가능하다. 특히 외국어의 경우가 더 특화되었다고 할 수 있다. 위 이미지를 클릭하면...', 'date': '2023.10.06.'}
# {'title': '인공지능을 활용한 스마트한 일상, 초거대AI 총정리!', 'text': '인공지능은 어느새 우리의 일상 깊숙이 침투해 함께 공존하고 있습니다. 과거 간단한 명령만 실행하던 인공지능이 이제는 의료, 법률, 문화예술 분야로 내용이 확대되면서 거의 모든 영역에서 인공지능을 활용하는 사람들이 늘어나고 있습니다. 이러한 의 확대를...', 'date': '2023.09.19.'}
# {'title': '코카콜라 인공지능기술을 활용하여 브랜드 혁신을 주도하다.', 'text': '코카콜라 인공지능기술을 활용하여 브랜드 혁신을 주도하다. 마케팅 전략 by 마켓캐스트 2023. 9. 25. 08:30 공감 2021년 9월... 더불어 현재 마케팅과 크리에이티브 분야에서는 창의력을 더욱 발휘하고 향상시키기 위한 새로운 도구로 생성형 (GenAI)을...', 'date': '2023.09.25.'}
# {'title': '[종목분석] 인공지능,반도체 싸이맥스 주가전망과 하반기 실적...', 'text': '인공지능,반도체 싸이맥스 주가전망을 살펴봅니다. 위 기업은 반도체장비사업과 환경설비 사업을 영위하고 있는 곳으로 반도체시장의... 인공지능,반도체 싸이맥스 주가를 상승시키는 주력생산을 보면 EFEM과 LPM, TM입니다. 종속기업으로 있는 신도이앤지를 통해 미세먼지와...', 'date': '2023.08.26.'}
# {'title': '[주식시장 미리보기] 삼성전자 인공지능 가우스 과연 챗GPT...', 'text': '최근 삼성전자 인공지능 가우스 상표출원을 보며 앞으로의 AI 시장이 어떻게 될지 생각해보겠습니다. 삼전에서 특허청에 AI 소프트웨어와 관련한 상표를 출원했습니다. 챗 GPT와 유사한 생성형 인공지능 서비스를 차체 기술력으로 선보인 건데 챗GPT를 잡고 대세로 떠오를지 귀추가...', 'date': '2023.09.09.'}
# {'title': '[테마주분석] 인공지능, ai챗봇 관련주 외국인과 기관이...', 'text': '올해 초 챗GPT로 시작된 인공지능 시장에 ai챗봇 관련주 기업들이 치열한 경쟁을 하고 있습니다. 엄청난 열풍을 일으킨 오픈ai가 기업용 챗봇을 출시했다고 발표하면서 국내에 있는 인공지능 관련주들이 지금 강세를 보이고 있네요. 여러 종목 중에서 현재 매수 상위권에 있다고...', 'date': '2023.10.04.'}
# {'title': 'Clipdrop 생성형 인공지능 서비스, 구독 시 알아둬야 할 점과...', 'text': 'Clipdrop 생성형 인공지능 서비스의 월 구독 비용이 1,200원으로 정말 저렴한데요. 유용한 기능이 많아 활용해 봐도 좋을 거라... 직접 활용해 보니 프롬프트를 활용한 인공지능 이미지 생성 외에도 각종 툴을 제공하고 있어 다양하게 활용해 볼 수 있습니다. 해지...', 'date': '2023.08.16.'}
# {'title': '만들기 블루윌로우로 쉬운 ai 이미지 생성! 인공지능 강의', 'text': '뉴미디어캠퍼스에선 챗gpt, 바드, 뤼튼 등 여러 인공지능 툴을 활용하여 SNS 콘텐츠 생성 강의를 진행하고 있습니다. 자세한 SNS 콘텐츠 제작 강의와 인공지능 강의 문의는 하단 링크를 참고해주세요! 강의/컨설팅 문의하기 ***-****-**** #ai이미지만들기 #ai이미지생성...', 'date': '2023.09.25.'}
# {'title': '통신 3사의 인공지능 고객센터 AICC 기술', 'text': 'AICC는 AI Contact Center로 고객센터에 음성 인식, 음성 합성, 문장 분석 등 각종 인공지능 기술을 적용한 것입니다. 이 기술을 적용해 상.담원 연결을 위해 기다리지 않고 24시간 상.담이 가능하며 상.담사도 AI로부터 답변 관련 정보를 받아 빠르게 업무 처리가...', 'date': '2023.10.05.'}
# {'title': '오피스 소프트웨어 기업도 인공지능(AI) 전쟁', 'text': "오피스 소프트웨어(SW) 기업 간 인공지능(AI) 전쟁이 본격화될 전망입니다. 오피스 SW의 강자인 폴라리스 오피스와 한글과컴퓨터, 구글... 과제부터 업무까지 가능한 '폴라리스 오피스 AI' 출처=폴라리스 오피스 홈페이지 폴라리스 오피스는 생성형 (AI) 기능을 자유롭게...", 'date': '2023.08.31.'}
# {'title': '인공지능 이용 만감류 생육정보 수집 연구', 'text': '가중되며 인공지능과 빅데이터에 기반한 스마트농업이 미래농업의 대안으로 부각되고 있습니다. 제주특별자치도 농업기술원은 정확한 빅데이터 수집 체계를 개발하기 위해 인공지능 기술을 활용한 생육정보 수집 시스템 연구에 나섭니다. 농업기술원은 제주에서...', 'date': '2023.08.17.'}
# {'title': '전국 청소년 인공지능 프론티어 챌린지 2023', 'text': "글로벌 인공지능 기업이 함께하는 청소년 '인공지능 프론티어 챌린지' 경진대회 소식 입니다. 아마존웹서비스코리아, 구글클라우드, 한국마이크로소프트, 엔비디아 코리아, 네이버 클라우드, 엔에이치엔 클라우드, 케이티 클라우드, 삼성SDS, 쌍용정보통신 등 9개...", 'date': '2023.08.02.'}
# {'title': '[알쓸신잡(新Job)] 인공지능 산업의 발전에 앞장서는 데이터...', 'text': '사람과 비슷한 수준으로 대화가 가능한 인공지능 챗봇, ‘챗GPT’를 알고 계신가요? 챗GPT의 등장은 세계적인 선풍을 일으키며 그에 따라... 한국지능정보사회진흥원(NIA)이 진행하는 국가사업의 데이터 가공 업무에 참여토록 하여 디지털 일자리 창출에도 앞장서고 있습니다. 데이터...', 'date': '2023.07.14.'}
# {'title': '인공지능 PPT 생성 - Gamma App', 'text': '정말 올해의 핫하디 핫한 키워드는, 누가 뭐라 해도 인공지능, AI 일것입니다. 물어보는것에 대답을 해주고, 일목요연하게 정리 해주고, 그림도 그려주고... 정말 무궁무진하게 발전하고 있는듯 한데요. 가볍에 테스트 해볼만한 사이트 하나 가져와봤어요! 바로바로, https://gamma.app...', 'date': '2023.09.21.'}
# {'title': '초보자도 쉽게 이해할 수 있는 인공지능 AI', 'text': '이런 현상과 함께 인공지능(AI) 또는 "머신 러닝" 모델은 계속 진화해 가고 있습니다. 오늘은 초보자도 쉽게 이해할 수 있는 인공지능 가이드로 챗봇을 넘어 다양한 종류의 인공지능을 발견하고 이 새로운 디지털 창조물들이 이미 우리의 삶에서 어떤 역할을 하고 있는지...', 'date': '2023.08.07.'}
# {'title': '멕시코의 인공지능(AI) 산업', 'text': '중 인공지능(AI)은 컴퓨터 시스템 내 알고리즘을 만들어 컴퓨터가 인간처럼 학습하고, 추론하고, 지각할 수 있도록 하는 기술입니다. 인공지능은 자동화, 데이터 분석, 이미지 및 음성 인식, 고객 응대, 자율 주행 등 다양하게 활용될 수 있어 4차 산업혁명의 핵심 기술...', 'date': '2023.08.27.'}
# {'title': '인공지능 Ai 챗봇 뜻, 활용분야 및 장점 알아보자', 'text': '인공지능 기반의 Ai 챗봇은 사람과의 대화를 모방하고 학습할 수 있기 때문에 시간이 지남에 따라 더 지능적으로 작동하는 것이 특징입니다. 2. AI 챗봇의 활용 분야: Ai 챗봇은 다양한 분야에서 활용할 수 있습니다. 간략하게 활용 사례를 보여드릴게요. 고객 서비스 : 기업은 Ai...', 'date': '2023.10.12.'}
# {'title': '‘학술회의는 지겨워’라는 편견을 깬 2023 인공지능대학원...', 'text': '인공지능이 단순히 지능을 묻고 답하는 걸 넘어 인간의 영역이라 불리던 예술까지 넘보고 있는데요. 미술도 이제는 인공지능이 그린 그림과 사람이 그린 그림을 구분하기 어려운 지경입니다. 위 사진은 고흐의 별이 빛나는 밤이고, 아래는 이 그린 고양이입니다....', 'date': '2023.09.04.'}
# {'title': '더불어 사는 사회를 위한 인공지능 윤리', 'text': '인공지능의 발전으로 우리 삶이 속속들이 변화하고 있습니다. 크게는 인간이 추론하기 어려운 영역을 단시간 내에 빠르게 추론하여 합리적인 의사결정을 돕고, 작게는 인공지능 기반 맞춤형 추천을 통해 개인의 취향을 파악하고, 네트워크를 연결할 수 있는 전자기기를...', 'date': '2023.08.11.'}
# {'title': '인공지능(AI) 디지털교과서개발 아이디어, 온라인으로도 듣는다!', 'text': '첨부파일 [교육부 08-03(목) 조간보도자료] 인공지능(AI) 디지털교과서 개발 아이디어, 온라인으로도 듣는다!.pdf 2025년 인공지능(AI) 디지털교과서 도입 예정 교과 교사를 대상으로, 효과적인 교과별 학습지원을 위한 기능에 대해 의견수렴 교육부(부총리 겸 교육부장관 이주호)는...', 'date': '2023.08.02.'}
# {'title': '「인공지능(AI) 디지털교과서 개발 지침」 발표, 개발의...', 'text': '첨부파일 [교육부 08-30(수) 조간보도자료] 인공지능(AI) 디지털교과서 개발 지침 발표, 개발의 신호탄 쏘다.pdf 8월 30일(수) 「인공지능(AI) 디지털교과서 개발 지침」 발표 학습데이터 수집 및 관리, 기반 구축 등 핵심 기능과 클라우드 보안인증 관련 준수사항 등으로 구성 교육부...', 'date': '2023.08.29.'}
# {'title': '네이버 인공지능 검색 cue: 사용기', 'text': '네이버 인공지능 검색 cue: 는 신청해서 승인을 받아야 사용할 수 있습니다. 승인받은 후에는 항상 cue.search.naver.com 에 접속해서 검색을 했었는데. 이제 보니 네이버 검색창의 우측에 cue: 버튼이 생겼네요. 그냥 검색과의 차이를 보기 위해 "자동차 트렌드"라고 검색해보았습니다....', 'date': '2023.09.25.'}
# {'title': '인공지능(AI) 디지털교과서 개발 아이디어,교사·학생...', 'text': '첨부파일 [교육부 07-07(금) 조간보도자료] 인공지능(AI) 디지털교과서 개발 아이디어, 교사·학생·학부모가 직접 제안한다!.pdf 교사·학생·학부모가 직접 참여하는 인공지능(AI) 디지털교과서 디자인연수회(워크숍) 개최 사용자 참여설계 구현을 위해 연수회(워크숍)에서 도출된...', 'date': '2023.07.06.'}
# {'title': 'ai 이미지 생성 사이트 블루윌로우 회원가입하기! 인공지능 강사', 'text': '바드 등 여러 ai 툴들을 활용한 SNS 콘텐츠 제작 강의를 진행하고 있습니다. 자세한 SNS 콘텐츠 강의 문의와 인공지능 강사 소개는 아래 포스팅을 참고해주세요! 강의/컨설팅 문의하기 ***-****-**** #무료ai이미지생성 #ai이미지생성 #ai이미지생성사이트 #블루윌로우 #강사', 'date': '2023.09.25.'}
# {'title': '텍스트로 이미지를 만드는 인공지능 스테이블 디퓨전', 'text': '스테이블 디퓨전은 이미지 생성 인공지능입니다. 주소는 https://stablediffusionweb.com/ 사용법은 텍스트를 입력해서 이미지를 만들어 주도록 만들어진 이미지 생성 인공지능 모델입니다. 이렇게 텍스트를 입력해서 이미지를 만들어 주는 것을 text-to...', 'date': '2023.10.03.'}
# {'title': '에이닷vs믿음vs익시...통신업계 인공지능(AI) 대전', 'text': "국내 대표 이동통신사들이 초거대 인공지능(AI) 기반 서비스를 강화하고 있습니다. 최근 SK텔레콤이 인공지능 브랜드 '에이닷'을 정식... '믿음'은 다양한 응용 사례를 쉽게 학습할 수 있는 '협업 융합 지능'을 갖췄고, 과거 대화를 기억해 활용하는 등 '사람에 더 가까운...", 'date': '2023.10.06.'}
# {'title': "SV인베스트먼트, 인공지능(AI) 반도체 스타트업 '리벨리온'의...", 'text': '재료/모멘텀 인공지능(AI) 반도체 스타트업 리벨리온의 투자사 동사는 삼성전자와 협력해 내년 하반기까지 AI칩 리벨의 개발 완료 계획 리벨은 삼성 4나노 공정을 이용하며 삼성 HBM3E 메모리도 탑재 예정 데이터센터용 AI 반도체 ATOM 을 삼성 5나노 공정에서...', 'date': '2023.10.05.'}
# {'title': '[핀테크 취준카페] #7편 - 인공지능(AI) 기업 소개', 'text': '[핀테크 취준카페] #7편 - 인공지능(AI) 기업 소개 오늘은 최근 가장 관심이 집중되고 있는 인공지능(AI)기업 중 대표적인 5곳을 알아보겠습니다. 인공지능(AI) 기업은 인공지능을 금융에 접목하여 로보어드바이저, 챗봇, 인슈어테크 등 다양한 서비스를 개발하고 있는...', 'date': '2023.09.04.'}
# {'title': '인공지능이 또 저를 울리네요', 'text': '그동안 인공지능이 개발되고 세상이 경천동지 상전벽해되어 강호에 나설까 하면 태클을 거는 족속들 때문에 고민이 많았는데 ... 아 ... 챗... 그래그래 우리나라 인공지능 화이팅이다 ! 라고 하려고 했는데 야 ... 뭐라고라 ?? 휴우 ... 이제 한테도 무시받는 사람이 되었나 ...', 'date': '2023.10.08.'}
# {'title': 'FKCCI x KOTRA Business+ Forum: 인공 지능 시대의 에너지...', 'text': '한불상공회의소는 급속한 기술 발전과 디지털 변혁의 시대 속 지속 가능한 미래 형성에 있어 AI의 중추적인 역할을 인식하고, "인공 지능 시대의 에너지 전환"이라는 주제로 본 포럼을 개최하게 되었습니다. 본 포럼의 특별 연사로는 녹색기후기금(GCF) 수석 데이터...', 'date': '2023.09.27.'}
# {'title': "네이버의 새로운 인공지능(AI) 검색 'Cue(큐):'", 'text': "네이버 메인화면에 노출된 인공지능(AI) 검색 'Cue(큐):'. 출처=플레이 네이버 캡처화면 최근, 네이버가 생성형 AI 검색 ‘Cue(큐):’의 베타... 네이버의 새로운 인공지능(AI) 검색 'Cue(큐):' 출처='Cue(큐):' '큐(Cue):'는 네이버에서 새롭게 선보인 (AI) 검색 서비스입니다. 언어...", 'date': '2023.09.22.'}
# {'title': 'AI기술(인공지능)로 라스트마일을 개선하다!', 'text': '기업에서 인공지능(AI)을 활용하는 경우가 증가하고 있습니다. 물류 산업 역시 AI가 빠르게 적용되는 분야로 특히 라스트마일에 긍정적인 결과를 가져오고 있습니다. 오늘은 AI 기술과 라스트마일의 관계에 대해 살펴봅니다. AI를 통한 라스트마일 최적화 "AI는 우리 네트워크에...', 'date': '2023.10.20.'}
# {'title': '제주도, 인공지능 활용해 아열대‧열대작물 병‧해충 조기...', 'text': '지원사업은 인공지능 구현의 핵심 밑바탕이 되는 학습용 데이터를 구축해 산업 경쟁력과 사회적 문제해결 역량을 강화하기 위한 목적으로 과학기술정보통신부와 한국지능정보사회진흥원(NIA)이 추진하는 사업입니다. * 제주특별자치도 컨소시엄 : 제주특별자치도(주관)...', 'date': '2023.08.31.'}
# {'title': "'줌'에 추가된다는 인공지능 비서, 어떤 역할 맡을까", 'text': "줌 AI 컴패니언 로고 (출처 : Zoom) 9월 5일(현지시간) 미국 화상 회의 서비스 개발사 줌 비디오 커뮤니케이션이 인공지능(AI) 비서 기능 '줌 AI 컴패니언(Zoom AI Companion)'을 발표했다. AI 컴패니언은 화상 회의 소프트웨어 '줌'을 더 편리하게 사용하도록 도움을 주는 기능이다. 줌...", 'date': '2023.09.07.'}
# {'title': '생성형 인공지능 이란?', 'text': '생성형 인공지능은 특정 요구를 하는 이용자에 따라 생성되는 인공지능으로 말할 수 있다. 다향한 콘텐츠 생성에 이용이 되는데 미술, 코딩, 비디오, 이미지, 시, 소절 등 데이터 원본으로 학습을 통한 학습이다. 이미 전세계에서 챗GPT, 미드저니 등 다양한 모델이 공개 되었으며...', 'date': '2023.09.09.'}
# {'title': '“인공지능 시대의 성평등”주제, 제3회 양성평등정책포럼 개최', 'text': '“인공지능 시대의 성평등”주제, 제3회 양성평등정책포럼 개최 (사진=부산여성가족과평생교육진흥원 제공) 부산시와... 제3회 양성평등정책포럼에는 동아대학교 임소연 교수가 ‘인공지능 시대의 성평등’을 주제로 특강을 진행했다. 임소연 교수는 “이 객관적이며...', 'date': '2023.10.20.'}
# {'title': '생성형 인공지능 기술의 교육적 활용과 윤리적 쟁점을 논의하다.', 'text': '첨부파일 [교육부 07-21(금) 조간보도자료] 생성형 인공지능 기술의 교육적 활용과 윤리적 쟁점을 논의하다..pdf 「제8회 디지털 인재양성... 1월∼) ‘생성형 인공지능(AI) 기술의 교육적 활용과 윤리’를 주제로 열리는 이번 토론회는 챗지피티(ChatGPT)로 대표되는 생성형...', 'date': '2023.07.20.'}
# {'title': '다양한 인공지능 모델들', 'text': '챗GPT를 통해 인공지능에 대한 관심이 많은데요. 인공지능을 구분해 보도록 하겠습니다. 먼저 생성형 AI라는 말이 있는데요. 생성형 AI(Generative AI) 언어 생성 모델(ChatGPT) GPT(Generative Pre-trained Transformer) 미리 학습(Pre-trained) 트랜스포머라는 언어 모델을...', 'date': '2023.09.12.'}
# {'title': '2023 인공지능대학원 심포지엄(8.17~18) 개최', 'text': '인공지능대학원의 성과 공유 및 협력 연결망(네트워크) 마련 인공지능융합혁신대학원(동국대, 아주대, 부산대, 전남대) 현판 증정 및 총장 간담회 개최 과학기술정보통신부(장관 이종호, 이하 ‘과기정통부’)는 8.17(목)~18(금) 이틀 간 「2023 대학원 심포지엄」...', 'date': '2023.08.17.'}
# {'title': '인공지능이 꿈을 통제할 수 있도록 도와줍니다', 'text': '프로피틱의 하드웨어 투자는 소수의 인공 지능 회사가 디바이스나 웨어러블에 투자하고 있는 시점에 이루어졌습니다. 전 애플 직원이... 울버그와 베리는 인공지능이 헤일로 장치에서 작동할 수 있는 충분한 훈련 데이터를 제공하기 위해 돈더스 연구소의 1년간의 연구...', 'date': '2023.10.15.'}
# {'title': "2023 코센 브린지 포럼 '인공지능' 주제 포럼 개최", 'text': '<2023 코센 브릿지 포럼 : 국가전략분야 인공지능> 인공지능(AI) 기술은 이제 산업과 사회 모든 분야에서 일상적으로 사용되고 있습니다. AI는 그 자체로 큰 가치를 창출하는 산업이며, 동시에 산업 패러다임에 혁신적인 변화를 가져오고 있습니다. AI의 안전하고 책임감 있는...', 'date': '2023.10.18.'}
# {'title': '#빅데이터경영_인공지능 미래탐구', 'text': '#빅데이터경영_인공지능 미래탐구 #국민대 AI빅데이터 커리큘럼... #인공지능 영역에서 가장 활동적인 석학 #복수의 미래, 긍정적 미래상, 미래의 단점, 단순화 압축, 미래 대응력 #미래에 대한 고찰... 세계경제포럼(2년마다) 일자리 보고서/ 필란드이 미래위원회의 세미나,국가예산...', 'date': '2023.09.16.'}
# {'title': "[IT 소식] [과기원NOW] KAIST, '인공지능과 예술' 논하는 국제...", 'text': 'KAIST 제공 ■ 한국과학기술원(KAIST)은 인공지능(AI)와 예술을 주제로 오는 19일 대전 카이스트 본원 대강당에서 국제심포지엄을 개최한다고 13일 밝혔다. AI 시대에서 예술의 경계가 어디까지인지를 묻고 이에 대한 담론을 나눈다. 심포지엄에는 캐이 왓슨 영국...', 'date': '2023.10.17.'}
# {'title': '인공지능 어디까지 ? 예측의 과거와 현재', 'text': '"카네기 멜론 대학 로봇연구소 한스 모리벡 박사는 인공지능이 10년마다 세대가 바뀔 정도로 급속히 발달해 2050년이면 인간의 지능을 능가할 수 있다고 전망하기도 했다. 2020년까지는 ... 생쥐(10만 MIPS) 정도의 지능을 갖춘 로봇이 등장하고 2030년까지는...', 'date': '2023.09.23.'}
# {'title': '[KTL TODAY] KTL, 의료인공지능개발지원센터 개설로...', 'text': '의료 인공지능산업 지원 위해 구축 세계 의료 AI 산업은 2027년 시장 규모가 약 674억 달러(USD)로 성장할 것으로 전망되는 고부가가치... 의료인공지능개발지원센터(디센터1976 5층/1,130평 규모)를 개소하게 됐습니다. AI 의료기기 개발과 관련 국책과제 연구 진행중 지원센터의...', 'date': '2023.09.11.'}
# {'title': '인공지능(AI) 기반 시설농가 온라인 재배 분석, 구독 서비스....', 'text': '에이(A)-벤처스로 팜커넥트 선정 - 인공지능(AI) 기반 시설농가 온라인 재배 분석 상담 구독 서비스 개발 (01-06-에) AI 재배분석 컨설팅... 팜커넥트는 전국 1,800개 시설 농가에서 실시간으로 수집한 환경·생육 정보를 분석하여 (AI) 기반의 온라인 재배분석 정보와 심층 학습...', 'date': '2023.08.25.'}
# {'title': 'AI 산업 투자 ETF TIMEFOLIO 글로벌AI인공지능액티브', 'text': '글로벌AI인공지능액티브 목차 1. 기본 정보 2. 구성 종목 3. 최근 수익률 4. 마치는 말 & 함께 보시면 좋은 게시물 지금 AI 관련 테마는 나스닥 상장 기업들이 이끌고 있고, 국내 상장 ETF 중 글로벌 AI 산업 투자 ETF 상품은 사실 많지가 않습니다. 현재 "AI" 혹은 "...', 'date': '2023.05.27.'}
# {'title': '"수리수리 인공지능"하면 뚝딱 만들어지는 문해력교육...', 'text': '요즘 하루가 멀다하고 다양한 인공지능 활용교육 도구들이 쏟아져나오고 있다. 그 새로운 도구의 홍수 속에서 지금 당장 학교 현장에서... 하지만 생성형 인공지능 서비스들이 대부분 그랬던 것처럼 유료화의 길을 걷게 되리라는 걱정이 앞서기도 한다. 아무튼 현재는 아무...', 'date': '2023.08.03.'}
# {'title': '인공지능과 언어로 소통하는 프롬프트 엔지니어 Prompt...', 'text': '지난해, 대화하는 인공지능(AI) ‘챗GPT’의 등장은 그야말로 혁신이었습니다. 다들 ‘챗GPT’를 한 번쯤은 써 봤을 거예요. 호기심으로... ‘챗GPT’는 정보를 찾아 제공하는 것은 물론, 마치 사고를 하는 듯한 창의적인 답변까지 하는 생성형 입니다. ‘챗GPT’의 등장으로...', 'date': '2023.09.13.'}
# {'title': '인공지능 리터러시(AI Literacy)를 위한 교수-학습...', 'text': 'ChatGPT 서비스 개시 이후 인공지능으로 인해 세상이 어떻게 변화할 것인지에 대한 관심이 뜨겁게 달아올랐다. 교육계 역시 인공지능 활용교육에 대한 모색이 활발하게 이루어지고 있다. 그런데 이런 분위기 속에서 문득 드는 생각이 있다. 활용으로 인해...', 'date': '2023.08.15.'}
# {'title': '데이터라벨링 인공지능 학습용 데이터 : 어린이 청소년 재연...', 'text': '2023년 인공지능 학습용 데이터 구축사업 어린이· 청소년 재연 배우 모집 공고 놀이기구 시설 및 이용자 위험 상황 인식데이터 구축을 위한어린이· 청소년 재연 배우를 모집한다는 공고입니다. 놀이시설 안전사고 예방용 시스템 개발을 위해서 영상 수집에 들어가는...', 'date': '2023.09.01.'}
# {'title': '직접 써본 인공지능 판독기, 사람과 인공지능을 정확하게...', 'text': '인공지능(AI) 챗봇인 챗GPT는 처음 출시됐을 때 엄청난 인기를 끌었습니다. 궁금한 내용을 질문하면 사람과 비슷한 말투로 일목요연하게... 인공지능은 날이 갈수록 사람과 비슷한 글 실력을 보이고 있습니다. 인공지능으로 작성한 대학교 과제나 논문은 사람이 며칠을 공들여...', 'date': '2023.08.09.'}
# {'title': '보이스피싱, 인공지능으로 막아낸다!', 'text': '바로 목소리 위조 인공지능을 악용한 수법입니다. 전화기 너머로 가까운 사람의 목소리가 들려온다면 아무리 의심이 많은 사람이라도... SNS상에서도 A가수가 부르는 B가수의 곡이라며 인공지능을 이용해 특정 가수의 목소리를 구현하는 경우를 찾아볼 수 있는데, 보이스피싱 집단은...', 'date': '2023.07.17.'}
# {'title': '의료 AI 인공지능 관련주 언제 터질지 모름', 'text': '최근 핫한 섹터 : 의료 바이오, 인공지능 AI 2차 전지 산업 쪽에서 조정이 이루어지면서 주도주가 교체되고 있습니다. 지금 또다른 새로운... 뿐만 아니라 인공지능 AI 관련주도 주도주로 자리잡았습니다. 미국에서 가장 유명한 엔비디아부터 셀바스AI, 한미반도체 등 골고루 많이...', 'date': '2023.09.13.'}
# {'title': '레오나르도 AI 가입 및 인공지능 이미지 생성 후기', 'text': '메인 페이지에서 맘에 드는 이미지를 찾고 적용된 프롬프트를 활용해서 인공지능 이미지를 만들어 보도록 하겠습니다. ▲ 메인에... 드림스나이퍼, 스태이블 디퓨전 등의 인공지능도 선택해서 생성할 수 있는데 적용된 샘플러와 일부 옵션들은 그대로 적용됩니다. 여기서는...', 'date': '2023.05.14.'}
# {'title': '스마트테크코리아에서 본 이스트소프트의 인공지능 기술들', 'text': '이유는 이 이스트소프트 사장님이 뛰어난 인공지능 기술을 꾸준히 연구 개발하고 있었더라고요. 제가 챗GPT 원리를 잘 몰랐을 때... 실제로 셔터스톡은 인공지능이 학습한 데이터 또는 원재료의 사진을 촬영한 원저작권자에게 AI가 만든 사진을 판매하면 판매액의 일부를...', 'date': '2023.07.07.'}
# {'title': '[종로구cctv] 소중한 우리 회사 창고 물건, 인공지능이 지킵니다.', 'text': '안녕하세요 인공지능 수도권cctv 종로구cctv 전문 업체 자비스넷입니다. 보통 기계를 제조하는 업체들에는 물건을 보관하거나 재고를... 인공지능을 활용한 자가보안을 추구하기에 더욱 신속한 알림을 드리고자 노력합니다. 위 솔루션에서는 상황 발생 즉시 이 어떠한...', 'date': '2023.10.19.'}
# {'title': 'SKT AI 서비스 A.(에이닷) 더욱 스마트해진 인공지능 누려봐요', 'text': '하지만 또 인공지능이 여전히 어렵게 느껴지시는 분들도 계실 것 같습니다. 그래서 오늘은 누구나 쉽게 SKT AI 서비스에 대해 이야기해보려고 하는데요. 스마트폰만 있으면 누구나 쉽게 쓸 수 있는 앱인 A.(에이닷)이 그 주인공입니다 :) A.(에이닷)은 일상형 디지털 메이트로...', 'date': '2023.07.11.'}
# {'title': 'Boardmix 협업툴 인공지능 화이트 보드, AI 사진...', 'text': 'Boardmix 협업툴 인공지능 화이트 보드, AI 사진, 프레젠테이션 사이트 안녕하세요. 사진&IT 크리에이터 자유분방입니다. 이번 글에서는 Boardmix라는 협업툴 겸 인공지능 AI를 이용한 파워포인트, 템플릿, AI사진, 흐름도, 마인드맵 등을 만들 수 있는 획기적인 협업 툴 소개...', 'date': '2023.09.04.'}
# {'title': '[궁금한 경제Y] 현대판 러다이트운동, 인공지능은 우리의...', 'text': '· · · · 최근 chatGPT, DALL-E 등의 인공지능은 인간만의 고유 영역으로 여겨왔던 인문, 예술 부문에서 인간과 유사하거나 그보다 뛰어넘는 역량을 가질 수 있음을 보여주었어요. 인공지능 기술이 인간의 일들을 대신할 수 있다는 점에서 환영받고 있지만, 반대로 인간의 직업을 앗아갈...', 'date': '2023.08.22.'}
# {'title': '러시아, 인공지능 도입으로 IT 인력 부족 해결 계획', 'text': '러시아 로스텔레콤은 인공지능을 도입해 IT 인력 부족 문제를 해결하겠다는 계획이다. 운영자는 소프트웨어 개발을 위한 자체 AI... 바로 사람 대신 인공 지능으로 대체하는 것이라고 Kommersant는 적고 있다. IT 직원을 알고리즘과 기술로 교체하려는 Rostelecom의 계획은...', 'date': '2023.09.30.'}
# {'title': '소상공인을 위한 인공지능 챗GPT와 함께하는 식당 메뉴 구성...', 'text': '인공지능 챗GPT와 함께하는 식당 메뉴 구성 노하우 소상공인을 위한 인공지능 챗GPT와 함께하는 식당 메뉴 구성 및 가격 설정 노하우 안녕하세요, 소상공인 여러분! 오늘은 제가 인공지능 챗GPT와 함께 식당 메뉴 구성에 대해 이야기 나눈 내용을 유튜브 영상으로 만들어 보았습니다....', 'date': '2023.10.10.'}
# {'title': '인공지능 챗봇 빙이 알려주는 군봉묵은지김치찜 대박 비결?', 'text': "#인공지능빙 #군봉묵은지김치찜 안녕하세요. 맛집을 넘어 대박집을 소개하고 대박의 비결을 알려드리는 '인공지능 빅데이터 상권분석 온라인마케팅 전문가 김영갑교수'입니다. 인공지능 챗봇 빙이 알려주는 군봉묵은지김치찜 대박 비결? 인천 연수구 옥련동 맛집 군봉묵은지김치찜....", 'date': '2023.09.04.'}
# {'title': "인공지능이 기자 대신한다? 알고 보니 '해프닝'", 'text': '인공지능(AI)도 기사를 쓸 수 있다는 소식에 많은 언론이 긴장했다. 미국 일간 뉴욕타임스(NYT)는 익명의 제보자 3명의 제보를 바탕으로... 인공지능 기술의 급격한 발전으로 다양한 업계에서 AI에 일자리를 뺏기진 않을까 우려하고 있다. 올해 4월 9일 비즈니스 인사이더는 AI가...', 'date': '2023.07.21.'}
# {'title': 'AI 그림 그리기, Bing Image Creator로 인공지능 이미지...', 'text': 'Bing 이미지 생성기는 검색 사이트와 유사한 인터페이스로 누구나 쉽게 인공지능 이미지를 생성해 볼 수 있습니다. 추가로 생성한 AI 그림 ▲ 개인적으로 고양이를 좋아해 인공지능으로 다양하게 생성해 봤는데요. 프롬프트를 입력할 때 마지막에 수채화, 유화, 디지털 아트...', 'date': '2023.04.08.'}
# {'title': '[최초를 넘어 최고로] 인공지능(AI) 스마트 교통관제 시스템...', 'text': '보유하고 있는 혁신제품 중 ‘인공지능(AI) 스마트 교통관제 시스템’은 차량정보 영상을 수집하여 운전자와 보행자를 안전하게 인도하는 서비스로 혁신제품 뿐만 아니라 우수조달물품으로 지정되었다고 합니다. 조달청은 외 수출 조달 기업들을 지원하기 위해 앞으로도 수출...', 'date': '2023.08.22.'}
# {'title': '한글 실력이 탁월한 인공지능 유튜브 요약 서비스 : 써머리...', 'text': '그런데 최근 생성형 인공지능 서비스들이 등장하면서 동영상 요약 서비스가 속속 등장하고 있다. 동영상에서 스크립트를 추출한 후 인공지능이 그 내용을 요약, 정리해준다. 워낙 많은 요약 서비스들이 등장하다보니 어떤 것을 활용할지 고민해야 할 정도다. 동영상 요약 서비스는...', 'date': '2023.08.25.'}
# {'title': '대한민국 초거대 인공지능(AI) 도약 방안 발표', 'text': '대한민국 초거대 인공지능(AI) 도약 방안 발표 2023.09.13 과학기술정보통신부 과학기술정보통신부(장관 이종호, 이하 과기정통부)는 9월 13일(수) 오전 청와대 영빈관에서 ‘대한민국 초거대 인공지능 도약’ 행사를 개최 행사는 챗지피티에 대응한 국내 기업의 독자적...', 'date': '2023.09.13.'}
# {'title': '바이든 행정부, 인공지능 칩 중국에 수출 중단 계획 발표 후...', 'text': '3% 하락 마감 - 바이든 행정부, 인공지능 칩 중국에 수출 중단 계획 발표 후 반도체 주가 하락 - Bank of America (BAC.N), 3분기 이익, 이자수익 예상치 상회, 약 2.1% 상승 EU Market Closing STOXX 600 ▼ 449.76 (-0.1%) DAX ▲ 15,251.69 (0.1%) FTSE 100 ▲ 7,675.21 (0.6%) CAC 40 ▲ 7,029.70...', 'date': '2023.10.18.'}
# {'title': '[광주cctv] 돌봄센터, 인공지능으로 아이들의 안전을 지킵니다.', 'text': '방과 후 아이들을 안심하고 맡기실 수 있도록 안녕하세요 인공지능 경기cctv 광주cctv 전문 설치 자비스넷입니다. 여러분은 혹시... 광주cctv 이러한 이유로 아이들을 더욱 각종 상황에서 안전하게 보호할 수 있도록 광주시에 있는 다함께돌봄센터 지점에 cctv를...', 'date': '2023.10.19.'}
# {'title': '우리나라에서도 인공지능 시스템을 만든다?', 'text': '오늘은 한국판 인공지능 시스템에 대한 소식을 들고 찾아왔습니다. 네이버에서는 2023년 2월 27일 데뷰(DEVIEW)에서 서치 GPT 프로젝트를... 네이버는 8월 24일 콘퍼런스 단(DAN) 23에서 생성형 인공지능(AI) 기반 검색 서비스 ‘큐(CUE):’를 공개하고, 변화하는 검색 서비스 청사진을...', 'date': '2023.08.30.'}
# {'title': 'Ai ETF (인공지능 관련주) 결국은 반도체 (국내 & 미국)', 'text': '최근 AI ETF인 글로벌엑스의 로보틱스&인공지능 ETF(BOTZ)나 로봇공학 및 자동화 관련 AI인 iSHARES의 IRBO 그리고 로봇 기술에 진심인 ROBT... AI 관련주는 결국 반도체 (엔비디아의 GPU 사례) 뭐 인공지능 관련주나 AI 관련주로 꼽히는 회사는 많습니다. OPEN AI (챗GPT 개발사)에...', 'date': '2023.06.08.'}
# {'title': '[오늘의 경제상식] 인공 지능 스타트업, 국가별 현황', 'text': '예술가들이 비전을 실현할 수 있도록 돕는 DALL-E의 기능부터 주요 대도시의 전력 요구 사항을 자동화하는 것까지, 인공지능(AI)은... 2022년 인공지능 투자는 다양한 글로벌 부문으로 확산되었습니다: 헬스케어 무수히 많은 애플리케이션을 보유한 의료 부문은 전...', 'date': '2023.09.22.'}
# {'title': '오디오크래프트 AudioCraft 출시(ft. 음악 제작 인공지능)', 'text': '여러 기업들이 인공지능(AI) 개발에 열을 올리고 있는 가운데 페이스북과 인스타그램을 운영하는 메타에서 오디오 크래프트(AudioCraft)... 오디오 크래프트는 텍스트를 입력하는 것만으로 음악을 만들 수 있으며 작곡과 작사도 할 수 있게 하는 모델입니다. 오픈...', 'date': '2023.08.12.'}
# {'title': '인공지능 챗GPT 사용법 누구나 쉽게 숏폼 제작하기 강의후기', 'text': '챗GPT가 나온 후 인공지능에 대한 관심도 늘어났고, 활용할 수 있는 인공지능 서비스, 플랫폼도 정말 많이 나오고 있습니다. 생성형AI라 불리는 인공지능들을 이용해서는 글쓰기, 이미지 만들기, 동영상 만들기 등도 쉽게 할 수 있는데요. 블로그, 유튜브, 인스타그램 운영...', 'date': '2023.08.23.'}
# {'title': '인공지능의 빈틈을 찾아라! AI 공격', 'text': "여러분 인공지능 챗봇 '이루다'를 기억하시나요? 대한민국의 스타트업 스캐터랩에서 발표했던 이루다는 22살 여대생의 컨셉으로... 초기의 이루다 ⓒ 스캐터랩 https://luda.ai/ 이처럼 머신러닝을 위주로 하는 인공지능 기술은 여러 분야에서 다양하게 적용되고 있습니다....", 'date': '2023.06.30.'}
# {'title': 'AI 인공지능 개발자 취업 국비지원학원', 'text': '인공지능 개발자 하는일 AI개발자 국비지원을 알아보기 전에 기본적으로 어떤 업무를 하는지를 알아야겠죠?!! 인공지능개발자 취업 직무는 AI 시스템 및 응용 프로그램의 설계 구축을 하고 배포를 하는 업무를 하게 됩니다. 요즘에 방대한 데이터가 많다보니 데이터분석과...', 'date': '2023.07.26.'}
# {'title': '로봇 인공지능 관련주 BOTZ ETF 리얼리뷰', 'text': '요즘 로봇과 인공지능에 대한 투자자들의 관심이 뜨겁습니다. 이에 따라 로봇 관련 주식의 주가 흐름도 상당히 호조를 보이고... BOTZ 포트폴리오 BOTZ는 다양한 로봇 및 인공지능 기술에 투자하고 있는 기업들로 구성되어 있는데요. 미국을 비롯하여 일본, 스위스 등 다양한...', 'date': '2023.06.22.'}
# {'title': '인공지능 비메모리 반도체 관련주 엔비디아 주가 상승, 국내...', 'text': '7개 종목 중에서도 특히 인공지능 관련주이자 비메모리 반도체 기업 엔비디아가 +2.95%로 가장 강세를 기록했다. 글로벌 시가총액 6위이자 반도체 기업 중 1위인 인공지능 관련주 엔비디아는 2위 TSMC와 2배 이상의 격차를 보이는 압도적인 기업이다. 반도체 분야는 크게...', 'date': '2023.10.03.'}
# {'title': '인공지능 스터디 part2.', 'text': '인공지능의 산출물에 대한 저작권 문제가 이미 대두되고 있으며 초기 방대한 데이터를 확보해 데이터에 대한 이슈 없이 이미 세팅을 끝낸 업체와 후발 주자의 격차는 클 수 밖에 없다. (5) 산업 벨류체인 1 - 파운데이션모델 - 대다수 하면 이 파운데이션 모델을 생각....', 'date': '2023.09.15.'}
# {'title': 'SK텔레콤 A.(에이닷) 공식출시 나만의 AI 개인비서 인공지능', 'text': "SK텔레콤 A.(에이닷) 공식출시 나만의 AI 개인비서 인공지능 안녕하세요. 사진&IT 크리에이터 자유분방입니다. SK텔레콤은 AI관련 기술... 그동안에도 인공지능 AI로서 실질적으로 일상에 도움이 되는 인공지능 기술들을 보여주기도 했지만, 지금까지는 '베타버전'이었습니다. 그리고...", 'date': '2023.09.27.'}
# {'title': '인공지능으로 오래된 사진 화질 개선 _ Upscayl', 'text': '인공지능 기술을 활용하여 사진의 화질을 개선하는 UpScayl을 이용하여 범일동 1953년 철길옆을 지나는 사람들 사진의 화질을... #범일동 #Upscayl #인공지능 #화질 #개선 서양인이 그린 고종의 모습입니다. 왼쪽이 업스케일링한 이미지, 원본이 원본...', 'date': '2023.10.11.'}
# {'title': "채혈측정부터 모바일 앱을 통한 사전감지까지 '인공지능을 통한...", 'text': '진단에서 예방, 그리고 인공장기까지 헬스케어 과학기술을 진일보 중입니다. 진단부터 예방을 이어 이제는 유관분야의 인공장기까지 인공지능에 기반한 헬스케어의 영역은 무궁무진합니다. 당뇨병에 이어 다른 성인병과 합병증도 헬스케어 과학기술이 해결할 수 있기를 희망합니다.', 'date': '2023.08.08.'}
# {'title': '[수원cctv] 심플한 인테리어를 해치지 않는 카페 인공지능cctv', 'text': '컴팩트한 사이즈여도 인공지능 기능은 확실합니다. 안녕하세요 인공지능 경기cctv 수원cctv 설치 전문 자비스넷입니다. 현대인의 일상 중 일부분이 되어버린 카페, 대한민국엔 다양한 카페가 존재하는데요. 어느 공간이든 사람이 존재하고 물건이 존재하며 그로 인한 절도...', 'date': '2023.10.09.'}
# {'title': '앱개발, 인공지능, 증강현실, 핀테크 등 약 3만 건 수록', 'text': '오늘은 핀테크기업, 인공지능기업, 앱개발업체, 어플리케이션개발과 관련된 정보를 담고 있는 2023 4차산업 기업·스타트업 주소록에... 게임 소프트웨어 개발 및 공급업부터 호스팅 및 관련 서비스업까지 총 21개의 업종별로 분류했기 때문에 핀테크기업, 기업...', 'date': '2023.10.16.'}
# {'title': '서울 도시제조업 문제해결 인공지능(AI) 아이디어 경진대회...', 'text': '안녕하세요 서울경제진흥원 SBA입니다 오늘은 서울 도시 제조업 문제해결 인공지능(AI) 아이디어 경진대회 참가자 모집 공고 소식을... 서울 도시제조업의 문제 해결을 위한 인공지능(AI) 아이디어 경진대회 ✅️ 공모분야 AI를 활용한 서울 도시제조업 문제해결 혁신 아이디어...', 'date': '2023.09.26.'}
# {'title': '인공지능 데이터라벨링, 내일배움카드 신청 가능한 크라우드웍스', 'text': '인공지능 데이터라벨링, 내일배움카드 신청 가능한 크라우드웍스 안녕하세요. 사진&IT 크리에이터 자유분방입니다. 요즘은 뉴스를 보다 보면 인공지능 로봇이 아르바이트를 몇 명을 대체했다는 등의 뉴스가 나오게 됩니다. AI 은 일하기 편하게 하기 위해서 만들어지는...', 'date': '2023.05.30.'}
# {'title': '인공지능 프로그래밍을 위한 코드 위스퍼러 비주얼 스튜디오...', 'text': '바로 인공지능 AI 기반으로 코딩툴의 등장입니다. 마이크로소프트의 코 파일럿은 매달 10달러를 내야 하지만 아마존의 코드 위스퍼러의 경우 무료로 사용할 수 있습니다. 인공지능 프로그래밍 툴 코드 위스퍼러 설치 마이크로소프트 코 파일럿의 경우 비주얼...', 'date': '2023.07.31.'}
# {'title': '신개념의 맛집 검색 방법, 인공지능 빙으로 맛집 검색하기', 'text': '#인공지능맛집검색 #빙으로맛집검색 #신개념맛집찾기 안녕하세요. 인공지능과 빅데이터를 이용해서 상권분석과 온라인마케팅을 알려드리는 김영갑 교수입니다. 오늘은 인공지능 챗봇 마이크로소프트 빙을 이용해서 맛집을 검색하는 다양한 사례를 설명드리도록 하겠습니다. 맛집...', 'date': '2023.09.02.'}
# {'title': '파파코 인공지능 AI 투자해 보고, 출석체크로 앱테크까지!', 'text': '최근 인공지능 기반 AI 투자 플랫폼들이 많이 생겨나고 있는데요. 파파코에서는 투자뿐만 아니라 출석 체크를 통한 포인트 지급... 파파코는 인공지능 AI로 개발된 트레이딩 프로그램인데요. 요즘 챗 GPT나 AI, 로봇 기술에 대한 개발이 엄청나게 진행되고 있죠. 세상에 나와있는...', 'date': '2023.10.06.'}
# {'title': '[Specialized Info] 인공지능과 의료기기', 'text': "질병 진단 인공지능 개발 '붐' 인공지능(AI)이 4차 산업혁명의 핵심으로 부상한 가운데 바이오헬스 분야에서도 AI를 접목한 서비스를 개발하기 위해 국내외 많은 회사와 연구진들이 나서고 있습니다. 특히 우리나라는 탄탄한 정보통신기술(ICT) 인프라와 단일건강보험체제로...", 'date': '2023.08.03.'}
# {'title': '제조업 분야에서 인공지능이 영향을 미칠 영향', 'text': '하나인 인공지능(AI)에 초점을 맞추고 있습니다. 아직 정확한 범위는 알려지지 않았지만 AI가 노동 시장에 상당한 영향을 미칠 가능성이 있다는 것은 더 이상 비밀이 아닙니다. OECD 보고서에 따르면, 인공지능은 "범용 기술"이기 때문에, 거의 모든 분야와 직업이 영향을...', 'date': '2023.07.26.'}
# {'title': '뤼튼 사용법 4 - 자주 쓰는 문구 저장하기 / 인공지능 강의', 'text': '뉴미디어캠퍼스에선 뤼튼, 챗gpt와 같은 인공지능 플랫폼을 활용한 SNS 콘텐츠 제작 강의를 진행하고 있습니다. 자세한 인공지능 강의 문의와 SNS 마케팅 강사 소개는 포스팅 하단 링크를 참고해주세요! 지난 뤼튼 사용법 3에선 pdf 파일을 업로드 해서 분석하는 법에 대해...', 'date': '2023.08.04.'}
# {'title': '[부천cctv] 더욱 선명한 음식점 보안, 인공지능 400만 화소로', 'text': '인공지능으로 더욱 똑똑하게 400만 화소로 더욱 선명하게 안녕하세요 경기cctv 부천cctv 설치 전문 업체 자비스넷입니다. 음식점을... 그 중 하나인 보안 역시 챙기는 방법은 여러가지가 있는데요, 요즘은 자가설치부터 인공지능cctv까지 여러가지 선택의 폭으로 넓어졌습니다....', 'date': '2023.10.06.'}
# {'title': '미국 교육시장, 인공지능(AI)과 만나다', 'text': '해외는 지금 신산업으로의 인공지능(AI) 교육산업… 혁신과 기회의 지평을 열다 메타버스(Metaverse), 공간의 의미를 새롭게 해석하다... 그리고 이는 전 세계 산업 전반에 큰 영향을 미치고 있는데 교육산업도 예외는 아니며, (AI)과 교육의 결합을 통해 새로운...', 'date': '2023.07.29.'}
# {'title': '구글 AI 인공지능 챗봇 바드 사용법', 'text': '챗gpt를 선두로 마이크로소프트에 이어 구글까지 ai 인공지능 챗봇 바드를 발표했습니다. 그래서 제가 사용법을 간략하게 알려드리려고... 다만 다른 챗봇과 마찬가지로 구글 AI 인공지능 바드 역시 이미지를 따로 보여주지는 않습니다. Bard의 최대 장점이라고 볼 수 있는 부분은...', 'date': '2023.06.06.'}
# {'title': '[용인cctv] 대형 비닐하우스, 화훼 매장에 인공지능을 적용하면?', 'text': '안녕하세요 인공지능 경기cctv 용인cctv 설치 전문 자비스넷입니다. 식집사라는 말, 들어보셨나요? 반려식물을 키우는 분들에게 붙여진... 농장cctv 이러한 고민을 가지신 경기도 용인시 내 대형 화훼 비닐하우스엔 이런 부분을 해결하기 위한 cctv 설치를 진행하였습니다....', 'date': '2023.10.10.'}
# {'title': '인공지능의 활용 1', 'text': '기업들은 여기저기서 챗봇 (인공지능 대화 시스템) 을 사용합니다. 외부 시스템을 쓰는 경우도 있고, 대기업의 경우 자체적으로 구축하기도 합니다. https://www.hitech.co.kr/news/articleView.html?idxno=21273 최근들어 본의아니게 포스코, 그중에서도 광양제철소에 관심을 많이...', 'date': '2023.10.11.'}
# {'title': '우주항공과 인공지능에 관심있는 학생들 주목!...', 'text': '국립중앙과학관에서는 초등 4학년 ~ 6학년 또는 동일 연령(11세 ~ 13세) 청소년을 대상으로 인공지능과 우주항공을 주제로 한 여름방학... 4(금) 10:00 2023년 캠프 주제는 <새로운 우주를 누리다 “우주 누리” / 인공지능 + 우주항공>입니다. 캠프에서는 우주항공 관련 전시관...', 'date': '2023.07.18.'}
# {'title': '인공지능 AI', 'text': '전세계적으로 인공지능 열품이 대단합니다. 마치 스마트폰이 처음 등장했을 때의 열기입니다. ChatGPT... 인공지능 AI Artificial Intelligence 블핑 제니 사진 편집하시려면 https://clipdrop.co/ 문서 작업은.....Notion...', 'date': '2023.09.01.'}
# {'title': '인공지능과 함께라면 난도 디자이너! AI 디자이너 양성과정...', 'text': '인공지능 활용 기술은 갈수록 더 중요해지고 있어요 할 줄 아느냐 모르냐는 큰 차이인거 아시죠? 인공지능 실력, 정말 놀랄만큼 출중하다구요! 인공지능을 활용기술 습득해 필요한 그림도, 디자인도, 사진도 얻어가세요! AI 디자이너 양성과정 수강생 모집!...', 'date': '2023.08.14.'}
# {'title': '지능을 가진 존재가 지켜야 할 약속, 인공지능 윤리', 'text': '점차 커져가는 인공지능 윤리에 대한 관심 인공지능이 나날이 발전하고 있습니다. 얼마 전까지 인공지능이라고 하면 사람보다 뛰어난 연산능력으로 복잡한 계산을 처리하는 도구로 생각하였습니다. 최근 ChatGPT와 같은 생성형 AI (Generative AI)는 기존의 복잡한 처리능력을...', 'date': '2023.06.29.'}
# {'title': '인공지능의 급성장, 급격한 인구감소', 'text': '글로벌 출산율 저하, 인구감소를 250년전 산업혁명 시기 이후의 인구급증과 대비해서 인공지능 시대의 전환점으로 파악하는게 흥미롭다. 향후 글로벌 경제가 처할 상황은 출산율 저하로 청년층 감소, 노령화 가속으로 인한 부양의 부담이 가중되는 상황을 어떻게...', 'date': '2023.06.05.'}
# {'title': "[인문학 강의] 인공지능과 미래인문학_'ChatGPT를 활용한...", 'text': "충청남도교육청교육연수원(공주시 소재)에서 인공지능과 미래인문학 과정 중 5급 이하 공무원 약 40명을 대상으로 'ChatGPT를 활용한 보고서 작성'에 관한 주제로 강의했습니다. 강의에서는 [인공지능 ChatGPT를 활용해 업무의 효율성을 높이는 방안]으로 보고서, 이메일, 보도자료...", 'date': '2023.08.20.'}
# {'title': '인공지능 챗GPT, 빙, 바드, 뤼튼, 클로바X 이용한 소상공인...', 'text': '소상공인을 위한 블로그 글쓰기 특강 인공지능 챗GPT, 빙, 바드, 뤼튼, 클로바X 중심으로 인공지능을 활용한 블로그 글쓰기는 소상공인에게 시간을 절약하게 도와주고 품질 높은 콘텐츠를 생산하는 좋은 방법입니다. 인공지능으로 생성된 기본 내용을 수정하고 맞춤화하여 브랜드...', 'date': '2023.08.25.'}
# {'title': '2027년 AI 인공지능 반도체 시장 매출 전망은?', 'text': "오늘은 '2027년 AI 인공지능 반도체 시장 매출 전망은?' 에 대하여 알아보도록 하겠습니다. 전 세계 인공지능(AI) 반도체 매출이 앞으로 5년간 두 자릿수 이상의 성장률을 지속하며 2배 이상 커질 것이란 분석이 나왔습니다. AI 반도체 시장은 생성형 AI의 발전과 데이터...", 'date': '2023.08.25.'}
# {'title': '대한민국 초거대 AI 도약… 인공지능을 전 국민 일상 속으로', 'text': "생성형 인공지능(AI) '챗GPT'는 23년 상반기 과학기술계의 최대 화두 중 하나였습니다. 이에 정부는 24년도 예산 9090억 원을 투입, 복지... 인공지능을 전 국민 일상 속으로 2024년 9090억 원 투입 2023년 상반기 과학기술계의 최대 화두 중 하나는 미국의 오픈AI가 개발한 생성형...", 'date': '2023.09.21.'}
# {'title': 'AI 인공지능 IoT 삼성 스마트싱스 SmartThings 연결하고...', 'text': '삼성 큐브 공기청정기 센서, 네트워크, AI 인공지능 기술을 통해 집안의 가전, 조명, 에너지 관리, 보안까지 제어하여 사용자의 편의성을... 스마트홈으로 구축하는 것을 뛰어넘어 이젠 AI 인공지능으로 더욱 똑똑해진 기능들을 살펴보았어요. 지금 삼성닷컴 홈페이지에 들어가시면...', 'date': '2023.07.26.'}
# {'title': '반도체 종목 SK하이닉스 주가변동 인공지능 AI 5세대...', 'text': 'SK하이닉스 | 인공지능 AI 5세대 HBM메모리 2차전지 | 전기차 돈버는투자공부 홈카페 라떼아트 안녕하세요 초보주식투자자입니다... SK하이닉스가 인공지능 AI용 5세대 메모리 HBM3E를 개발에 성공하고 엔비디아에 샘플을 공급해 테스트를 거친 후 내년 상반기부터 양산에...', 'date': '2023.08.22.'}
# {'title': '인공지능의 진짜 성공이 의미하는 것 (ft. 테슬라, 일론 머스크)', 'text': '일론 머스크는 이미 2013년부터 인공지능에 관심이 많아 구글의 래리 페이지, 리드 호프먼 허사비스 등과 열띤 토론을 했죠. 페이팔 마피아와 버락 오바마 대통령과도 만나며 인공지능의 위험성과 규제에 대해 알리기도 했습니다. 2015년에는 ChatGPT를 만든 샘 올트먼을 만나...', 'date': '2023.09.22.'}
# {'title': '[주식분석] 엔비디아 제친 차세대 인공지능 반도체 주식 종목분석', 'text': '이번 시간에 알아볼 내용은 한동안 인기를 끌었던 엔비디아의 뒤를 이을 차세대 인공지능 반도체 주식에 대한 분석입니다. 반도체 종목을 찾는 사람이라면 엔비디아를 못 들어본 분들은 없습니다. 올해가 시작하면서부터 시작된 챗gpt와 열풍은 엔비디아의...', 'date': '2023.06.21.'}
# {'title': '파파코 인공지능 AI 투자 플랫폼 미국 지수 ETF 투자 후기', 'text': '파파코는 자체 개발한 인공지능(AI) 기반의 100% 자동화 펀딩 플랫폼인데요. 2016년부터 2020년까지 약 5년 동안 개발 및 테스트를 거쳤다고 합니다. 처음에는 기업용 인공지능 트레이딩 프로그램을 목표로 하였지만 여의치 않았다고 하는데요. 결국 2020년 6월 15일 법인 설립 및...', 'date': '2023.10.05.'}
# {'title': '바드 구글 인공지능 얼마나 똑똑할까? 바드 사용법', 'text': '얼리어답터 리뷰/IT정보 바드 구글 인공지능 얼마나 똑똑할까? 바드 사용법 by 엔돌슨 2023. 5. 2. 바드 구글 인공지능 얼마나 똑똑할까? 구글에서 만든 인공지능 아시나요? OpenAPI의 챗GPT가 큰 인기를 끌고 있지만, 인공지능의 원조는 테크 1위 기업인 구글이 아닐까...', 'date': '2023.05.02.'}
# {'title': '포토샵 2024, 생성형 채우기로 인공지능 경험하기', 'text': '이번 어도비의 전폭적인 업데이트를 통해 디자인 툴과 인공지능이 절묘하게 결합되었습니다. 지난번에는 일러스트레이터에서 인공지능을 경험해 보았는데, 오늘은 포토샵에서 AI의 능력을 살펴 보겠습니다. 어도비 포토샵 2024에서는 생성형 채우기와 생성형 확장을 통해 작업자가...', 'date': '2023.10.17.'}
# {'title': '어플리케이션제작 최신 인공지능을 이용하여 경쟁력 갖추는 방법', 'text': '최신 인공지능을 이용한 어플리케이션 제작 방식은 모든 코딩을 인공지능이 대신해주게 되면서 어플리케이션을 제작하는데 코딩 개발자들이 없이 가능해졌습니다. 인공지능 어플리케이션 제작 방식은 종래의 코딩 위주의 개발 방식에서 벗어나 만들고자 하는 페이지를 계획하고...', 'date': '2023.06.27.'}
# {'title': '[양주cctv] 니트회사 물류창고, 화재 관리까지 인공지능으로?', 'text': '인공지능cctv의 세계는 무궁무진합니다. 안녕하세요. 화재cctv 경기cctv 양주cctv 설치 전문 자비스넷입니다. 365일, 화재의 위험은 우리... 모든 현장 상황은 기본 cctv처럼 인공지능 영상분석을 곁들여 침입 등에도 감지를 하면서 만약 지정된 이상수치 이상으로 실내 환경의...', 'date': '2023.09.29.'}
# {'title': '[수원cctv] 철공소에 화재 감지가 되는 인공지능cctv를...', 'text': '자비스넷은 연기감지카메라를 보유한 유일한 인공지능 보안 업체로 많은 고객님들께서 화재 관련 보안 문의를 주시곤 합니다. 이러한... 보통 화재 감지를 하는 인공지능cctv를 떠올리신다면 열화상카메라를 떠올리시는데, 이 열화상카메라를 포함해 기존 화재 감지기와...', 'date': '2023.10.04.'}
# {'title': '[생활문화] AI 인공지능을 활용한 블로그 운영', 'text': '"AI 인공지능을 활용한 블로그 운영" 과정에 대해 알아볼게요^^ 어떤 내용을 배우나요? 서초여성인력개발센터 블로그 운영 주제에 관한 인공지능 활용, 계정 설정 및 레이아웃 꾸미기 , 인공지능 서비스 가입 및 활용, 블로그 분석 내용 기반 콘텐츠 생산 연습, 해외 콘텐츠 활용...', 'date': '2023.09.05.'}
# {'title': '뚜봇아 가정 양육수당 알려줄래 이벤트 안내::인공지능...', 'text': '대구시 인공지능(ai) 민원상담사 뚜봇! 뚜봇아~ 가정 양육수당 알려줄래? 이벤트 에 대해 대구북구에서 알려드립니다! 자세한 내용은 아래의 게시물을 참고해주세요❗ 뚜봇아~ 가정 양육수당 알려줄래? ✅이벤트 기간 9. 11.(월) ~ 9. 22.(금) ✅당첨자 발표 9. 27.(수) 뚜봇...', 'date': '2023.09.12.'}
# {'title': '2023 월드IT쇼 SK텔레콤 AI 인공지능 기술과 UAM', 'text': '인공지능 스피커로도 괜찮을 것 같네요. A.(에이닷)은 대화형 인공지능 서비스를 지원하는 개인 맞춤형 AI 에이전트입니다. 전용 앱을 통해서는 사용자의 취향에 맞춘 사진 보정, KBO 프로야구 중계, 게임, FLO 음악 추천 등을 즐겨볼 수 있는데요. 최근 업데이트를 통해...', 'date': '2023.04.28.'}
# {'title': '인공지능 스터디 part1.', 'text': '(1) 인공지능 why? 고성장이 보이는 섹터 대한민국이 여러가지로 유리한 포지션을 갖춘 산업 투자뿐 아니라 개개인의 삶에서도 반드시... 인공지능이 인터넷 만큼의 성장이 나올지는 솔직히 모르겠습니다. 허나 확실한 건 아직 초기 시장이며 을 사용자들이 앞으로 매년...', 'date': '2023.09.14.'}
# {'title': '‘이미지 생성 1타 인공지능‘ 미드저니, 기본 가이드', 'text': "최근 인공지능 이미지 생성 서비스인 '미드저니(Midjourney)가 사용자 수 1000만명을 돌파했다. 지난 7월에 서비스를 시작해, 11월에 300만명을... 프로필 이미지에 특화된 인공지능, 일본 2D 애니메이션 스타일에 특화된 등 AI 이미지 생성 시장이 갈수록 분화되는 양상을...", 'date': '2023.02.16.'}
# {'title': '생성형 인공지능 누가누가 잘하나?-GenAI 50', 'text': 'CB Insights는 8월 8일 전 세계에서 가장 유망한 민간 생성형 인공지능(GenAI) 50개 기업 GenAI 50 수상기업을 발표했다. 2023년 수상 기업 중 16개는 미디어, 엔터테인먼트 캐릭터 애니메이션, 의료 분야 약물 발견 등 산업별 GenAI 사용 사례에 중점을 두고 있다. 20개...', 'date': '2023.08.11.'}
# {'title': '인공지능 데이터라벨링, 남녀노소 가능해 (feat. 무료교육...', 'text': '먼저 이 일에 대해 잘 모르는 분들이 많으실 것 같아 간단히 설명드리자면, 인공지능이 어떠한 데이터를 학습할 수 있도록 그에 맞는... 굉장히 많은 것들이 인공지능화 되어가고 있어요. 그만큼 어떻게 보면 사람이 할 일을 AI가 대신한다고 볼 수 있지만, AI가 사람에 준하는 일을...', 'date': '2023.10.15.'}
# {'title': '오산시, 운암뜰 인공지능(AI)시티 도시개발사업 토지주 면담', 'text': '‘운암뜰 인공지능(AI)시티 도시개발’사업 토지주들과 면담을 가졌습니다. 이날 면담에는 토지주 10여 명이 방문한 가운데 시청 도시개발과 관계자도 참석했는데요. ‘운암뜰 인공지능(AI)시티 도시개발’사업은 오산동 166번지 일원의 약 58만여 제곱미터 면적에 동탄 트램 연결...', 'date': '2023.08.18.'}
# {'title': 'AMD 그래픽카드 스테이블 디퓨전으로 인공지능 사진 만든 소감', 'text': '얼마 전 그래픽카드 구매를 할 때, 인공지능 그림 돌리려고 AMD에서 엔비디아로 바꾼다는 글이 몇 개 보이길래 뭔가 했더니~ 스테이블 디퓨전(Stable Diffusion) 일명 webui가 엔비디아 그래픽카드에서 잘 돌아가는 것이었군요. 이웃이신 서타이거 님께서 만드신 ...', 'date': '2023.05.03.'}
# {'title': '현재 주가조작이 의심되는 종목을 인공지능 바드(Bard)에...', 'text': '현재 실험 버전으로 제공되고 있는 구글의 인공지능 서비스 \'바드(Bard)\'에 "현재 한국 주식시장에서 주가조작이 진행되고 있는 듯한 종목이... 챗GPT, 바드 같은 인공지능이 놀라움도 주기는 하지만 아직은 정확도 측면에서 가야 할 길은 많이 남은 것 같기는 해 보입니다. 대신 정답이...', 'date': '2023.06.05.'}
# {'title': '인공지능 AI 골드러쉬 (ft. 닷컴버블 vs 인터넷 붐)', 'text': '* Wedbush 분석가 Dan Ives에 따르면 주식 시장에서 "인공지능 AI 골드 러시"가 막 시작되고 있습니다. * 현재의 주식 시장은 닷컴 버블이 터지던 1999년보다 1995년과 더 비슷해 보인다고 말했습니다. * 아이브스는 "인공지능 혁명이 이제 막 시작되고 있다"고 말했습니다....', 'date': '2023.07.30.'}
# {'title': '가온그룹 주가 전망 및 실적 분석 (ft. 로봇, 인공지능 관련주)', 'text': '로봇, 인공지능 관련주) 안녕하세요. 머니알람입니다. 이번 포스팅에서는 로봇, 인공지능 관련주 중 하나인 가온그룹에 대해서 다뤄보려고 합니다. 가온그룹 주가 전망 및 실적 분석까지 알아보도록 하겠습니다. 먼저 어떤 기업인지 살펴볼까요? 가온그룹은 어떤 기업일까?...', 'date': '2023.10.03.'}
# {'title': '새로워진 인공지능 비서 SKT A.(에이닷), 이젠 챗GPT 기능까지', 'text': "새로워진 인공지능 비서 SKT A.(에이닷), 이젠 챗GPT 기능까지 안녕하세요. 사진&IT 크리에이터 자유분방입니다. SKT의 인공지능 AI 서비스인 A.(에이닷)이 6월 30일 '내 손안의 AI 친구'라는 새로운 슬로건을 기반으로 업데이트되었습니다. 기존에도 영리했던 A.(에이닷)에 어떤...", 'date': '2023.07.21.'}
# {'title': '[기회기자단] 경기도, 인공지능 활용해 모두를 위한 예술혁명 실현', 'text': '6월 12일(월)까지 14일간 열리는 이번 전시회는 경기도와 경기도문화재단이 사전 모집한 예술에 관심이 있는 발달장애인들에게 생성형 인공지능(AI)을 활용해 예술 활동 교육을 하고, 예술가와 협업해 완성한 작품 30점을 전시하는 것입니다. 이번 전시는 을 활용해...', 'date': '2023.05.31.'}
# {'title': '자율주행과 인공지능 그리고 학습방법', 'text': '언어 간 번역에서 신약 설계에 이르기까지 모든 종류의 데이터를 처리하고 모든 작업을 수행할 수 있는 단일 AI 모델 아이디어는 인공 일반 지능(AGI)으로 알려져 있습니다. 어떤 사람들에게는 그것이 모든 인공지능 연구의 궁극적인 목표이고, 다른 사람들에게는 그것이 우리가...', 'date': '2023.08.09.'}
# {'title': '강사양성 과정] 성공하는 소상공인을 만드는 인공지능 활용법', 'text': '#김영갑교수 #강사양성과정 #인공지능활용 안녕하세요. 소상공인을 위한 인공지능 활용 전문가 김영갑 교수입니다. 소상공인을 위한 중장년 디지털 강사양성 과정 성공하는 소상공인을 만드는 인공지능 활용법 인공지능 빅데이터 활용 상권분석 온라인마케팅 전문가 김영갑교수...', 'date': '2023.09.14.'}
# {'title': '인공지능 챗 chat GPT 의 플러그인, 브라우징 활용법', 'text': '얼리어답터 리뷰/IT정보 인공지능 챗 chat GPT 의 플러그인, 브라우징 활용법 by 엔돌슨 2023. 5. 23. 인공지능 챗 chat GPT 의 플러그인, 브라우징 활용법 챗GPT 안에서 모든 걸 해결할 수 있게 됩니다. 이제는 호텔 예약, 비행기 예약, 배달 주문, 주식 정보, 날씨 정보 등을...', 'date': '2023.05.23.'}
# {'title': '인공지능 머신러닝 책 추천-파이썬 3학년 머신러닝의 구조', 'text': '♣ 인공지능 머신러닝 책 추천-파이썬 3학년 머신러닝의 구조 선형 회귀, 서포트 벡터 머신, 랜덤 포레스트... 머신러닝을 위해 필수로 익혀야하는 이 개념들을 초등학생도 이해할 수 있게 쉽게 풀이한 책이 있어 소개합니다. 저도 파이썬을 열심히 공부한 초등학생들에게 ...', 'date': '2023.10.13.'}
# {'title': '인공지능 속도에 밀려나는 ‘AI 윤리’, 특이점 올까', 'text': '인공지능은 기본적으로 인간의 지능을 모방하는 기술로, 다양한 분야에서 유용하게 활용되지만 실제로 써 보면 항상 긍정적인 결과를 낳는 것은 아니다. 편리와 효율을 강조하다보니 오히려 인간의 권리나 가치를 침해하거나, 편향과 차별을 야기하거나, 부정적인 목적으로...', 'date': '2023.03.31.'}
# {'title': 'AICE 인공지능 인기 자격증 BASIC 코스', 'text': 'AICE 인공지능 인기 자격증 BASIC 코스 최근 AICE라고 불리는 인공지능 자격증이 인기이다. 대기업 재직자들이 인공지능 자격증 취득을 위해 힘을 쓰고 있다고 한다. AICE 자격증에 대해 알아보도록 하자. AICE 자격증 BASIC 코스 AICE는 AI Certificate for Everyone의 약자로...', 'date': '2023.07.05.'}
# {'title': '[이천cctv] 야외 농장, 까다로운 보안을 풀컬러 인공지능...', 'text': '주변이 어두워도 문제 없는 보안카메라 안녕하세요 인공지능 경기cctv 이천cctv 설치 전문 자비스넷입니다. 자비스넷에선 여러가지... 자비스넷이 제일 중요하게 여기는 것은 신속하고 편리한 보안으로 이러한 화재를 비롯해 카메라에 침입 현황이 보일 시 영상분석...', 'date': '2023.10.12.'}
# {'title': '[경제/사회] 구글 인공지능 채팅 gpt, BARD 후기', 'text': '오늘은 구글 인공지능 채팅을 해봤는데요. 한 번 소개해보려 해요. 이렇게 구글에 BARD를 검색하면 바로 나와요. 프롬포트 입력하는 곳에... © markusspiske, 출처 Unsplash 이러한 BARD라는 인공지능 채팅에서 얻을 수 있는 정보는 정말 빠르고 쉽게 얻을 수 있어요. 다만, 이 글에 대한...', 'date': '2023.06.08.'}
# {'title': '미국펀드투자 자동매매도 AI인공지능펀드로 해보기', 'text': '파파코로 미국펀드투자 자동매매 해보기 주식시장에서도 비약적으로 인공지능 기술이 발전하면서, 손 하나 까딱 안 하고 주식을... 인공지능 주식투자 플랫폼 [ 파파코 ] 오늘 소개해 드릴 인공지능 주식투자 플랫폼 [파파코]역시, 자동으로 펀딩을 해서, 레버리지와 인버스에...', 'date': '2023.09.15.'}
# {'title': '광주인공지능사관학교 4기 교육생 2차 모집 중!', 'text': '세계로 도약하는 No.1 AI 핵심인재양성의 산실 광주인공지능사관학교에서 4기 교생을 모집합니다! [ 모집기간 ] 2023.03.01.(수) ~ 03.31.... 광주인공지능사관학교 홈페이지 신청 https://gj-aischool.or.kr/ [ 문 의 ] 운영사무국 062)710-3257~9 2020년 개교한...', 'date': '2023.03.09.'}
# {'title': '10초 만에 답을 알려주는 인공지능? 챗GPT!', 'text': '한국 IDC에 따르면 국내 인공지능 시장은 전반적인 성장세를 보이고 있습니다. 그 중, 최근 높은 관심을 받고 있는 챗GPT를 아시나요? 챗GPT란 대화형 인공지능으로 현재 대화형 인공지능 분야에서 가장 발전된 기술 중 하나인 오픈AI의 GPT-3.5로 학습된 대규모 언어 모델입니다....', 'date': '2023.05.04.'}
# {'title': '제품 촬영도 이젠 인공지능 시대 AI 마케팅 현재 무료 서비스', 'text': '요즘 인공지능이 다양한 분야에서 활동하는데요. 앞으로 우리가 살아갈 사회 여러 분야에서 인공지능이 어디까지 발전할지 궁금해져 갑니다. 오늘은 제품 촬영한 이미지를 인공지능을 통해 다양한 이미지로 만드는 사이트를 소개해 드리겠습니다. 제품의 배경을 멋집 이미지로...', 'date': '2023.08.07.'}
# {'title': '우리나라 교육과정을 알고 있는 토종 생성형 인공지능...', 'text': '하이퍼클로바 엑스가 한글 데이터에 기반을 둔 인공지능 서비스이다. 교사 입장에서 제일 먼저 확인해 보고 싶은 것은 우리나라... 하지만 챗GPT나 다른 외국 생성형 인공지능 서비스들이 활용하는 데이터에는 우리나라 교육과정이 반영되지 않고 있다. 교육과정에 대한 질문을 하면...', 'date': '2023.08.26.'}
# {'title': '인공지능- 음악을 작곡하는 AI도구', 'text': '인공지능 - 음악을 작곡하는 AI도구 [생성형 음악 제작 도구] 1. AudioCraft 2. OpenAI Jukebox 와 MuseNet 3. Amper Music 4. Soundful 5. AIVA (Artificial Intelligence Virtual Artist) 6. Ecrett Music 7. Soundraw 8. Amadeus Code 가트너의 설문조사에 따르면, 을 사용한 적이 있는...', 'date': '2023.08.09.'}
# {'title': '구글이 만든 인공지능 서비스 챗봇 구글 바드 사용해보기', 'text': '이미 사용해 보신분도 있겠지만 구글이 지난 구글I/O때 공개한 구글의 인공지능 서비스 챗봇 구글 바드를 이제 누구나 사용할 수 있도록... 즉 인공지능 서비스가 보여주는 답변이 항상 정답은 아닙니다. 그러나 아래와 같이 객관적인 답이 정해진 문제에 대한 답변은 꽤 정확하게...', 'date': '2023.05.16.'}
# ...
# {'title': 'Adobe AI 포토샵 일러스트 인공지능 컨텐츠 CR 로고 추가', 'text': 'Adobe AI 포토샵 일러스트 인공지능 컨텐츠 CR 로고 추가 2023년 10월 10일(현지시간), 세계적으로 유명한 소프트웨어 기업인 어도비(Adobe)가... AI 인공지능 컨텐츠 CR 기호의 활용과 기능 CR 기호는 이미지, 비디오, PDF 콘텐츠의 우측 상단에 표시되며, 물방울 모양에 CR이라 적힌...', 'date': '2023.10.13.'}
# {'title': '인공지능이 발전하면 사라질 직업, 생겨날 직업이 무엇이 있을까?', 'text': '특히 인공지능이 개발이 되면서 미래에는 없어질 직업들이 있다고 이야기하고 계실텐데요. 인공지능의 발전은 여러 산업과 직업에 영향을 미칠 수 있어 미래를 대비하기 위해서 미리 알아보고 준비하시는 것이 필요하답니다. 일부 직업은 자동화나 기술의 도입으로 인해...', 'date': '2023.05.25.'}
# {'title': "대구경동초 '한여름 밤의 디지털 플리마켓'···인공지능(AI)과...", 'text': "대구경동초 '한여름 밤의 디지털 플리마켓'···인공지능(AI)과 독서몰입교육 연계 대구 뉴스/교육 by 요즘대구 2023. 7. 21. 12:36 공감 대구시교육청 지정 인공지능(AI)교육 선도학교를 운영하고 있는 대구경동초등학교는 2023년 7월 20일(목) 18시 30분, 학교 운동장에서 학생 및...", 'date': '2023.07.21.'}
# {'title': '부모교육 [HELLO AI! 인공지능시대 자녀교육과 정신건강]', 'text': '인공지능시대 자녀교육과 정신건강] 참여자를 모집합니다! (งᐛ)ว (งᐖ )ว 인공지능시대에 살아가며 자녀를 어떤 인재로 키울 수 있을지에 대한 해답과 우리 아이들의 마음을 들여다보는 시간! ( •͈ᴗ-)ᓂ-ෆ 참여하신 분들 중 추첨을 통해 총 10분께 명지병원...', 'date': '2023.08.17.'}
# {'title': "[찾아라! 최초인물] 최초의 인공지능 로봇 예술가 '에이다'", 'text': '최초의 인공지능 로봇 예술가 에이다 시작해 볼까요? 시, 조각, 회화를 넘나들며 작품활동을 활발하게 하고있는 영국의 한 예술가... 오늘은 최초로 전시회를 열고 직접 창작한 시까지 낭송하는 인공지능 아티스트 에이다를 만나볼까요? 에이다는 2019년 영국에서 프로그래머...', 'date': '2023.05.11.'}
# {'title': '인공지능학과, 어떻게 준비하면 좋을까?', 'text': '인공지능 기술 (디지털 휴먼 등의 인간-공지능 간 자연스러운 감성의 교류를 제공할 수 있는 첨단 기술에 대한 이해 능력) 2. 확장/혼합현실 기술 (기술 사용자의 몰입감 및 현장감을 최대한 극대화할 수 있는 첨단 환경에 대한 이해 능력) 3. 실감 콘텐츠 기획 (최신 기술을 바탕으로...', 'date': '2023.09.05.'}
# {'title': '연결하고 인공지능(AI)인 CLOVA에게 온도와 습도값을...', 'text': '습도값을 인공지능(AI)인 Clova에게 음성으로 읽어달라고 해볼거에요! 먼저 아두이노와 센서를 연결하는 작업을 해야해요! 녹칸다... 이제 인공지능(AI)인 clova에게 측정한 온도와 습도값을 음성으로 읽어달라고 해볼거에요! 엔트리 캐릭터를 클릭하면 읽어주도록...', 'date': '2023.10.07.'}
# {'title': '구글 바드 사용법 구글 인공지능(Bard) AI 챗봇!', 'text': '구글에서도 챗GPT에 맞서기 위해서 인공지능 챗봇을 선보였는데요. 그래서 오늘은 구글 인공지능 챗봇, 구글 바드(Bard) 사용법에 대해서 알아보겠습니다. 구글 바드 사용조건 구글 바드는 챗GPT와 다르게 조건이 하나가 있는데 바로 만 18세 이상인 구글 계정에서만 사용이...', 'date': '2023.06.13.'}
# {'title': "달서중 '2023 인공지능(AI) 캠프'···AI·VR·로봇·드론...", 'text': "달서중 '2023 인공지능(AI) 캠프'···AI·VR·로봇·드론 교육 프로그램 대구 뉴스/교육 by 요즘대구 2023. 7. 25. 15:15 2 달서중 '2023 인공지능(AI) 캠프' 대구광역시교육청 선정 ‘SW-AI교육 중점 학교’인 달서중학교는 2023년 7월 22일(토), 작년에 이어 2회째 달성군 초등학생...", 'date': '2023.07.25.'}
# {'title': '전문 인공지능 챗봇 열풍!... (feat. 환경 관련 인공지능 사례)', 'text': '최근 세계적으로 주목받는 챗GPT와 같이 인공지능 기술은 일상 속 다양한 부분에서 도움을 주고 있는데요. 심지어 환경 문제에 대응하는 인공지능 기술 역시 개발되고 있는 상황입니다! 오늘은 푸루와 함께 세계를 흔든 챗GPT 사용법부터 국내 환경 관련 기술...', 'date': '2023.02.23.'}
# {'title': '누구나 쉽게 배우는 소프트웨어와 인공지능, 2023 온라인...', 'text': '코딩을 잘 모르는 이부터 코딩에 능수능란한 이들까지 새롭고 다양한 프로그램으로 소프트웨어, 인공지능과 친해질 수 있게 해주는... 어린이들이 사랑하는 친근한 캐릭터인 펭수나 엘사, 전 세계인이 사랑하는 BTS 등 특별한 캐릭터들이 프로그램의 주인공이 된 것이 반갑게...', 'date': '2023.06.22.'}
# {'title': '주말의 챗GPT, 인공지능에 의한 정보유출 우려 뉴스들 (ft....', 'text': "여튼 챗GPT 같은 인공지능이 코딩도 할 줄 안다는데 이것이 악용되면 해킹, 정보유출 등의 우려가 앞으로 더 커질 것임은 당연히 걱정이... 그러니 이런 기사 뒤에 '인공지능에 의한 해킹, 보안 우려에 대한 연구투자의 필요성'에 대한 것이 깔릴 수 밖에 없을 겁니다. 이에 대해서...", 'date': '2023.04.02.'}
# {'title': '인공지능이 주식시장을 구할 수 있을까?', 'text': '챗GPT의 갑작스러운 인기로 촉발된 인공지능에 대한 관심의 급증은 수조 달러의 주식시장 가치를 창출했습니다. 엔비디아는 현재 인공지능 시장에서 선두로 175% 이상 급등하여 1조 달러 클럽에 가입했으며, 메타도 119% 상승했습니다. 알파벳과 마이크로소프트와 같은 빅 테크...', 'date': '2023.06.14.'}
# {'title': '인공지능의 논란과 기회 3-Panic & Opportunities of AI', 'text': '나머지 나라들이 챗GPT에 재미 삼아 프롬프트(질문/명령)를 입력하는 동안 선점한 국가는 인공 슈퍼 지능을 얻게 된다. 핵무기 사용을 저지하려면 핵무기가 필요하다. 인공지능도 마찬가지다. 지구상 거의 모든 국가가 인공지능 개발이나 군비경쟁에 서로 협력하는 이유다....', 'date': '2023.06.07.'}
# {'title': '인공지능 스피커 기가지니LTE2 알아보기', 'text': '집안에 여러가지 가전을 제어할 수 있는 상태가 되면서 어느덧 인공지능 스피커에 대해 관심이 생기고 있습니다. 특히 저같은... 기가지니 LTE 2는 KT에서 출시한 인공지능 스피커 지니 라인업 제품 중 하나이며, 지니 2세대 제품입니다. 아무래도 KT 유저들을 타겟으로...', 'date': '2023.09.13.'}
# {'title': '구글 지메일, 인공지능으로 초안 ‘뚝딱’ 만든다', 'text': '구글 I/O 2023 (출처: 더모바일인디안(TheMobileIndian)) 구글이 발표한 새로운 생성형 인공지능(AI) 기능으로 지메일(Gmail) 작업이 더욱 빠르고... 단순히 사용자가 원하는 프롬프트를 입력하면 인공지능이 관련 지식을 기반으로 문장을 자동 완성시켜준다. 어조를 변경할 수 있는...', 'date': '2023.05.12.'}
# {'title': '챗GPT 사용법 인공지능 글쓰기부터 마케팅활용하는 방법 강의', 'text': '챗GPT 사용법 인공지능 글쓰기부터 마케팅활용까지 줌 특강 강의 챗GPT를 활용해서 할 수 있는 작업은 정말 다양합니다. 블로그 글쓰기... 지난번 진행한 챗GPT 사용법 강의에서는 "인공지능과 함께 글쓰기부터 마케팅까지" 주제로 활용에 대한 강의를 진행하였습니다....', 'date': '2023.07.01.'}
# {'title': '데이터안심구역에서 인공지능 빅데이터 분석과 파이썬 무료...', 'text': '같은 인공지능에 대한 관심과 열기가 대단합니다. 기업이나 기관, 업체에서 생산된 단일 DATA들을 다양하게 연계하여 분석할 때 실생활에... 빅데이터와 인공지능 등에 관심이 많고 분석 및 활용과 관련된 직무에 대해 알아볼 수 있는 진로 체험도 있습니다. 해당 커리큘럼은 매주...', 'date': '2023.05.31.'}
# {'title': '[사람나래] 인공지능으로 공무원 복무 관리, 일하는 방식...', 'text': "인사혁신처는 '인공지능 기반 지능형(스마트) 복무 관리 시스템'을 내년부터 시범 운영하고 오는 2025년까지 전 중앙행정기관이 본격 시행할 수 있도록 시스템을 구축한다고 밝혔는데요. 추진 배경을 정리하면 아래와 같습니다. 첫째, 전 중앙행정기관 공통 시스템을 통한 유연한...", 'date': '2023.06.20.'}
# {'title': 'MZ 세대의 자기 계발, 인공지능 시대에 자아 이미지부터 바꿔라.', 'text': '아날로그 세상에서 디지털 세상으로 바뀌고, 인공지능으로 인하여 기존의 일자리에서 새로운 일자리를 찾아야 하는 변화의 시점에서... MZ 세대 모두가 자아 이미지를 바꾸어 인공지능 시대에 주역이 되기를 바랍니다. 사랑합니다. 감사합니다. 모바 비즈 올림', 'date': '2023.06.24.'}
# {'title': '인공지능의 논란과 기회 4-Panic & Opportunities of AI', 'text': '우리 스스로 인공지능을 능가하지 못할 것이라고 말하는 것이 안전하다. 오픈AI 창업자 \'샘 알트만\'은 "오픈AI가 어떻게 큰 사업이 될지는 모르겠다. 슈퍼 지능을 구축한 다음, 그다음은 어떻게 할 것인지 거꾸로 물어보려고 한다"고 언급했다. 실제로는 꽤 사실적인 표현이다....', 'date': '2023.06.08.'}
# {'title': '인공지능 전문가 데이터라벨링, 알바와 전업으로 가능한 일', 'text': '본인도 무엇이 좋을까 고민하던 찰나 인공지능 전문가 데이터라벨링에 대한 이야기를 듣게 되었다. 미래 산업이라고 부를 정도로 많은 사람이 관심을 가지는 직종으로, 데이터라벨링은 알바와 전업으로 도전하는 추세다. 데이터라벨링은 기계 학습 및 모델을 훈련하기...', 'date': '2023.07.25.'}
# {'title': '인공지능으로 운전 습관... 혁신제품 ‘인공지능 기반 교통사고...', 'text': '인공지능(AI) 기술을 기반으로 도로 위험도 관찰, 범죄 차량 추적, 도로파손 여부, 고령 운전자 인지능력 등 빅데이터를 모으고, 운전자를 실시간으로 관리하고 파악해 안전운전을 하도록 교육합니다. 덕분에 많은 운전자가 자신의 운전 습관을 객관적으로 인지하고 개선해...', 'date': '2023.08.17.'}
# {'title': '네이버 하이퍼클로바X - 국내 초거대 AI 인공지능 모델 24일...', 'text': "챗 GPT의 '네이버' 버전이라고 생각하시면 된답니다.ㅎㅎ) 종종 초거대 인공지능(AI) 언어모델 관련 소식을 전하긴 했지만, 한국 기업에 대한 소식을 전하는 건 처음인 것 같은데요. ㅎㅎ (사실상 현재로서 거의 유일한 K-AI거대언어모델!ㅋㅋ) 아직 출시된 건 아니고요. 오는 8월...", 'date': '2023.08.22.'}
# {'title': 'AI관련주, 인공지능 챗GPT 그리고 관련주들', 'text': "정의한다 지능을 갖고 있는 컴퓨터 시스템 정도로 기억해두자 AI가 무섭다고 느껴졌던 영화 '아이로봇' AI가 산업에 미치는 영향 인공지능의 역사는 1700년 대 사람이 로봇처럼 체스를 두던 체스기계의 등장을 시작으로 체스 세계 챔피언과 맞붙은 IBM의 ‘딥 블루’, 이세돌...", 'date': '2023.02.27.'}
# {'title': '2023 온라인 코딩파티 시즌2 소프트웨어 인공지능 교육 6주간...', 'text': "과학기술정보통신부와 교육부, 한국과학창의재단은 누구나 쉽고 재미있게 소프트웨어와 인공지능 교육을 체험할 수 있는 '2023 온라인... 소프트웨어와 인공지능의 원리를 쉽고 재미있게 게임처럼 체험할 수 있도록 매년 새롭고 다양한 프로그램으로 구성하여 진행되고 있으며...", 'date': '2023.10.09.'}
# {'title': '2023년 지질자원 데이터 활용 및 인공지능 경진대회', 'text': '2023년 지질자원 데이터 활용 및 인공지능 경진대회 소식 입니다. 참가자격은 지질자원 연구데이터 활용·아이디어 제시 및 AI 모형 개발 등에 관심 있는 국민 누구나 입니다. * 2023년 지질자원 데이터 활용 및 인공지능 경진대회 : http://www.geodata-con.kr/2023/index.php 2023년...', 'date': '2023.06.10.'}
# {'title': '한국 기준금리 발표 및 전망부터 2023년 트렌드인 인공지능...', 'text': '글로벌 마켓토크: 결국 인공지능이 2023년 메가 트렌드가 될까? 마켓Chef: Chef가 생각하는 강세장의 조건은? 리서치 하이라이트... 한국 기준금리 발표 및 전망부터 2023년 트렌드인 인공지능, 기술주까지 삼성증권 유튜브로 POP하게 알아볼까요? 삼성증권 구독 이벤트...', 'date': '2023.06.14.'}
# {'title': '인공지능 보이스 피싱, 스미싱, 피싱 차단해 주는 싹다잡아 어플...', 'text': '출처 PHYLLIS 인공지능 싹다잡아 어플은 위 어플들보다 더 강력하고 유익한 어플인 거 같아서 교육합니다. 우리모두 보이스 피싱, 스미싱 등에서 자유로우면 좋겠습니다. 인공지능 보이스 피싱, 스미싱, 피싱 차단해 주는 싹다잡아 어플 교육 싹다잡아 어플 보이스 피싱 차단하고...', 'date': '2023.07.24.'}
# {'title': 'ai 관련주 루닛 주가 인공지능 의료기기', 'text': 'ai 관련주 루닛 주가 인공지능 의료기기 요즘 ai관련주에 대한 관심이 많아지면서 ai도 좀 더 세분화되고 있습니다. 원래 처음 인공지능과 AI에 불을 붙인 것은 "Chat GPT"의 등장이었습니다. 질문만 하면 정말 사람처럼 정확한? 대답을 해주니 너 나 할 것 없이 관련 사업에...', 'date': '2023.08.08.'}
# {'title': '인공지능 교육, 정보보호 교육 [아주대학교] 일반대학원 후기...', 'text': '인공지능 교육, 정보보호 교육 [아주대학교] 일반대학원 후기 신입생 모집 안녕하세요. 취업비서 인크루트 입니다. 산업보안, 기계학습... 분이라면 인공지능 교육, 정보보호 교육 [아주대학교] 일반대학원 후기 신입생 모집 지원하실 수 있습니다. 교육, 정보보호...', 'date': '2023.07.17.'}
# {'title': '인공지능(AI) 강군, 방위사업청이 대전시와 함께 이끕니다!', 'text': '이번 포럼은 방위사업청의 대전시대 개막 이후, 대전광역시와 함께 하는 첫 번째 행사로서 국정과제인 AI기반 과학기술 강군 육성을 위해 필수적인 국방 인공지능과 반도체 발전 미래 전략을 중앙정부와 지방자치단체가 함께 준비한다는 의미를 갖습니다. 대통령 직속...', 'date': '2023.08.02.'}
# {'title': 'AI 인공지능 ETF SRVR, CLOU, IROB (ft. 챗gpt 관련주...', 'text': '인공지능(AI)가 답변을 해주는 채팅 플랫폼이다. 지금까지 우리는 검색을 하면 키워드 중심으로 자료가 나오고 그중에서 원하는 자료를 찾고 정보를 취합했다. 그러나 이제는 자료를 찾아서 취합해 주는 역할을 인공지능이 대신하게 될 것이다. 인간은 아닌데 인간처럼 정보를...', 'date': '2023.01.30.'}
# {'title': '네이버 큐 cue 인공지능 AI 검색 하이퍼클로바X 점점...', 'text': '마이크로소프트의 New Bing처럼 네이버 검색에 AI 인공지능을 결합한 대화형 AI 검색 서비스인 cue가 드디어 서비스를 시작했습니다. 네이버 하이퍼클로바X 요소중 하나인 네이버 cue는 키워드 기반이던 기존의 검색 방식에서 벗어나 대화를 통해 원하는 결과를 좀 더 편하게 쉽게 얻을...', 'date': '2023.09.21.'}
# {'title': 'SW개발자 양성과정 - 챗GPT를 활용한 인공지능 개발자 교육생...', 'text': 'SW개발자 양성과정 - 챗GPT를 활용한 인공지능 개발자 교육생 모집 안녕하세요. 취업비서 인크루트 입니다. 오늘은 청년취업사관학교 금천캠퍼스와 함께하는 SW개발자 양성과정 - 챗GPT를 활용한 인공지능 개발자 교육생 모집에 대해서 자세히 안내해드리는 시간을...', 'date': '2023.06.27.'}
# {'title': '소프트웨어·인공지능과 함께! 디지털 새싹 캠프 1학기에도...', 'text': '소프트웨어·인공지능과 함께! 디지털 새싹 캠프 1학기에도 함께해요 ✔️ 디지털 새싹 캠프 학기 중 어떻게 운영되나요? ✔️ 디지털... ▶ 자세히 보기 : http://bit.ly/3MeQs31 #디지털새싹캠프 #소프트웨어 #인공지능 #교육부 디지털 새싹 캠프 1학기에도 함께해요 디지털 새싹...', 'date': '2023.04.06.'}
# {'title': '[송파cctv] 화재 감시와 침입감지가 가능한 인공지능cctv...', 'text': '인공지능이 꾸준히 개발을 거듭하는 가운데 2010년 이후부터는 cctv 역시도 인공지능과 결합한 형태로 감시에 있어 더욱 편리해졌습니다. 그리고 이제는 화재 감시 역시도 cctv로 가능하게 되었는데요, 자비스넷은 그 화재cctv에 강점을 보이는 회사입니다. 서울cctv 이번에...', 'date': '2023.09.18.'}
# {'title': '「인공지능 시대 안전한 개인정보 활용 정책 방향」 살펴보기', 'text': '개인정보보호위원회( 이하 ‘개인정보위’)가 8월 3일 「인공지능 시대 안전한 개인정보 활용 정책 방향」을 발표하였습니다. AI에 대한... 이번 포스팅에서는 최근 발표된 「인공지능 시대 안전한 개인정보 활용 정책 방향」을 통해 개인정보위가 향후 중점적으로 추진해 나갈...', 'date': '2023.08.10.'}
# {'title': '인공지능이 정보를 처리하며 발생하는 오류, 할루시네이션', 'text': '인공지능이 정보를 처리하며 발생하는 오류, 할루시네이션 할루시네이션은 인공지능(AI)이 정보를 처리하는 과정에서 발생하는 오류를 이야기합니다. 챗GPT등 인공지능 서비스가 활성화됨에 따라 나타난 신조어로, 질문의 맥락과 관계 없는 답을 이야기 하거나 사실이 아닌...', 'date': '2023.06.19.'}
# {'title': '인공지능 붐이 불러온 데이터센터 수요( 에퀴닉스 디지털리얼티 )', 'text': '자극된 투자 심리와 인공지능에 대한 기대는 에퀴닉스에게 에퀴닉스와 디지털리얼티 모두에 대한 투자 심리가 개선된 것은 맞으나, 시장에서는 디지털리얼티보다는 에퀴닉스가 AI 데이터 센터 수요 수혜를 받을 것으로 전망하고 있습니다. 이와 같은 수혜 노출의 차이는...', 'date': '2023.09.14.'}
# {'title': '인공지능 기업투자 : 성장성과 추천 종목 정리', 'text': '인공지능 기업투자 : 성장성과 추천 종목 정리 인공지능 기술은 기계 학습, 자연어 처리, 이미지 분석 등을 통해 사람과 유사한 인지 능력을 갖는 시스템을 개발하는 기술이다. 최근 몇 년간 인공지능 기술은 계속해서 발전해 왔으며, 향후에는 더욱 빠른 성장이 예상된다. 현재...', 'date': '2023.06.06.'}
# {'title': '[광주cctv] 400만 화소는 기본으로, 인공지능 영상분석까지!', 'text': '자비스넷은 인공지능을 통한 더욱 빠르고 안전한 보안을 제시합니다. 안녕하세요 경기cctv 광주cctv 설치 전문업체 자비스넷입니다.... 경기cctv 오늘 설치를 진행한 경기도 광주시의 한 순대국 전문점엔 자비스넷 만의 강점인 영상분석이 적용된 400만 화소...', 'date': '2023.09.11.'}
# {'title': '반도체가 인공지능에 사용된다고? 차세대 PIM 반도체', 'text': '인공지능은 인간의 뇌 속 신경망을 본뜬 ‘인공신경망’을 이용하여 데이터를 학습하고 응용합니다. 인간의 뇌가 수많은 세포의 상호작용으로 작동하는 것처럼 인공신경망도 수많은 연산 과정이 필요한데, 이러한 연산 과정의 속도를 반도체가 높여줍니다. 에...', 'date': '2023.03.28.'}
# {'title': '인공지능과 편향성', 'text': '인공지능은 편향성이 없는 도구로서 개발되지만, 훈련 데이터와 개발 과정에서 인간의 편향이 반영될 수 있습니다. 이는 인공지능 시스템이 편향된 결론이나 의사결정을 내리는 경우를 발생시킬 수 있습니다. 이러한 편향성은 사회적인 불평등과 인종 차별 등과 관련된 문제를...', 'date': '2023.06.23.'}
# {'title': '의료 AI 인공지능 관련주 딥노이드 주가 전망', 'text': 'AI 플랫폼: DEEP: PHI는 고성능의 장비나 프로 그래밍 지식이 없어도 인공지능 (AI)에 관심만 있다면 간단한 모듈 조립만으로 인공지능 (AI) 모델 기획과 솔루션 개발을 경험할 수 있는 플랫 폼입니다. AI 교육: AI와 코딩에 관한 사전 지식이 없어도 누구나 AI 기초부터 AI 개발...', 'date': '2023.08.23.'}
# {'title': '구글 바드 사용법 1 - 인공지능 바드 소개 및 회원가입!', 'text': "지난 포스팅에선 구글 인공지능 바드와 챗gpt의 차이점에 대해 알아봤는데요. 오늘은 구글 바드 사용법 첫 번째 시간! 구글 바드 소개와 가입에 대해 알아보겠습니다! 1. 구글 인공지능 바드란? 구글에서 나온 인공지능 '구글 바드'는 챗봇 형식으로 챗gpt 처럼 질문을 한 뒤 답변을...", 'date': '2023.06.19.'}
# {'title': '인공지능 기술 프론티어는 어디까지? AI EXPO KOREA 2023', 'text': '2023년 5월 10일부터 12일까지 3일간 서울 COEX에서는 "AI EXPO KOREA 2023(국제인공지능대전)"이 개최되었습니다. 이번 행사에서는 인텔, HP... ▲ AI EXPO KOREA 2023 현장 (출처 : 촬영) 이번 AI 기술 설명회에서는 많은 교수와 연구생들이 언어 , 영상 , 예측 ...', 'date': '2023.05.22.'}
# {'title': '인공지능으로 문제를 만들고 채점과 피드백은 MS...', 'text': '교사의 교육 활동 중 가장 중요한 축을 이루는 학생 평가를 인공지능과 에듀테크를 활용하여 쉽게, 효율적으로, 체계적으로 처리할 수 있는 한 가지 예시를 제시한 것이다. ChatGPT의 등장으로 인해 촉발된 인공지능 교육에 대한 관심은 사실 대부분 호기심에 가득찬 탐색 수준에...', 'date': '2023.07.25.'}
# {'title': '간단하고 강력한 추천 AI 인공지능 번역기! DeepL 사용법 후기!', 'text': 'SoftWare.Web 간단하고 강력한 추천 AI 인공지능 번역기! DeepL 사용법 후기! 영댕이 2023. 3. 30. 10:29 최근 우리는 세계 곳곳에서 생산되는... 그런데 최근에는 AI 인공지능 기술의 발전으로 인해서 번역기의 성능이 크게 향상되어서 이제는 간단한 정보의 문맥은 크게 불편함...', 'date': '2023.03.30.'}
# {'title': 'AI(인공지능)가 바꾼 우리의 삶, 그리고 앞으로 전망', 'text': 'AI(인공지능)은 현재까지 빠르게 발전하고 있으며, 이러한 발전은 우리의 삶에 깊은 영향을 미치고 있습니다. AI는 컴퓨터나... 이 글에서는 AI(인공지능)가 우리의 미래에 어떤 변화를 가져올 것인지, 그리고 그 변화가 어떤 긍정적이나 부정적인 측면을 가질 수 있는지에 대해...', 'date': '2023.10.19.'}
# {'title': "'그림으로 배우는 AI 인공지능 기술의 이해' 참석후기", 'text': "'그림으로 배우는 AI 인공지능기술의 이해' 참석후기 4월 21일 금요일 오전 10시 신도림 역 스마트 구로 홍보관에 40명이 넘는 구로구민들이 모였습니다. 빅데이터, 인공지능, 네트워크 기술 등의 IT 기술이 발전을 거듭하면서 모든 것이 디지털화하는 ‘디지털 트랜스포메이션’...", 'date': '2023.05.04.'}
# {'title': '인공지능과 함께 읽은 시를 그린 그림', 'text': '그 시를 학습한 인공지능이 그림에 구상적 이미지들을 덧입히는 과정으로 이루어집니다. 추상적 감각과 감정은 언어로 개념화되고 인공지능이 학습한 수많은 데이터와 기록에 의해 구상화됩니다. 이 안에서 근거가 되는 기록은 나를 포함하지만 내 것이 아닌, 마치...', 'date': '2023.10.20.'}
# {'title': 'AGV AMR 차이점 ? 인공지능 AI 로봇 특징 정리', 'text': '로봇 기술이 계속해서 빠르게 발전하고 있는 가운데, 인공지능 AI 기술의 도입으로 더욱 다양하고 복잡한 작업까지 수행 가능해지고... 이번 페이지에서는 AGV와 AMR의 기본 원리와 차이점을 알아보고, 이 두 기술이 어떻게 로봇으로 발전하고 있는지를 중심으로...', 'date': '2023.09.02.'}
# {'title': '생성형 인공지능 모델의 책무성 관련 이용자 보호 쟁점 논의', 'text': '학계, 기업, 시민단체, 정부 등 총 30여명의 각계 전문가로 구성된 민관협의회는 그동안 ‘알고리즘 저널리즘 시대의 이용자 보호 방안’, ‘생성형 인공지능 기반 챗봇 서비스에서의 이용자 보호 쟁점’ 등을 다루었으며, 앞으로도 지능정보시대 이용자 보호 현안들에 대해...', 'date': '2023.06.29.'}
# {'title': '경제신문 :) ‘의료 인공지능’ 냄새만 풍겨도 상승…올들어...', 'text': '‘의료 인공지능’ 냄새만 풍겨도 상승…올들어 6배 오른 종목도 (매일경제) 바이오 종목 투자 대세로 부상한 ‘의료AI’ 루닛 등 외국인 순매수 상위권에 포진 © owenbeard, 출처 Unsplash 한 줄 요약 코스닥 시장에 상장된 의료 (AI) 관련주들의 주가는 큰 폭으로 오르고...', 'date': '2023.09.12.'}
# {'title': '뇌졸중 및 전립선암 솔루션은 전세계 유일한 인공지능 솔루션 제품', 'text': '관리까지 인공지는 다중 뇌질환 분석 + 인공지능 다중 암 분석 뇌, 전립선, 폐로 확장 중인 동사의 의료 영상 진단 사업 영역 인공지능 기반 의료 영상 진단 기술 개발 전문기업 신규 플랫폼 출시 및 기업·병원과의 협약을 통한 판로 확보 일본 최대 원격의료기관...', 'date': '2023.06.22.'}
# {'title': '챗GPT 인공지능 AskUp을 카카오톡에서 이미지 글자까지...', 'text': '챗GPT 인공지능 대화형 문장검색이 대세인가요? 이제 챗GPT 인공지능 AskUp을 카카오톡에서 이미지 글자까지 인식해서 사용할 수 있습니다. 카카오톡 채팅에서 인공지능 대화형 검색과 이미지 글자까지 아주 대단한 기술이죠. 서비스 시작한 지 3일 된 거 같은 데 사용자가...', 'date': '2023.03.12.'}
# {'title': 'AI 인공지능 관련주 모음집: 반도체 기업 포함!', 'text': '대다수는 인공지능 관련 사업을 영위하고 있다는 이유만으로 수 배씩 오르는 기현상을 보이고 있으니 말이다. 물론, 이 말이 AI 산업 전체를 부정적으로 바라본다는 뜻은 아님. MS, 구글, 오라클, 아마존, 메타, AT&T, 암젠 등 각 산업의 꼭짓점 기업들이 잇따라 을 채택하고...', 'date': '2023.07.22.'}
# {'title': '대구시 인공지능(AI) 민원상담사 "뚜봇아~ 치킨 줄래?" 이벤트', 'text': '대구시 인공지능(AI) 민원상담사 "뚜봇아~ 치킨 줄래?" 이벤트 대구시 인공지능(AI) 민원상담사 뚜봇! 뚜봇에게 대구 대표 축제인 대구치맥페스티벌에 관해 물어보고 간단히 인증샷을 올리는 이벤트에 참여해 보세요 총 50분을 추첨하여 치킨 기프티콘(2만원)을 선물로 드립니다...', 'date': '2023.08.11.'}
# {'title': '어도비AI 포토샵 파이어플라이 모델2 인공지능 디자인', 'text': '어도비AI 포토샵 파이어플라이 모델2 인공지능 디자인 어도비AI 포토샵 파이어플라이 모델2 인공지능 디자인 어도비(Adobe)는 지난 몇 년 동안 AI를 활용한 혁신적인 제품과 모델을 개발하여 인공지능(AI) 시장에서 강력한 포지션을 구축하고 있습니다. 이 회사는 최근에도 AI 제품과...', 'date': '2023.10.14.'}
# {'title': '인공 지능 판사는 공정할까?', 'text': '이런 의미에서 본다면 인공 지능 판사는 과연 수많은 경우의 수와 맥락을 파악하는 게 가능할까요? 사회 문제를 윤리적으로 바라보기... #인공지능판사는공정할까? #개암나무 #희진쌤책읽어주세요 #독서지도사추천도서 #어떤양형의이유 #공정성 #공평 #윤리 ...', 'date': '2023.10.13.'}
# {'title': '인공지능 사례 자율주행 의료 번역 총정리', 'text': '인공지능 사례 자율주행 의료 번역 총정리 인공지능(AI)은 현대 사회에서 아주 중요한 역할을 맡고 있다. 우리는 이미 AI 기술을 여러 사례를 통해 볼 수 있다. 오늘은 인공지능의 다양한 사례를 살펴보려고 한다. 인공지능 개념 은 크게 약한 과 강인한 으로...', 'date': '2023.06.06.'}
# {'title': '로봇 강아지 인공지능 AI의 루나 로봇 강아지첫만남 후기', 'text': '얼리어답터 리뷰/IT정보 로봇 강아지 인공지능 AI의 루나 로봇 강아지첫만남 후기 by 엔돌슨 2023. 8. 29. 로봇 강아지 인공지능 AI의 루나 로봇 첫만남 후기 딸아이를 위해서 루나 펫로봇을 구매하였습니다. 이전에도 소니 아이보 및 에일릭 로봇을 잘 가지고 놀았는데요. 소니...', 'date': '2023.08.29.'}
# {'title': '인공지능 마케팅이란? 데이터를 활용해야하는 이유! SNS...', 'text': "AI를 활용한 인공지능 마케팅은 어떤식으로 할 수 있을까요? 오늘은 인공지능 마케팅과 데이터를 활용한 데이터 기반 의사결정을 해야하는 이유에 대해 알아보겠습니다! 마케터들의 고민 마케터들의 고민중 하나는 투자된 돈으로 어떠한 일들이 일어났는지 '한 번에' 알기...", 'date': '2023.06.22.'}
# {'title': '안내] 인공지능 빙, 바드, 챗GPT, 클로바X 활용스타벅스 vs...', 'text': '인공지능과 빅데이터 활용 상권분석 전문가 김영갑 교수입니다. 이미 공지하여 드렸던 상권분석전문가과정 3주차 프리뷰 특강의 내용을 다음과 같이 변경하게 되었습니다. 인공지능 빙, 바드, 챗GPT, 클로바X 활용 스타벅스 vs 교촌치킨 상권전략 비교 이전에 공지하였던 프리뷰...', 'date': '2023.10.03.'}
# {'title': "'ai vs 인간'.. 인공지능 공부하면서 얻은 질문 11가지", 'text': "같은 인공 생명체) © comparefibre, 출처 Unsplash 사람들은 ai를 두고 '의인화의 오류'에 빠진다. 이들은 인간이 아니다. © rodlong, 출처 Unsplash 인공지능 로봇과 사람이 싸울지 화합하며 살아갈지는 아무도 알 수 없다. © santesson89, 출처 Unsplash ai의 생존욕구...", 'date': '2023.09.19.'}
# {'title': '[인공지능 빙, 바드, 챗GPT, 클로바X, 뤼튼에게 묻다]...', 'text': '안녕하세요 인공지능과 빅데이터를 활용해서 소상공인을 위한 상권분석과 온라인마케팅을 가르치고 있는 김영갑교수입니다. 오늘은 지하철을 이용하며 인공지능 챗봇이 어디 정도 정확한 답변을 주는지 비교하는 실험을 해 보았습니다. 우리의 삶 속에서...', 'date': '2023.09.07.'}
# 완료

# %%
#저장된 게시물 리스트를 데이터프레임으로 변환후 csv로 저장
df = pd.DataFrame(result)
df
# Out:
#                                        title  \
# 0    엘지 휘센 인공지능스스로에어컨(FQ19P7DPAN) 누수현상 해결...
# 1               로보어드바이저 수익률 비교, 인공지능 투자 성과는?
# 2           [종목분석] 의료 인공지능 딥노이드 주가 전망을 살펴봅니다
# 3                AI 인공지능 파이토치 서적으로 가볍게 시작해보죠
# 4      NPU 관련주 뜻 - 인공지능 구글 텔레칩스 칩스앤미디어 주가 전망
# ..                                       ...
# 325          로봇 강아지 인공지능 AI의 루나 로봇 강아지첫만남 후기
# 326       인공지능 마케팅이란? 데이터를 활용해야하는 이유! SNS...
# 327  안내] 인공지능 빙, 바드, 챗GPT, 클로바X 활용스타벅스 vs...
# 328       'ai vs 인간'.. 인공지능 공부하면서 얻은 질문 11가지
# 329     [인공지능 빙, 바드, 챗GPT, 클로바X, 뤼튼에게 묻다]...
#
#                                                   text         date
# 0    엘지 인공지능스스로에어컨 분해방법은 해 보지 않으면 어렵고 당황스럽지만 막상 해 보...  2023.08.09.
# 1    그럼 인공지능인 로보어드바이저와 일반 펀드의 운용 성과는 어땠을까요? 2022년 펀...  2023.09.26.
# 2    그 중에서 오늘은 인공지능 딥노이드 주가를 살펴보려고 하는데 해당 종목은 이미 많이...  2023.08.30.
# 3    인공지능이 표면적으로 한풀 꺽였다고는 하지만 관련된 서적과 툴들은 꾸준하게 발전하고...  2023.10.02.
# 4    NPU 관련주 뜻 - 인공지능 구글 텔레칩스 칩스앤미디어 주가 전망 NPU 뜻 NP...  2023.10.09.
# ..                                                 ...          ...
# 325  얼리어답터 리뷰/IT정보 로봇 강아지 인공지능 AI의 루나 로봇 강아지첫만남 후기 ...  2023.08.29.
# 326  AI를 활용한 인공지능 마케팅은 어떤식으로 할 수 있을까요? 오늘은 인공지능 마케팅...  2023.06.22.
# 327  인공지능과 빅데이터 활용 상권분석 전문가 김영갑 교수입니다. 이미 공지하여 드렸던 ...  2023.10.03.
# 328  같은 인공 생명체) © comparefibre, 출처 Unsplash 사람들은 ai...  2023.09.19.
# 329  안녕하세요 인공지능과 빅데이터를 활용해서 소상공인을 위한 상권분석과 온라인마케팅을 ...  2023.09.07.
#
# [330 rows x 3 columns]

# %%
#데이터 프레임 저장
# csv는 sep 쉼표가 반드시 있어야 한글이 안깨짐
df.to_csv(f'./naver_{fname}.csv', sep=',', encoding='utf-8-sig')

# %% [markdown]
# # 구글 플레이 스토어 리뷰

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time, random, pandas as pd

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=953,0')
options.add_experimental_option("detach", True)

driver = webdriver.Chrome( options = options)
url = 'https://play.google.com/store/apps/details?id=com.coupang.mobile.play'
driver.get(url)
time.sleep(random.randint(2,3))

# %%
# 리뷰 더보기 클릭
xpath = '//*[@id="ow97"]/section/div/div[2]/div[5]/div/div/button/span'
driver.find_element(By.XPATH, xpath).click()
time.sleep(random.randint(2, 3))

# %%
# 스크롤
for i in range(10):
    review_box = driver.find_element(By.CSS_SELECTOR, 'div.fysCi')
    driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', review_box ) #스크롤할 객체
    time.sleep(random.randint(2, 3))

# %%
# get_view()
reviews = driver.find_elements(By.CSS_SELECTOR, 'div.RHo1pe')
result = []

for view in reviews:
    con_dict = {}
    con_dict['text'] = view.find_element(By.CSS_SELECTOR, 'div.h3YV2d').text
    con_dict['stars'] = view.find_element(By.CSS_SELECTOR, 'div.iXRFPc').text
    con_dict['date'] = view.find_element(By.CSS_SELECTOR, 'span.bp9Aid').text
    result.append(con_dict)
    print(con_dict)
    
print('완료')
# Out:
# {'text': '좋은 컨텐츠들이 많이 늘어 영어공부에 유용합니다. 다만 1. 영한 통합자막 지원 / 2. 구간이동 기준조정 기능 (10초 이외에 2초, 5초) 이 있으면 도움이 많이 될것 같은데, 개발팀에서 검토 해주시면 좋을것 같습니다. (프렌즈, 오피스 등 넷플릭스에서 보면서 제공되던 기능들이 여기서 되지 않아 아쉬움을 느끼는 사람이 많을것 같아요~)', 'stars': '', 'date': '2023년 10월 3일'}
# {'text': '몇주 전부터인가 갤럭시탭 s8로 앱 실행시 로딩화면만 지속되고 화면이 안넘어갑니다. 몇번 껐다키기를 반복해서 앱이 실행되더라도 영상마다 로딩이 걸리고, 자막 선택상태인데도 표출이 안되구요. 다른 ott 어플은 문제가 없는데 쿠플만 그러네요. 폰으로 실행했을때는 이상 없는데.. 조치 부탁드립니다', 'stars': '', 'date': '2023년 10월 21일'}
# {'text': '1. 어떤 종류의 프로그램이라도 기본적으로 스마트폰 세운 상태로도 시청할 수 있기를 바랍니다. 터치하면 무조건 세로 보기로 전환되는 것은 바람직하지 않습니다. 2. 좌측 끝 쯤에 화면밝기 바는 있습니다만 가로세로 화면에서 사용하도록 우측 끝 쯤에 🔊 바를 넣어 주세요. 3. 좌로 우로 밀어서도 뒤로 가기 및 앞으로 가기 기능을 넣어주세요.', 'stars': '', 'date': '2023년 11월 7일'}
# {'text': '영상을 다운로드하면 와이파이,데이터없이도 볼수있는게 아니였나요?저장하고 와이파이,데이터를 키지않고보았더니 처음 4분은 잘볼수있었는데 나중에는 와이파이가 필요하다며 안되더라구요,아닌 미디어도있는데 왜 그런건지 궁금합니다.넷플릭스보다 재미있는게많아서 쿠팡플레이를 가입하고 넷플릭스를 지우려고했는데 넷플릭스보다 안좋은것같습니다.이 부분대해서 답변부탁드립니다.', 'stars': '', 'date': '2023년 10월 8일'}
# {'text': '단점 왜캐 안고쳐요? ㅡㅡ 1. 회차 검색 불가 (과거회차 볼려면 한세월 내리고 영상보고 돌아가면 다시 첨부터 다시 내려야함) 2. 드라마 예능등 보다가 뒤로가기 등 회차목록으로 돌아가기 없음 (무조건 다시 검색해서 프로필 눌러야 회차나옴) 3. 오프닝 스킹등 없음. 4. 최근회차가 너무 늦음. (티비 다시보기 무료보기 보다도 늦음 ㅡㅡ) 그 외에도 많은데 이건뭐 관리자가 앱 안쓰는거나 마찬가지네여 개답답함', 'stars': '', 'date': '2023년 10월 5일'}
# {'text': '개선사항 정확하게 말씀드립니다. 제발 고쳐주세요. 특별한거 아닙니다. 다른 앱에선 다 가능한 기능입니다. 1. 이전화 버튼 만들어주세요. 다음화는 있는데 이전화는 왜 없나요... 이전편 보려면 회차 들어가서 스크롤 무한히 내려야하네요 ;;;; 2. 무한도전 볼때 회차들어가면 매번 1회부터 떠있습니다. 500화 보려면 매번 스크롤 엄청 내려야해요. 예를 들어서 350회 보고있던 중이면 350회 부터 나와야지 왜 항상 1회부터 나오나요. 진짜 스트레스 만땅입니다;;;; 쿠팡은 최고인데 쿠플은 왜이런지 참...', 'stars': '', 'date': '2023년 10월 27일'}
# {'text': '만족해요. 액션이랑 코미디를 좋아하는데 그 취향에 맞는 작품은 많네요. 근데 TV앱에서 버그를 경험했습니다. 일본 프로그램 보다가 자막이 잘 나오다가 다음 회차로 가니까 아예 자막이 안 나오더라고요. 모든 회차가 마찬가지였고 메인 페이지로 가고 다시 돌아와도 결과는 같았어요. 앱을 나갔다가 들어오니까 정상적으로 자막이 나오던데 처음엔 2화까지만 자막을 지원하나 싶었습니다. 다른 분이 이걸 경험 했으면 아예 안 볼 수도 있겠다 싶더군요. 수정하는게 좋다고 생각합니다.', 'stars': '', 'date': '2023년 11월 16일'}
# {'text': '샤오미 미스틱에서 재생시 검은화면에 자막만 나오고 뒤로가기나 기타 다른 작동시 바로 다운되어 전원을 껐다 켜야합니다. 지켜본결과 주로 자동재생버튼, 이어보기 등과 관련된 것 같으니 빠른 확인 후 조치 바랍니다.', 'stars': '', 'date': '2023년 12월 7일'}
# {'text': '아니... 다운로드 받아서 시청하는데 네트워크 오류가 왜 뜨냐구요... 개빡치게 캐쉬삭제 업데이트 지웠다 깔기 재부팅 저장한거 지웠다 깔기 할 수 있는 수단을 다 해도 자꾸 네트워크 오류 하... 저장해서 보는데 왜 네트워크 오류가 뜨는지 도저히 이해가 안가네요 제발 개선좀요 제발🙏', 'stars': '', 'date': '2023년 11월 26일'}
# {'text': '제발 앱에서 자막크기 좀 키울 수 있게 해주세요. 아니면 브라우저로 볼 때 자꾸 앱에서 보라는 팝업이라도 안 뜨게 해주시든지요. 갤럭시탭울트라에서는 앱으로 보면 자막이 너무너무 쪼그매서 어쩔 수 없이 크롬으로 보는데, 자꾸 플레이 중간에 앱에서 보라는 팝업이 떠버리는 바람에 영상 끊기고 로그인까지 같이 풀리고 다시 로그인해서 이어보기 하더라도 보던 위치에서 이어보기되지도 않아요... 진짜 미쳐버리겠어요...', 'stars': '', 'date': '2023년 10월 14일'}
# {'text': '시청하다가 홈으로 나가면 재생중이던 영상이 아래쪽에 작게뜨는데 가끔가다가 검정화면으로 뜨면서 화면이 눌러지지도 않고 다시 어플로 들어가도 검은화면은 계속 유지돼서 아예 영상을 볼 수도 없고 검정화면을 끌수도 없습니다. 검정화면을 닫으려면 핸드폰 전원을 아예 꺼버리는 방법밖에 없어서 이건 빨리 고쳐졌으면 좋겠어요.', 'stars': '', 'date': '2023년 8월 13일'}
# {'text': '컨텐츠의 양과 질은 논외로 하더라도, 당최 다운로드 기능은 왜 있는지 모르겠네요. 와이파이 환경에서는 안되나요? 다운로드를 할때는 창을 활성화 시켜두고 지켜보고 있어야 하나요? 어렵게 다운된 파일은 왜 그렇게 에러가 많나요? 20년 전 P2P 사이트도 이정도는 아니었네요. 1기가 다운 받으려면 하루가 넘게 걸리기도 하네요. OTT 앱을 3개 쓰는데, 단연코 최악입니다.', 'stars': '', 'date': '2023년 9월 13일'}
# {'text': '좋은 어플 감사합니다. 저 그런데 가로보기 모드일때 볼륨키 위치가 네비키 위치와 겹쳐있는데, 볼륨키가 안보일때 백키 홈키 누르려다가도 볼륨조정이 되어서 볼륨이 갑자기 커질때가 많아요. 업데이트해도 그 문제 해결이 안되어있어서 수정요청드립니다. 개발자분들 화이팅입니다!!', 'stars': '', 'date': '2023년 9월 13일'}
# {'text': '불편한 점) 1) 멀티프로필 잠금기능없어 불편합니다. 2) 컨텐츠가 다른 ott에 비해 개인적으로 부족. 쿠팡쇼핑목적으로 가입하지 쿠팡플레이만을 위해 결제를 할 것 같진 않아요. 3) pc로 컨텐츠 간략 섬네일재생화면크기가 너무 작습니다. ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ 그래도 쿠팡쇼핑 겸 이용할 수 있어 좋습니다.', 'stars': '', 'date': '2023년 9월 2일'}
# {'text': '앱 오류랑 버벅거리는게 너무 심해요 영상시청 중에 잠시 핸드폰 화면이 꺼졌다 켜지면 무조건 나갔다가 다시 들어와야 영상재생이 됩니다... 시청중인 컨텐츠 삭제하기도 눌러도 안없어지는 일이 허다하고요. 영상 하나를 여러번 멈췄다가 보면 재생중인 목록에 하나의 영상이 여러개 뜨기도 해요. 이 외에도 그냥 앱이 느리고 버벅거리고 영상재생 오티티라기에는 너무 불편합니다.', 'stars': '', 'date': '2023년 9월 9일'}
# {'text': '얼마전에 스포방지 하기위한 설정이 업데이트 되어 너무 좋은데, 썸네일도 약간 신경써주시면 감사하겠습니다. 예를들어, 축구에서 스포방지 하려고 스코어를 가렸는데 특정팀의 특정선수가 골세리머니하고 있는 장면이 썸네일 화면이라면, 스코어는 가렸지만 누가 이겼겠구나 이선수가 골을 넣었네 등 반쪽 스포가 되서 사실상 스코어 가리는 의미가 없어지는 것 같습니다.', 'stars': '', 'date': '2023년 8월 22일'}
# {'text': '다른 건 정말 다 좋았어요 영화나 드라마 쿠팡 시리즈같이 정말 다 좋았지만 딱 하나 아쉬웠던 건 스포츠 축구나 야구 스코어 좀 가리는 설정이 없나 하고 찾아봐도 없더라고요 축구는 거의 새벽에 해서.. 보기가 힘들어 하이라이트를 많이 보거든요 그래서 출근 퇴근 시간에 하이라이트를 많이 보는 스타일인데 하이라이트, 풀경기 들어가면 떡하니 스코어 표시 되어있고 그게 스포가 돼버리니 경기 보는 맛이 없어져서 너무 불편해요 스코어 가리는 설정 추가해줬으면 좋겠어요 라리가 시즌 시작하면 하이라이트나 풀 경기 계속 볼 텐데 스포가 되면 보기가 싫어져요... 제가 못 찾은 걸 수도 있는데 만약 있다면 알려주세요! 만약 그런 설정이 없다면 꼭 추가해 주셨으면 좋겠습니다!', 'stars': '', 'date': '2023년 7월 20일'}
# {'text': '유플러스티비에서 앱 설치 후 사용중입니다. 앱 내 검색탭에서 콘텐츠 검색을 하려하는데 검색칸에 글자만 입력되고 검색은 전혀 되지 않습니다. 입력 후 확인버튼을 눌러도 하단의 지금 뜨는 콘텐츠로만 넘어갑니다. 티비앱 내에서 콘텐츠 검색은 어떻게 하는지, 혹은 정상적으로 되는건 맞는지 확인부탁드립니다.', 'stars': '', 'date': '2023년 6월 27일'}
# {'text': '경기 중계는 잘해주는데 중계가 인터넷이여서 그런지 너무 끊겨서 경기 집중이 안되고 골 장면도 하나도 못 봄. 화질도 1080에서 계속 360으로 바뀌어서 보기 힘듬. 차라리 쿠플보다 TV중계가 훨씬 나음. 그냥 경기 반이 끊기는데 보지말라는 건가? 인터넷 하지말고 제발 축구는 TV중계로 봅시다. 와이파이 바로 옆에서 보는데 이딴 상태임. 많은 수정이 필요. 앞으로는 제발 TV중계로 보자. 중요장면만 끊기는 쿠플 억까. 진짜 억까인 중계 첨 봄. 끝.', 'stars': '', 'date': '2023년 7월 30일'}
# {'text': '영상 다운받는게 중간에 멈춤 삭제후 재 다운을 몇번을 해야 다운이 완료됨 영상을 다운받았는데 왜 네트워크오류로 플레이가 불가능한지 저장된 영상 틀때마다 끝까지 돌려서 다 완전히 다운된것 확인하고 재생해도 네트워크없음 뜨면서 재생불가 이 알람은 한번뜨면 인터넷 있건없건 무조선 재생불가 이딴걸 영상앱이라고', 'stars': '', 'date': '2023년 8월 27일'}
# {'text': '컨텐츠 들여오는 센스가 별로인듯 ott플랫폼으로 애니메이션 보는편인데 더빙이 유명한건 자막만 있고 자막이 좋은건 더빙밖에 없음. 리뷰도 다 그얘기뿐인데 업데이트를 안함... 둘 다 지원하는게 보통인데 보려는거마다 다 저 상태길래 짜증나서 넷플릭스 결제함', 'stars': '', 'date': '2023년 7월 2일'}
# {'text': '이전까지 사용을 잘 했습니다. 그런데 8월 부터 다른 앱(넷플릭스,티빙 등)을 실행하면 쿠팡 플레이가 먼저 화면에 자동 실행 되어 버립니다.이유가 뭘까요? 설정에서 뭘 할려고 해도 알수가 없네요....현재는 불편해서 삭제한 상태입니다. 와우 회원이라 사용은 하고 싶은데..자동 실행말고는 컨테츠가 부족한 느낌...', 'stars': '', 'date': '2023년 9월 24일'}
# {'text': '오디오 물림 너무 불편합니다 어떤사람이 달았던 리뷰중 불친절한 어플이라는데 백퍼 공감합니다 영상 시작 후 몇초동안 작동안되는것도 불편하고 이어보기 마지막시청등 누르면 자꾸 처음부터 재생되는것 등등 너무너무너무 불편합니다 돈주고 쓰는게 너무 아까울 지경이에요 빠른 개선 바랍니다', 'stars': '', 'date': '2023년 7월 21일'}
# {'text': '스마트티비는 스마트폰 어플처럼 해당회차에서 선택을 하는게 아니라 1화부터 초기화 돼서 해당 회차 보려면 쭉 내려서 봐야 하는건 여전하네요. 진짜 개불편하고 최신 스마트티비에서 사용중인데 무한 로딩 걸리기 일수고 검정화면에서 넘어가지 않고 재인증 로그인하라는 에러메세지까지 아주 개 그지같은 불편하기 짝이 없는 어플이에요.', 'stars': '', 'date': '2023년 10월 14일'}
# {'text': 'TV용앱은 앞뒤로 빨리감기가 너무 느린점등 너무 기본 기능만 탑재되있어 다소 불편합니다. (유튜브같이 전진할수록 고속가속되는기능이 있으면 좋겠네요). 특히 시청하다 일시중지하고 다른일보고오면 스크린세이버가 작동되있고 플레이하면 다시 처음부터 시작인데 이때 보던지점까지 가는것은 큰 고통입니다. 킹팡께서 조금 더 신경써주시길..', 'stars': '', 'date': '2023년 7월 2일'}
# {'text': "콘텐츠는 뭔가 교양의 영역에 해당하는 콘텐츠가 너무 많음 편하게 보는걸 의의로 여겨야 할꺼 같다. Lg web os용 어플 쓰는데 오후 10시에 영화를 제대로 못보게 화질구지 + 버퍼링으로 TV에서 보는게 불가능하게 하면... 이걸 써야하는지 의문이 있다. 이상한건 폰에서는 전반적인 로딩부터가 약간 빠르고 버퍼링이 덜한 것 같은 이상한 느낌. 똑같은 인터넷인데 이게 왜 그런지는 알 수 없음 'ㅁ'", 'stars': '', 'date': '2021년 3월 14일'}
# {'text': '개선해야 될 부분들 □1. 화면 사이드를 더블 터치하거나 스와이프를 통한 시간 이동 기능이 없음 □2. 화면 방향에 따른 자동 회전 기능이 없음. 심지어 휴대폰에서 자동 회전을 켜놔도 어플은 작동하지 않음. □3. 아래 위 레터박스가 존재하는 영화에 좌우 검은 여백까지 존재하는 경우 손가락으로 확대 제스처를 취해도 아무 움직임이 없음. □4. 백그라운드에서 미디어 어플 재생 중에 쿠팡플레이로 영화를 틀면 기존 미디어 어플이 중지되지 않고 계속 재생 됨. 결국 쿠팡플레이 컨텐츠와 사운드가 중첩되는 현상 발생 □5. 무선이어폰(유선은 테스트 안 해봄)에서 정지, 재생 명령을 보내도 작동하지 않음. □6. 계정 공유를 하는 경우 계정마다 비밀번호 설정 기능이 필요해 보임 □7. 컨텐츠 킬 때마다 쿠팡플레이 로고 뜨는게 의미가 있는지 의문 □어플 키고 첫 영화 튼 지 2분만에 발견한 부분들입니다. 얼마나 더 나올지는 모르겠지만 개발팀에서 충분히 피드백을 하면 차차 나아지리라 기대합니다.', 'stars': '', 'date': '2021년 2월 27일'}
# {'text': "자주자주 티비연결이 안됩니다. 문의를해도 일반적인 내용확인만 해보라는데 안내해준 ''와이파이 네트워크 속도와 기기에 와이파이가 잘 연결되어 있는지 확인해주세요. 연결할 수 있는 다른 와이파이가 있다면 동일하게 버퍼링 현상이 발생하는지 확인부탁드립니다. 사용하시는 기기의 재부팅 후 재시도..'' 전부 여러번 시도했구요 모든부분 이상없이 다른기기는 잘되고 있고요. 티비연결이 안될때는 아예 연결창이 클릭도 안되게 비활성상태에요. 이정도면 쿠플문제라 여겨지네요. 제대로 된 해결방안을 안내하던지 쿠플쪽에서의 해결방안이 필수로 필요하지 않을까요? 쿠플을 시청하길 바란다면요.", 'stars': '', 'date': '2022년 8월 20일'}
# {'text': '로켓 와우 클럽으로 영상 서비스를 이용 할수있다는 것이 만족스럽네요. 다만 오픈 초기인지라 영상의 경우 다른 어플들 처럼 영상을 중간에 보다가 다시 시청 할경우 그위치로 가는 기능이 없어서 처음으로 돌아가는 것 그리고 화면에 따라 영상을 맞춰 주는 기능이 없어 아쉽네요! 추후 업데이트로 추가 되었으면 좋겠습니다.', 'stars': '', 'date': '2020년 12월 29일'}
# {'text': '너무너무 좋은데 아직 초기라 그런지 보완해야할 점들이 많이 보인다. 컨텐츠 부족은 뭐 다 알거고 이것 외 2가지 정도 문제점이 보인다. 첫번째는 자막, 몇몇 영상들이 자막과 싱크가 안맞는다. "나를 책임져,알피" 라는 영화 싱크가 안맞았는데 이 영화만 그런지 다른 몇몇 영화도 그런지 모르지만 싱크 안맞음은 큰 문제다. 그리고 한국영화 속에서 영어 대사가 나올때 그 영어 부분에 대한 자막이 제공되지 않는다. 이 부분은 "마스터"라는 영화를 볼때 나타났다. 이런 여러 자막과 관련된 문제는 영상시청을 위한 어플에서 치명적이다. 두번째는 화면분할이다. 요즘 휴대폰 성능 발전과 대화면의 스마트폰이 많이 나온다. 이를 이용한 멀티테스킹, 화면을 분할에서 동시에 여러 앱을 사용하는 유저가 많은데 영상시청 도중 화면분할을 실시하면 그 영상이 처음부터 다시 재생된다. 이 두가지가 사용해보면서 느낀 점이다. 빠른 시일내로 업데이트가 이뤄졌으면 좋겠다. 쿠팡이 잘됐으면 좋겠다 화이팅', 'stars': '', 'date': '2021년 1월 2일'}
# {'text': '안녕하세요 앱스토어 리뷰를 하나하나 다 보실지 모르겠지만 답답한 마음에 글을 올려봅니다. 적은 인력으로 ott 앱을 만드는게 쉬운일은 아니지만 업데이트를 봤을때 우선순위를 다시 고려해보면 좋지 않을까 싶습니다 데이터를 까봐야 알겠지만 감각적으로 봤을때 가장 많이 보는 콘텐츠 중 하나가 스포티비 콘텐츠 일거 같은데 라이브를 보면서 답답해 죽는 줄 알았습니다. 크롬캐스트 이슈도 많고 티비앱도 안되고 하지만 무엇보다 기본적으로 되야하는 것 중 답답했던게 레이턴시 이슈로 끊기는 증상에 대한 대응책이 없는 점입니다( 업계 기본인 1. 화질 오토 -> 데이터적으로 해상도가 낮은게 끊겨서 튕기는 것보다 잔류할 확률이 높을 것입니다.데이터 스트리밍이 안될 때 끊기지 않게 자연스럽게 화질을 낮추는게 좋지 않을까요? 2.라이브 같은 경우도 스트리밍은 계속 되고 몇초 정도 딜레이된 영상을 볼 수 있게 만드는 기능이 추가 되면 좋을 것 같습니다 넷플이나 유투브 같은 곳에서 쉽게 레퍼런', 'stars': '', 'date': '2021년 5월 10일'}
# {'text': '모바일 시청시 핸드폰 화면에 꽉차게 해서 보는 기능이 없어서 불편합니다. 너튜브, 땡플릭스 등 다수의 재생앱에선 가능한 기능인데 쿠팡플레이도 가능하게 업데이트 해주면 좋을것 같습니다. 더불어 화면 밝기나 음량조절도 아이콘 터치없이 그냥 화면 좌우를 위아래로 움직여서 조절하면 편할것 같습니다. 한가지 더 말씀드리면 TV로 시청시 긴 로딩시간과 재생중 버퍼링, 화질저하로 인하여 시청하기가 힘듭니다. 동일한 컨디션에서 땡플릭스는 문제없이 아주 잘 보고 있습니다. 이건 쿠팡플레이의 문제로 판단되며 개선이 필요할것 같습니다. 아직 런칭초기지만 여러 사용자들의 의견들이 잘 반영되어 발전하는 쿠팡플레이가 되길 바래봅니다.', 'stars': '', 'date': '2021년 4월 1일'}
# {'text': '-저렴한 구독료에 비해 컨텐츠가 많아 좋습니다. -자막싱크가 안맞거나 아예 뜨지 않을 때도 많습니다. -영상시청 중 인터페이스가 많이 아쉽습니다. 2화를 보는 중에 4화로 건너뛰고 싶으면 굳이 화면을 나가서 회차리스트를 봐야만 합니다. 시청화면에 바로 회차리스트 버튼을 두어 연결해주면 편할것같습니다. -영상 다 봤을 때 후반 크레딧은 스킵하고 다음 회차로 넘어가는 버튼이 있으면 좋겠습니다. -어플을 새로 켜서 이전에 시청하던 컨텐츠를 이어볼때, 마지막까지 시청한 시점에서 다시 시작하질 않고 아예 처음부터 영상이 시작됩니다. 내가 어디까지 봤더라 하고 굳이 찾아봐야하는 것이 조금 번거롭습니다. 어플 잘 사용하고 있습니다 개선해주시면 더 좋겠습니다 감사합니다.', 'stars': '', 'date': '2023년 4월 2일'}
# {'text': '컨텐츠도 점점늘어가고 못 본 영화를 볼 수있는점이 좋지만, 플레이어 자체 문제점을 계속 개선해 주셨으면 좋겠습니다 화면 회전이 안되는것과 되감기,넘기기 기능을 초 단위로 스와이프해서 넘긴다던지, 화면 밖에서도 작은 창으로 계속해서 볼수 있다던지 소리만 출력되게 한다던지 고런 기능들이 더 보기 편하게 만들어 줄것같습니다', 'stars': '', 'date': '2021년 1월 23일'}
# {'text': '컨텐츠가 적으면 있는거 중에서 안 본거 찾아서 보면 되지만 플레이어 자체 기능이 부족하거나 어플이 유저친화적이지 않으면 아무리 재밌는 영상도 보기 싫어집니다. 누가 이대로 ok한건지.. 완성도도 낮은데 걍 대충 하래서 출시한 느낌.. 개발자들이 얼마나 회사에 충성심이 없으면 아무도 지적을 안 했을까.. 혹은 지적을 했다면, 회사가 얼마나 꼰대마인드이길래 누군가가 지적했었어도 무시했을까.. 건너뛰기 조절, 세로모드, 미니모드, 배속재생 등등 모자른게 너무 많아요. 업데이트 되고있다고 하나 더 필요해 보입니다. 컨텐츠 분류도 무슨 이상한 수식어 넣어가지고 분류 해 놓았는데.. 관객평점 높은 영화라고 모아놓는게 아니고 걍 평점대로 줄세우기 할수있는 기능이 필요합니다. 필터 여러개 걸 수 있어서 자기가 원하는거 선택하는게 훨씬 편리합니다. 지적하고 싶은게 산더미같음...', 'stars': '', 'date': '2021년 4월 23일'}
# {'text': '장점: 넷플릭스에 없는 컨텐츠들이 있다. 저렴하다. 개선점: 1. 한국컨텐츠에도 한국어 자막이 있으면 좋겠다. 2. 로딩중 에러가 너무 잦고 불러오기 실패 후 재생지점이 리셋된다. 3. 시청 중 다른 앱 사용이 불가하여 메시지 확인 잠깐 해도 멈춰버리고 다시 되돌아가면 로딩시간이 소요된다. 때로는 재생지점이 리셋되어있음 4. 볼륨과 화면밝기 조절 바가 너무 짧아서 터치가 잘 안된다. 5.(옵션) 한국에서 만든 ui 디자인치고 투박한 느낌. 메뉴 폰트라든가 전체적인 배치 등이 좀 더 세련되고 편리했으면 좋겠다. 계속 업데이트해주시면 감사하겠습니다.', 'stars': '', 'date': '2021년 6월 22일'}
# {'text': '다운이 1시간 넘게 진행 중인데, 진행 상황은 어디에도 표시가 안 되고.. 내가 쓴 데이터를 보니 1도 안 줄어들어있고ㅋㅋ 다운 기능은 전혀 쓸모가 없음ㅠ 그리고 최고화질은 480p까지만 설정이 돼서 모바일로 봐도 화질이 구림... 뭐 아직 시작이니까 점차 개선되겠지만, 기대하고 이용해봤는데 아직까진 단점이 많이 보여서 아쉽네요.. 어쨌든 응원합니다. 와우로켓 회원은 추가 금액 없이 이용 가능하다는 게 제일 놀랍네요.. 갓팡, 이래서 끊을 수가 없다니까요..', 'stars': '', 'date': '2020년 12월 24일'}
# {'text': '일단 로켓와우에 대한 서비스라 생각하니 가격 면에서 많은 점수를주고 있습니다. 개선해야 할 점으로는 다양한 영상의 업로드 너무 인기없는 드라마나 영화가 대다수라 생각합니다.두번째는 카테고리의 정리 너무 정리가 지저분해서 검색 말고는 영상을 찾기가 힘든데 제목을 항상 기억하는것도 아닐 뿐더러 그냥 이미지를 보다가 혹은 지나가다 보는 경우가 많기에 카테고리 정리를 해주셨음 합니다. 세번째 영상을 보는도중 화면터치로 시간이동을 할 수 있게 만들어주셨으면 합니다.', 'stars': '', 'date': '2021년 3월 2일'}
# {'text': '이제 시작이라 컨텐츠가 빈약한건 이해합니다..헌데.. 1. 여러프로필로 여러 기기에서 접속 가능하다 했는데, 모든 기기에 쿠팡을 먼저 깔고 로그인을 해야 쿠팡플레이를 이용할 수 있네요..헐.. 2. 와이파이로 접속한건데, 스트리밍이 너무 버벅여서 감상을 할 수가 없네요..ㅜㅜ 3. 화질이 HD로 해도 생각보다 깨끗하질 않네요.. 개선이 되려나요...', 'stars': '', 'date': '2020년 12월 25일'}
# {'text': '컨텐츠도 많이 다양해지고 특히 스포츠쪽에 볼게 많아서 애용하고있는데 ios는 화면 꺼져도 소리만 들을수 있지만 안드로이드는 안되는게 조금 아쉽습니다... 안드로이드도 화면 꺼져도 소리만 재생할수 있게 업데이트 해주시면 감사하겠습니다!', 'stars': '', 'date': '2023년 9월 17일'}
# {'text': '4K화질 지원해주세요. 콘텐츠는 볼게 많은데 화질이 너무 낮은 것 같습니다. 그리고 시리즈물을 시청할때 자동으로 최신 시즌이 기본으로 되어 있어 처음부터 보기 귀찮게 되어있습니다 또 오프닝&엔딩 건너뛰기 기능도 있으면 좋을것 같네요.', 'stars': '', 'date': '2023년 6월 25일'}
# {'text': '소리 볼륨 조절하려고 가로 화면 기준 오른쪽을 터치하면 바로 볼륨바 중간?지점이 아무데나 바로 눌려버려서 소리 엄청 귀찢어지게 커지고 시끄럽고 깜짝 놀라기 일쑤입니다ㅡㅡ 일단 첫 터치를 하면 볼륨바가 뜬 다음에 거기서 위 아래로 조정을 하게 하던가, 아니면 네이버처럼 아예 좌우 절반씩 밝기/음량으로 나눠서 위아래로 별도 터치없이 문질러서 움직이면 조절 가능하게 좀 바꿔주세요. 소리 바꿀때마다 불편해죽겠네요. 방에서 혼자 보다가 주변에 겁나 시끄럽게 소리 확 찢어지고..ㅡㅡ', 'stars': '', 'date': '2021년 4월 4일'}
# {'text': '찜 목록좀 제대로 표시해주세요 찜 목록이 일정수량 넘어가면 더이상 표시가 안되며 최근에 찜한 목록 몇개밖에 볼 수가 없어요. 이거 한 일년은 넘은거 같은데 아직도 그대로네요. 모바일로 볼때 전체화면으로 하면, 폰을 반대로 뒤집어서 볼때 화면도 뒤집히는게 아니라 고정되어있는것도 참.. 충전꽂고 볼때도 있는데 특정 각으로만 봐야하니.', 'stars': '', 'date': '2022년 12월 26일'}
# {'text': '개선요청사항 1.화면비율조정할수 있었으면 좋겠습니다. 2. 가장 필요한 기능인데 스와이프기능이 필요합니다 좌측 상하스와이프시 밝기 우측 상하 볼륨 좌우 스와이프시 비디오 프레임 스킵 3.마지막으로 외부모니터 에어플레이나 미러링이 안되는건 무슨 정책때문이신거 같은데 그것까지 된다면 완벽할더 같습니다. 어쨌든 잘 보고 있습니다 감사합니다.', 'stars': '', 'date': '2021년 2월 7일'}
# {'text': '무한도전 다시보기를 주로 보고있습니다~ 예를들어 13년꺼 보고있다가 회차선택하면 08년부터 상단으로 다시 올라가있어서 회차선택을 일일이 내려서 선택해야 하는게 너무 불편합니다.. 보고있는 영상에 고정되어서 근처 영상을 선택할수 있도록 업데이트 해주세요 많은분들이 공감할듯ㅠㅠㅠ', 'stars': '', 'date': '2022년 10월 7일'}
# {'text': '쿠팡 좋아하는 1인! 쿠팡플레이 이용 하면서 느낀것 몇자 적어봅니다. 1.영상을 시청하다가 중간에 나갔다가 다시 보던 영상을 재생 하려고 할때 처음부터 보기 와 시청하던 부분부터 이어보기를 선택할수있는 옵션 버튼 생성이 있었음 좋겠습니다. 2.메인에서 내가 시청하던 영상 목록을 확인 시켜주는데 시청완료 한 영상은 지워져 버려 다시 찾아야 되는 불편함.. 3.메인에 계속보기 리스트 (내가 보다가 정지한 영상목록)에서는 상세 보기나 회차 정보가 확인이 안되서 불편함 쓸데없이 1일전 마지막 시청 이런 문구만 나옴.. 그자리에 회차나 상세 정보로 넘어갈수있는 기능이나 만드세요', 'stars': '', 'date': '2023년 6월 12일'}
# {'text': '장점 1. 싸다 단점 1. 더빙 -더빙에 대한 문제가 제일 큰 단점같은데, 더빙상태가 심각하다. 자막을 지원하지 않는 컨텐츠가 너무 많아서 보통 강제로 더빙판으로만 시청해야 하는데, 더빙 수준이 너무 낮아서 그냥 더빙판은 아예 안보게 된다. 2. 다운로드 문제 -다운로드를 지원하지 않는 영상이 너무 많은데, 이 부분은 다운로드 할 수 있는 영상을 좀 늘려주면 좋겠다. 또, 10번중에 7번은 와이파이에 문제가 없는데도 1.6기가짜리 영화 하나가 하루종일 다운이 안되는 경우도 많음.(핸드폰 문제X) 3. 앱 자체의 오류 -분명 다운로드한 영화를 보는데, 갑자기 네크워크 오류로 강제로 나가진다. 몇 번을 다시 들어가도 계속 오류가 발생한다. 다운로드 기한이 만료된 것도 아님. 4. 실속이 없다. -이 부분은 가격이 싸니까 이해가 어느 정도 된다만 차라리 가격을 조금 올리고 재미있는 영화들을 추가해줬으면 좋겠다. 보면 항상 영화는 많은데 대부분 재미없는 B급 영화들로 수만 채운 느낌.', 'stars': '', 'date': '2023년 2월 23일'}
# {'text': '화면 방향전환 안됨. 드래그로 빨리감기/되감기 안됨. 무조건 10초단위로만 가능. 앱내 화면밝기 조절 안됨. 화면터치로 소리조절 안됨. 완성도가 매우 떨어지는데, 스크린미러링시 볼수 없게 하는 기능은 넣어놓음. 가격이 저렴하고 와우클럽만 하면 되는거니, 그 점 고려하면 괜찮은편이긴 함', 'stars': '', 'date': '2021년 1월 5일'}
# {'text': '점점 볼게 많아져서 정말 좋습니다만 몇 가지 편의성을 추가해주시면 좋을거 같습니다. 1. 자막 크기 조절이 좀 필요할 것 같습니다. 탭으로 볼 때 너무 작아서 편의성이 좀 떨어지더라구요. 2. 영어 자막도 추가가 되면 좋을 것 같습니다. 3. 오프닝 엔딩 스킵과 넷플릭스처럼 다음화로 빠르게 넘어갈 수 있도록 부탁드리구요. 4. 영상을 볼 때 다음화 뿐만 아니라 이전화로 돌아갈 수 있는 버튼을 만들어 주시면 편의성에 도움이 될 것 같습니다.', 'stars': '', 'date': '2022년 1월 29일'}
# {'text': 'EPL 경기 중계를 해줘서 좋긴합니다 그런데 이용하다보니 개선할 부분이 있어 몇자 남겨봅니다 1. 음향조절바, 밝기조절바 좀 개선해주세요 축구 전반 끝나고 하프타임때 잠깐 다른것 좀 하려고 이전화면으로 돌아가려다 새벽에 완전 깜짝 놀랐네요 2. 작은화면으로도 볼 수 있게 개선해주세요 화면도 보면서 다른 앱으로 할 일도 할 수 있도록 바뀌었으면 좋겠습니다', 'stars': '', 'date': '2021년 4월 11일'}
# {'text': '무료사용 외 큰 장점 못 느끼겠네요 자막이 화면 중앙에 보이는 경우가 많은건 저만 그런건가요? 모든 영상이 다 그러는건 아닌데 자막이 화면 중앙에 나오는 경우가 많아 거슬리네요. 티빙에선 그런 영상 본 기억이 없거든요. 보던 영상 리스트에서 사라져서 또 검색해서 찾아야하고 나 혼자 쓰는데 키츠 유저는 왜 매번 같이 뜨는건지. 여러모로 유저가 편리한 곳은 아니네요', 'stars': '', 'date': '2022년 12월 18일'}
# {'text': '아무리 싼맛에 쓴다지만 단점이 좀 크네요. 외국 애니 저장 후 감상 시 자막이 날라감. 자체 자막 설정이 아닌 사용 스마트폰 자막 설정을 사용해서, 자막 크기나 색 바꾸려면 설정 한 바퀴 돌아야 합니다. 찜한 작품 위치는 매번 달라져서 찾아다니길 포기했구요. 사용자는 하나밖에 없는데 왜 매번 떠서 귀찮게 하는지 모르겠고... 장점은 싸다는 거.', 'stars': '', 'date': '2022년 12월 14일'}
# {'text': '콘텐츠가 갈수록 많아져서 출시 초기엔 볼 게 없었지만, 이젠 볼 게 많아져서 콘텐츠에 대해선 별을 충분히 주고 싶네요. 하지만, 앱은 정말 안 좋아요. 다운로드 멈춤, 자막 리셋되어 안 나옴, 다음화/전화 이동 버튼 없음, 소리/밝기 조정 슬라이드 선택 잘 안됨, 검색 잘 안됨 등등 앱은 별 1개 밖에 안 되네요. 디즈니플러스, 넷플릭스, 웨이브 써 봤지만 앱은 쿠팡플레이가 비교불가하게 꼴찌입니다.', 'stars': '', 'date': '2022년 11월 24일'}
# {'text': '콘텐츠는 생각보다 다양해서 저렴한 가격에 만족스러운데 tv연결이 잘 안돼요 ㅠㅠ 낮까지만해도 바로 연결돼서 잘 봤는데 밤에 보려고 다시 연결하려하니 연결버튼이 비활성화된 채로 어떻게 해도 활성화되지 않아요. 제가 뭘 잘못 건드렸나 여기저기 검색해봐도 관련된 내용은 못 찾았는데 리뷰보니 저만의 문제는 아닌가보네요.', 'stars': '', 'date': '2021년 6월 15일'}
# {'text': 'snl 너무 재밌어용!!!!❤👍재밌는 콘텐츠 감사합니다 snl만을 위한 기능인것같아 조금 조심스럽지만 남겨봅니당 1. 유튜브 북마크/챕터구분 기능처럼 에피소드별로 북마크가 있어, 탐색할 필요 없이 원하는 부분을 바로 골라보면 좋을것 같요. 현재는 탐색바 이동에따라 미리보기 화면이 액티브하게 변하는게 아니라 원하는 시점으로 정확하게 이동하기 어려워요(탐색바 기능을 좀더 정밀하게 개선해주셔도 좋을 것 같아요) 2. 코너 몰아보기 특집도 만들어주심 감사하겠습니다. 예를들어 저는 기가후니 시리즈만 골라보는데, 일부 인기 코너(주기자가간다, 기가후니 등)를 몰아볼 수 있는 특집 컨텐츠가 주기적으로 나오면 좋을것같아요 3. 배속 선택화면에서 완료버튼 빼주세요. 누워서 한손으로 가로로 들고보는 상황에서 우측 모서리에 위치한 완료버튼 누르기가 손 동선이 편하진 않은것같아요. 완료 버튼 생략하고 배속 숫자만 눌러도 바로 적용됐음 좋겠어요', 'stars': '', 'date': '2022년 2월 5일'}
# {'text': '기존 쿠팡와우도 잘 사용하던 입장에서 추가비용 없이 사용이 되는 것만으로도 충분히 만족스럽습니다. 아직 컨텐츠의 양이 적긴 하지만 이건 시간이 해결해줄 문제라 믿습니다. 그건 그렇고 어플리케이션 아이콘 바꿀 생각 없으신가요? 인터넷 익스플로러 11에 쿠팡 로고를 억지로 집어넣은 것 같은 느낌이 듭니다. 직설적으로 얘기하자면 좀 많이 촌스러워 보여요...', 'stars': '', 'date': '2020년 12월 24일'}
# {'text': '시청중 핸드폰 홈화면으로 가면 영상 창이 작아지는데 그 상태로 다른 앱을 열거나 하면 화면은 사라져 화면이 다시 열리지도 않고 소리만 나고 앱을 강제종료해도 소리는 계속 나네요. 화면을 다시 열수도 없고. 다른앱도 안들어가지는 상태로 다운되서 폰을 다시시작해서 들어와야해요.', 'stars': '', 'date': '2022년 12월 2일'}
# {'text': '노트10+ 사용자입니다. 크롬캐스트를 이용해 TV로 전송해서 보는데 드라마 한 편 보는 동안 최소 5회는 끊기는 것 같습니다. 전송에 실패했다며 321 코드의 에러가 뜹니다. 집의 와이파이가 5G와 일반이 자동으로 왔다갔다해서 그럴 수는 있겠습니다만, 같은 환경에서 유튜브 화면을 전송해서 볼 때는 단 한번도 끊긴 적이 없습니다. 끊기는 증상이 날 때는 앱에서 일시정지 등의 버튼을 눌러도 먹통입니다. 밀리듯 한참있다가 멈추거나 아예 버튼이 먹지 않는 경우가 대부분입니다. 컨텐츠를 즐기고 싶어도 매우 불편해서 쿠플을 사용하고 싶지 않을 정도입니다. 이왕 화면 전송 기능을 만들어 두셨으니 최적화도 해주시면 감사하겠습니다.', 'stars': '', 'date': '2022년 7월 26일'}
# {'text': '먼저 쿠팡 와우회원으로서 이런 좋은 앱을 쓸수 있어서 너무 좋습니다 그러나 한국영화는 자막 지원이 안되네요 또한 외국영화는 자막 대사가 1초 내지 1.5초 정도 미리 나오는 경우가 있습니다 "호빗 1편 뜻밖의 여정"과 " 클로버 필드 " 두편은 대사가 많은데 보기에 약간은 불편합니다 (쿠팡이 워낙 빠른 로켓배송을 지향하니까 자막도 빠르게 나오나봅니다 ^^~) 아마도 초기 서비스라서 그런듯한데 해상도나 사운드 엄청 좋은것은 인정합니다 점차 개선이 될것이라고 믿습니다 그리고 화면 몰입감 좀 높일수 있도록 꽉찬 화면도 지원이 됐으면 하는 바램입니다. 좋은 어플 감사합니다', 'stars': '', 'date': '2021년 1월 18일'}
# {'text': '잘사용하다가 안드로이드 소프트웨어 업데이트 후로 기기가 이 버전과 호환되지않는다고 업데이트 불가능으로 뜨네요. 그래서 지우고 재설치하려는데 이제는 아예 설치 불가능뜹니다. 캐시도 다지우고 국가도 대한민국 확인했는데도 바뀌는게 없어요. 안내주신대로 프로텍트 인증도 완료했는데 여전히 호환되지않는다고 설치불가능이네염', 'stars': '', 'date': '2023년 3월 6일'}
# {'text': '오류 수정 감사합니다. . 노트10-크롬캐스트로 연결해서 TV로 보는데, 연결준비완료까진 뜨지만 갑자기 좌측하단에 초록색 ad라는 네모와 0:00이 뜨더니 화면은 검은색이고 소리만 들려요.. 어플지우고 다시깔고 다 해봐도 안되네요. 타사 OTT는 아무이상 없이 잘 되고요. 10.14 업데이트하고 나아지려나했더니 여전하네요....', 'stars': '', 'date': '2022년 10월 23일'}
# {'text': '콘텐츠 양과 질은 앞으로 나아지리라 봅니다. 다만 다른 유사서비스에 비해 뷰어 기능이 현저히 떨어집니다. 두번 터치나 스윽 문질러 앞뒤로 가기라든지 기기를 어느 방향으로 하든지 화면이 정상 전환 되게 한다든지 하는 아주 사소하지만 없으면 굉장히 불편한 기능들이 아쉽네요. 그밖의 차별화된 기능도 필히 필요하다고 봅니다.', 'stars': '', 'date': '2021년 2월 23일'}
# {'text': '1. 다른 이용자 리뷰대로 다운로드가 중간중간 멈춤 (와이파이 문제 아님. 넷플릭스 다운로드는 문제 없음) 2. 다운로드 시 자막은 다운로드 되지 않음 3. 앱 업데이트를 하지 않으면 이용 불가함. 네트워크를 차단해도 불가. 네트워크 접속이 어려운 환경인데 이것 때문에 다운로드 해놓은 영상조차 못 보고 있음 4. 갤럭시탭에서 안나 감독판 5화 재샌 시 네트워크 연결 상태가 좋지 않습니다. (AN-NET-OFF) 오류가 뜸. 같은 네트워크에서 다른 기기를 쓰거나 다른 영상 재생 시 뜨지 않음. 다운받은 영상이라 와이파이를 끄고 재생해도 뜸.', 'stars': '', 'date': '2023년 3월 4일'}
# {'text': '리뷰들 보시긴 합니까? 폰으로 볼 때는 음성이 많이 끊기고 지지직 거려요. 티비 연결해서 볼 때는 영상이 많이 끊겨요. 렉이 심해요. 아주 많이. 너무 자주. 거슬릴 정도고 몰입방해까지 되네요. 다른분들 리뷰들도 체크하셔서 개선 좀 부탁드립니다. 와우회원비 얼마 안된다고 시스템구축이나 문제점 개선을 소홀히 하시는건 아니겠죠?', 'stars': '', 'date': '2021년 5월 20일'}
# {'text': '아직은 개선할게 너무 많이 보이네요. 이어보기도 제대로 안되고 시작할때 쓸데없는 애니메이션으로 출퇴근길에 영상을 보려는 사람의 소중한 시간을 빼앗고 프로필은 터치하기 힘들게 쓸데없이 위에 나오고 좌우 더블탭으로 10초전후 이동도 안되고 HDR도 지원하지않으며 음악듣다가 영상을 재생하면 음악이 꺼저야하는데 그러지도 않고 패드 지원안되고 일부기기에서는 마지막 자막설정이 꺼져서 매번 바꿔줘야하고 아직 컨텐츠도 적고... 일단 닥터후 하나때문에 보는데 오픈을 한거면 하루빨리 개선했으면 하네요. 주변에 추천해주려고 해도 인터페이스부터 컨텐츠까지 부족한게 너무 많아서 아직은 꺼려집니다.', 'stars': '', 'date': '2021년 1월 17일'}
# {'text': '쿠팡플레이어가 시작한지 얼마 안됀거 치고는 좋았습니다. 컨텐츠는 부족하지만 앞으로 채워나갈꺼라 믿습니다. 아직 영상 볼때는 불편한점 못느꼈지만 메뉴 화면이 정리가 안된 느낌이듭니다. 특히 장르에서 불편함을 많이느낀거같네요 ㅠㅠ 이런점들이 더 보기 간단하게 보환된다면 원하는 영상도 쉽게 찾을수있고 데이터 수집에도 도움이되지않을까 생각이드네요??? ㅠㅠㅠ', 'stars': '', 'date': '2021년 1월 8일'}
# {'text': '전에 별로라고 리뷰 달았는데 이제는 그래도 어느정도 스포츠나 영상들도 올라와서 볼거리는 생겨서 좋은 거 같습니다 다만 아직도 아쉬운 점이 많습니다.. 아직도 화면 확대는 안되네요.. 갤럭시 폴드 유저만 이러나요.. 화면의 반도 안되는 크기로 보기 어려워요.. 무한도전 볼라는데 화면 확대 좀 추가해주세요', 'stars': '', 'date': '2022년 1월 27일'}
# {'text': '가격, 콘텐츠, 편리성면에서 비교해보면 가격은 기존에도 와우멤버십 사용중이었어서 쿠팡플레이가 압승입니다. 콘텐츠는 아무래도 베타버전이다보니 빈약한 편입니다. 개인적으로 볼거리가 많진 않았어요. 편리성은 UI측면에서는 깔끔하고 이쁜데 기능적으로는 재생속도나 넘겨보기 등 기존에 익숙한 기능들이 없어서 불편했습니다. 가격적인 면에서 경쟁력이 너무 강하기 때문에 앞으로 컨텐츠 확보와 피쳐구현에 힘쓴다면 금방 커질 수 있을 것 같아요. 응원합니다.', 'stars': '', 'date': '2020년 12월 24일'}
# {'text': '은근 볼게 많음 해상도 와챠보다 떡떡 최고로 잘켜지고 로딩없음 ㄷㄷ 빠른 개선요청요 1. 시청중인 목록과 찜리스트 한번에 쫙 펼쳐 볼수있게 요구, 지금은 가로나 세로로만 슬라이딩해야 해서 찾아보기가 너무 불편해 불가능에 가까움 !!! 와챠나 넷플처럼 목록좀 보게 해주세요 2. 팝업기능신설 3. 시청시 180도 돌려도 화면방향 고정돼 안돌아감;;; 이게제일심각 갑자기왜이러죠 4. 배속 기능 추가좀요 5. 왓챠처럼 배우이름 누르면 작품들 뜨게해주세요 6.모바일 화면비율 확대축소기능이 없어서 타앱으로 보는중입니다; 신속해 신설좀요 7.자막개구림 배경색왜넣음?빼셈 8. 더블터치 되감기빨리감기기능 요청', 'stars': '', 'date': '2021년 2월 27일'}
# {'text': '추노가 있는 걸 보고나서 느낀점을 적어드립니다! 첫째로는 영상의 방향전환이 안되는점이 많이 당혹스럽습니다... 요즘시대에 영상시창을하면서 방향전환이 안된다니... 둘째로는 자막의 문제점입니다. 한글자막 영어자막등 자막기능 자체가 없다시피해서 영상을 볼때 자막을 이용하는 분들이 많이 불편할 것 같습니다. 그 외에는 아직 이용 초반이라 모르는건진 모르겟지만 잘 보고있습니다!', 'stars': '', 'date': '2022년 1월 8일'}
# {'text': '갤럭시 s21+ 장점 1. 가성비 갑 월2900으로 이용 가능한 많은 컨텐츠 + 로켓배송 넷플이랑 비교하는 것 자체가 멍청한 비교. ㄹㅇ 거지근성 어디 안감. 단점. 1. 자막 미지원 2. 밝기 및 음량 조절 불편. 중앙을 중심으로 좌, 우 화면 전체를 이용해 조절할 수 있는게 편할듯 함. ex) 삼성 동영상 플레이어 3. 화면 비율 엉망 (불편한 정도는 아니지만 화면 비율변경이 자유로웠음 함. 꽉찬 화면 미지원) 4. 앱 밝기 제어 삭제 (앱 밝기 권한을 앱에서 가져가다보니 팝업으로 볼때 밝기 조절이 안됨) - 이 모든 단점이 가격으로 무마가 가능. 그만큼 가성비', 'stars': '', 'date': '2021년 8월 6일'}
# {'text': '어플이 너무너무 불친절해요. 이전화,다음화 버튼이 없어서 보려면 영상리스트에서 찾아야하고... 시즌구분없이 일렬로 나열해놔서 무한도전같은 프로그램 최근꺼 보려면 끊임없이 스크롤해야하고, 영상 시작할때 쿠팡플레이 로고도 너무 오래나와요. 타 OTT들은 어플구성이나 편의성 어떻게 했는지 참고 좀 하시길 ㅠㅠ', 'stars': '', 'date': '2023년 5월 19일'}
# {'text': '컨텐츠는 아직 많이 부족하지만 차차 보완되겠죠..와우회원으로 쿠팡플레이까지 무료로 이용가능하다는건 엄청난 매리트로 보입니다. 동영상 재생시 재생속도 선택, 앞부분이 뒷부분 스킵 기능이 있으면 좋겠네요인터페이스도 깔끔하고 컨텐츠만 보완된다면 거의 완벽하네요.근데 그러고 나서 가격 올려버리면.....', 'stars': '', 'date': '2020년 12월 25일'}
# {'text': '외국 영화는 한국어 자막을 설정해놔도 나오지도 않고, 영화들을 다운로드 받고 있는데 갑자기 다운로드가 자기 멋대로 중지되버리고 다운로드 다 받은 영화를 재생 시키면 재생도 안되고 ㅠㅠ 그 외에도 여러가지가 있지만... ㅠㅠ 개선되어야 될 점이 많아 보이네요..ㅠㅠ 잘 되길 빌면서 고쳐줬으면 하는점들을 남겨봅니다...', 'stars': '', 'date': '2022년 12월 9일'}
# {'text': '드디어 스마트티비 쿠플앱에 찜한목록이 보이네요 업뎃 감사합니다..근데 찜한 목록은 홈화면에서도 한참 내려야 아래쪽에 보이네요? 이거 위로 순서 좀 옮기거나 아님 핸드폰 어플처럼 내 프로필에 들어가서는 못보나요? ㅠㅠㅠㅠ 애초에 이렇게 업뎃을 해주셨음 좋았을텐데.. 그리고요 마찬가지로 스마트티비로 볼 때 중간쯤 보던 영화를 다시 처음부터 보려면 처음부터라는 버튼이 없어 앞으로 돌리는 버튼을 계속누르고 있어야되는것도 수정좀 해주세요 이건 너무 고전적인 방법 아닌가요ㅠㅠㅠ', 'stars': '', 'date': '2022년 11월 14일'}
# {'text': '컨텐츠 개수가 부족한건 아직 시작 단계이고, 더 추가할 계획이라고 했으니 이해가 됩니다만 앱은 조금 고쳐주셨으면 하는 바램입니다. 상하 좌우 슬라이드가 가끔 불편합니다. 나는 아래로 내리고 싶은데 옆으로 넘어간다든지 옆으로 넘기고 싶은데 아래로 내려간다든지 의도치 않게 움직일 때가 많습니다. 그리고 UI가 너무 넷플릭스나 왓챠 따라간다는 느낌도 많이 받았습니다. 따라가는건 좋지만 왓챠나 넷플릭스보다 카테고리나 후기와 같은 면에서 더 사용하기 편했으면 좋겠어요. 착한가격, 양질의 컨텐츠로 많은 사랑 받길 바래봅니다.', 'stars': '', 'date': '2020년 12월 24일'}
# {'text': '회차가 많은 프로그램의 경우 예) 무한도전 시즌 1부터 스크롤을 내려서 최신화를 보는게 너무 힘듭니다 시즌 별로 되어있는게 아니다보니 이해합니다만, 최소한 못해도 100-200 / 201-300 / 301-400 이런식으로 카테고리가 나눠져있어야 한다고 봅니다 수정이 되면 리뷰 또한 긍정적으로 수정하도록 하겠습니다', 'stars': '', 'date': '2023년 1월 4일'}
# {'text': '한 편을 끝까지 재생했으면 또는 거의 끝까지 재생했으면 다음번에 다시 재생할때는 처음부터 다시 재생 시작했으면 좋겠습니다. 아이들 영상처럼 3~4분짜리 짧은 영상은 반복해서 보는 건데 기존에 재생했던 것 다시 재생하려고 하면 재생시작되자마자 바로 다음화로 넘어가버리네요.. 컨트롤도 뜨지 않아서 앞으로 되감기 할 수도 없고.. 이전화로 넘기는 버튼도 없고... 무슨 윈도우 안전모드 부팅하는 것처럼 재생대기하는 때부터 화면 연타하고 있게 만드네요.. 솔직히 좀 짜증납니다', 'stars': '', 'date': '2021년 2월 18일'}
# {'text': '넷플릭스이용자인데.. 비교안하려고 해도 비교되요.. 화면 앞으로 돌리기 등등 느려요 많이요.. 로딩도 길고 어플 사용하는데 개선점들을 수용하고 고쳐주면 좋을것 같아요.. 콘텐츠도 적은데 앞으로 많이 늘어날거라 기대하고있어요.. 그래도 특색이 있는것 같아서 잘 다듬으면 잘 애용할 의향있어요~', 'stars': '', 'date': '2021년 8월 1일'}
# {'text': '폰 방향이 다르면 화면도 똑같이 따라와야하는데 한방향으로만 볼수있게끔 할수있는게 불편하고요 음량 화면밝기등 제스쳐로 할수 있는게 없어요 안드로이는 미러캐스트나 미러링으로 티비로 볼수있게끔하는거 지원이 안되네요 티비랑 연결은 가능하나 지원하지 않아 너무 불편해요 다양한 컨텐츠는 없으나 더 발전하길 바랍니다', 'stars': '', 'date': '2020년 12월 30일'}
# {'text': '어플리케이션앱은 너무별로네요...일단 전체화면이 안되고 중간에만 네모사이즈로 나와서 4면이 다 붕뜹니다 거기에 자막까지 나오니 화면의 절반이 자막이라 도저히 못보겠어서 껐어요 이런 영상의 크기와 사이즈와 자막은..처음이예요 전체화면 관련 리뷰글들이 많은데 답변만 참고하겠다고 하시지말고 개선좀해주세요.. 불편해서 pc로보고있는데 비교적pc는 잘되어있네요 전체화면과 화질조정이랑 회차정보등등.. 핸드폰으로도 사람들이 많이 보는데 .. 이 리뷰가 앱관련 평가니까 어플리케이션으로 평가하는게 맞으니깐요...너무 불편해여 ...!', 'stars': '', 'date': '2021년 9월 30일'}
# {'text': '옛날에봤던 영화들 다시보는것을 좋아해서 새록새록하고 좋네요 단, 불편한부분이 몇가지 있습니다 화면 전환방향이 한쪽으로만되있어 불편한 부분이있습니다 오른쪽이던 왼쪽이던 한쪽만되는게 아니라 전환이 되면 좋겠습니다 또 중간중간 영상을 시청 중 다른 일을 해야할때 중간에 끄고 가야한다는게 아쉽네요 팝업창이 있어 동시에 보면서 할수있었음 좋겠습니다', 'stars': '', 'date': '2021년 2월 17일'}
# {'text': '일단 초기 앱이라 그런지 작품수들이 별로 다양하지 않은 것 같고 오류가 조금 많네요;;;;;; 그리고 다른 앱들과도 비교했을 때 한 영상당 먹는 저장공간이 기본 1GB를 넘겨버려서 저장기능은 조금 선호하지는 않습니다. 하지만 이 앱이 더 규모가 커지고 서비스들과 시스템들이 더 발전한다면 이 앱은 굉장한 앱이 될것같습니다. 앞으로 더 좋은 앱으로 만들어주세요.', 'stars': '', 'date': '2021년 2월 11일'}
# {'text': '다운로드 불가능 문제에 대해서 계속 사용자 탓으로 돌리는데(안정적인 네트워크 환경이나 내 앱설정의 와이파이 환경문제를 계속 언급하는데 확인결과 다 정상임. )어플상 분명 문제가 있으며 소프트웨어 결함으로 판단됩니다. 처음 출시됐을때부터 지금까지 계속 지속 되던 문제인데 담당자분들 아직 분석 못한건가요? 알고도 그냥 방치하는 건가요? 도대체 언제 수정되는 겁니까? 업데이트로 빠른시일내 피드백 부탁드립니다.', 'stars': '', 'date': '2022년 8월 9일'}
# {'text': '너무 버퍼링이 심해서 다운 받아서 크롬캐스트로 보고 있습니다 근데 언제부터인가 다운 받은것도 버퍼링이 생기네요 아마도 해외스포츠 중계서비스를 시작할때부터 그런거 같습니다 다운받으나 스크리밍 하나 똑 같은 버퍼링 현상이 일어나니 이해할수가 없구요 일부 컨텐츠는 매번 다운 실패가 발생해서 다운도 안되고요 참고로 같은 폰에서 넷플릭스는 다운이든 스트리밍이든 문제없이 나옵니다', 'stars': '', 'date': '2021년 3월 11일'}
# {'text': '요청 컨텐츠 잘 넣어주시고 요즘은 나름 볼게 많아서 좋습니다. 근데 영상 보면서 화면 밝기 조절은 너무 방식이 불편합니다. 핸드폰 기본 밝기로 조정은 할 수 있도록 하던가 인앱 컨트롤러의 사용 편의성을 개선해 주세요. 지금은 화면 밝기 조정이 매우 어렵고 최저 밝기 맞추는 것조차 밝기 편차가 납니다 +월드컵 예선 전후반 시작할때 서버랙이 너무 심해요', 'stars': '', 'date': '2021년 9월 7일'}
# {'text': '언어선택이 프로필마다 바꿀수 있는게 아니라 처음에 한번 설정한 언어로 계속 그대로만 써야한다는게 불편하고, 음성이 영언데 한국어라고 표시되어 있고, 일본언데 영어라고 표시되어 있고...그나마 한국어 음성은 맞게 한국어라고 표시되어 있지만 자막은 제공 안해주고... 뭔가 보이는 앱의 시각적인 디자인이나 매 영상 초반에 나오는 Play 영상같은건 되게 멋내려고 한건 티내는 반면에 이런 실제로 사용하는 부분은 좀 허술하다는 인상이 들어서 그냥 다른 앱에서 계속 시청해야겠다는 생각이 듭니다.', 'stars': '', 'date': '2021년 5월 4일'}
# {'text': '갤럭시 s21 울트라로 보는데요, 어떤 영화나 드라마라도 전체화면으로 늘릴수 있게, 또는 화면에 맞출수 있게 해주세요. 인터스텔라는 위 아래 레터박스 없고 양 옆에만 있어서 잘 봤는데, 호빗은 양옆은 물론 위아래도 레터박스가 생겨서 화면이 엄청 작아요. 그 외에는 만족하면서 잘 보고 있습니다. 감사합니다 ^^', 'stars': '', 'date': '2021년 2월 15일'}
# {'text': '어느샌가 부터 영화보다가 홈버튼이나 다른 어플사용하면 화면은 검정화면에 소리만 계속 나오고 강제종료도 안되고 핸드폰 모든게 먹통이됩니다 핸드폰은 종료해야만 풀리고요... 그리고 외국영화를 볼때 더빙(한국어)를 누르면 한국어가 안나오고 영어선택후 다시 한국어 선택해야 그제서야 한국어가 나옵니다 빨리 해결이 되었으면 좋겠네요', 'stars': '', 'date': '2022년 10월 1일'}
# {'text': '음성영어로 하고 영자막으로 틀어놓고 보는데 다음화 넘어가면 한글자막으로 나오거나 한국어음성으로 나올 때가 너무 많음. 설정에 가보면 음성도 자막도 영어로 선택되어있는데 한국어 한글이 나옴.. 내가 보고싶은게 여기 밖에 없으니까 결제하고 보는거지 아니였음 이미 구독해지했음...', 'stars': '', 'date': '2023년 6월 13일'}
# {'text': '새로운 작품이 계속 들어와서 타 플렛폼 못지 않게 볼거리가 조금씩 많아지고있어서 좋음 그러나 찜한 목록 숫자가 한정 되어 있는지 어느 이상은 찜하기에 넣어둘수 없어 아쉽다. 수 좀 늘려주었으면 바람. 그리고 티비에서 주로 보는데 너무 소리가 작다ㅜ 자막이 좀 다양하게 늘어났음 좋겠다.', 'stars': '', 'date': '2022년 7월 26일'}
# {'text': '다운로드도 너무너무너무 느리고 (타사 플랫폼 절반용량인데 속도는 거의 세 배.. 아니 그 이상. 네트워크 속도 최상인데 1시간넘게 다운중인데 3할도 미처 안받아짐) 다운로드 용량이나 남은시간 표시가 안됨. 스트리밍도 너어무 느림 왓챠 초기버전처럼. 그래서 앞 뒤로 10초감기 기능있는데 한 번 한 번 눌러서 감아야하고 그마저도 버퍼링때문에 그냥 기다리는 게 나을 정도.', 'stars': '', 'date': '2021년 3월 11일'}
# {'text': '스마트뷰미러링이 안되네요 쿠팡플레이앱 핸드폰에 다운받아 티비화면으로 스마트뷰 미러링해서 보려고하는데 검은색화면만 나와요 키즈채널동영상강좌들 검은화면만 나오는 점 시정부탁드리고 영서당 강좌들 전구성이 제공되는게 아니라 일부 챕터만 제공되네요. 교재들도 구입할수있게 되면 좋겠어요', 'stars': '', 'date': '2021년 4월 20일'}
# {'text': '앱이 Ott중에 젤 구린것같습니다. 이어보기를 눌러도 매번 시즌1 1화가 재생되고, 이어보기가 사라졌다 떳다하며, 밝기 및 음량 조정 인식 잘안됨. 다음화 버튼도 잘안먹음. 다양한 휴대폰과 태블릿에서 나타는 공통 증상입니다. 그냥 앱이 엄청 구립니다.', 'stars': '', 'date': '2022년 12월 16일'}
# {'text': '와우회원으로 무료이용하니 웬만한건 감안하고 이용했는데요 중국영화에 자막 없는건 너무한거 아닙니까~~(이것 때문에 리뷰작성 찾아옴) 자막 설정 들어가보니 음성은 영어만 되고 자막은 선택없음만 있길래 영어로라도 보려했는데 쭝국어만 나와요. 영화만 가끔 봐서 다른건 모르겠는데 적인걸2가 그런 상태입니다. 이 외에도 위아래 화면돌아가기 불가, 화면 내 음량이나 밝기조절 불가 등 아주 기본적인 스펙이 안받쳐지는것도 좀 허술해 보입니다. 급하게 만들었구나 싶은 느낌? 다른걸 떠나서 여긴 한국인데 한국어 자막 서비스는 기본으로 해주셔야죠 당황스러워요 제가 못찾는거면 좋겠는데 이것저것 밀어봐도 없는걸 보니 자막 그냥 없는거죠?? -------- 적인걸2 한국어 자막 서비스 추가해주셨네요 의견반영 감사합니다 다른 부분들도 지속적으로 개선되면 좋겠습니다 수고하세요', 'stars': '', 'date': '2021년 1월 26일'}
# {'text': '갤럭시 사용자입니다 개인적인 의견입니다. 1, 더블탭 영상 스킵 2, 영상 화면 확대 꽉찬 화면으로 보고싶은데 안되네요 3, 핸드폰 홈 이동시 자동 재생 로켓와우 쓰다가 갑자기 어플 출시 했다고 그래서 바로 사용중입니다, 넷xx스,왓x 둘다 사용중인데 왓x보다 화질이나 속도는 훨씬 좋은거 같아요', 'stars': '', 'date': '2020년 12월 24일'}
# {'text': '원UI 3.0, 안드로이드 11에서 영상 플래이시 최상단 바가 안없어져요. DEX모드에서만 안없어 지던데. 삼성이 문제인지 쿠팡 앱이 문제인지 잘모르겠내요. 폰에서는 잘되고요. 덱스 모드에서 안되는데 안드 10, 원 UI 2.5 에서는 전화면으로 잘보였는데요. 버그 수정좀 해주세요. 유튜브는 전화면 잘되요.', 'stars': '', 'date': '2021년 2월 5일'}
# {'text': '다 좋은데 MI스틱에서 사용 가능하게 해주세요. 크롬캐스트 연결은 상시 공기계를 하나 따로 써야하고 자꾸 이유도 모르게 끊어집니다. 왜 왓챠나 넷플릭스 웨이브는 물론이고 최근 진출한 디즈니+까지 지원하던데 제가 구독하는 쿠팡플레이만 안 되나요? USB로 구형 TV나 프로젝터에 연결하는 기기는 저작권 문제가 있다고 하던데 타사들은 지원하니까 이상하네요.', 'stars': '', 'date': '2021년 12월 19일'}
# {'text': "잘 쓰고 있습니다! 다만 영상 시청 중 오류가 확인되어 리포트 하려고 했는데, QnA에 쓰여있는 '영상 재생 중 플레이어 화면' 내 [의견 보내기] 버튼이 없는 것을 확인했습니다. 프로필-의견남기기 란에는 정확한 카테고리가 없어 오류를 리포트하기가 어렵습니다. 해당 사항 관련하여 보완이 이루어졌으면 좋겠습니다.", 'stars': '', 'date': '2021년 10월 25일'}
# {'text': '와이파이나 데이터가 제대로 연결 되어있음에도 영상을 보는 중에도 계속 로딩이 오랜시간 되거나 갑자기 화질이 떨어져서 영상을 보기 어려워요ㅠㅜ 지금도 영상을 보고 있는데 3분 동안 로딩만 3번 했어요ㅠ 이 부분에 대해 고쳐졌으면 좋겠습니다. 그 외엔 다 좋아요!', 'stars': '', 'date': '2021년 3월 16일'}
# {'text': '렉이 너무 잘걸려요. 예를들면 무한도전 회차가 너무많을데 일일이 스크롤을 내리다보면 멈춤 현상이 너무 큽니다. 일일이 회차를 스크롤로 찾아야하는 불편함이 있어요. 여러 회차를 풀어주셔서 감사히 잘보고있지만 계속 앱 대기가 뜨거나 앱나가기가 되니 무도처럼 회차가 많은건 에피소드를 검색하게 해주셨으면 좋겠어요. 무도 리뷰에도 많은 분들이 불편함을 호소하고 있는데 , 앱 평가하기에 남겨봅니다.', 'stars': '', 'date': '2022년 12월 26일'}
# {'text': '질문) 저는 현제 N950(갤럭시노트8) 안드로이드9 버전에서 삼성덱스모드로 포터블 모니터 연결후 사용합니다. 현제 전체 기기다 정상인데요 덱스모드로 갤노트8연결후 쿠팡플레 를 실행시키면 창의 크기라든지 화면 비율이 조종이 안돼네요 11인치 디스플레이에서 핸드폰 화면크기정도로만 실행됩니다. 이유가무엇일까요? 자동메크로 답변말고 좀 진진하게 알려주세요', 'stars': '', 'date': '2023년 2월 8일'}
# {'text': '키즈모드에서 특정 콘텐츠는 노출이 되지않게 설정할 수 없나요? 넷플릭스는 관리자 모드에서 콘텐츠 제목 입력 여러가지 해두면 안뜨게 할 수 있는데 쿠플은 차단 기능이 없으니 아이에게 보여주기 꺼려지네요. 분명 양질의 콘텐츠도 있지만 아닌 것들도 있거든요. 좀 걸러 보여주고 싶네요 TV에 앱 설치하고 보여줄때 키즈모드를 기본으로 설정할 수 없는 문제도 해결되었으면 좋겠고요. 해결 부탁드려요.', 'stars': '', 'date': '2022년 11월 10일'}
# {'text': '배속 기능 없음 팝업기능 없음 자막언어 부족 컨탠츠 (영화,드라마)부족 수정-> 나날이 늘어가는 드라마 영화 감사합니다 이 가격에 배속과 pip기능만 있으면 대박이겠네요. 피드백 반영 감사합니다. 미드 볼때 오프닝 넘어가는 기능이 있었으면 좋겠어요. Pc로 볼때는 쿠팡플레이 크롬 스토어에 넷플릭스처럼 많은 기능이 있었으면 좋겠습니다.', 'stars': '', 'date': '2022년 10월 22일'}
# {'text': '화면이 상당히 작은것 같습니다. 거기에 화면터치도 느리고 빨리감기도 사용하는데 불편함이 들고 해상도 바꿀데 멈추는것도 불편하다고 생각이 듭니다. 그렇지만 이런 불편함들은 충분히 개선을 통해 나아질수 있다고 생각하고 더욱 더 쿠팡플레이가 커지고 잘되서 많은컨텐츠들이 나와준다면 더할나위 없다고 생각합니다.', 'stars': '', 'date': '2021년 1월 12일'}
# {'text': '와우 회원을 대상으로 (아직까진) 무료로 이용할 수 있어서 매우 좋은 서비스. 다만 영상 틀때마다 쿠팡플레이 인트로가 매번 나와서 거슬린다는 점.(잠시 나갔다 들어와도 인트로 감상해야 됨.) 한국어 컨텐츠에 한국어 자막을 제공하지 않는다는 점은 큰 단점으로 작용함. 특히 이어폰이 없어서 작은 소리로 영상을 감상하고 싶거나 아기나 가족이 깰까봐 큰소리로 영상을 틀지 못할 때에는 어쩔 수 없이 자막을 제공하는 넷플릭스를 감상할 수 밖에 없음. 청각 장애가 있는 분들께는 더욱 치명적인 단점일듯.', 'stars': '', 'date': '2021년 7월 19일'}
# {'text': '다른 ott에 없는 bbc 시리즈가 많아서 좋습니다. 닥터후 없어진건 아쉽네요. 영상 재생 해상도 선택이 가능한건 좋은데 영어자막 지원되는게 적고 10초 전후 이동시 딜레이가 깁니다. pip 모드에서 자막지원이 안되네요. 넷플릭스의 경우 다크모드 온오프 하면 자막이 떠서 똑같이 해봤는데 쿠팡플레이는 재생중이던 pip가 다크모드시 프로그램이 꺼집니다. pip 모드 자막지원 좀 해주세요.', 'stars': '', 'date': '2022년 3월 19일'}
# {'text': '원래 쿠팡이용하는 사람들에겐 공짜로 이용할 수 있다는 점에서는 이득이나 타사 어플 이용하고 있는 사람들은 필요성을 못 느낄것같아요. 컨텐츠야 추가되겠지만 아직 설정 디테일이나 스킵 기능이 불편합니다. 자막 위치 옮기기랑 글꼴기능도 추가되면 좋겠습니다.', 'stars': '', 'date': '2021년 4월 21일'}
# {'text': '보완해야 되는 것들이 많긴하다... 1.일반 오프닝 건너뛰기, 다음 에피소드로 넘어가기 등이 없다. 2.검색엔진이 이상하다. (예)를 들어 매트릭스라고 검색을 안하고 "매트" 또는 "매트릭"이라고 글자를 쳐서 검색하면 매트릭스 영화를 찾을 수 없다.(다른 영화들도 똑같다.) 그래서" 혹시라도 이 콘텐츠가 있을까?"하는 마음에 일일이 다 적어야 한다. 그 컨텐츠 제목이 길면 길수록 불편함이 크게 느껴진다. 3. 1080p까지만 지원을 한다. 4. 볼게 없다.(거짓말이 아니고 진짜 없다. SNL 볼려고 다운받는 사람이 아닌 이상 진짜 없다. 나는 미성년자여서 보고 싶어도 못 본다 ㅠ-ㅠ)', 'stars': '', 'date': '2022년 10월 2일'}
# {'text': '갤럭시탭 s8에서 영상을 재생해서 볼때 뭔가 부드럽지 않고 미세하게 영상이 뚝뚝 끊어지게 있습니다. 노트20 울트라에서는 동일 영상 재생시 그런게 없는데 갤탭 s8에서만 미세하게 뚝뚝 끊기면서 재생되네요 분명히 갤탭쪽 영상 재생능력이 더 좋은데도 이러는게 정상은 아닌것 같습니다 갤탭에서 크롬, 파이어폭스 브라우저 이용해서 쿠팡플레이 사이트로 영상 볼때는 멀쩡한걸 보면 앱 최적화쪽이 좀 부족한게 아닌가 싶습니다', 'stars': '', 'date': '2022년 6월 6일'}
# {'text': '쿠팡플레이 모바일과 LG스마트tv로 쿠팡플레이를 이용했었는데, 어느날부터 스마트tv를 통해서는 동영상이 오류가 떠서 더 이상 이용할 수가 없습니다. [PL1-ERR-DRM-6006]이라는 오류 메시지가 뜨고 더 이상 플레이가 되지 않는데, 어플을 지웠다 다시 설치해도 되지 않고 모든 콘텐츠가 이용 불가입니다. 검색을 해 봐도 전혀 나오지 않는 오류 메시지인데 뭐가 문제인지, 어디서 이 문제를 해결해야 하는지, 왜 쿠팡플레이 관계자는 이 문제를 해결 않는지, 모르는 것인지, 이런 문제는 없었던 문제인지, 참 난감합니다.', 'stars': '', 'date': '2023년 3월 1일'}
# {'text': 'SNL등 컨텐츠는 재밌습니다. 그런데 시스템이 한참 멀었네요. 지난번 보던게 다음에 보면 이어보기가.제대로 안되요. 힘들게 보던부븐 다시 찾아야해요. 그리고 10초 전후 버튼이 있는데 잘 눌러지지도 않고, 눌러져도 로딩이 20초는 되는것 같아요. 전반적 시스템 개선이 필요합니다', 'stars': '', 'date': '2022년 3월 10일'}
# {'text': '답변이 잘못된거 같아요. 그 얘기가 아니라 시청하던 에피소드 내에서 내가 15분20초까지 봤다면, 그 위치를 기억 못한다니까요? 그리고 심지어 내가 2화를 보고있었는데 홈으로 빠지든, 다른 앱을 이용하든, 화면을 껐든 했다가 다시 시청하러 들어가면 1화를 재생하거나 2화를 처음부터 재생합니다. 이 오류가 너무 심하다는 얘깁니다;; 개발자님 폰에서는 아무 문제가 없으신가요? 저는 폰 2개 사용했는데 2개 다 그러던데...', 'stars': '', 'date': '2021년 7월 20일'}
# {'text': '아이패드에서도, 핸드폰에서도 플레이 원활하고 넷플만큼은 아니지만 화질도 괜찮아요! 컨텐츠도 꽤 다양하구! 아쉬운 점은 자막ㅠㅠ 전체적으로 외국 컨텐츠는 모두 자막 검수 다시 해보시면 좋겠어요 내용과 다른 자막이 쓰여있을때도 있고 라라랜드 같은 경우는 자막이 중간중간 비워져있더라구요ㅠ 그 외엔 가성비 갑입니당 좋아요👍', 'stars': '', 'date': '2021년 5월 12일'}
# {'text': '콘텐츠가 꾸준히 들어오는건 좋아요 그러나 시스템적인 요소가 별로인 부분이 좀 있어요. 1. 화면 회전이 안 돼서 불편합니다. 2. 화면비율을 폰에 맞춰서 확대 축소할 수 없어서 불편합니다. +++ 곧 쿠팡플레이에 들어오는 작품들을 공지하는 카테고리도 있으면 좋을거 같아요!! 저는 원피스 10기 이후를 기다리는 사람인데 기약없이 기다려야하는게 좀 불편하더라고요. 그리고 관심있는 신규 영화와 드라마들이 올라오는 시간을 알림신청하고 기다리면 알아서 알람도 올 수 있는 기능도 있으면 참 좋을 거 같아요. 쿠팡플레이의 무궁한 발전을 기원합니다♡ p.s. 원피스 11기는 대체 언제 올라올까요?? 원피스 너무 잘 보고있어요 한달만에 4기부터 10기를 다 봤는데 보면서 너무 행복했어요.. 쿠팡플레이덕분에 시간죽이기도 딱이구용 파이팅..!! 원피스 올려주세요!!!', 'stars': '', 'date': '2021년 3월 9일'}
# {'text': '아 진짜 이정도 렉이면 앱 오픈을 하지 말던지 중계를 하지 말던지 해야되는거 아닌가요 버벅여서 불편하다 수준이 아니라 10초로딩 3초재생 후 튕김 반복하다가 이제 로그인도 안된다는데? 축구는 다 합쳐서 한 20분 본 것 같고 로딩시도는 30분 정도 한 것 같아서 이게 영상재생 앱인지 휴대폰 손난로인지 헷갈립니다 쿠팡맨들 막힘없이 오는 속도 반이라도 따라갔으면 좋겠네요', 'stars': '', 'date': '2021년 9월 7일'}
# {'text': '무한도전 같이 회차가 많은 품목은 넘겨지는 스택이 쌓일수록 오래걸리고 400회 ~ 500회 정도 되어가면 어플이 종료됩니다. 회차가 있는 품목들은 돋보기 기능을 넣어 회차나 특집명 혹은 정보를 유사하게 입력하여도 검색이 가능하게 만들어 주셔야 할 것 같습니다. 또한 회차가 많은 품목들은 시즌 품목이 나뉜 것처럼 1~100회 101~200회 처럼 나누어 주셔야 부득이하게 어플이 종료될 시 현재 보던 회차를 찾기위해 다시 많이 올려야 하는 불편함을 줄여 보다 쾌적한 쿠팡 플레이가 될 것으로 보이고 고객들의 만족도를 조금 더 높힐 수 있을것으로 보여집니다. 그리고 고객들이 불편함을 후기로 적는 경우가 종종 보이는것 같아 품목 카테고리에 대한 인기도와 고객들의 불편함을 확인하기 위해 후기확인도 수시로 하였으면합니다.', 'stars': '', 'date': '2022년 12월 10일'}
# {'text': "구글스토어에서 다운받은 앱중 처음 평가씀. 평소 쿠팡 애용자로서 쿠팡플레이가 잘 됐으면 해서 써봄 1 시청중 화면잠금 누른후 해제하려고 '3초간 누름'을 눌렀으나 안열림.. 한 5초 눌러야함. 화면잠금 해제가 번거로움 2 자막 오타 많음. 간만에 트랜스포머1 봤는데 오타만 한 너댓번 본것같음 3 자막 글씨가 작음 조정할수있는 메뉴가 있었으면 함 4 영상시청중 오른쪽 상단에 '의견보내기'를 누르면 의견을 작성할수있게 해놓아야하는더 그냥 큼직한 메뉴 라벨링, 영상,자막 등으로만 적어놓아서 내가 쓰고싶은 말을 할수가없음 5 핸드폰 충전 단자 위치때문에 화면회전을 하고싶은데도 자동회전이 안됨 6 영상 시청할때마다 우주화면에서 띵-하고 날아오는 쿠팡플레이 시그널영상좀 없앴으면함 이게 널리퍼지고 사용횟수가 많아지면 하루에도 영상을 몇개씩은 볼텐데 중간에 잠시 정지후 나갔다와도 그 화면을 봐야해서 본 편보다 쿠팡플레이 화면을 더 많이 보는 느낌 질림 슬슬 짜증남..^.^", 'stars': '', 'date': '2020년 12월 25일'}
# {'text': "자막 위치가 중간에 너무 가깝게 위치해 있어요. 전체화면을 하면 자막 위치가 전체화면 한 만큼 하단으로 이동하지 않고 그대로 원본비율에서의 위치 그대로 고정이라 영상의 중간 바로 아래까지 간섭합니다. 글꼴을 가장 작게 줄여서 본다 해도 쿠플 자막이 더 크기 때문에 쿠플 이용시 글꼴을 가장 작게 변경하고 종료하면 원래 크기로 수정해야하는 불편함이 생깁니다. 당연히 글꼴을 원래 크기로 키우고 시청하면 자막은 더 거대해져서 영상의 일정 부분을 잡아 먹습니다. 자막의 크기는 불만이 없습니다. 문제는 '자막의 위치'입니다. pc처럼 자막의 위치를 수정할 수 있게 기능 추가 해주세요.", 'stars': '', 'date': '2023년 4월 25일'}
# {'text': '와우멤버십 가입하니 쿠팡플레이도 쓸 수 있어서 정말 좋습니다. 다만, 1. 영상 시청할 때 옆으로 밀어서 앞으로감기 뒤로감기가 가능했으면 좋겠습니다. 터치해서 10초씩 왔다갔다하려니 불편합니다. 2. 자막 위치랑 색 같은 거 설정하는 기능이 있었으면 좋겠습니다.', 'stars': '', 'date': '2022년 3월 27일'}
# {'text': '아이 영어 노출용으로 썼었는데, 업데이트 이후인지 분명 언어 설정을 영어로 했는데 다음편에서 한국어로 변경됩니다. 예전에는 한번 영어설정하면 유지가 됐는데ㅠ 매번 10분마다 설정을 바꿔줘야 해서...너무 불편. 다른 사용자들도 같은 상태입니다. 설정유지 기능 없는지요... 갑자기 왜 바뀐건지...', 'stars': '', 'date': '2022년 10월 9일'}
# {'text': '컨텐츠를 정주행하고 있는데, 각 영상마다 볼륨 크기가 제각각이에요... 소리가 작아서 키워두면 다음 영상에서 볼륨테러당함. 그리고 썸네일 잘못 들어가 있는 영상도 간혹 있네요 덕분에 오래만에 원피스 정주행 잘하고 있습니다', 'stars': '', 'date': '2021년 2월 8일'}
# {'text': "'푸시 알림 받기'를 선택하고 싶지 않은데, 선택 안 하는 버튼은 보이지 않아서 계속해서 넘어가지 않고 있었는데, 오른쪽 상단의 X를 누르는 것이 선택 안 하기에 해당하는 것이었군요. 최대한 많은 사용자가 푸시 알림을 받게 하려는 의도는 알겠으나, 사용자 경험은 정말 좋지 않습니다.", 'stars': '', 'date': '2021년 7월 22일'}
# {'text': '아주 잘 이용하고 있는데 한가지 불편한 점이 있습니다. 화면을 밀어서 넘기는게 아니고 매번 10초씩 넘겨야 하는 점이 매우매우 불편합니다. 그리고 10초씩 넘기는 것도 더 넘겨지거나 덜 넘겨지는 일이 너무 많아서 이용하는데 불편함이 많습니다. 개선부탁드립니다.', 'stars': '', 'date': '2022년 12월 7일'}
# {'text': '우선 개인적으로 영화만 99퍼센트 보는 유저이고 지원되는게 몇개 없지만 한국 영화 및 드라마의 영문Eng 자막 제공이 되서 상당히 좋고 앞으로도 더 많이 한국 영화 드라마에 영문자막 지원수를 더 늘렸으면 합니다. 예전과 달리 스트리밍이 상당히 안정화되어 어느 영상을 시청해도 끊김이 거의 없다는 점을 칭찬해주고 싶습니다.', 'stars': '', 'date': '2022년 3월 27일'}
# {'text': '쿠팡플레이로 많은 시청을 했는데요! 그런데 조금 보완해야 할 부분이 있을 것 같아 말씀드려요♡ 1. 화면회전이 안 되네요ㅜ불편해서 걍 안 볼래 한 적도 있네요... 2. 제가 이누야샤를 보았는데, 이누야샤 화 중에서 빠져있고 앞이랑 똑같은 내용이 나오는 경우가 한 3번이나 제목만 다르고 똑같은 내용의 화가 나왔었습니다. 수정 부탁드립니다 3. 하지만 앞으로 추가할 목록을 볼 수 있는 기능이 생겼으면 좋겠습니다. 4. 그리고 로그인이 자꾸 풀리네요! 그게 조금 불편해요. 5. 그리고 프로필 사진을 바꿀 수 있는 기능도 생겼으면 좋겠습니다. 6. 다운로드를 받을 때 어느 정도 시간이 걸릴지 나오는 기능이 있었으면 좋겠습니다. 그리고 어떤 건 다운로드가 안 되는데 오류일까요?? 한 마디로 정리하면 1. 화면회전 기능 2. 이누야샤에서 누락된 화 수정 3. 앞으로 추가될 목록 기능 4. 로그인이 풀림 5. 프로필 바꾸는 기능 6. 다운로드 시간 표시 기능 ♡감사합니다♡', 'stars': '', 'date': '2021년 3월 13일'}
# {'text': '다운로드 기한 연장하기와 삭제 기능이 모두 작동을 안하네요. 그리고 해외 시리즈를 틀면 옵션에 분명 한글 자막 체크되어 있는데 한글이 안나와서 자막 없음 체크하고 영상 플레이 했다가 다시 한글 자막 체크해야 한글이 정상으로 나옵니다. 앱 개선 요청합니다.', 'stars': '', 'date': '2023년 3월 15일'}
# {'text': '재난문자 오는 등 알림 팝업창 뜨면 왜 재생이 멈추고 확인할때까지 화면이 꺼지지도 않는거죠? 잘때 플레이 해놓고 이런 상황이 생기면 일어나서 볼때까지 저러고 있어요;; 취침설정이나 타이머기능을 넣어주시면 좋을듯 화면 볼륨 밝기조정하는 방식도 좀 불편하네요', 'stars': '', 'date': '2021년 7월 26일'}
# {'text': '새로운 컨텐츠가 조금씩 들어오고 있어서 매 업데이트 때마다 기대하게 됩니다. 다만 앱 자체적으로 스마트뷰 기능이 추가된다면 더욱 좋을 것 같습니다. 아직 쿠팡플레이의 컨텐츠들은 모바일 환경에서만 감상할 수 있어서 작은 화면으로는 몰입도가 떨어지네요', 'stars': '', 'date': '2021년 1월 15일'}
# {'text': '아이 퍼피구조대 영어로 보여주는데 활용하고 있어요. 그런데 영어로 음성을 설정해 놔도 다음 에피소드로 넘어가면 또 한글로 바뀌어 버리네요 ^^; 에피소드 때마다 영어로 다시 선택해 줘야하는 게 불편합니다 ㅜ', 'stars': '', 'date': '2022년 10월 22일'}
# {'text': '이제 막 시작하는 단계여서 등록돼 있는 프로그램이나 영화 등에 대한 불만은 없습니다. 하나 부탁이 있다면 등록돼 있는 것들 전체보기 혹은 카테고리별로 다 볼 수 있었으면 좋겠습니다. 분명 메인에 있는 것 보다 더 많은 것이 있는거같은데 찾을수가 없어 답답합니다.', 'stars': '', 'date': '2021년 1월 9일'}
# {'text': '아니 뭐 어플을 만들려면 잘 만들던가 뭐만 하면 강제 로그아웃 되고 그래서 로그인하려고 보면 로그인도 메일 비번 다 맞는데 안된다 하고 이 시간대에 갑자기 서버가 터질리도 없고 와이파이 공유기 바로 옆에서 개빵빵할 때 켰는데 이러는 이유가 뭐임? 장난하는 것도 아니고 이따위로 장사하지마세요;; 로켓배송 빼고 제대로 하는 게 1도 없네;;;', 'stars': '', 'date': '2023년 1월 3일'}
# {'text': '아직까지는 원활한 이용을 위해서는 개선해가야 할 부분이 많이 있는 것 같지만, 그래도 이런건 좋은 서비스인것 같네요~ 쿠팡애용자로서 와우 한번으로 쇼핑과 영화를 동시에 즐길수있다는 점이 너무 좋아요~ 앞으로 다양하게 시청할수있는 채널과 장르들이 더 늘어났으면 좋겠네요~', 'stars': '', 'date': '2021년 2월 20일'}
# {'text': '1.5배속으로 설정하면 소리와 화면이 불일치. 폰 방향을 바꿔도 영상 나오는 화면의 방향은 바뀌지 않음 드라마 보려고 하는데 페이지를 알 수 없다고 함. 재설치하고 프로필 새로 만들고 등등 여러개 해봤지만 빡침. 못본 기간동안 보상은 해주려나 몰라. 멤버십 연장은 안할듯', 'stars': '', 'date': '2021년 12월 12일'}
# {'text': 'Ott어플중에 제일 관리 안하눈듯... 미디어패드 M5 사용중인데 풀hd로 보다가 잠시 멈추고 다시 들어가면 sd로 강제로 저화질로 되고 끊기면서 재생됨 기기 재부팅하고 보면 되긴하는데 다시 멈추고 보면 똑같이 저화질로 sd강제됨 이거 몇번째 수정해달라고 요청해도 안됨 기기문제가 아닌게 왓챠, 넷플릭스, 유플모바일티비 전부 문제없이 풀hd재생됨 관리자분 제발 어플 수정좀 해줘요 추가 후기- 여전히 어플은 고쳐지지 않았고 어플 개발자도 무슨문제인지 모르는거 같은데.. 사용자인 내가 hd로 보는 법 알아냄. 먼저 넷플릭스나 왓챠등 다른 ott어플을 켠뒤 영상을 켜고 백그라운드로 놔둔뒤 쿠팡플레이로 영화키면 풀hd로 볼수있음.', 'stars': '', 'date': '2023년 3월 10일'}
# {'text': '새로운 컨텐츠가 조금씩 생기고 있어 좋지만 현재는 넷플릭스, 왓챠 등이 가지고 있는 컨텐츠들에 비해 쿠팡 플레이는 앞으로 점점 개선해 나가야 할 부분이라고 생각합니다. 티비 셋톱박스도 지원해준다면 다양한 기기로 즐길 수 있는 날이 오길 기대합니다. 쿠팡플레이 자체에서도 오리지널 컨텐츠를 제작하면 기대해볼 만한 할 것같아요^^ 쿠팡플레이 앞으로의 여정을 응원하고 기대합니다.', 'stars': '', 'date': '2021년 3월 4일'}
# {'text': '다른 앱 보다 업데이트가 늦네요;; 2기까지 나온 작품이 1기만 있고 한번에 보려고 해도 나오는 속도가 느리니 사용하는데 불편한것 같습니다. 애니메이션 종류를 시청하는 입장에선 업데이트와 업로드가 원활히 이루어졌으면 하네요.', 'stars': '', 'date': '2022년 12월 25일'}
# {'text': '일단 별5개 드립니다 .. 유용하게 잘 쓰고 있지만 더욱더 쿠플이 타스트리밍에 뒤쳐지지않게 성공하려면 일단 자막의 개선(크기조절 설정변경 위치변경) 꼭 바꿔야될거같고요 다운로드 느림 이거만 바꿔도 사람들의 원성이 줄어들듯요', 'stars': '', 'date': '2022년 12월 27일'}
# {'text': '개발자님, 혹시 이 의견보시면 꼭 반영해주셨으면 합니다. 1. 재생속도 조절할 수 있게 해주세요. 0.5~1.5배속까지 자유롭게 조절할 수 있으면 좋겠습니다. 2. 화면 비율 조정 꽉찬 화면, 원본 비율 이런식으로 화면 비율을 조정할 수 있게해주시면 꽉차게 보다 큰 화면으로 영상볼 수 있지 않을까 싶습니다.', 'stars': '', 'date': '2021년 1월 16일'}
# {'text': '플레이어에 배속 설정 없는거보고 깜놀. 배속은 기본 아닌가...플레이어가 너무 구식..작품도 많고, 목차에맞게 정리도 잘되있어서, 이정도면 월결제해도 좋겠다 좋은앱 발견했다하고 플레이어 기분좋게 누른순간, O.M.G!! 진심 놀람. 밝기 조절이나 소리 조절은 잘찾아서 터치하면 되기는하는데(맨끝으로 잘찾아야해서 불편하긴함), 다른 동영상 어플들보다 훨씬 불편. 구성은 세련되지만 막상 플레이어 누르면 최악..요즘 짧고 빠른 컨텐츠가 유행인거 아시죠? 볼건많은데 시간은 없는 현대인들이라 동영상 정속으로 보는사람 정말 드물어요. 배속조절 필수. (약간만 개선되면 좋아질거같고 애정이 있으니 리뷰도 길게 남기는거지, 정말 고칠게 많은 답없는 최악의 어플이면 이런글도 안남겨요.배속없으면 월결제 하고싶어도 못해요. 업데이트 기대할게요)', 'stars': '', 'date': '2021년 7월 8일'}
# {'text': '1. 실행이 제대로 안됨 처음 앱 실행할때 빙글빙글 도는 로고 나오는것도 너무 느려터져서 답답한데 그다음 프로필 선택도 안되고 터치 안먹히고 하는 먹통현상이 심함. 2. 콘텐츠 재생도중에 멈춤이 심함. 다운로드 실패라면서 확인누르면 영상 처음부터 다시 재생됨. 개열받음', 'stars': '', 'date': '2021년 6월 3일'}
# {'text': '업데이트 하기 전에는 화면이 검어지거나 멈추거나(추가로 앱도) 팅기는게 잦았는데 업데이트 후에는 다른 건 고쳐졌지만 여전히 화면과 앱이 멈추는 현상에 추가로 화면이 깜빡거리는 버그가 추가로 생겼습니다. 여전히 정상적인 사용은 어려우므로 컴퓨터를 사용해야 하겠네요.', 'stars': '', 'date': '2022년 12월 6일'}
# {'text': '와우회원이라 이용중인데 아이가 너무 좋아합니다. 그런데 문제가 생겼어요. 잘보다가 갑자기 검은화면이나와요. 소리재생은되는데 화면이 안뜹니다. 그외 나머지는 다뜨는데요. 아이가 잘보던 폰에서만 안나오니 뭐가 문제인지....해결방법좀 알려주세요. 문제점. 영상재생은되지만 화면이 검다. 갑작스레 이런 이유가 뭘까요ㅜㅜ? 당일까지잘봤고 아이가 다른거하다 또보려고 켰는데 그랬어요.', 'stars': '', 'date': '2023년 5월 21일'}
# {'text': '다 좋은데 화면 비율 확대 기능이 있으면 좋겠네요. 지금은 이 부분만 아쉽습니다. 타이틀은 차차 늘어날테니... 추가: 업데이트 후 애니메이션 장르 검색이 불가능 하네요. 전에는 분명 애니메이션으로 검색해서 찾았는데 지금은 없다고만 나옵니다. 영어로는 일부 나오지만 전체 다 안 나오고...', 'stars': '', 'date': '2021년 1월 7일'}
# {'text': '제발 개선해줘야 될 사항 1.재생기록 초기화되는점 (ex.1시간 영상보는중 25분보다가 멈추고 몇시간 지났을때 영상을 다시보려하면 처음으로 돌아감) 2.자막크기 조절이 안됨(ex.태블릿으로 봤을때 영상크기에 비해 자막크기가 현저히 작음) 3. 다음화보기는 있는데 이전화보기는 없음', 'stars': '', 'date': '2021년 6월 4일'}
# {'text': '이전부터 매우 편하게 사용하고 있습니다..! 저렴한 가격에 다양한 프로그램, 영화를 볼 수 있어서 매우 좋은것 같아요!! 더해서 안드로이드tv에서도 지원이 된다면 더욱더 편하게 사용할 수 있을것 같습니다!! 안드로이드tv 지원도 조심스레 부탁드려볼게요!!', 'stars': '', 'date': '2021년 8월 5일'}
# {'text': '쿠팡와우하는데 플레이도 추가비용없이 볼수있어서 가성비면으로는 너무 좋아요 하지만 티비랑 연결할때 버퍼링이 2분에 한두번씩은 꼭 걸리더라구요 보는데 불편했어요 자막위치가 어중간하게있어서 조금 그렇긴한데 이런불편은 감수할수있어요. 버퍼링 문제 해결안되나요..ㅠㅠ 몰입이 깨져요ㅜㅜ 너무 자주 버퍼링걸림...', 'stars': '', 'date': '2021년 6월 6일'}
# {'text': '컨텐츠도 많고 좋은데 플레이속도 조절 0.7×배속 추가해주면 좋을거같다 속도높이는거는 디테일한데 늘이는거는 1.0배속에서 갑자기 0.5배속이라니 이건 아닌듯. 아이와활용하기가 어렵다. 영상이 너무 느려져 재미 없어지고 소리도 깨지고 영어노출해주기 어렵다. 영어 자막 한글자막 정도는 지원 되야 하지 않을까 쿠팡플레이 좋은데 너무 아쉬운점이다. 이것만 개선되면 별5개!', 'stars': '', 'date': '2022년 8월 11일'}
# {'text': '장점: 볼게 꽤 많음. 무려 2배속이 있음. 빨리넘기고 싶은 구간에 딴짓안해도됨. 단점: 한국영화 단점이 뭐라고 웅엉거리는지 잘안들려서 한글자막이 있어야하는데 왓챠는 한국영화에 다 자막이 뜨는데 쿠플에는 자막이 없어서 매우불편함. 같은영화라면 당연 왓챠에서 보게됨. 그리고 2017년도에 산 TV인데도 지원이 안되는점ㅠㅠ미러링으로만 볼수있음.. 뭐 자막만 있다면 2배속도 가능한 쿠플을 이용하고싶지만 연결도 번거로운데 한글자막도없어 말도 잘못알아들으니 손이 잘안감.. 제발 한글자막 지원좀 해주십쇼.. 한국영화는 후시녹음 잘안해서 뭔소린지 못알아듣고 지나가는 경우가 많습니다ㅠ', 'stars': '', 'date': '2022년 6월 9일'}
# {'text': '쿠플 재밌게 잘 이용하고 있습니다 건의사항이 하나 있는데요 지금 미드 같은 경우에는 한글 자막과 영어 자막을 선택할 수 있는데 한글+영어 자막 기능도 추가해주셨으면 좋겠어요 동시에 보고 싶습니다. 많은 도움이 될거 같아요. 앞으로도 더 좋은 운영 부탁드립니다 감사합니다.', 'stars': '', 'date': '2023년 2월 17일'}
# {'text': '와아~ 이제는 구글티비에서 이용이 가능해졌어요. 너무 편해요!!! 화질도 좋고 끊기는 일도 없고, 너무 좋습니다. 과거리뷰ㅡ아프리카티비, 와챠도 구글티비(크롬캐스트4세대)에 연동되서 폰이나 테블릿 없이 바로바로 볼 수 있는데, 쿠팡플레이는 핸드폰으로 꼭 따로 연결해야만 해서 많이 아쉽습니다.', 'stars': '', 'date': '2022년 7월 28일'}
# {'text': '에러 너무 자주 나는 거 아닌가요? 오늘만 에러 10번 난 거 같아요. 그리고 전 미드 볼 때 영어자막 틀어서 보는 거 좋아하는데, 중간에 왜 한국어 자막으로 갑자기 바뀌는지 모르겠어요. 근데 자막 설정 들어가보면 영어자막 선택돼있어서, 매번 자막 없는 걸로 설정 바꾼 후 다시 영문 자막 설정해야 해요. 제발 고쳐줘요 제발 돈 내고 보는 건데 진짜 너무 엉망이에요', 'stars': '', 'date': '2023년 3월 19일'}
# {'text': '잘 이용하고있는데 개선사항 요청드립니다. 저는 삼성덱스를 이용해서 tv로 보는데요. 외국영화를 볼때 자막을 키면 너무 작아서 자막이 안보입니다... 자막 크기를 설정할수 있도록 해주시거나 티비로 연결시 자막이 커지게끔 해주셔야할 것 같아요.. 빠른 개선 부탁드립니다', 'stars': '', 'date': '2021년 12월 23일'}
# {'text': '저번에 퍼피구조대 음성설정을 영어로 한번누르면 다음편도 계속영어 음성으로 나올수있도록 요청드렸는데 의견반영해 주셔서 감사합니다 아이패드나 핸드폰만 반영된거 같습니다 Pc사용할때도(크롬/엣지) 음성설정이 영어로 계속되게 변경부탁드립니다', 'stars': '', 'date': '2021년 10월 26일'}
# {'text': '화면비율조정이 안되는 치명적인 문제가 있습니다. 앞뒤로가기도 마치 초기 동영상플레이어처럼 특정 위치만 클릭해야되고요. 컨탠츠는 아주 조금씩 나아지고 있는데 아직도 UI와 UX 측면에서는 멀었습니다. 아마존프라임하고 너무 비교되네요...', 'stars': '', 'date': '2021년 3월 5일'}
# {'text': '첫 가입자입니다. 와우멤버십30일무료체험 버튼을 몇 번을 눌러도 다음으로 진행이 되지 않네요. 앱 지웠다가 다시 설치해도 똑같습니다. 서버가 한번에 몰리는 가입자들을 감당 못해서 이런건지 다른 사람들도 저랑 비슷한 현상을 겪는 것 같습니다. 개선 부탁드립니다. TV조선만 원망스러워지네요', 'stars': '', 'date': '2021년 11월 12일'}
# {'text': '잘 보고 있는데 문제가 좀 있어요. 일단 다운이 너무 느려서 거의 안되다시피 해요. 그래서 다운 기능이 없는 거나 마찬가지;; 그리고 영상 재생중에 갑자기 버벅거리는 현상이 일어나면 영상을 껐다가 다시 재생해야 하는 불편함도 있고요.', 'stars': '', 'date': '2022년 1월 3일'}
# {'text': '안녕하세요 잘 쓰고 있습니다만 불편한 점이 좀 있네요 다른 콘텐츠와 달리 NFL중계의 경우에는 보다가 중단한경우 재생리스트에도 안나오고 거의 세시간에 가까운 영상임에도 이어보기가 안돼서 너무 불편합니다 처음부터 보던곳을 때마다 찾아서 다시봐야해요 개선해주세요', 'stars': '', 'date': '2021년 9월 21일'}
# {'text': '저렴하게 이용할 수 있어서 좋습니다. 다만 동영상 플레이 ui에 불편한점이 많습니다. 전체화면시 폰을 뒤집어도 화면이 바뀌면 좋겠고, 터치로 음량조절이 가능했으면 좋겠네요. 일단 이 두 가지가 제가 느끼기엔 가장 필요한 점이라 생각됩니다.', 'stars': '', 'date': '2021년 2월 23일'}
# {'text': '핸드폰 이어폰 사용시 음악재생중 플레이하면 음악계속되고 (파워엠프어플) 화면은 재생되는데 소리가 안나와요..음악만 계속. 동일환경 넷플릭스는 음악 멈추고 재생 자동으로 잘되요. 쿠팡플레이 문제인듯. 수정요함', 'stars': '', 'date': '2022년 9월 23일'}
# {'text': '영상 비율 안맞는거야 기기별 비율이 있으니 그러려니 하겠는데 유독 쿠팡플레이가 심하게 안맞아요 . 왓챠처럼 비율안맞는 영상은 두손가락 스와이프로 화면 채우기라도 가능하게 해주세요 그리고 타블렛의 경우 화질은hd인데 자막은 480으로 흐릿하게 나오는 경우도있으니 수정부탁드립니다.영상컨텐츠는 예전보다 풍부해저서 볼만하지만 기능면에선 아직 멀었네여', 'stars': '', 'date': '2021년 8월 31일'}
# {'text': '완전 좋아요 2900원에 영화까지 즐길수있다니 아직 자막싱크 안맞는 영화가 좀 있지만 차차 개선될거라 생각합니다 보던 중인 드라마나 영화를 따로 위쪽에 보이도록 하는 것은 좋은데 끝까지 재생해야만 없어지더라구요 다 보기전에 자유롭게 목록에서 삭제할 수 있게 업데이트되면 좋을거같아요', 'stars': '', 'date': '2021년 1월 5일'}
# {'text': '화면 밝기가 기기문제인지 모르겠는데 처음 재생할 때 왜 자꾸 중간값으로 시작하나요? 화면밝기가 제일 어두운 상태에서 시작하는데 왜 혼자 보통밝기로 넘어가고 제일 어둡게 해도 가장 어둡게 되지도 않아서 다시 나갔다가 재생해야 하는 번거로움이 커요. 다른 ott처럼 밝기 연동되었으먼 좋겠습니다. 기기문제라면 해결책좀 부탁드리고 앱 문제라면 개선 부탁드려요.', 'stars': '', 'date': '2022년 10월 19일'}
# {'text': '자막이 왜이렇게 뜨나요... 자막이 두개뜨면 위아래로 나눠져서 뜨는게 아니라. (-고마워. -응나도 ) 이런식으로 한줄로 쭉 떠서 헷갈리고 이상해여.그리고 자막 글씨체도 제가 휴대폰에 설정해둔 글씨체로 떠서 기시감이 있고 집중이 안됩니다. 글씨체도 제 휴대폰 설정과 다르게 좀 고쳐주세요', 'stars': '', 'date': '2022년 4월 9일'}
# {'text': '가격도 좋고 볼것도 많고 다 좋아요!^^ 딱 한가지 아쉬운게있다면 자막이 보기좋게 바뀌면 좋을것같아요 크롬캐스트연결해서 보니까 자막이 영상과 검은색테두리 사이에 걸쳐져서? 보기살짝 불편했어요ㅠㅠ', 'stars': '', 'date': '2021년 2월 28일'}
# {'text': 'S22 울트라인데 드라마 재생시 프레임이 너무 떨어지네요. 화질 1080 기준 어게인마이라이프 시청시 프레임이 30 가까이 나오는 것 같은데 보기가 너무 불편하네요. 닥터로이어에서는 45~55 가량 나오는 것 같은데 참고 볼 수 있을 정도인 것 같구요. 작품에 따라서 프레임 편차가 있는 이유가 뭔지는 모르겠지만 재밌는 컨텐츠들을 즐길 수 없어서 아쉬워요.', 'stars': '', 'date': '2022년 6월 21일'}
# {'text': '쿠팡와우와 연동된다는 점에서는 매우 훌륭하다. 아쉬운 점이 있다면 몇몇 프로그램의 순서가 뒤죽박죽이라는것. 위베어베어스, 도라 디익스플로러라는 외국 애니메이션의 에피소드 순서가 뒤죽박죽이라 너무 불편하다. 쿠플 앱내에서 의견도 보내봤는데 1달넘게 고쳐지지 않고있음. 카테고리도 잘 분류가 안 된 것 같긴한데, 이제 막 시작하는 플랫폼치곤 크게 불편하진 않다. 에피소드 순서좀 다시 수정해주길 바란다.', 'stars': '', 'date': '2021년 12월 17일'}
# {'text': '갤럭시로 2.35:1 비율의 영상 (영화) 시청시 자동으로 전체화면 사용되게 업데이트해주세요. 수동으로 폰 설정들어가서 전체화면 사용 만들수도 있지만 요즘 다른 OTT앱들 왓챠나 넷플같은건 다 자동으로 전체화면 나오던데..', 'stars': '', 'date': '2021년 9월 16일'}
# {'text': '장점:처음 앱 출시 이후 컨텐츠가 많아진건 좋아요 단점: 크롬캐스트 기능이 제대로 되지 않아 출력이 버벅이는 경우가 잦아요. 단점2: ATV기기에선 아직 사용 불가능한게 아쉽습니다. android tv 에서도 볼 수 있게 해주세요.', 'stars': '', 'date': '2021년 5월 23일'}
# {'text': '원래 와우회원으로서 참 괜찮은데요 이런 시도, 역시 2900원 가격에 엄청난 편의는 불가능한것같네요 배속기능추가나 화질개선이 있었으면 좋겠구요 특히나 로딩시간이 너무깁니다 와이파이 재생인데도요,,, 차라리 와우+플레이는 5-6천원데, 와우만하면 월정액 2900원 그대로 해서라도 플레이가 조금 개선되면좋을것같아요', 'stars': '', 'date': '2020년 12월 26일'}
# {'text': '웜뫄ㅡ귀멸의 칼날이 19금인줄 오늘 처음 알게되네요. 성인인증중, 헐~.~ 애들은 이거 엄청 봤던디ㅡ 2022년 3월 18일 추가 내용. 웹 홈페에지상에서 재생하려니 다시 재부팅하기를 수차례. 캐쉬를 못비워 기다리라는 메시지... 충돌문제인가 싶어서 있는줄도 몰랐던 쿠팡플레이앱 지으고 다시 설치 중인데 설치가 엄청 더디고 지연되는 중, 헌데 오후... 안정적인 재생을 위해[버퍼링 방지]를 위해 다운로드를 세편 진행중 출근... 헉! 핫스핏 열린 메인폰으로 전송을 받고 있었는데 ... 내가 시킨 일이니. 데이타 10기가중 3.5기가정도 소모 ^^ 와이파이에서 다 받아진 줄 착각하다니. 데이타는 항상 목마르다! 추신: 캐쉬파일을 비우고 실행했더니 정싱상태로 회귀되었습니다. 메모리 관리가 곧 안정적인 재생을 보장하는군요. 쿠키파일과 임시저장파일 등을 비우시면 괜찮아지는 것으로 확인했습니다. 도움말 감사하구요! 앞으로도 잘 볼께요.', 'stars': '', 'date': '2022년 3월 27일'}
# {'text': '뭐 다른건 다 좋은데 영화든 드라마든 예능이던 애니메이션이든 장르별,종류별로 싹다 뭐뭐있는지를 볼 수 있음 좋겠어요 한번에 다 볼수가 없고 하나하나 검색하던지 메인에 추천된것만 봐야되서 뭐가있는지 뭘볼지 결정하기가 힘들어요', 'stars': '', 'date': '2020년 12월 27일'}
# {'text': '잘 쓰고있는데 몇가지 개선사항좀 건의드립니다. 1. 삼성 덱스를 통해 티비 등 더 큰 화면으로 시청시 영상은 잘나오는데 자막이 너무 작게 나옵니다. 자막 크기 조절이 필요합니다. 2. 영상 밝기조절 기능이 있으면 편할거같네요.', 'stars': '', 'date': '2021년 2월 1일'}
# {'text': '쿠플 너무너무 잘쓰고 있어요!! 다만 프로필별로 별도의 잠금(넷*릭스처럼 함께 앱을 사용하는 타인이 내 프로필에 접속하지 못하게 비번을 거는 것) 이 지원되지 않는다는 점이 좀 아쉽네요ㅠ그것만 빼면 전반적으로 다 만족하면서 시청중이에요!! 앞으로도 다양한 컨탠츠 업로드 부탁드립니다😊', 'stars': '', 'date': '2022년 2월 20일'}
# {'text': '평소에 로켓와우 잘 이용하던 고객들에게 더 많은 서비스를 제공해준다는 점에서 좋은 부분인 것 같습니다! 많은 리뷰들에 적혀있듯이 컨텐츠가 많이 부족한 건 사실이나 이 부분에 대해서는 천천히 늘려가면 되는 것이기 때문에 크게 문제가 될 것이 있을 거라고는 생각이 안듭니다. 다음 컨텐츠 추가할 때 영화 애프터1과 애프터2 좀 추가해주세요..ㅠㅠ 진짜 그럼 평생 사용할게요', 'stars': '', 'date': '2020년 12월 24일'}
# {'text': '최근 영상 재생 중에 [an-bcp-drmpol] 이라는 오류가 뜨면서 재생이 안됩니다. 이전에 문의했을 때 앱 삭제 후 재설치하라고 하여 그대로 했었고 프로필 추가부터해서 쿠팡앱까지 삭제 후 재설치 해봤는데도 해결이 안되네요...다른 방법이 있다면 안내바랍니다.', 'stars': '', 'date': '2022년 4월 23일'}
# {'text': '쿠팡와우이용자인데 무료로 이용할 수 있어서 너무 좋아요. 다만 재생시 자꾸 끊기고 (일시멈춤이 아니고 다시재생시 처음부터 다시시작하네요) 다운로드시 다운로드실패가 잘됩니다. 6개 다운받았는데 그중 한개만 다운받고 나머진 전부 실패.. 오류만 개선된다면 참 좋겠습니다~', 'stars': '', 'date': '2021년 5월 15일'}
# {'text': "'크롬캐스트용' 앱에는 pc와 달리 '자막 크기 및 위치 설정' 메뉴가 없습니다. 자막이 너무 작거나 위치가 화면을 가리기도 합니다. 그리고 메인 화면에서 ,'시청중인 컨텐츠 삭제' 기능'도 없습니다. 개선되었으면 합니다.", 'stars': '', 'date': '2022년 10월 12일'}
# {'text': '주로 다운로드 해서 비행기에서 봄...근데 제대로 다운되는 꼴을 못 봤음...앱 삭제 후 재설치하면 1개 정도는 다운됨...그리고 또 안됨..그럼 또 삭제 후 재설치....영상 하나 다운할 때 마다 재설치 하고 있음...고객센터 전화 걸면 용량과 통신 상태 얘기만 하는데....누굴 바보로 아나..', 'stars': '', 'date': '2023년 5월 17일'}
# {'text': '잘보고있으나 쿠팡플레이로고가 나오는 첫부분 밝기/소리조절이 막아져있어 불편합니다. 특히 밝기가 너무낮아 안보일때보다 제일 불편할때는 자기전 틀었을때 눈이많이부셔도 참고 기다려야하죠 작지만 우선 기분이 상하고 시청하게됩니다.', 'stars': '', 'date': '2021년 6월 27일'}
# {'text': '출시된후 몇개월동안 잘 시청했습니다 지난주말부터 영상을 누르면 그대로 멈춰버리고 핸드폰기능까지 마비되면서 (한참 기다려야꺼짐) 앱삭제후 재설치해도 계속 멈춰버립니다 그러면서 핸드폰 발열도 심해집니다 업데이트하면서 뭔가 기능끼리 충돌이있는거 같은데 빠른시일내에 복구해주세요 너무불편하네요', 'stars': '', 'date': '2021년 6월 16일'}
# {'text': '지금까진 너무 좋게 사용하고있어요 초기다 보니 영상이 제한적인게 아쉽긴 하지만 수시로 업데이트 하시는거보면 열심히 노력중이신거같아요 !! 사용하면서 느끼는거지만 카테고리 기능을 추가해주셨으면 합니다 검색만으로 찾기엔 한계도 있는거 같아서 부탁드려요 앞으로도 좋은 앱 위해 힘써주세요~~~', 'stars': '', 'date': '2021년 1월 21일'}
# ...
# {'text': '서버 좀 늘려주세요 국대경기보는데 오류때문에 못봤습니다', 'stars': '', 'date': '2023년 11월 21일'}
# {'text': '스마트폰이랑 IPTV로 시간떼우기에 참 좋았습니다^^*', 'stars': '', 'date': '2023년 11월 30일'}
# {'text': '호메틱스 박스r 4k 플러스 사용중인데 An net off라고 에러코드 뜨면서 안되는데 해결방법좀 알려주세요? 무슨 답을 줘야되는거 아니에요? 이것도 해결못하시면서...쩝쩝 뭐 아직도 해결책도 모르신거 같네요 진짜 좀 무능하신거 같네요', 'stars': '', 'date': '2023년 7월 8일'}
# {'text': '스포츠 경기 결과를 보지 않고 경기 HL 를 보는 것이 낙입니다. 경기결과가 보이지 않게 옵션 처리할 수 있는 기능을 개발해주세요. 감사합니다.', 'stars': '', 'date': '2023년 8월 15일'}
# {'text': 'LGu+ IOT로 쿠플 들어가서 보면 검색에 숫자만 적히고, 글씨는 안써짐.. 이 오류 수정은 도대체 얼마나 있어야 할런지. 엘지유플러스 문제인가. 아니면 쿠플 문제인가. 알수가 없음. 분명 이런 피드백 오지게 받았을텐데 쿠플 이용자가 엄청 많을텐데.. 나만 이걸 피드백하는건가... 욕나옴', 'stars': '', 'date': '2023년 11월 21일'}
# {'text': '진짜 너희들 앱개발 어디서 하냐? 플레이어기능이 가장 중요한데..가장 엉망이건 머냐? 버그가 이렇게 많고 불편한앱 진짜 오래간만에 본다.', 'stars': '', 'date': '2023년 11월 18일'}
# {'text': '쿠팡 최고예요. 다양한 컨턴츠에 교육까지 완전 만족', 'stars': '', 'date': '2023년 10월 22일'}
# {'text': '쿠팡 와우도 쓸 겸 스포츠도 볼 겸 겸사겸사해서 사용중인데 앱 최적화랑 스포츠 알림기능이 있었으면 좋겠습니다. 23/24부터 라리가도 맡는다고 알고 있는데 알림 기능 추가 부탁드립니다', 'stars': '', 'date': '2023년 7월 20일'}
# {'text': '자꾸 네트워크 상태가 좋지 않습니다 라고 하는데요.. AN-NET-OFF 라고 뜹니다', 'stars': '', 'date': '2023년 11월 21일'}
# {'text': '아무리 축구 붐이 일어나 시청자가 몰렸다 해도. 독점 중계도 아니고 고작 월드컵 2차 예선인데.. 4~5분 간격으로 중계가 끊기면 본선에서는 어떻게 하려고 하는지.. 개선 부탁드립니다. 쿠팡 플레이가 한국 K리그부터 여러 시스템 도입으로 축구계를 이끌고 있는 만큼 항상 응원하고 있습니다.', 'stars': '', 'date': '2023년 11월 21일'}
# {'text': '해외폰, 빔프로젝터는 어플이 안열려요. 루팅한 기기에선 사용이 불가하다네요. 다른 ott는 다 되는데 왜 이거만 안되는지 모르겠어요;;; 개선해주세요', 'stars': '', 'date': '2023년 7월 26일'}
# {'text': '접속량이 많은 스포츠중계는 접속이 안되네요.', 'stars': '', 'date': '2023년 11월 21일'}
# {'text': '축구보려면 오류떴다고하고 축구볼려고 하는데 진짜 별로네 가입 끊습니다', 'stars': '', 'date': '2023년 11월 21일'}
# {'text': '축구 경기 결과 안보이게 해주세요. 점수 스포가 돼버리면 하이라이트 찾아보는 재미가 없어집니다. 스포티비 하이라이트 운영 참조하시면 됩니다. 쿠플 응원합니다.', 'stars': '', 'date': '2023년 8월 17일'}
# {'text': '아니 귀떼기 나갈뻔했네 ㅡㅡ 아니 화면 나갈라다가 음량 최고로 올려져서 귀떼기 나갈뻔했잖아요 화면한번 터치하고 음량조절 할수 있게 좀 바꿔요좀 ㅡㅡ 아 내 청력 진짜 이런걸 신경못쓰냐진짜', 'stars': '', 'date': '2023년 8월 9일'}
# {'text': '드라마 전편 다운로드시 다수에 편이 다운로드가 되지 않고 fail 및 다운로드 되는것처럼 무한 정지', 'stars': '', 'date': '2023년 11월 14일'}
# {'text': '그냥 좀 별로인게. 알고리즘 추천 별로임. 추천받고 싶지 않음.', 'stars': '', 'date': '2023년 10월 10일'}
# {'text': '패치이후 한국영화 틀었더니..각 한국영화가 안나옴 이부분만 보이게 나입니다. 답답해죽겠내', 'stars': '', 'date': '2023년 11월 19일'}
# {'text': '삼성 프리스타일 빔프로젝터에서 재생 시 PL1-ERR-MEDIA-3016 코드가 뜨며 재생이 되지 않고 있습니다. 다른 어플에서는 다 잘 재생이 되는데 쿠팡플레이만 재생되지 않네요...', 'stars': '', 'date': '2023년 9월 6일'}
# {'text': '일본 영화나 일본 드라마등등 많이 올려주세요 너무 부족합니다!! 그리고 안드로이드tv 요새 업데이트가 뜸한데 쿠팡플레이 안드로이드tv버전 엄청 무겁고 더 느려졌네요 ㅡ.ㅡ;3 최적화 패치좀 해주세요 타 ott보다 엄청나게 무겁고 느립니다', 'stars': '', 'date': '2023년 7월 14일'}
# {'text': '축구 하이라이트 보려고 접속하면 영상 나오기전에 스코어 다 나와있어서 볼맛안나요 수정 좀 해주세요', 'stars': '', 'date': '2023년 9월 29일'}
# {'text': '다 좋은데 실시간 채팅도 다시보기 지원했으면 좋겠어요. 아무튼 F1 중계 감사...', 'stars': '', 'date': '2023년 11월 5일'}
# {'text': '볼게 너무 없음. 싸서 그런가? 가격을 더 올리고 다양한 컨텐츠 부탁.', 'stars': '', 'date': '2023년 9월 26일'}
# {'text': 'tv로 연결후 보면 엄청자주끊어짐 이러면 결제구지할 필요성 단1도 없는데?', 'stars': '', 'date': '2023년 9월 29일'}
# {'text': '축구 같이 인기있는 라이브할 때 버퍼링이 잦아요.', 'stars': '', 'date': '2023년 10월 13일'}
# {'text': '쿠팡플레이 잘쓰고있는데 업데이트할려니 이앱은 기기와 더 이상 호환되지 않습니다 자세한 정보는 개발자에게 문의하세요 이거 왜이러나요? 그리고 드라마다운 받았는데 네트워크 오류로 실행이 안되는건 왜 그런건가요 힘들게 받았는데 실행 안되서 열받네요', 'stars': '', 'date': '2023년 11월 13일'}
# {'text': '광고보고 온건데 사기였네? ㅋ 공짜로 볼수 있다더니 가입 하려면 멤버십 가입 후 사용할수 있다 이러네 ㅋ 바로 삭제 한다', 'stars': '', 'date': '2023년 10월 22일'}
# {'text': '최악. 노트북으로 볼 때 드라마나 영화는 로딩때문에 아예 못 보고 짧은 아동용 애니만 겨우 돌아갑니다 회차넘어가면 언어설정부터 다시 해줘야 하구요 스크롤 내릴 때도 제멋대로 위로 올라갑니다', 'stars': '', 'date': '2023년 8월 24일'}
# {'text': '별한개도 주기싫어요. 해외나와서 로밍하고 왔는데도 업뎃만 실컨시키고 정작 안봐짐..허당..쿠팡해지하고 싶어지는 충동을 느낌니다.', 'stars': '', 'date': '2023년 6월 29일'}
# {'text': '컨텐츠가 너무 한정적이라 의견을 남겼음에도 불구하고 읽기는 커녕 아예 답장조차없고 돈 내는 의미가 없는거같아요 빠른 시일내에 확인좀 하시고 더 많은 컨텐츠가 있으면 좋겠어요', 'stars': '', 'date': '2023년 8월 27일'}
# {'text': '찜 할수 있는 기능 있었으면 좋겠네요. 무한도전 같은건 회차가 너무 많아서 내가 보고싶은편 찾아보기가 힘들어요.', 'stars': '', 'date': '2023년 8월 2일'}
# {'text': '내가 보던 목록이 아무리 껐다 켜도 안떠서 매번 볼 때마다 검색해야되는데 이게 맞아요? 버그인지 뭔지 오류좀 빨리 수정해주세요 힐링하려고 보는건데 스트레스 너무받음', 'stars': '', 'date': '2023년 7월 27일'}
# {'text': '갤럭시 S23 욽트라로 변경하고나서 해상도가 최대 480p로 나오네요. 재설치해도 동일합니다. 어떻게 된건가요.', 'stars': '', 'date': '2023년 6월 30일'}
# {'text': '1.5배속 이상하면 프레임이 왤케 끊기나요 최적하 할생각은 아예 없나요? 프레임 문제 해결해야 더 커질텐데...', 'stars': '', 'date': '2023년 7월 27일'}
# {'text': '1. 자주 멈추는 다운로드.. 2. 자막이 설정되있어도 안나옴 3. 세상 불편한 ui/ux 가입자만 늘리지 말고 넥플릭스 좀 써보세요..ㅡ.ㅡ', 'stars': '', 'date': '2023년 7월 30일'}
# {'text': '잘보고 있는데요.. 어느 날부터 시청중인 콘텐츠 기록이 안떠요ㅠㅠ 시청 기록자체가 다 사라졌어요.. 왜 그런거죠?', 'stars': '', 'date': '2023년 6월 26일'}
# {'text': '별점하나주기도 열받네요. 쿠팡플레이스 무료라고 어그로 끌더니, 와우 가입하면, 30일무료체험 이후에는 매월 5000원 미만, 유료결제 시스템. 사기당한기분이네요.. 요즘에도 이런식으로 영업하는게 3류 거지들이나 하는거지..않나요?', 'stars': '', 'date': '2023년 8월 1일'}
# {'text': '외국 어린이들이 보는 영상은 없는 것 같아요 뽀로로 영어버전이라던가... 노래 말구요; 구할 수 없는 걸 찾는 걸까요ㅎ', 'stars': '', 'date': '2023년 7월 13일'}
# {'text': '모바일은 왜 자막크기가 변경이 안되는지 티비랑 연결해서 보는데 눈 나쁜사람 자막읽기 겁나 어렵네요 모바일도 자막크기 설정할수있도록 해주시오', 'stars': '', 'date': '2023년 7월 30일'}
# {'text': '아 진짜 별점 확 깍을께요 아니 왜 티비에서 시청중였던게 안보이죠 셋탑 모뎀 꺼놧다 재부팅을 해봐도 시청중인건 보이지도 않고 간혹 시청완료한것도 시청중이라고도 나오고 너무 관리 안하는거 아닌가요 다른거에 비해 많이 불편하네요', 'stars': '', 'date': '2023년 7월 27일'}
# {'text': '티비로 갑자기 오류라면서 안나오기 시작한지 몇달째.. 고객센터 전화해도 별 도움되는 것도 없었고 그냥 안보고 있네요.', 'stars': '', 'date': '2023년 8월 18일'}
# {'text': '자막이 좀 더 아래에 있었으면 좋겠어요 ㅠㅠ 배우들 얼굴을 가려요😭 그리고 중드가 더 많았으면 좋겠어요..!', 'stars': '', 'date': '2023년 7월 20일'}
# {'text': 'TV에서 축구 보는데 렉 진짜 진짜 역대급으로 심해서.. 렉도 겁나 안 풀리고 잦고... 하 ㅠ 똥폰 공기계로는 잘 돌아가고;;;', 'stars': '', 'date': '2023년 8월 3일'}
# {'text': '잔 버그도 너무많고 무슨 다운로드하는데 하루종일 떠있고 좀만 뭐하몀 네트워크ㅡ안듀ㅣㄴ다하고;;;;;; 돈주고는 절대 안쓸듯 ...멀었네요 기술 아직', 'stars': '', 'date': '2023년 8월 29일'}
# {'text': '저렴한건 좋아요. 하지만 서비스도 저렴하면 안되는거 아닌가요? 예고도 공지도 없이 보고있던 콘텐츠를 하루아침에 내려버리면 어떡하나요..', 'stars': '', 'date': '2023년 6월 25일'}
# {'text': '와 대박이다 옛날옛적 추억의 미드를 여기서 찾았음 마담세크리터리!!!!!!감사합니다 쿠팡플레이 깔아만놓고 써본적없는데 와우회원인게 이렇게 행복할수가!!!', 'stars': '', 'date': '2023년 8월 28일'}
# {'text': '별 한 개도 아까워요 UI가 왤캐 불친절해요? 그리고 업데이트 후에 자막이 아예 안 나와요;', 'stars': '', 'date': '2023년 8월 28일'}
# {'text': '리뷰작성 안하는데 남겨봅니다. 영상볼 때 너무 끊겨서 불편하네요. 컨텐츠도 별로.', 'stars': '', 'date': '2023년 9월 9일'}
# {'text': '시카고 파이어 너무 재밌습니다~! 시즌 10도 얼른 나오면 좋겠어요! 다음 내용이 너무 궁금해요..', 'stars': '', 'date': '2023년 8월 14일'}
# {'text': '다운로드 해야 볼수가 있게 되어 있는데 하루종일 8시간동안 있어도 절반에서 로딩만 되는 엉터리 앱입니다. 저도 쿠팡 와우 회원입니다. 쿠팡회원 무료감상 절대로 아닙니다. 삭제 합니다.', 'stars': '', 'date': '2023년 6월 21일'}
# {'text': '시청중에 홈으로 나가면 먹통이 됩니다 ㅠㅠ 그리고 pc로 볼땐 오프닝 건너뛰기가 없어요 개선좀 갤노트10플', 'stars': '', 'date': '2023년 8월 9일'}
# {'text': '아니 로그인을 하는데 도대체 왜 로그인을 할수가 없다고만 뜨는데 잠시후에 해도 안되고 어쩌라는거야', 'stars': '', 'date': '2023년 7월 27일'}
# {'text': '쿠팡멤버라 공짜로 쓰긴 하는데 볼것도 별로 없고 검열도 심함 넷플릭스 추가로 구매해서 보는게 나을듯', 'stars': '', 'date': '2023년 10월 22일'}
# {'text': '어플이 너무너무 불친절해요. 이전화,다음화 버튼이 없어서 보려면 영상리스트에서 찾아야하고... 시즌구분없이 일렬로 나열해놔서 무한도전같은 프로그램 최근꺼 보려면 끊임없이 스크롤해야하고, 영상 시작할때 쿠팡플레이 로고도 너무 오래나와요.', 'stars': '', 'date': '2023년 7월 21일'}
# {'text': '영화 및 드라마 등 재생이 되는게 없습니다. 오류인듯 한데 확인 요청드립니다.', 'stars': '', 'date': '2023년 7월 3일'}
# {'text': '광고에서 매우많은컨텐츠 라고했는대 막상 뚜껑열어보면 다지나간 컨텐츠에 그마저도 B급보다못한 작품이 상당히많고 저렴한가격으로 그나마 보는거지 왜 한국은 과대광고가 판치는건지 전혀모르겠음 돈내고 보기엔 진짜 너무아까움', 'stars': '', 'date': '2023년 7월 13일'}
# {'text': '쿠팡플레이를 통해 국대 경기나 K리그 잘 보고있습니다!! 다만 한가지 추가 해주셨으면 하는 부분이 있어서요 스코어 off를 할수있었으면 좋겠어요 재시청이나 하이라이트를 볼때 결과를 모르는 상태에서 볼수있게요!! 저번에도 문의 드렸는데 빠르게 개선이 됬으면 좋겠습니다!', 'stars': '', 'date': '2023년 4월 25일'}
# {'text': '업데이트 후에도 재생 오류 뜸', 'stars': '', 'date': '2023년 11월 21일'}
# {'text': '블루투스 이어폰 에프터샥 오픈컴 사용중인데 정지,재생 버튼이 안먹히네요.유튭이나 넷플에선 되는데요.그리고 시청중 통화나 문자 확인시 보던 영상이 다시 처음부터 재생되는게 불편합니다.그리고 접근성에 보이스 어시스턴트를 켜서 시력이 약한 사람들의 관점으로볼때 넷플은 이미지를 터치하면 영상의 제목을 읽어주고 플레이가되면 영상 터치시 10초 앞,뒤 재생등 소리로 읽어주는데 여긴 그런게 없네요', 'stars': '', 'date': '2021년 12월 17일'}
# {'text': '와우 멤버십 2,900원으로 영상 스트리밍 서비스까지 누릴 수 있어서 넘 좋아요~ 쿠팡 쓰시는 분들이라면 강추! 이따금씩 영화나 TV프로그램 보는 경우가 많은 분들은 넷플릭스나 왓챠에 비해 가성비가 좋은 듯해요! 계정도 4개, 기기는 5개까지 이용 가능한데 가격이 너무 싸잖아유~~~ 저두 쿠플 나온뒤로 바로 갈아탔습니다아 하핫', 'stars': '', 'date': '2021년 1월 17일'}
# {'text': '티켓팅 4만명 기다렸는데 다른 경로로 접근하라하네... 사람 몰릴거 알았으면 제대로 구축해놔야지 이따위로 관리할거면 그냥 다른데 맡기시길....', 'stars': '', 'date': '2023년 6월 28일'}
# {'text': '지난 리뷰 삭제후 재작성합니다. 시청 중 사용자의 동작이나 조정이 없으면 일정시간 후 앱이 종료되는 설정이 되면 좋겠습니다. 보다가 잠들었는데, 배터리 소진으로 폰이 꺼져서 아침 알람을 놓쳐서 두번이나 지각할 뻔 했어요.', 'stars': '', 'date': '2023년 2월 7일'}
# {'text': '자막이 하나도 안나와요 한국어 자막 해제했다가 다시 체크해도 앱 껏다가 켜도 자막이 안나옴 pc에선 잘 나오는데 어플로는 안나와서 사용을 못하겠네요 + 답변 받고 다른 리뷰들 보니 한달 이상 지속된 이슈인거같아 그냥 앱을 지웠습니다. 와이파이 사용중 다운로드 안하고 시청중에 저런 현상이었고 카테고리 불문하고 그냥 자막 자체가 안나옵니다.', 'stars': '', 'date': '2023년 1월 20일'}
# {'text': '전체화면이 안돼서 불편. 내가 본 영상리스트가 ui메뉴에 없고 다시 검색해서 봐야하는점이 불편. 일시정지했다가 재생하면 광고가 나오는게 불편. 검색어를 타이핑할때 관련 제목이 뜨면 편할텐데 그러지않아서 불편합니다. 전체적으로 기능들이 미흡하네요', 'stars': '', 'date': '2021년 9월 19일'}
# {'text': 'Z플립3사용중인데 드라마보려고 재생시키니까 오류 걸려요 소리만나오다가 화면이 나오는데 화면밝기 일시정지 할수있는 화면이 안나오고.. 중간에 다른거하려고 하면 멀티화면으로 작게 변경되지않고 쿠팡플레이 화면에서 그냥멈추네요 이제 이틀사용했는데 너무 불편해요', 'stars': '', 'date': '2022년 9월 28일'}
# {'text': '맨시티경기 티겟구매를 위해 설치하였으나 쿠팡플레이 월정액 가입유도와 서비스취소할 경우 티켓이 취소된다는건 뭔 말같지도 않은 소리인지 돈독이올라도 너무올랐네요 별점 1점도 아까운 쓰레기 앱입니다.', 'stars': '', 'date': '2023년 7월 28일'}
# {'text': '와~ 쿠팡이 작심하고 컨텐츠를 늘리고 있나보네요. 한달 전에 깔았다가 볼 게 없어 지웠는데 아이 영어 때문에 다시 들어와봤더니 그새 보여줄만한 게 많아졌어요. 엘리너는 궁금해, 스콜라스틱 시리즈 등 무해하고 영어 흘려듣기 시킬만한 좋은 시리즈가 많네요. 이대로 쭉 유지시켜 주시길 바랍니다. 2012년판 피터래빗 TV 시리즈도 추가되고 잠수네 추천 영상들 많이 올라왔으면 좋겠네요. 그리고 즐겨찾기 기능이 추가되었으면 좋겠습니다. 있는데 제가 못찾는 걸수도 있겠지만요.', 'stars': '', 'date': '2021년 6월 23일'}
# {'text': '언제적 결제방식 쓰는 뱅크페이로만 결제시키는건지,,, 하라는거 다하고 똥개짓 다 했더니 입력시간 초과 ㅋㅋㅋㅋ 에라이', 'stars': '', 'date': '2023년 6월 28일'}
# {'text': '쓸대없는 화면이 많음. 프로필 선택화면(이건 뭐 어쩔수 없다 치고) 영상 골라서 시작 누르면 몇세관람가 3초 쿠팡 스플레시 로고 3초 이게 타 앱이랑 뭐가 다르냐 하면 영상 어디든 플레이 하면 항상 뜸 항상. 실수든 의도하든 영상 중간에 중단하고 다시 보면 또 6초정도 낭비함. 이렇게 쓰잘대기없는 시간을 매번 낭비할 필요가 있나 싶음. 내가 보고싶은건 컨텐츠지 로고랑 관람가 표시가 아니니깐 한번은 용서되도 계속 나오니 지긋지긋해짐. 이거 보는사람들 유료맴버십 가입자잖음? 광고 보기싫어서 이런거 찾아온거고. 그럼 그에 맞게 쓰잘대기 없이 딜레이 주는건 그만뒀음 좋겠음. Ui구린건 언젠가 업뎃될거라 믿고 어느정도 용서되는데 아무의미없이 시간낭비하는 등의 ux구린건 좀 생각해보길..', 'stars': '', 'date': '2023년 6월 16일'}
# {'text': '자막이 생겼으면 좋겠어요 선풍기 소리, 주변 소음으로 인해 소리가 잘 안 들릴 때가 있네요 그리고 쿠팡플레이로 보면 볼륨이 너무 작게 들려요 기존 티비를 그냥 볼 땐 소리 10번 대여도 잘 들리는데 쿠팡플레이를 연결해 보면 20번대까지 키워야 하네요 원래 쿠플로 보면 소리가 작아지는 게 맞는지요?', 'stars': '', 'date': '2023년 7월 12일'}
# {'text': '쿠팡 멤버십 가입만하면 무료로 즐길 수 있는 건 좋은데 아직 소비할 만한 컨텐츠 부족이 너무 큼... 그리고 영상 다운로드 후 네트워크 연결 상태 유무에 상관없이 이따금씩 동영상이 재생되지 않을 때가 많음. 쿠팡에 대한 신뢰가 높은 편인데 아직 개선할 점이 많은 앱.', 'stars': '', 'date': '2021년 5월 6일'}
# {'text': '사용자 입장에서 연구하고 개선할 의지가 없어보임 불편한 점 꾸준히 후기 올라오는데 업데이트 한 적이 없음 다음화 버튼이 있으면 이전화 버튼도 만들던가 아니면 회차에서 지금 몇화를 보고있는지 하이라이트를 넣어주던가 이런 기본적인거좀 .. 다음화 잘못누르면 다시 보던거 찾기 매우 귀찮아서 점점 안보게됨 그리고 어디 다른기기 로그인해놓은거 재로그인 해야되는 주기가 너무 짧음.. 시청하다가도 갑자기 로그인인증하라고 로그아웃되버리니 뭐하자는건지 여러가지로 짜증나요 쿠팡이란', 'stars': '', 'date': '2022년 4월 21일'}
# {'text': '자막 크기를 설정할 수 있으면 좋겠습니다. 어두운 장면에 흰 자막이 크게 뜨니 장면에 몰입하기가 힘드네요.. 가시성 때문에 자막 색을 바꾸는건 무리일 것 같고 크기 설정이라도 되면 너무 편하게 사용할 것 같습니다.', 'stars': '', 'date': '2022년 2월 22일'}
# {'text': '영상 업데이트 안하시나요? 아직도 방영중인 예능프로가 왜 7월 31일부터 멈춰 있는거죠? 11월인데 몇달을 업데이트 안한건 너무 하지 않나요? 그러면서 메인화면에는 매주업데이트 라고 되어있고 혹시나 해서 다른 프로그램도 보니 똑같이 같은 날에 아니 7월달에 멈춰있네요? 그리고 프로그램 리뷰를 보니 최신회차 업데이트 되면 오래된 회차가 없어진다던데.. 이래서 누가 이용하겠나요? 비용이 저렴하다고 질과 양도 저렴하면 안되는거 아닌가요? 돈을 조금더 받더라도 최고의 품질을 보여줘야 하지 않나 싶네요 소비자는 절대 바보가 아닙니다', 'stars': '', 'date': '2022년 11월 3일'}
# {'text': '9월말 업데이트부터 VOD 시청후 15분정도 되면 메모리가 부족하다는 메세지와 함께 어플이 종료되고 재시작됩니다. LG 스마트TV로 시청중이며 업데이트 전까지는 아주 잘됐으며 넷플이나 웨이브도 함께 사용중이나 이런문제 없습니다. 꼭 고쳐주시길 부탁합니다.', 'stars': '', 'date': '2021년 10월 5일'}
# {'text': '가격면에서는 압도적인데 초기라 그럴까요 기능이 좀 부실해요. 보고 싶은 컨텐츠 찜하기 기능도 있으면 좋겠네요. 보유 컨텐츠 수준도 아직은 좀...뭐랄까 넷플릭스나 왓챠같이 본격적인 OTT를 해보겠다는 느낌보다는 쿠팡와우 회원들에게 부가적으로 서비스를 제공한다는 느낌이 더 큽니다용 그런데 2900원의 메리트를 생각하면 이 수준도 감동적이긴 합니다. 월 2900원에 로켓직구, 로켓배송, 로켓프레시 배송비도 무료, 5명이서 계정공유까지 하는데 뭐...', 'stars': '', 'date': '2020년 12월 24일'}
# {'text': '요즘 폰으로만 영상자료를 보는 사람은 거의 없는걸로 아는데... 안드로이드 TV박스에선 구동되지 않네요. 거의 모든 TV박스가 루팅된 롬을 이용하는데 그것땜에 실행조차 안되는건 좀 무리라 봅니다. 어차피 결제는 쿠팡에서 하는데 쿠팡플레이를 루팅된 기기에서 구동을 못하게 막은건... 곧 유료로 또 바꾸려는 뜻인가 싶어서 좀 꺼려지네요', 'stars': '', 'date': '2021년 10월 11일'}
# {'text': '처음엔 이 가격치곤 볼게 꽤 있다고 생각했는데...애니 대부분이..2기는 없고 1기만 있어요..흐름 끊겨요ㅠㅠ 2기나 새로운 애니,영화 좀 많이 올려주세요ㅠ +그리고 자꾸 오프닝 건너뛰기나 다음화보기 버튼이 없어져요..한 두번이 아니라 좀 불편하네요..ㅠㅠ', 'stars': '', 'date': '2023년 1월 25일'}
# {'text': '잘쓰고 있었는데 어느순간부터 꽉찬화면 재생이 안되고 검은화면 여백이 많게만 재생되네요 화면 조절 기능도 없어서 꼼작없이 화면을 작게 봐야 됩니다 화면 비율 설정이나 그런게 필요해보입니다', 'stars': '', 'date': '2021년 3월 6일'}
# {'text': '잘 사용하고있습니다. 좋은 양질의 컨텐츠를 보다 좋은 방향으로 이끌어주신점 너무 감사합니다 다름이 아니라 화면 전환 기능이 아직 추가된거같지 않아 많이 불편합니다.', 'stars': '', 'date': '2023년 6월 5일'}
# {'text': 'Tv에서 쿠팡플레이 시청하면 (tv자체에 쿠팡플레이 어플을 다운받아서) 자막이 너무 밑으로 내려가서 (혹은 화면비율이 다소 커져서?) 자막이 첫번째줄만 보여요. 그 마저도 다 보이지 않습니다. 핸드폰보다 tv 로 시청을 더 많이보는데! 너무 불편합니다!!!!!!!!!! 좀 고쳐주세요!!!!!!!!!!!!!!!!!!!!', 'stars': '', 'date': '2023년 3월 29일'}
# {'text': '엘지 스마트티비 이용하는 1인입니다. 쿠플이 티비에 설치가 안되고 앱스토어에도 나오질않아 양쪽 고객센터에 문의를 했더니 버젼이 호환이안된다고 해서 항상 스크린쉐어로밖에 못보고있네요 물론 제티비의 문제일수도 있으나 호환가능하게 버젼의 폭을 좀 넓혀주셔서 업뎃좀 부탁드립니다. 웨이브나 디즈니 티빙은 전부설치가되는데 쿠플만 안되네요 매우 아쉽습니다. 좋은 어플을 제대로 사용하지못하고 있네요ㅠㅠ', 'stars': '', 'date': '2023년 2월 22일'}
# {'text': '다 좋은데...다운로드를 한거면 네트워크 연결이 안됐어도 그냥 볼수있는거 아니에요?? 근데 왜 안보이건지 모르겠는데 진짜 답답하고 짜증나서 데이터도 켜봤는데 소용도 없고 데이터로 다른건 다 되는데 쿠팡플레이가 이상한건지 내가 이상한건지 내 폰이 이상한건지.......', 'stars': '', 'date': '2023년 1월 15일'}
# {'text': '매우 만족. 처음 출시됐을 때는 로그인이 안되고 무한 로딩이라 이용 자체를 못했는데 지금은 정상적으로 이용 가능함. 다른 플랫폼에 비하면 컨텐츠는 적지만 와우회원(비싸지도않음)이면 로켓배송제품 할인도 받고 교환반품비도 30일안에는 무료인데다가 추가적으로 TV프로그램 이용할수 있는 쿠팡플레이까지. 대혜자임. 전문적인 플랫폼과 비교하시는 분들이 있는데 솔직히 쿠팡플레이 보려고 와우회원 가입한다기보다 이미 회원가입 되있었는데 추가적으로 쿠팡플레이 이용하는 사람들이 더 많을거라 생각됨. 쿠팡플레이는 넷플릭스같이 전문적인 플랫폼이 아닌 와우 회원에게 주어지는 서비스격이라 생각되는데.가격부터가 많이 차이나고. 제공하는 서비스도 다르잖음. 처음부터 이 앱에서 좋은 서비스가 제공된다면 좋겠지만 와우회원에게 굳이 하지 않아도 될 서비스를 무료로 제공한다는 점에서 이정도면 만족. 처음에는 로그인조차 안됐는데 이제 로그인 가능한 거 보면 느리지만 조금씩 개선중인것 같고. 불편사항도 점차 개선되길바람.', 'stars': '', 'date': '2021년 1월 23일'}
# {'text': '오프라인으로 저장하고 재생하는데 인터넷 연결이 안된다고 재생이 안돼요', 'stars': '', 'date': '2023년 7월 16일'}
# {'text': '한편의 영상을 다 보고난 후 다음편으로 자동 플레이 되는건 좋지만 다시 이전 편을 보고 싶은데 플레이 마지막에 걸려 있어서 보고 싶은 편을 못보고 계속 자동으로 다음편이 플레이 됩니다 ex) 6편 보다가 4편 다시보기 하고 싶은데 자동으로 5편으로 넘어감... 실행 종료 후 다시 해봐도 안되고.. 겁나 빡쳐서 설치 제거 할까 하다가 업데이트 해보고 그래도 안되면 삭제 각이요!!', 'stars': '', 'date': '2021년 11월 10일'}
# {'text': '백그라운드재생 안되나요...ㅠㅠ 라디오처럼 듣고싶은데 나가게되면 다시 처음부터 봐야되고 불편하네요..', 'stars': '', 'date': '2023년 7월 27일'}
# {'text': '제가 축구 티켓팅을 하기 위해서 쿠팡플레이 어플을 다운 받아서 사용하게 되었는데, 대기번호를 받는 과정에서 도중에 튕기는 현상이 2번 발생해서 초기화가 되었어요. 아무리 사용하시는 분들이 많더라도 어플을 사용하는 과정 중에 발생하는 오류들을 고쳐주세요.', 'stars': '', 'date': '2022년 6월 19일'}
# {'text': '어디까지 봤는지를 기억을 못함 ㅋㅋ 다른앱열거나 화면 껐다 키면 첨부터 시작함 ㅋㅋ 진짜 븅0어플 그자체', 'stars': '', 'date': '2023년 7월 22일'}
# {'text': '영상이 안틀어짐. 어플지웠다 깔아도 안됨', 'stars': '', 'date': '2023년 10월 24일'}
# {'text': '쿠팡플레이 관계자분 꼭 답변 부탁드립니다. 얼마 전까지 쿠팡와우를 통해 쿠팡플레이를 애용하던 시청자입니다. 다른기기에서 사용한 적도 없고, 아이디를 빌려준 적도 (최근 시청이 안되면서 다른기기에서 로그인 1회함.)는데 어느 날부터 어떤 프로그램이든 시청하려고 하면 "스트리밍 에러 - 기기에서 스트림이 불가합니다. os를 업데이트 하시거나 다른 기기에서 시청해보시기 바랍니다."라는 문구가 뜨며 재생이 안되는데 각종 방법을 다 써봐도 저 오류가 해결되지 않네요. (영상중간에 녹화를 한다던가, 스크린샷을 찍는 둥 불법적인 일을 저지릌 적도 없음) 제가 시도했던 방법은 1. 쿠팡플레이 삭제 및 재설치 2. 쿠팡, 쿠팡플레이 삭제 및 재설치 3. 쿠팡관련 어플 삭제 후 해당기기 구글 광고ID재설정 4. 쿠팡 어플 내 인증되어 있는 기기 해제 후 재설정 위 4가지 말고는 제가 할 수 있는 방법이란 게 떠오르질 않네요. 고객센터 전화해봐도 4번말만 되풀하구요. 빠른답변 부탁드려요.', 'stars': '', 'date': '2022년 3월 18일'}
# {'text': "갤폴드 사용시 테블릿으로 인식해서 TV연결을 위한 '기기 연결' 기능이 없는 것으로 확인했고, 개발자 측에서 관련사항 보완중임을 회신 받음. 가지고 있던 공기계를 통해서 TV 연결을 완료함. 다만, 태블릿용 UI에도 기기연결 기능이 있어야 할 것으로 보임.", 'stars': '', 'date': '2021년 10월 25일'}
# {'text': '우선 폰으로 볼땐 버벅거리는게 없어서 괜찮은데 태블릿으로 재생하면 계속 툭툭 끊기고 엄청 버벅거려요 다른 다시보기앱은 잘되고 깨끗하게 나오는데 이것만 그러네요 눈아파서 못보겠어요 하~ 안드로이드 화면 확대 되게 해주세요 영화같은 경우는 위아래양옆이 다 공백이라 화면이 너무 작음', 'stars': '', 'date': '2021년 7월 9일'}
# {'text': "시리즈로 나오는 만화들.. 예를 들어서 '위 베어 베어스'를 영어 버전으로 쭉 보고 싶은데 회차마다 영어버전으로 다시 바꿔줘야해서 불편해요. 분명 설정은 영어로 되어있는데 왜 회차가 바뀌면 한국말로 나오나요? 예전에는 안 그랬던 것 같은데 오류인지 확인이 필요해 보입니다.", 'stars': '', 'date': '2022년 10월 14일'}
# {'text': '「폰에서 영상 재생할 때 꽉찬 화면은 어떻게 보나요? 상하좌우 여백이 너무 많아 보기 불편합니다」 「22년 4월 9일 전체 화면 보기 가능하도록 업데이트 되었네요. 넷플이나 타 ott에 없는 드라마나 영화 있는게 메리트네요. 다른 ott에서 하지 않는 국내 프로축구나 농구 등도 중계해주면 좋을 것 같습니다(해외 중계보다 훨씬 효율적일 것 같습니다).」', 'stars': '', 'date': '2022년 4월 9일'}
# {'text': '다양한 컨텐츠가 많아서 좋아요 다만 아쉬운 점이 있다면 영상재생하고 나서 화면이 고정되어있어서 폰충전하면서 보기 불편해요 화면도 돌아가게 해주시면 좋겠어요 그리고 교육에 스페인어가 사라졌던데 이유가 있나요?ㅠ', 'stars': '', 'date': '2022년 6월 11일'}
# {'text': '일단 컨텐츠부족한건 어쩔수없고..늘려가겠죠뭐 화면 무조건 가로전환모드만 강제에 팝업재생모드안되는게 불편 무엇보다 앞으로넘기는 기능이 넘불편하네요 글고 무엇보다 인트로 쓸데없이 몇초잡아먹는건 굳이 필요한가싶습니다 그래도 와우회원이 같이 사용할수있다는건 매우좋음', 'stars': '', 'date': '2021년 2월 6일'}
# 완료

# %%
# 요소별 추출
def get_content(review):
    condic = {}
    condic['text'] = review.find_element(By.CSS_SELECTOR, 'div.h3YV2d').text
    condic['rat'] = len(review.find_elements(By.CSS_SELECTOR, 'span.Z1Dz7b'))
    condic['date'] = review.find_element(By.CSS_SELECTOR, 'span.bp9Aid').text
    return condic

# %%
result = [get_content(review) for review in reviews]

# %%
df = pd.DataFrame(result)
df
# Out:
#                                                   text  rat           date
# 0    좋은 컨텐츠들이 많이 늘어 영어공부에 유용합니다. 다만 1. 영한 통합자막 지원 /...    5   2023년 10월 3일
# 1    몇주 전부터인가 갤럭시탭 s8로 앱 실행시 로딩화면만 지속되고 화면이 안넘어갑니다....    1  2023년 10월 21일
# 2    1. 어떤 종류의 프로그램이라도 기본적으로 스마트폰 세운 상태로도 시청할 수 있기를...    4   2023년 11월 7일
# 3    영상을 다운로드하면 와이파이,데이터없이도 볼수있는게 아니였나요?저장하고 와이파이,데...    3   2023년 10월 8일
# 4    단점 왜캐 안고쳐요? ㅡㅡ 1. 회차 검색 불가 (과거회차 볼려면 한세월 내리고 영...    1   2023년 10월 5일
# ..                                                 ...  ...            ...
# 435  우선 폰으로 볼땐 버벅거리는게 없어서 괜찮은데 태블릿으로 재생하면 계속 툭툭 끊기고...    1    2021년 7월 9일
# 436  시리즈로 나오는 만화들.. 예를 들어서 '위 베어 베어스'를 영어 버전으로 쭉 보고...    3  2022년 10월 14일
# 437  「폰에서 영상 재생할 때 꽉찬 화면은 어떻게 보나요? 상하좌우 여백이 너무 많아 보...    5    2022년 4월 9일
# 438  다양한 컨텐츠가 많아서 좋아요 다만 아쉬운 점이 있다면 영상재생하고 나서 화면이 고...    4   2022년 6월 11일
# 439  일단 컨텐츠부족한건 어쩔수없고..늘려가겠죠뭐 화면 무조건 가로전환모드만 강제에 팝업...    3    2021년 2월 6일
#
# [440 rows x 3 columns]

# %% [markdown]
# # 예제) 대한민국 지역 여행기사 수집

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import math, time

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=953,0')
options.add_experimental_option("detach", True)

# %%
search = input('검색어를 입력하세요.')
# Out:
# 검색어를 입력하세요.서울

# %%
URL = 'https://korean.visitkorea.or.kr/search/search_list.do?keyword='+search

driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(3)

# %%
# 리뷰 더보기 클릭
xpath = '//*[@id="s_recommend"]/div[2]/a'
driver.find_element(By.XPATH, xpath).click()
time.sleep(random.randint(2, 3))

# %%
# 여행기사 더보기 클릭
# driver.find_element(By.CSS_SELECTOR, ".more_view").click()
driver.find_element(By.CSS_SELECTOR, "#s_recommend > .more_view > a").click()

# %%
result = driver.find_elements(By.CSS_SELECTOR, '.tit a')
result[0].text
# Out:
# ''

# %%
a = driver.find_element(By.XPATH, '//*[@id="search_result"]/ul/li[1]/div[1]/div[1]/a')

# %%
a.text
# Out:
# '서울 근교 여행, 아이와 나들이 떠나는 인천 여행 코스'

# %%
tit_xpath = '//*[@id="search_result"]/ul/li[*]/div[1]/div[1]/a'
result = driver.find_elements(By.XPATH, tit_xpath)
len(result), result[0].text, result[1].text
# Out:
# (10, '서울 근교 여행, 아이와 나들이 떠나는 인천 여행 코스', '자연도 즐기고 역사도 되짚어보고, 서울식물원과 식민지역사박물관')

# %%
for i, title in enumerate(result, 1):
#     print(i, title.text) 줄바꿈 지워도 잘 돌아감
    print(i, title.text.replace('\n', ''))
# Out:
# 1 서울 근교 여행, 아이와 나들이 떠나는 인천 여행 코스
# 2 자연도 즐기고 역사도 되짚어보고, 서울식물원과 식민지역사박물관
# 3 소확행 찾아 카페행, 야외 정원이 있는 서울 카페 4
# 4 낯익은 길목에 담긴 근대사의 함성과 눈물, 서울 도심 투어
# 5 한가로운 여행, 책과 서울
# 6 다 같이 돌자 서울 한 바퀴~ 405번 버스 여행
# 7 높은 곳에서 보는 높은 가을 하늘♡ 서울 전망대 모음 4
# 8 대중교통으로 만나는 무장애 여행 '서울 600년'
# 9 숲과 강 그리고 야경까지, 서울 도심 속 휴식과 낭만 여행
# 10 할머니와 손주가 함께 떠나는 가을날의 서울

# %%
driver.find_element(By.XPATH, '/html/body/div[3]/div/div[1]/div[15]/a[2]').click()
time.sleep(random.randint(2, 3))

# %% [markdown]
# # 요구사항
# 1 : 수집 갯수를 입력받는다.
# 2 : 수집 갯수에 따라 페이지를 이동한다.
# 3 : 각 페이지별 데이터를 수집한다.(타이틀 텍스트)
# 4 : 출력

# %%
cnt = int(input('크롤링 할 건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt / 10) # 크롤링 할 전체 페이지 수 (올림)
print(page_cnt) #한 페이지에 10개의 콘텐츠가 나온다는 것을 알고 있음!
# Out:
# 크롤링 할 건수는 몇건입니까?: 15
# 2

# %%
tit_xpath = '//*[@id="search_result"]/ul/li[*]/div[1]/div[1]/a'
no = 0

for x in range(1, page_cnt+1):
    print(f'========= {x} 페이지 작업 =========')
    mylist = driver.find_elements(By.XPATH, tit_xpath)
    
    for item in mylist:
        no += 1
        if no > cnt:
            break
        print(no, item.text.replace('\n', ''))
    
    if no <= cnt:
        a = f'/html/body/div[3]/div/div[1]/div[15]/a[{x+1}]'
        driver.find_element(By.XPATH, a).click()
        time.sleep(2)

print('========= 작업 완료 =========')
driver.close()
# Out:
# ========= 1 페이지 작업 =========
# 1 서울 근교 여행, 아이와 나들이 떠나는 인천 여행 코스
# 2 자연도 즐기고 역사도 되짚어보고, 서울식물원과 식민지역사박물관
# 3 소확행 찾아 카페행, 야외 정원이 있는 서울 카페 4
# 4 낯익은 길목에 담긴 근대사의 함성과 눈물, 서울 도심 투어
# 5 한가로운 여행, 책과 서울
# 6 다 같이 돌자 서울 한 바퀴~ 405번 버스 여행
# 7 높은 곳에서 보는 높은 가을 하늘♡ 서울 전망대 모음 4
# 8 대중교통으로 만나는 무장애 여행 '서울 600년'
# 9 숲과 강 그리고 야경까지, 서울 도심 속 휴식과 낭만 여행
# 10 할머니와 손주가 함께 떠나는 가을날의 서울
# ========= 2 페이지 작업 =========
# 11 당신을 위로해 줄 한잔, 서울 수제맥줏집
# 12 그리고 그것들은 행복하게 다시 쓰였습니다, 세운상가와 서울새활용플라자
# 13 서울 수제버거 맛집 5선
# 14 한 곳에서 끝내자! 서울 복합문화공간 4
# 15 서울 지하철 타고 도심 속으로 일출 여행 간다
# ========= 작업 완료 =========
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[150], line 20
#      17         time.sleep(2)
#      19 print('========= 작업 완료 =========')
# ---> 20 driver.close()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:459, in WebDriver.close(self)
#     451 def close(self) -> None:
#     452     """Closes the current window.
#     453
#     454     :Usage:
#    (...)
#     457             driver.close()
#     458     """
# --> 459     self.execute(Command.CLOSE)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#     350     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=120.0.6099.71)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF662594D02+56194]
# 	(No symbol) [0x00007FF6625004B2]
# 	(No symbol) [0x00007FF6623A76AA]
# 	(No symbol) [0x00007FF66238E1E9]
# 	(No symbol) [0x00007FF66238F7CE]
# 	(No symbol) [0x00007FF6623A7CC3]
# 	(No symbol) [0x00007FF662380580]
# 	(No symbol) [0x00007FF6624235D7]
# 	(No symbol) [0x00007FF662423387]
# 	(No symbol) [0x00007FF662415E40]
# 	(No symbol) [0x00007FF6623E4A45]
# 	(No symbol) [0x00007FF6623E5AD4]
# 	GetHandleVerifier [0x00007FF66290D5BB+3695675]
# 	GetHandleVerifier [0x00007FF662966197+4059159]
# 	GetHandleVerifier [0x00007FF66295DF63+4025827]
# 	GetHandleVerifier [0x00007FF66262F029+687785]
# 	(No symbol) [0x00007FF66250B508]
# 	(No symbol) [0x00007FF662507564]
# 	(No symbol) [0x00007FF6625076E9]
# 	(No symbol) [0x00007FF6624F8094]
# 	BaseThreadInitThunk [0x00007FFC5F6D7344+20]
# 	RtlUserThreadStart [0x00007FFC5FEA26B1+33]

# %% [markdown]
# # 다시 재실습해보기

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import math, time

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=953,0')
options.add_experimental_option("detach", True)

# %%
search = input('검색어를 입력하세요.')
# Out:
# 검색어를 입력하세요.전주

# %%
URL = 'https://korean.visitkorea.or.kr/search/search_list.do?keyword='+search

driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(3)

# %%
# 여행기사 더보기 클릭
# driver.find_element(By.CSS_SELECTOR, ".more_view").click()
driver.find_element(By.CSS_SELECTOR, "#s_recommend > .more_view > a").click()

# %%
result = driver.find_element(By.CSS_SELECTOR, '.tit a')
result.text
# Out:
# ''

# %%
a = driver.find_element(By.XPATH, '//*[@id="search_result"]/ul/li[1]/div[1]/div[1]/a')
a.text
# Out:
# "[살아보기 여행-전주편] '반반(半半) 전주'"

# %%
# 여러개 추출 하기
tit_xpath = '//*[@id="search_result"]/ul/li[*]/div[1]/div[1]/a'
result = driver.find_elements(By.XPATH, tit_xpath)
len(result), result[0].text, result[1].text
# Out:
# (10, "[살아보기 여행-전주편] '반반(半半) 전주'", '전주 여행, 기차 타고 떠나기 좋은 가을 낭만 여행')

# %%
for i, title in enumerate(result, 1):
    print(i, title.text)
# Out:
# 1 [살아보기 여행-전주편] '반반(半半) 전주'
# 2 전주 여행, 기차 타고 떠나기 좋은 가을 낭만 여행
# 3 비빔밥 와플부터 콩나물 아이스크림까지!
# 요즘 뜨는 전주의 맛 6
# 4 [전주] 슬로시티 전주에서 바삐 달려왔던 일상에 쉼표를, 전주 정가한옥
# 5 가장 한국전인 멋의 고장, 전주한옥마을
# 6 풋풋한 청춘 서사 〈스물다섯 스물하나〉 속
# 전주 서학동예술마을과 한벽굴
# 7 전주여행, 색다르게 즐기는 전주 핫플레이스
# 8 [전주] 천천히, 오래 지켜가는 지속 가능한 전주, 사랑가득 한옥 펜션
# 9 [전주] 가만히 좋은 생각을 하게 되는 곳, 전주 '한옥혜윰'
# 10 한 번 와보시게~, 전주한옥마을

# %%
cnt = int(input('크롤링 할 건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt / 10) # 크롤링 할 전체 페이지 수 (올림)
print(page_cnt)
# Out:
# 크롤링 할 건수는 몇건입니까?: 91
# 10

# %%
tit.xpath = '//*[@id="search_result"]/ul/li[*]/div[1]/div[1]/a'
no = 0

for x in range(1, page_cnt+1):
    print(f'===={x}페이지 작업 ====')
    mylist = driver.find_elements(By.XPATH, tit_xpath)
    
    for item in mylist:
        no += 1

# %% [markdown]
# # 특정 게시글의 상세 정보 추출하기

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import math, time

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=953,0')
options.add_experimental_option("detach", True)

# %%
URL = "https://korean.visitkorea.or.kr/detail/rem_detail.html?cotid=be3db10c-b642-409c-81cc-c4cdecb5bd8b&temp="
driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(3)

# %%
title = driver.find_element(By.CSS_SELECTOR, "h2[id=topTitle]")
title.text
# Out:
# '향긋한 굴구이, 시원한 대구탕과 함께 하는 겨울 거제여행'

# %%
title = driver.find_element(By.XPATH, '//*[@id="topTitle"]')
title.text
# Out:
# '향긋한 굴구이, 시원한 대구탕과 함께 하는 겨울 거제여행'

# %%
title = driver.find_element(By.ID, 'topTitle').text
title
# Out:
# '향긋한 굴구이, 시원한 대구탕과 함께 하는 겨울 거제여행'

# %%
contents = driver.find_elements(By.CSS_SELECTOR, ".txt_p p")
len(contents)

for content in contents:
    print(content.text)
# Out:
# 찬바람이 불기 시작하는 이 즈음이면 전국의 포구는 미식가들로 붐비기 시작한다. 겨울이면 한껏 기름기가 오르는 생선이며 조개를 맛보려는 미식가들의 발걸음으로 유명식당 문턱이 닳는다. 도루묵이며 숭어 등등 겨울이면 맛이 드는 여러 해산물 중에서도 최고의 맛을 꼽으라면 단연 굴과 대구가 아닐까. 향긋한 굴구이와 시원하면서도 얼큰한 대구탕 한 그릇이면 코끝을 얼리는 차가운 겨울 바람이 오히려 고맙게 느껴진다.
# 거제는 굴구이와 대구요리 등 싱싱한 겨울 해산물을 맛볼 수 있는 대표적인 겨울별미 여행지다. 별미여행의 시작은 거제면 내간리에 자리한 굴구이집이다. 굴하면 이웃한 통영을 떠올리지만, 거제에서도 통영 못지 않게 굴이 많이 생산된다. 통영에서 신거제대교를 넘어 호곡, 녹산, 법동 등지를 지나 거제면 내간리까지 이어지는 1018번 지방도로를 따라가다 보면 해안가에 굴양식을 위한 지주들이 끝 간 데 없이 꽂혀 있는 것을 볼 수 있다. 바다 위에는 가지런히 떠있는 투하식 굴양식장의 부표들도 장관을 이루고 있다.
# 거제 사람들은 굴을 주로 구이로 먹는다. 예전에 굴을 캐던 사람들이 모닥불을 피우고 구워먹던 것이 세월이 흘러 자연스럽게 상품화가 됐다고 한다. 내간리 해안가에 굴구이를 내는 집이 모여있다. 굴구이를 주문하면 맛보기로 생굴이 나오고 곧 이어 굴튀김과 굴무침이 가득 담긴 접시도 놓여진다. 고추, 파와 함께 바삭하게 튀긴 굴튀김은 일식집에서 맛보던 그것과는 또 다른 맛을 낸다. 매콤한 맛이 이마와 콧등에 송글송글 땀을 맺히게 한다. 각종 야채와 함께 버무려진 굴무침도 매우면서도 새콤한 맛으로 젓가락질을 바쁘게 만든다.
# 굴무침과 굴튀김을 다 먹을 때면 커다란 철판 하나가 불 위에 올려진다.  뚜껑을 열어보면 껍질을 까지 않은 생굴이 가득 담겨있다. 가장자리에 검은 테두리가 선명한데, 이는 굴이 싱싱하다는 증거기도 하다. 거제 굴구이는 구우면서 동시에 찌는 방식. 다 익기까지는 5분 정도가 걸리는데, 장갑을 끼고 칼로 껍질을 까서 먹는다.
# 굴껍질을 까보면 육즙이 가득 고여 있다. 칼로 굴을 살짝 들어내면 탱글탱글한 굴이 보기에도 먹음직스럽다. 특유의 진한 굴향도 후각을 강하게 자극한다. 초장에 살짝 찍어 입으로 가져가면 짭조롬한 맛이 입안을 가득 채운다. 굴 자체에 간이 되어 있어 양념을 찍지 않고 그냥 먹어도 맛있다. 거제의 굴구이 집 대부분은 굴구이, 굴죽, 굴국밥 등 다양한 굴요리를 파는데, 굴구이 세트를 시키면 굴구이와 굴튀김을 비롯한 다양한 굴요리를 코스로 먹을 수 있다.
# 거제의 또다른 겨울 별미는 대구다. ‘눈 본 대구, 비 본 청어’라는 속담도 있듯, 찬바람이 부는 겨울은 대구에 맛이 제대로 드는 때다. 12월부터 이듬해 2월까지는 대구 산란기인데, 이때 잡히는 알 잔뜩 머금은 대구는 천하일미라고 해도 과언이 아니다. 외포항이 자리한 진해만에는 겨울이면 전국 최대규모의 대구 어장이 형성된다. 1980년대 한때 진해만을 가득 메웠던 대구가 사라지면서 ‘금대구’라고 불리던 시절도 있었다. 어쩌다 한두 마리가 잡히면 수십만원에 팔렸다는 기사가 신문에 소개될 정도로 귀한 생선이었다. 그러다 90년대 중반 거제수협이 대구알 방류 사업에 성공하면서 2000년대 중반부터 외포항으로 대구가 돌아오기 시작했다.
# 이른 아침부터 외포항에 자리한 거제수협 외포출장소 어판장은 대구 경매에 참여한 중매인들로 북적거린다. 어판장 바닥에 늘어선 갓 잡은 대구를 꼼꼼하게 살피던 중매인들은 경매가 시작되면 경매사에게 손가락 신호를 열심히 보낸다. 이렇게 30분이 지나면 나무상자에 담겨 있던 대구는 모두 팔려나간다. 대구잡이에는 호망을 쓴다. 호망은 대구를 유인하기 위해 길그물을 길게 놓고 그 끝에 둥그런 통그물을 붙인 것이다. 통그물의 모양이 단지(壺)처럼 생겨 호망이라 부른다. 야행성인 대구는 밤에 쏘다니다 호망에 걸리는데, 그물코에 꿰는 것이 아니니 산 채로 올라오는 대구도 많다. 외포항에는 대구요리를 내는 식당 10여곳이 늘어서 있다. 대구탕 거리로도 불린다. 대구는 회나 찜도 좋지만, 이맘땐 탕만 한 게 없다. 뽀얀 국물이 언 듯 보기에는 꼭 곰탕같다. 국물은 구수하면서도 진하다. 소금만으로 간을 해 깊고 그윽한 맛을 낸다.
# 외지인들은 생대구가 좋다고 하지만, 어민들은 살짝 말린 대구를 더 선호한다. 내장과 아가미, 알과 이리 등을 제거하고 해풍에 3~5일 말린 대구는 수분이 쏙 빠져 더욱 차진 맛을 낸다. 말린 것으로 탕을 끓이면 더 뽀얗고 구수한 맛의 국물을 얻을 수 있다는 것이 상인들의 귀띔이다. 외포항 곳곳에서는 대구를 말려 건대구로 만드는 작업을 쉽게 볼 수 있는데, 부둣가 햇볕이 드는 곳에는 어김없이 내장을 빼고 나무꼬치로 꿴 대구가 널려 있다.
# 말린 대구를 콩나물, 채소 등과 함께 쪄 먹는 대구찜도 맛있다. 생대구에서는 맛볼 수 없었던 쫀득한 맛과 말린 생선 특유의 감칠맛을 함께 느낄 수 있다. 코다리찜과 비슷하다고 보면 된다. 대구는 지방 함유량이 적고 열량도 높지 않아 다이어트에 그만이며 각종 비타민이 많이 들어 있어 원기 회복에도 도움이 된다고 한다.
# 굴과 대구로 배가 든든해졌다면 거제도의 아름다운 풍경 속으로 들어가보자. 거제는 우리나라에서 제주도 다음으로 큰 섬이다. 350km가 넘는 해안선을 따라 바다와 기암괴석이 어우러진 비경이 펼쳐진다. 거제에서 가장 아름다운 풍광을 꼽으라면 아마도 신선대와 ‘바람의 언덕’일 것이다. 해금강 가는 갈곶리 도로 오른편에 신선대가, 왼편에 바람의 언덕이 각각 자리한다. 신선대는 신선이 내려와 풍류를 즐겼다고 할 정도로 해안 경관이 절경이다. 파도가 쉴 새 없이 밀려와 기암괴석에 부딪혀 하얗게 부서지는 모습이 감탄을 자아낸다.
# 바람의 언덕은 갈곶리 도장포마을 북쪽 해안에 있는 언덕으로 사시사철 바닷바람이 분다고 해서 이렇게 이름붙었다. 바다와 풍차가 어우러진 이국적인 경치가 매력적이다.
# 신선대 입구에 자리한 해금강테마박물관은 가족들과 함께 돌아보기 좋은 곳이다. 1950~1980년대까지의 생활상을 볼 수 있는 곳으로 다이얼식공중전화, 대폿집 풍경을 재현한 전시장, 난로 위에 놓인 알루미늄 도시락 등 ‘그때 그 시절’을 구경하다 보면 시간가는 줄 모른다.
# 학동에 있는 학동흑진주몽돌해변도 놓치기 아까운 풍경이다. 흑진주처럼 반들반들 윤이 나는 검은 몽돌이 덮인 몽돌밭 해변이 1.2km에 걸쳐 펼쳐져 있다. 바닷물이 밀려들고 나갈 때마다 몽돌밭에서는 ‘자글자글’하는 소리가 나는데, 우리나라 자연 소리 100선에 선정될 만큼 아름답고 감미롭다.
# 구불구불 이어지는 해안선을 따라 즐기는 바다 드라이브도 거제 여행의 낭만을 더해준다. 특히 여차~홍포간 해안도로는 한국에서 가장 아름다운 바닷길이라고 해도 손색이 없을 정도. 푸른 바다와 정다운 포구마을, 깍아지른 해안절벽이 어우러진 풍경은 자꾸만 차를 세우게 만든다. 거가대교도 빼놓을 수 없는 명소다. 장목면과 부산 가덕도를 연결한 4.5km의 사장교로 일출과 일몰을 감상하기에도 좋다.
# <당일 여행 코스>
# 내간리 굴구이→해금강테마박물관→신선대→바람의 언덕→외포항
#
# <1박 2일 여행 코스>
# 첫째 날 / 거제도 포로수용소 유적공원→내간리 굴구이→학동흑진주몽돌해변→학동 숙박
# 둘째 날 / 해금강테마박물관→신선대→바람의 언덕→외포항
#
# 관련 웹사이트 주소
# -거제문화관광 http://tour.geoje.go.kr
# -해금강테마박물관 www.hggmuseum.com
#
# 문의 전화
# -거제시청 관광과 055-639-4173
# -해금강테마박물관 055-632-0670
#
# 대중교통 정보
# -[버스] 서울-거제(고현) : 서울남부터미널에서 하루 28회(06:40~24:00) 운행, 약 4시간 20분 소요. 문의 : 서울남부터미널 1688-0540, 전국시외버스통합예약안내서비스 www.busterminal.or.kr , 고현시외버스터미널 1688-5003
#
# 자가운전 정보
# -대전통영고속도로→통영 IC→남해안대로 거제 방향→신거제대교→거제대로→1018번 지방도→내간리
# 숙박 정보
# -라이트하우스호텔 : 거제시 장승포로, 055)681-6362, www.geojelighthouse.com
# -베니키아호텔거제 : 거제시 성산로, 055)991-1000, www.benikeahotel.kr
# -머그학동 : 거제시 동부면 학동3길, 010)5036-3889, http://mughakdong.com
# -애드미럴호텔 : 거제시 서간도길, 055)687-3761, www.admiralhotel.co.kr
#
# 식당 정보
# -원조거제굴구이 : 굴구이, 거제면 거제남서로, 055)632-4200
# -외포효진횟집 : 대구탕, 장목면 외포2길, 055)635-6340
# -양지바위횟집 : 대구탕, 장목면 외포5길, 055)635-4327
# -항만식당 : 해물뚝배기, 거제시 장승포로7길, 055)682-4369
# 축제와 행사 정보
# -2015 거제대구수산물축제 : 12월 19~20일, 055)639-4274, 외포항 일대
# 주변볼거리
# -지심도, 해금강, 외도보타니아, 칠천량해전공원
# 글, 사진 : 최갑수(여행작가)
#
# ※ 위 정보는 2019년 3월에 갱신된 정보로, 이후 변경될 수 있으니 여행 하시기 전에 반드시 확인하시기 바랍니다.
# ※ 이 기사에 사용된 텍스트, 사진, 동영상 등의 정보는 한국관광공사가 저작권을 보유하고 있으므로 기사의 무단 사용을 금합니다.
# <class 'str'>

# %%
contents = driver.find_elements(By.CLASS_NAME, 'txt_p')
print(contents[0].text) #0번째의 객체를 뽑아서 텍스트를 추출
print(contents) #객체들이 뽑힘
# Out:
# 찬바람이 불기 시작하는 이 즈음이면 전국의 포구는 미식가들로 붐비기 시작한다. 겨울이면 한껏 기름기가 오르는 생선이며 조개를 맛보려는 미식가들의 발걸음으로 유명식당 문턱이 닳는다. 도루묵이며 숭어 등등 겨울이면 맛이 드는 여러 해산물 중에서도 최고의 맛을 꼽으라면 단연 굴과 대구가 아닐까. 향긋한 굴구이와 시원하면서도 얼큰한 대구탕 한 그릇이면 코끝을 얼리는 차가운 겨울 바람이 오히려 고맙게 느껴진다.
# [<selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1547")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1554")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1561")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1568")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1575")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1582")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1589")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1596")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1603")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1610")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1617")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1624")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1631")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1638")>, <selenium.webdriver.remote.webelement.WebElement (session="f41ec345ac4e4e21b946731ce705c42f", element="E037355417F2776F13A57B37E68745A4_element_1646")>]

# %%
contents = driver.find_elements(By.CLASS_NAME, 'txt_p')

contents_list = []
for item in contents:
    contents_list.append(item.text)
contents_list
# Out:
# ['찬바람이 불기 시작하는 이 즈음이면 전국의 포구는 미식가들로 붐비기 시작한다. 겨울이면 한껏 기름기가 오르는 생선이며 조개를 맛보려는 미식가들의 발걸음으로 유명식당 문턱이 닳는다. 도루묵이며 숭어 등등 겨울이면 맛이 드는 여러 해산물 중에서도 최고의 맛을 꼽으라면 단연 굴과 대구가 아닐까. 향긋한 굴구이와 시원하면서도 얼큰한 대구탕 한 그릇이면 코끝을 얼리는 차가운 겨울 바람이 오히려 고맙게 느껴진다.',
#  '거제는 굴구이와 대구요리 등 싱싱한 겨울 해산물을 맛볼 수 있는 대표적인 겨울별미 여행지다. 별미여행의 시작은 거제면 내간리에 자리한 굴구이집이다. 굴하면 이웃한 통영을 떠올리지만, 거제에서도 통영 못지 않게 굴이 많이 생산된다. 통영에서 신거제대교를 넘어 호곡, 녹산, 법동 등지를 지나 거제면 내간리까지 이어지는 1018번 지방도로를 따라가다 보면 해안가에 굴양식을 위한 지주들이 끝 간 데 없이 꽂혀 있는 것을 볼 수 있다. 바다 위에는 가지런히 떠있는 투하식 굴양식장의 부표들도 장관을 이루고 있다.',
#  '거제 사람들은 굴을 주로 구이로 먹는다. 예전에 굴을 캐던 사람들이 모닥불을 피우고 구워먹던 것이 세월이 흘러 자연스럽게 상품화가 됐다고 한다. 내간리 해안가에 굴구이를 내는 집이 모여있다. 굴구이를 주문하면 맛보기로 생굴이 나오고 곧 이어 굴튀김과 굴무침이 가득 담긴 접시도 놓여진다. 고추, 파와 함께 바삭하게 튀긴 굴튀김은 일식집에서 맛보던 그것과는 또 다른 맛을 낸다. 매콤한 맛이 이마와 콧등에 송글송글 땀을 맺히게 한다. 각종 야채와 함께 버무려진 굴무침도 매우면서도 새콤한 맛으로 젓가락질을 바쁘게 만든다.',
#  '굴무침과 굴튀김을 다 먹을 때면 커다란 철판 하나가 불 위에 올려진다.  뚜껑을 열어보면 껍질을 까지 않은 생굴이 가득 담겨있다. 가장자리에 검은 테두리가 선명한데, 이는 굴이 싱싱하다는 증거기도 하다. 거제 굴구이는 구우면서 동시에 찌는 방식. 다 익기까지는 5분 정도가 걸리는데, 장갑을 끼고 칼로 껍질을 까서 먹는다.',
#  '굴껍질을 까보면 육즙이 가득 고여 있다. 칼로 굴을 살짝 들어내면 탱글탱글한 굴이 보기에도 먹음직스럽다. 특유의 진한 굴향도 후각을 강하게 자극한다. 초장에 살짝 찍어 입으로 가져가면 짭조롬한 맛이 입안을 가득 채운다. 굴 자체에 간이 되어 있어 양념을 찍지 않고 그냥 먹어도 맛있다. 거제의 굴구이 집 대부분은 굴구이, 굴죽, 굴국밥 등 다양한 굴요리를 파는데, 굴구이 세트를 시키면 굴구이와 굴튀김을 비롯한 다양한 굴요리를 코스로 먹을 수 있다.',
#  '거제의 또다른 겨울 별미는 대구다. ‘눈 본 대구, 비 본 청어’라는 속담도 있듯, 찬바람이 부는 겨울은 대구에 맛이 제대로 드는 때다. 12월부터 이듬해 2월까지는 대구 산란기인데, 이때 잡히는 알 잔뜩 머금은 대구는 천하일미라고 해도 과언이 아니다. 외포항이 자리한 진해만에는 겨울이면 전국 최대규모의 대구 어장이 형성된다. 1980년대 한때 진해만을 가득 메웠던 대구가 사라지면서 ‘금대구’라고 불리던 시절도 있었다. 어쩌다 한두 마리가 잡히면 수십만원에 팔렸다는 기사가 신문에 소개될 정도로 귀한 생선이었다. 그러다 90년대 중반 거제수협이 대구알 방류 사업에 성공하면서 2000년대 중반부터 외포항으로 대구가 돌아오기 시작했다.',
#  '이른 아침부터 외포항에 자리한 거제수협 외포출장소 어판장은 대구 경매에 참여한 중매인들로 북적거린다. 어판장 바닥에 늘어선 갓 잡은 대구를 꼼꼼하게 살피던 중매인들은 경매가 시작되면 경매사에게 손가락 신호를 열심히 보낸다. 이렇게 30분이 지나면 나무상자에 담겨 있던 대구는 모두 팔려나간다. 대구잡이에는 호망을 쓴다. 호망은 대구를 유인하기 위해 길그물을 길게 놓고 그 끝에 둥그런 통그물을 붙인 것이다. 통그물의 모양이 단지(壺)처럼 생겨 호망이라 부른다. 야행성인 대구는 밤에 쏘다니다 호망에 걸리는데, 그물코에 꿰는 것이 아니니 산 채로 올라오는 대구도 많다. 외포항에는 대구요리를 내는 식당 10여곳이 늘어서 있다. 대구탕 거리로도 불린다. 대구는 회나 찜도 좋지만, 이맘땐 탕만 한 게 없다. 뽀얀 국물이 언 듯 보기에는 꼭 곰탕같다. 국물은 구수하면서도 진하다. 소금만으로 간을 해 깊고 그윽한 맛을 낸다.',
#  '외지인들은 생대구가 좋다고 하지만, 어민들은 살짝 말린 대구를 더 선호한다. 내장과 아가미, 알과 이리 등을 제거하고 해풍에 3~5일 말린 대구는 수분이 쏙 빠져 더욱 차진 맛을 낸다. 말린 것으로 탕을 끓이면 더 뽀얗고 구수한 맛의 국물을 얻을 수 있다는 것이 상인들의 귀띔이다. 외포항 곳곳에서는 대구를 말려 건대구로 만드는 작업을 쉽게 볼 수 있는데, 부둣가 햇볕이 드는 곳에는 어김없이 내장을 빼고 나무꼬치로 꿴 대구가 널려 있다.',
#  '말린 대구를 콩나물, 채소 등과 함께 쪄 먹는 대구찜도 맛있다. 생대구에서는 맛볼 수 없었던 쫀득한 맛과 말린 생선 특유의 감칠맛을 함께 느낄 수 있다. 코다리찜과 비슷하다고 보면 된다. 대구는 지방 함유량이 적고 열량도 높지 않아 다이어트에 그만이며 각종 비타민이 많이 들어 있어 원기 회복에도 도움이 된다고 한다.',
#  '굴과 대구로 배가 든든해졌다면 거제도의 아름다운 풍경 속으로 들어가보자. 거제는 우리나라에서 제주도 다음으로 큰 섬이다. 350km가 넘는 해안선을 따라 바다와 기암괴석이 어우러진 비경이 펼쳐진다. 거제에서 가장 아름다운 풍광을 꼽으라면 아마도 신선대와 ‘바람의 언덕’일 것이다. 해금강 가는 갈곶리 도로 오른편에 신선대가, 왼편에 바람의 언덕이 각각 자리한다. 신선대는 신선이 내려와 풍류를 즐겼다고 할 정도로 해안 경관이 절경이다. 파도가 쉴 새 없이 밀려와 기암괴석에 부딪혀 하얗게 부서지는 모습이 감탄을 자아낸다.',
#  '바람의 언덕은 갈곶리 도장포마을 북쪽 해안에 있는 언덕으로 사시사철 바닷바람이 분다고 해서 이렇게 이름붙었다. 바다와 풍차가 어우러진 이국적인 경치가 매력적이다.',
#  '신선대 입구에 자리한 해금강테마박물관은 가족들과 함께 돌아보기 좋은 곳이다. 1950~1980년대까지의 생활상을 볼 수 있는 곳으로 다이얼식공중전화, 대폿집 풍경을 재현한 전시장, 난로 위에 놓인 알루미늄 도시락 등 ‘그때 그 시절’을 구경하다 보면 시간가는 줄 모른다.',
#  '학동에 있는 학동흑진주몽돌해변도 놓치기 아까운 풍경이다. 흑진주처럼 반들반들 윤이 나는 검은 몽돌이 덮인 몽돌밭 해변이 1.2km에 걸쳐 펼쳐져 있다. 바닷물이 밀려들고 나갈 때마다 몽돌밭에서는 ‘자글자글’하는 소리가 나는데, 우리나라 자연 소리 100선에 선정될 만큼 아름답고 감미롭다.',
#  '구불구불 이어지는 해안선을 따라 즐기는 바다 드라이브도 거제 여행의 낭만을 더해준다. 특히 여차~홍포간 해안도로는 한국에서 가장 아름다운 바닷길이라고 해도 손색이 없을 정도. 푸른 바다와 정다운 포구마을, 깍아지른 해안절벽이 어우러진 풍경은 자꾸만 차를 세우게 만든다. 거가대교도 빼놓을 수 없는 명소다. 장목면과 부산 가덕도를 연결한 4.5km의 사장교로 일출과 일몰을 감상하기에도 좋다.',
#  '<당일 여행 코스>\n내간리 굴구이→해금강테마박물관→신선대→바람의 언덕→외포항\n  <1박 2일 여행 코스>\n첫째 날 / 거제도 포로수용소 유적공원→내간리 굴구이→학동흑진주몽돌해변→학동 숙박\n둘째 날 / 해금강테마박물관→신선대→바람의 언덕→외포항\n  관련 웹사이트 주소\n-거제문화관광 http://tour.geoje.go.kr\n-해금강테마박물관 www.hggmuseum.com\n  문의 전화\n-거제시청 관광과 055-639-4173\n-해금강테마박물관 055-632-0670\n  대중교통 정보\n-[버스] 서울-거제(고현) : 서울남부터미널에서 하루 28회(06:40~24:00) 운행, 약 4시간 20분 소요. 문의 : 서울남부터미널 1688-0540, 전국시외버스통합예약안내서비스 www.busterminal.or.kr , 고현시외버스터미널 1688-5003\n  자가운전 정보\n-대전통영고속도로→통영 IC→남해안대로 거제 방향→신거제대교→거제대로→1018번 지방도→내간리\n\n숙박 정보\n-라이트하우스호텔 : 거제시 장승포로, 055)681-6362, www.geojelighthouse.com  \n-베니키아호텔거제 : 거제시 성산로, 055)991-1000, www.benikeahotel.kr  \n-머그학동 : 거제시 동부면 학동3길, 010)5036-3889, http://mughakdong.com\n-애드미럴호텔 : 거제시 서간도길, 055)687-3761, www.admiralhotel.co.kr\n  식당 정보\n-원조거제굴구이 : 굴구이, 거제면 거제남서로, 055)632-4200\n-외포효진횟집 : 대구탕, 장목면 외포2길, 055)635-6340\n-양지바위횟집 : 대구탕, 장목면 외포5길, 055)635-4327\n-항만식당 : 해물뚝배기, 거제시 장승포로7길, 055)682-4369\n\n축제와 행사 정보\n-2015 거제대구수산물축제 : 12월 19~20일, 055)639-4274, 외포항 일대\n주변볼거리\n-지심도, 해금강, 외도보타니아, 칠천량해전공원\n\n글, 사진 : 최갑수(여행작가)\n  ※ 위 정보는 2019년 3월에 갱신된 정보로, 이후 변경될 수 있으니 여행 하시기 전에 반드시 확인하시기 바랍니다.\n※ 이 기사에 사용된 텍스트, 사진, 동영상 등의 정보는 한국관광공사가 저작권을 보유하고 있으므로 기사의 무단 사용을 금합니다.']

# %%
#하나의 문자열로 통합
contents_merge = ' '.join(contents_list)
contents_merge
# Out:
# '찬바람이 불기 시작하는 이 즈음이면 전국의 포구는 미식가들로 붐비기 시작한다. 겨울이면 한껏 기름기가 오르는 생선이며 조개를 맛보려는 미식가들의 발걸음으로 유명식당 문턱이 닳는다. 도루묵이며 숭어 등등 겨울이면 맛이 드는 여러 해산물 중에서도 최고의 맛을 꼽으라면 단연 굴과 대구가 아닐까. 향긋한 굴구이와 시원하면서도 얼큰한 대구탕 한 그릇이면 코끝을 얼리는 차가운 겨울 바람이 오히려 고맙게 느껴진다. 거제는 굴구이와 대구요리 등 싱싱한 겨울 해산물을 맛볼 수 있는 대표적인 겨울별미 여행지다. 별미여행의 시작은 거제면 내간리에 자리한 굴구이집이다. 굴하면 이웃한 통영을 떠올리지만, 거제에서도 통영 못지 않게 굴이 많이 생산된다. 통영에서 신거제대교를 넘어 호곡, 녹산, 법동 등지를 지나 거제면 내간리까지 이어지는 1018번 지방도로를 따라가다 보면 해안가에 굴양식을 위한 지주들이 끝 간 데 없이 꽂혀 있는 것을 볼 수 있다. 바다 위에는 가지런히 떠있는 투하식 굴양식장의 부표들도 장관을 이루고 있다. 거제 사람들은 굴을 주로 구이로 먹는다. 예전에 굴을 캐던 사람들이 모닥불을 피우고 구워먹던 것이 세월이 흘러 자연스럽게 상품화가 됐다고 한다. 내간리 해안가에 굴구이를 내는 집이 모여있다. 굴구이를 주문하면 맛보기로 생굴이 나오고 곧 이어 굴튀김과 굴무침이 가득 담긴 접시도 놓여진다. 고추, 파와 함께 바삭하게 튀긴 굴튀김은 일식집에서 맛보던 그것과는 또 다른 맛을 낸다. 매콤한 맛이 이마와 콧등에 송글송글 땀을 맺히게 한다. 각종 야채와 함께 버무려진 굴무침도 매우면서도 새콤한 맛으로 젓가락질을 바쁘게 만든다. 굴무침과 굴튀김을 다 먹을 때면 커다란 철판 하나가 불 위에 올려진다.  뚜껑을 열어보면 껍질을 까지 않은 생굴이 가득 담겨있다. 가장자리에 검은 테두리가 선명한데, 이는 굴이 싱싱하다는 증거기도 하다. 거제 굴구이는 구우면서 동시에 찌는 방식. 다 익기까지는 5분 정도가 걸리는데, 장갑을 끼고 칼로 껍질을 까서 먹는다. 굴껍질을 까보면 육즙이 가득 고여 있다. 칼로 굴을 살짝 들어내면 탱글탱글한 굴이 보기에도 먹음직스럽다. 특유의 진한 굴향도 후각을 강하게 자극한다. 초장에 살짝 찍어 입으로 가져가면 짭조롬한 맛이 입안을 가득 채운다. 굴 자체에 간이 되어 있어 양념을 찍지 않고 그냥 먹어도 맛있다. 거제의 굴구이 집 대부분은 굴구이, 굴죽, 굴국밥 등 다양한 굴요리를 파는데, 굴구이 세트를 시키면 굴구이와 굴튀김을 비롯한 다양한 굴요리를 코스로 먹을 수 있다. 거제의 또다른 겨울 별미는 대구다. ‘눈 본 대구, 비 본 청어’라는 속담도 있듯, 찬바람이 부는 겨울은 대구에 맛이 제대로 드는 때다. 12월부터 이듬해 2월까지는 대구 산란기인데, 이때 잡히는 알 잔뜩 머금은 대구는 천하일미라고 해도 과언이 아니다. 외포항이 자리한 진해만에는 겨울이면 전국 최대규모의 대구 어장이 형성된다. 1980년대 한때 진해만을 가득 메웠던 대구가 사라지면서 ‘금대구’라고 불리던 시절도 있었다. 어쩌다 한두 마리가 잡히면 수십만원에 팔렸다는 기사가 신문에 소개될 정도로 귀한 생선이었다. 그러다 90년대 중반 거제수협이 대구알 방류 사업에 성공하면서 2000년대 중반부터 외포항으로 대구가 돌아오기 시작했다. 이른 아침부터 외포항에 자리한 거제수협 외포출장소 어판장은 대구 경매에 참여한 중매인들로 북적거린다. 어판장 바닥에 늘어선 갓 잡은 대구를 꼼꼼하게 살피던 중매인들은 경매가 시작되면 경매사에게 손가락 신호를 열심히 보낸다. 이렇게 30분이 지나면 나무상자에 담겨 있던 대구는 모두 팔려나간다. 대구잡이에는 호망을 쓴다. 호망은 대구를 유인하기 위해 길그물을 길게 놓고 그 끝에 둥그런 통그물을 붙인 것이다. 통그물의 모양이 단지(壺)처럼 생겨 호망이라 부른다. 야행성인 대구는 밤에 쏘다니다 호망에 걸리는데, 그물코에 꿰는 것이 아니니 산 채로 올라오는 대구도 많다. 외포항에는 대구요리를 내는 식당 10여곳이 늘어서 있다. 대구탕 거리로도 불린다. 대구는 회나 찜도 좋지만, 이맘땐 탕만 한 게 없다. 뽀얀 국물이 언 듯 보기에는 꼭 곰탕같다. 국물은 구수하면서도 진하다. 소금만으로 간을 해 깊고 그윽한 맛을 낸다. 외지인들은 생대구가 좋다고 하지만, 어민들은 살짝 말린 대구를 더 선호한다. 내장과 아가미, 알과 이리 등을 제거하고 해풍에 3~5일 말린 대구는 수분이 쏙 빠져 더욱 차진 맛을 낸다. 말린 것으로 탕을 끓이면 더 뽀얗고 구수한 맛의 국물을 얻을 수 있다는 것이 상인들의 귀띔이다. 외포항 곳곳에서는 대구를 말려 건대구로 만드는 작업을 쉽게 볼 수 있는데, 부둣가 햇볕이 드는 곳에는 어김없이 내장을 빼고 나무꼬치로 꿴 대구가 널려 있다. 말린 대구를 콩나물, 채소 등과 함께 쪄 먹는 대구찜도 맛있다. 생대구에서는 맛볼 수 없었던 쫀득한 맛과 말린 생선 특유의 감칠맛을 함께 느낄 수 있다. 코다리찜과 비슷하다고 보면 된다. 대구는 지방 함유량이 적고 열량도 높지 않아 다이어트에 그만이며 각종 비타민이 많이 들어 있어 원기 회복에도 도움이 된다고 한다. 굴과 대구로 배가 든든해졌다면 거제도의 아름다운 풍경 속으로 들어가보자. 거제는 우리나라에서 제주도 다음으로 큰 섬이다. 350km가 넘는 해안선을 따라 바다와 기암괴석이 어우러진 비경이 펼쳐진다. 거제에서 가장 아름다운 풍광을 꼽으라면 아마도 신선대와 ‘바람의 언덕’일 것이다. 해금강 가는 갈곶리 도로 오른편에 신선대가, 왼편에 바람의 언덕이 각각 자리한다. 신선대는 신선이 내려와 풍류를 즐겼다고 할 정도로 해안 경관이 절경이다. 파도가 쉴 새 없이 밀려와 기암괴석에 부딪혀 하얗게 부서지는 모습이 감탄을 자아낸다. 바람의 언덕은 갈곶리 도장포마을 북쪽 해안에 있는 언덕으로 사시사철 바닷바람이 분다고 해서 이렇게 이름붙었다. 바다와 풍차가 어우러진 이국적인 경치가 매력적이다. 신선대 입구에 자리한 해금강테마박물관은 가족들과 함께 돌아보기 좋은 곳이다. 1950~1980년대까지의 생활상을 볼 수 있는 곳으로 다이얼식공중전화, 대폿집 풍경을 재현한 전시장, 난로 위에 놓인 알루미늄 도시락 등 ‘그때 그 시절’을 구경하다 보면 시간가는 줄 모른다. 학동에 있는 학동흑진주몽돌해변도 놓치기 아까운 풍경이다. 흑진주처럼 반들반들 윤이 나는 검은 몽돌이 덮인 몽돌밭 해변이 1.2km에 걸쳐 펼쳐져 있다. 바닷물이 밀려들고 나갈 때마다 몽돌밭에서는 ‘자글자글’하는 소리가 나는데, 우리나라 자연 소리 100선에 선정될 만큼 아름답고 감미롭다. 구불구불 이어지는 해안선을 따라 즐기는 바다 드라이브도 거제 여행의 낭만을 더해준다. 특히 여차~홍포간 해안도로는 한국에서 가장 아름다운 바닷길이라고 해도 손색이 없을 정도. 푸른 바다와 정다운 포구마을, 깍아지른 해안절벽이 어우러진 풍경은 자꾸만 차를 세우게 만든다. 거가대교도 빼놓을 수 없는 명소다. 장목면과 부산 가덕도를 연결한 4.5km의 사장교로 일출과 일몰을 감상하기에도 좋다. <당일 여행 코스>\n내간리 굴구이→해금강테마박물관→신선대→바람의 언덕→외포항\n  <1박 2일 여행 코스>\n첫째 날 / 거제도 포로수용소 유적공원→내간리 굴구이→학동흑진주몽돌해변→학동 숙박\n둘째 날 / 해금강테마박물관→신선대→바람의 언덕→외포항\n  관련 웹사이트 주소\n-거제문화관광 http://tour.geoje.go.kr\n-해금강테마박물관 www.hggmuseum.com\n  문의 전화\n-거제시청 관광과 055-639-4173\n-해금강테마박물관 055-632-0670\n  대중교통 정보\n-[버스] 서울-거제(고현) : 서울남부터미널에서 하루 28회(06:40~24:00) 운행, 약 4시간 20분 소요. 문의 : 서울남부터미널 1688-0540, 전국시외버스통합예약안내서비스 www.busterminal.or.kr , 고현시외버스터미널 1688-5003\n  자가운전 정보\n-대전통영고속도로→통영 IC→남해안대로 거제 방향→신거제대교→거제대로→1018번 지방도→내간리\n\n숙박 정보\n-라이트하우스호텔 : 거제시 장승포로, 055)681-6362, www.geojelighthouse.com  \n-베니키아호텔거제 : 거제시 성산로, 055)991-1000,  ...

# %% [markdown]
# ## 이미지 추출하여 저장하기

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time, urllib.request

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=953,0')
options.add_experimental_option("detach", True)

# %%
URL = "https://korean.visitkorea.or.kr/detail/rem_detail.html?cotid=be3db10c-b642-409c-81cc-c4cdecb5bd8b&temp="
driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(3)

# %%
import os
os.getcwd()
# Out:
# 'C:\\workspace\\python\\WASSUP'

# %%
f_dir = input("이미지 저장 폴더명 : ")

now = time.localtime()
s = '%04d%02d%02d_%02d%02d%02d'%(now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)
f_dir = f_dir+'_'+s
os.makedirs(os.getcwd()+'\\'+f_dir)
# Out:
# 이미지 저장 폴더명 : 이미지추출

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")

# %%
html_src = driver.page_source

# %%
html_dom = BeautifulSoup(html_src, 'lxml')
html_dom
# Out:
# <html lang="ko"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <title>향긋한 굴구이, 시원한 대구탕과 함께 하는 겨울 거제여행&gt; 여행기사 | 추천! 가볼만한곳:대한민국 구석구석 </title>
# <meta content=" 찬바람이 불기 시작하는 이 즈음이면 전국의 포구는 미식가들로 붐비기 시작한다. 겨울이면 한껏 기름기가 오르는 생선이며 조개를 맛보려는 미식가들의 발걸음으로 유명식당 문턱이 닳는다. 도루묵이며 숭어 등등 겨울이면 맛이 드는 여러 해산물 중에서도 최고의 맛을 꼽으라면 단연 굴과 대구가 아닐까. 향긋한 굴구이와 시원하면서도 얼큰한 대구탕 한 그릇이면 코끝을 얼 12월추천가볼만한곳|2015년12월추천가볼만한곳|가족|거제|거제1박2일코스|거제가볼만한곳|거제당일코스|겨울|겨울먹거리|겨울제철음식|경상남도|굴|굴구이|굴무침|굴양식장|대구|대구탕|대구회무침|드라이브|몽돌해변|미식여행|바다|바람의언덕|신선대|여행|연인|외포항|추천가볼만한곳|친구|해금강테마박물관|힐링" name="description"/>
# <meta content="12월추천가볼만한곳|2015년12월추천가볼만한곳|가족|거제|거제1박2일코스|거제가볼만한곳|거제당일코스|겨울|겨울먹거리|겨울제철음식" name="keywords"/>
# <meta content="website" property="og:type"/>
# <meta content="향긋한 굴구이, 시원한 대구탕과 함께 하는 겨울 거제여행&gt; 여행기사 | 추천! 가볼만한곳:대한민국 구석구석" id="ogtitle" property="og:title"/>
# <meta content="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=c531fd60-c5bf-4028-b8f2-dbeddad9e1ec" id="ogimage" property="og:image"/>
# <meta content=" 찬바람이 불기 시작하는 이 즈음이면 전국의 포구는 미식가들로 붐비기 시작한다. 겨울이면 한껏 기름기가 오르는 생선이며 조개를 맛보려는 미식가들의 발걸음으로 유명식당 문턱이 닳는다. 도루묵이며 숭어 등등 겨울이면 맛이 드는 여러 해산물 중에서도 최고의 맛을 꼽으라면 단연 굴과 대구가 아닐까. 향긋한 굴구이와 시원하면서도 얼큰한 대구탕 한 그릇이면 코끝을 얼 12월추천가볼만한곳|2015년12월추천가볼만한곳|가족|거제|거제1박2일코스|거제가볼만한곳|거제당일코스|겨울|겨울먹거리|겨울제철음식|경상남도|굴|굴구이|굴무침|굴양식장|대구|대구탕|대구회무침|드라이브|몽돌해변|미식여행|바다|바람의언덕|신선대|여행|연인|외포항|추천가볼만한곳|친구|해금강테마박물관|힐링" property="og:description"/>
# <meta content="https://korean.visitkorea.or.kr/detail/rem_detail.do?cotid=be3db10c-b642-409c-81cc-c4cdecb5bd8b&amp;con_type=10500" property="og:url"/>
# <meta content="index,follow" name="robots"/>
# <link href="https://korean.visitkorea.or.kr/detail/rem_detail.do?cotid=be3db10c-b642-409c-81cc-c4cdecb5bd8b&amp;temp=" rel="canonical"/><!-- 2019-07-26  url 추가 -->
# <link href="/resources/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/><!-- 0904 파비콘 추가 -->
# <link href="../resources/css/jquery-ui.min.css" rel="stylesheet" type="text/css"/>
# <link href="../resources/css/swiper.min.css" rel="stylesheet" type="text/css"/>
# <link href="../resources/css/trss.css?v=20210723001d29b8629-f155-4a3d-929f-a61275796a75" rel="stylesheet" type="text/css"/>
# <link href="../resources/css/common.css?v=d29b8629-f155-4a3d-929f-a61275796a75" rel="stylesheet" type="text/css"/>
# <link href="../resources/css/content.css?v=d29b8629-f155-4a3d-929f-a61275796a75&amp;d=20200228001" rel="stylesheet" type="text/css"/>
# <link href="../resources/css/flickity.css" rel="stylesheet" type="text/css"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-RSGGQ7395J&amp;cx=c&amp;_slc=1" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-6FHD6PPZEF&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-4XLNR00KRE&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" charset="UTF-8" src="https://1330chat.visitkorea.or.kr/ttalk/js/ttalkDev.js" type="text/javascript"></script><script async="" id="www-widgetapi-script" src="https://www.youtube.com/s/player/0d02ada0/www-widgetapi.vflset/www-widgetapi.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-LYY1LJZCC4&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PJVBVKB"></script><script src="../resources/js/jquery-1.11.2.min.js"></script>
# <script src="../resources/js/jquery-ui.min.js"></script>
# <script src="../resources/js/flickity.pkgd.min.js"></script>
# <script src="/resources/js/jquery.cookie.js"></script>
# <script src="../resources/js/swiper.min.js"></script>
# <script src="../resources/js/common.js?v=20201027d29b8629-f155-4a3d-929f-a61275796a75"></script>
# <script src="../resources/js/global.js?v=20201027d29b8629-f155-4a3d-929f-a61275796a75"></script>
# <script src="../resources/js/cupertino-pane.min.js"></script>
# <script src="../resources/js/sigunguCode.js"></script>
# <script src="../resources/js/details.js?v=20201027d29b8629-f155-4a3d-929f-a61275796a75"></script>
# <script src="../resources/js/masonry.pkgd.min.js"></script>
# <script src="/resources/js/swiper.thumbnails.js?v=20190201001" type="text/javascript"></script>
# <script src="/resources/js/rwdImageMaps.min.js" type="text/javascript"></script>
# <script src="//dapi.kakao.com/v2/maps/sdk.js?appkey=44732c3ca5b90a4f1f49c6b38df023d1&amp;libraries=services,clusterer,drawing" type="text/javascript"></script><script charset="UTF-8" src="https://t1.daumcdn.net/mapjsapi/js/main/4.4.14/kakao.js"></script><script charset="UTF-8" src="https://t1.daumcdn.net/mapjsapi/js/libs/services/1.0.2/services.js"></script><script charset="UTF-8" src="https://t1.daumcdn.net/mapjsapi/js/libs/clusterer/1.0.9/clusterer.js"></script><script charset="UTF-8" src="https://t1.daumcdn.net/mapjsapi/js/libs/drawing/1.2.6/drawing.js"></script>
# <script src="../resources/js/kakao.min.js"></script>
# <script id="schema" type="application/ld+json">
# 			{
# 				"@context": "http://schema.org/",
# 				"@type": "WebPage",
# 				"headline": "향긋한 굴구이, 시원한 대구탕과 함께 하는 겨울 거제여행> 여행기사 | 추천! 가볼만한곳:대한민국 구석구석",
# 				"description" : " 찬바람이 불기 시작하는 이 즈음이면 전국의 포구는 미식가들로 붐비기 시작한다. 겨울이면 한껏 기름기가 오르는 생선이며 조개를 맛보려는 미식가들의 발걸음으로 유명식당 문턱이 닳는다. 도루묵이며 숭어 등등 겨울이면 맛이 드는 여러 해산물 중에서도 최고의 맛을 꼽으라면 단연 굴과 대구가 아닐까. 향긋한 굴구이와 시원하면서도 얼큰한 대구탕 한 그릇이면 코끝을 얼 12월추천가볼만한곳|2015년12월추천가볼만한곳|가족|거제|거제1박2일코스|거제가볼만한곳|거제당일코스|겨울|겨울먹거리|겨울제철음식|경상남도|굴|굴구이|굴무침|굴양식장|대구|대구탕|대구회무침|드라이브|몽돌해변|미식여행|바다|바람의언덕|신선대|여행|연인|외포항|추천가볼만한곳|친구|해금강테마박물관|힐링",
# 				"text" : " 찬바람이 불기 시작하는 이 즈음이면 전국의 포구는 미식가들로 붐비기 시작한다. 겨울이면 한껏 기름기가 오르는 생선이며 조개를 맛보려는 미식가들의 발걸음으로 유명식당 문턱이 닳는다. 도루묵이며 숭어 등등 겨울이면 맛이 드는 여러 해산물 중에서도 최고의 맛을 꼽으라면 단연 굴과 대구가 아닐까. 향긋한 굴구이와 시원하면서도 얼큰한 대구탕 한 그릇이면 코끝을 얼리는 차가운 겨울 바람이 오히려 고맙게 느껴진다.   거제는 굴구이와 대구요리 등 싱싱한 겨울 해산물을 맛볼 수 있는 대표적인 겨울별미 여행지다. 별미여행의 시작은 거제면 내간리에 자리한 굴구이집이다. 굴하면 이웃한 통영을 떠올리지만, 거제에서도 통영 못지 않게 굴이 많이 생산된다. 통영에서 신거제대교를 넘어 호곡, 녹산, 법동 등지를 지나 거제면 내간리까지 이어지는 1018번 지방도로를 따라가다 보면 해안가에 굴양식을 위한 지주들이 끝 간 데 없이 꽂혀 있는 것을 볼 수 있다. 바다 위에는 가지런히 떠있는 투하식 굴양식장의 부표들도 장관을 이루고 있다.   거제 사람들은 굴을 주로 구이로 먹는다. 예전에 굴을 캐던 사람들이 모닥불을 피우고 구워먹던 것이 세월이 흘러 자연스럽게 상품화가 됐다고 한다. 내간리 해안가에 굴구이를 내는 집이 모여있다. 굴구이를 주문하면 맛보기로 생굴이 나오고 곧 이어 굴튀김과 굴무침이 가득 담긴 접시도 놓여진다. 고추, 파와 함께 바삭하게 튀긴 굴튀김은 일식집에서 맛보던 그것과는 또 다른 맛을 낸다. 매콤한 맛이 이마와 콧등에 송글송글 땀을 맺히게 한다. 각종 야채와 함께 버무려진 굴무침도 매우면서도 새콤한 맛으로 젓가락질을 바쁘게 만든다.   굴무침과 굴튀김을 다 먹을 때면 커다란 철판 하나가 불 위에 올려진다.  뚜껑을 열어보면 껍질을 까지 않은 생굴이 가득 담겨있다. 가장자리에 검은 테두리가 선명한데, 이는 굴이 싱싱하다는 증거기도 하다. 거제 굴구이는 구우면서 동시에 찌는 방식. 다 익기까지는 5분 정도가 걸리는데, 장갑을 끼고 칼로 껍질을 까서 먹는다.   굴껍질을 까보면 육즙이 가득 고여 있다. 칼로 굴을 살짝 들어내면 탱글탱글한 굴이 보기에도 먹음직스럽다. 특유의 진한 굴향도 후각을 강하게 자극한다. 초장에 살짝 찍어 입으로 가져가면 짭조롬한 맛이 입안을 가득 채운다. 굴 자체에 간이 되어 있어 양념을 찍지 않고 그냥 먹어도 맛있다. 거제의 굴구이 집 대부분은 굴구이, 굴죽, 굴국밥 등 다양한 굴요리를 파는데, 굴구이 세트를 시키면 굴구이와 굴튀김을 비롯한 다양한 굴요리를 코스로 먹을 수 있다.   거제의 또다른 겨울 별미는 대구다. ‘눈 본 대구, 비 본 청어’라는 속담도 있듯, 찬바람이 부는 겨울은 대구에 맛이 제대로 드는 때다. 12월부터 이듬해 2월까지는 대구 산란기인데, 이때 잡히는 알 잔뜩 머금은 대구는 천하일미라고 해도 과언이 아니다. 외포항이 자리한 진해만에는 겨울이면 전국 최대규모의 대구 어장이 형성된다. 1980년대 한때 진해만을 가득 메웠던 대구가 사라지면서 ‘금대구’라고 불리던 시절도 있었다. 어쩌다 한두 마리가 잡히면 수십만원에 팔렸다는 기사가 신문에 소개될 정도로 귀한 생선이었다. 그러다 90년대 중반 거제수협이 대구알 방류 사업에 성공하면서 2000년대 중반부터 외포항으로 대구가 돌아오기 시작했다.   이른 아침부터 외포항에 자리한 거제수협 외포출장소 어판장은 대구 경매에 참여한 중매인들로 북적거린다. 어판장 바닥에 늘어선 갓 잡은 대구를 꼼꼼하게 살피던 중매인들은 경매가 시작되면 경매사에게 손가락 신호를 열심히 보낸다. 이렇게 30분이 지나면 나무상자에 담겨 있던 대구는 모두 팔려나간다. 대구잡이에는 호망을 쓴다. 호망은 대구를 유인하기 위해 길그물을 길게 놓고 그 끝에 둥그런 통그물을 붙인 것이다. 통그물의 모양이 단지(壺)처럼 생겨 호망이라 부른다. 야행성인 대구는 밤에 쏘다니다 호망에 걸리는데, 그물코에 꿰는 것이 아니니 산 채로 올라오는 대구도 많다. 외포항에는 대구요리를 내는 식당 10여곳이 늘어서 있다. 대구탕 거리로도 불린다. 대구는 회나 찜도 좋지만, 이맘땐 탕만 한 게 없다. 뽀얀 국물이 언 듯 보기에는 꼭 곰탕같다. 국물은 구수하면서도 진하다. 소금만으로 간을 해 깊고 그윽한 맛을 낸다.   외지인들은 생대구가 좋다고 하지만, 어민들은 살짝 말린 대구를 더 선호한다. 내장과 아가미, 알과 이리 등을 제거하고 해풍에 3~5일 말린 대구는 수분이 쏙 빠져 더욱 차진 맛을 낸다. 말린 것으로 탕을 끓이면 더 뽀얗고 구수한 맛의 국물을 얻을 수 있다는 것이 상인들의 귀띔이다. 외포항 곳곳에서는 대구를 말려 건대구로 만드는 작업을 쉽게 볼 수 있는데, 부둣가 햇볕이 드는 곳에는 어김없이 내장을 빼고 나무꼬치로 꿴 대구가 널려 있다.   말린 대구를 콩나물, 채소 등과 함께 쪄 먹는 대구찜도 맛있다. 생대구에서는 맛볼 수 없었던 쫀득한 맛과 말린 생선 특유의 감칠맛을 함께 느낄 수 있다. 코다리찜과 비슷하다고 보면 된다. 대구는 지방 함유량이 적고 열량도 높지 않아 다이어트에 그만이며 각종 비타민이 많이 들어 있어 원기 회복에도 도움이 된다고 한다.   굴과 대구로 배가 든든해졌다면 거제도의 아름다운 풍경 속으로 들어가보자. 거제는 우리나라에서 제주도 다음으로 큰 섬이다. 350km가 넘는 해안선을 따라 바다와 기암괴석이 어우러진 비경이 펼쳐진다. 거제에서 가장 아름다운 풍광을 꼽으라면 아마도 신선대와 ‘바람의 언덕’일 것이다. 해금강 가는 갈곶리 도로 오른편에 신선대가, 왼편에 바람의 언덕이 각각 자리한다. 신선대는 신선이 내려와 풍류를 즐겼다고 할 정도로 해안 경관이 절경이다. 파도가 쉴 새 없이 밀려와 기암괴석에 부딪혀 하얗게 부서지는 모습이 감탄을 자아낸다.   바람의 언덕은 갈곶리 도장포마을 북쪽 해안에 있는 언덕으로 사시사철 바닷바람이 분다고 해서 이렇게 이름붙었다. 바다와 풍차가 어우러진 이국적인 경치가 매력적이다.   신선대 입구에 자리한 해금강테마박물관은 가족들과 함께 돌아보기 좋은 곳이다. 1950~1980년대까지의 생활상을 볼 수 있는 곳으로 다이얼식공중전화, 대폿집 풍경을 재현한 전시장, 난로 위에 놓인 알루미늄 도시락 등 ‘그때 그 시절’을 구경하다 보면 시간가는 줄 모른다.   학동에 있는 학동흑진주몽돌해변도 놓치기 아까운 풍경이다. 흑진주처럼 반들반들 윤이 나는 검은 몽돌이 덮인 몽돌밭 해변이 1.2km에 걸쳐 펼쳐져 있다. 바닷물이 밀려들고 나갈 때마다 몽돌밭에서는 ‘자글자글’하는 소리가 나는데, 우리나라 자연 소리 100선에 선정될 만큼 아름답고 감미롭다.   구불구불 이어지는 해안선을 따라 즐기는 바다 드라이브도 거제 여행의 낭만을 더해준다. 특히 여차~홍포간 해안도로는 한국에서 가장 아름다운 바닷길이라고 해도 손색이 없을 정도. 푸른 바다와 정다운 포구마을, 깍아지른 해안절벽이 어우러진 풍경은 자꾸만 차를 세우게 만든다. 거가대교도 빼놓을 수 없는 명소다. 장목면과 부산 가덕도를 연결한 4.5km의 사장교로 일출과 일몰을 감상하기에도 좋다.                &lt;당일 여행 코스&gt;              내간리 굴구이→해금강테마박물관→신선대→바람의 언덕→외포항                      &lt;1박 2일 여행 코스&gt;              첫째 날 / 거제도 포로수용소 유적공원→내간리 굴구이→학동흑진주몽돌해변→학동 숙박         둘째 날 / 해금강테마박물관→신선대→바람의 언덕→외포항                      관련 웹사이트 주소              -거제문화관광             http://tour.geoje.go.kr              -해금강테마박물관             www.hggmuseum.com                           문의 전화                  -거제시청 관광과 055-639-4173         -해금강테마박물관 055-632-0670                      대중교통 정보                  -[버스] 서울-거제(고현) : 서울남부터미널에서 하루 28회(06:40~24:00) 운행, 약 4시간 20분 ...
# 				"publisher": {
# 				"@type": "CreativeWork",
# 				"name": "한국관광공사 대한민국 구석구석"
# 			},
# 			"url": "/detail/rem_detail.do?cotid=be3db10c-b642-409c-81cc-c4cdecb5bd8b&temp="
# 		}
# 	</script>
# <!--[if lt IE 9]>
# 		<script src="../resources/js/html5shiv.js"></script>
# 	<![endif]-->
# <style>
# 		/* .tap{content:"";overflow:hidden;display:block;width:940px;clear:both;}
# 		.tap li{float:left;height:85px;cursor:pointer}
# 		.tap li a{display:block}
# 		.tap li img{height:85px;}
# 		@media screen and (max-width: 1023px) {
# 		.tap{width:100%;}
# 		.tap li{width:50%;height:auto;}
# 		.tap li img{height:100%;}
# 		}
#
# 		.holidays_thema{padding:5% 4% 7%;background: #a3f4d2 url(/resources/theme/images/bg_holidays.jpg) no-repeat 50% 100%/100% auto;}
# 		.holidays_thema .tab_menu .swiper-thumbnails{font-size:0;}
# 		.holidays_thema .tab_menu .swiper-thumbnails:after{content:'';display:block;clear:both;}
# 		.holidays_thema .tab_menu .swiper-thumbnails button{display:inline-block;width:20%;vertical-align:bottom;}
# 		.holidays_thema .tab_menu .swiper-thumbnails button img{width:100%;}
# 		.holidays_thema .tab_menu .swiper-thumbnails button .img_on{display:none;}
# 		.holidays_thema .tab_menu .swiper-thumbnails button.is-active img{display:none;}
# 		.holidays_thema .tab_menu .swiper-thumbnails button.is-active .img_on{display:block;}
# 		.holidays_thema .swiper-container{width:100%;margin:0 auto;}
# 		.holidays_thema .swiper-container .swiper-wrapper li{width:100%;text-align:center;}
# 		.holidays_thema .swiper-container .swiper-wrapper img{display:inline-block;}
# 		.banner{display:block;}
# 		 */
# 		.PC_ver {width: 100%;height: auto;}
# 		.mobile_ver{display: none;}
# 		.tap{content:"";overflow:hidden;display:block;width:940px;clear:both;}
# 		.tap li{float:left;height:85px;cursor:pointer;}
# 		.tap li a{display:block;}
# 		.tap li img{height:30px;}
# 		@media screen and (max-width: 1023px) {
# 		.PC_ver img {display: none;}
# 		.mobile_ver {display:block;width:100%;}
# 		.mobile_ver img {display: block;  width:100%;}
# 		.tap{width:100%;}
# 		.tap li{width:50%;height:auto;}
# 		.tap li img{height:100%;}
# 		/*.holidays_thema{padding:5% 4% 7%;background: url(https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=8d127b8d-2862-4d63-86dc-3d6083a32a46&mode=raw) no-repeat 50% 100%/100% auto;}*/
# 		.holidays_thema .tab_menu
# 		.swiper-thumbnails{font-size:0;}
# 		.holidays_thema .tab_menu .swiper-thumbnails:after{content:'';display:block;clear:both;}
# 		/*.holidays_thema .tab_menu .swiper-thumbnails button{display:inline-block;width:12.5%;vertical-align:bottom; padding:1px;}*/
# 		.holidays_thema .tab_menu .swiper-thumbnails button img{width:100%;}
# 		.holidays_thema .tab_menu .swiper-thumbnails button
# 		.img_on{display:none;}
# 		.holidays_thema .tab_menu .swiper-thumbnails button.is-active img{display:none;}
# 		.holidays_thema .tab_menu .swiper-thumbnails button.is-active
# 		.img_on{display:block;}
# 		.holidays_thema
# 		.swiper-container{width:100%;margin-top:10px;}
# 		.holidays_thema .swiper-container .swiper-wrapper li{width:100%;text-align:center;}
# 		.holidays_thema .swiper-container .swiper-wrapper img{display:inline-block;}
# 		.banner{display:block;}	}
#
# 	 	/*도레미*/
# 	 	img{border:0 none;}
#
# 		.type_w{display:block;}
# 		.type_m{display:none;}
#
# 		.doremimk .tab_menu .swiper-thumbnails{font-size:0;}
# 		.doremimk .tab_menu .swiper-thumbnails:after{content:'';display:block;clear:both;}
# 		.doremimk .tab_menu .swiper-thumbnails button{display:inline-block;width:20%;vertical-align:bottom;}
# 		.doremimk .tab_menu .swiper-thumbnails button img{width:100%;}
# 		.doremimk .tab_menu .swiper-thumbnails button .img_on{display:none;}
# 		.doremimk .tab_menu .swiper-thumbnails button.is-active img{display:none;}
# 		.doremimk .tab_menu .swiper-thumbnails button.is-active .img_on{display:block;}
# 		.doremimk .swiper-container{width:100%;}
# 		.doremimk .swiper-container .swiper-wrapper li{height:auto !important;}
#
# 		@media screen and (max-width: 1023px) {
# 			.type_w{display:none;}
# 			.type_m{display:block;}
# 		}
#
# /*여행가는 달*/
#
# .main_quick {
#     position: fixed;
#     left: 0;
#     bottom: 0;
#     right: 0;
#     z-index: 100;
#     transition: bottom .5s ease-in-out;
# }
#
# .main_quick .inr {
#     position: relative;
#     width: 940px;
#     margin: 0 auto;
# }
#
# .event_hojung {
#    position: absolute;
#    right: -155px;
#    bottom: 470px;
#    max-width: 174px;
# }
#
# .event_hojung img {
#  width:100%;
# }
#
# .hojong_area {
#    position: fixed;
#    left: 0;
#    bottom: 0;
#    right: 0;
# }
#
# .event_hojung img:hover {
#  content: url("https://support.visitkorea.or.kr/img/call?cmd=TEMP_VIEW&name=86ff9b83-ba9b-48a1-9726-1f14c4e5fa52.png");
# }
# .event_close {
#  text-align:center;
#  background-color:#000;
#  color:#fff;
#  padding: 5% 0%;
#  font-weight: bold;
# }
#
# .inr_2 {
#    position: relative;
#    width: 940px;
#    margin: 0 auto;
# }
#
# .ev1 {
# 	border: 5px solid black;
# 	 position: absolute;
#     right: -154px;
#     bottom: 215px;
#     width: 174px;
#     height: 273px;
#    /* background: url(../images/sub/ev_rel_quick1.png) 0 0 / 100% 100% no-repeat;*/
#     background: url('../resources/images/sub/p_floating_1.png');
#     text-indent: -9999px;
# }
#
# @media screen and (max-width: 1023px){
# 	.event_hojung {
# 	   position: fixed;
# 	   left: 50%;
# 	   top: 40%;
# 	   display: inline-block;
# 	   transform: translate(-50%, -50%);
# 	   cursor: pointer;
# 	   text-align: center;
# 	   width: 100%;
# 	   max-width: 238px;
# 	}
# }
#
# /* .main_quick .inr + .inr .ev1 {
#     position: absolute;
#     right: -154px;
#     bottom: 215px;
#     width: 174px;
#     height: 273px;
#     background: url(../images/sub/ev_rel_quick1.png) 0 0 / 100% 100% no-repeat;
#     text-indent: -9999px;
# } */
#
#
#
# 		section, div, article, ul, li, dl, dt, dd, h3, h4, p, span, img {padding: 0; margin: 0; /* letter-spacing: -0.05em; */ box-sizing: border-box; word-break: keep-all;}
#         li {list-style: none;}
#
#         .screen-out {position:absolute; top:0; left: 0; width: 0; height: 0; font-size: 0 ; color: transparent; }
#
#         .main-floating-banner {
# 		    position: fixed;
# 		    width: 334px;
# 		    float:right;
# 		    right: 5%;
# 			top: 270px;
# 		    z-index: 100;
# 		    transition: bottom .5s ease-in-out;
# 		}
#         .main-floating-banner img {width: 100%;}
#         .main-floating-banner p {width: 100%; height: 100%; margin-top: 7.6%;}
#         .main-floating-banner button {position:absolute; top: 0; right: -2.7%; width: 52px; height: 52px; background: url('../resources/images/sub/icon_close.png') 0 0 no-repeat; z-index: 10; background-size: contain}
#         .main-floating-banner a {position:absolute; bottom: 10%; left: 11%; width: 73%; height: 10%;}
#
#
#
#         @media all and (max-width:1024px){
#             section, section img {width: 100%;}
#             .main-floating-banner {width: 43.5%}
#             .main-floating-banner button {width: 18%; height: 13%; }
#         }
#
#         @media all and (max-width:767px){
#
#
#         }
#
#          /* section 1 */
#         body.open-modal {overflow: hidden}
#         .content {position: relative;}
#         .content a, .content button {position: absolute;}
#         .content.term button {bottom: 12%; left: 50%; transform: translateX(-50%); width: 38%; height: 8%;}
#         .content.term li.on {opacity: 1}
#         .content.term li {position:absolute; top: 20.2%; opacity: 0}
#         .content.term li:nth-of-type(1) {left: 6.8%; width: 17.3%}
#         .content.term li:nth-of-type(2) {left: 24.8%; width: 16.7%;}
#         .content.term li:nth-of-type(3) {left: 42%; width: 17.1%;}
#         .content.term li:nth-of-type(4) {left: 60.3%; width: 16.7%;}
#         .content.term li:nth-of-type(5) {left:78%; width: 16.7%;}
#
#         .content.guide a {bottom: 1%; left: 49.5%; transform: translateX(-50%); width: 56%; height: 11%;}
#         .content img {margin-top: -1px;}
#
#
#         .modal {display: none; position: fixed; top: 0; left: 0; width: 100%; height: 100%; z-index: 1000;}
#         .modal--active {display: block}
#         .modal-backdrop, .modal-wrapper {top: 0; left: 0; z-index: 10; width: 100%; min-height: 100%; pointer-events: none;}
#         .modal-wrapper {overflow:auto; position: absolute; height: auto;}
#         .modal-backdrop {position: fixed; height: 100%; background: rgba(0,0,0, 0.6); pointer-events: auto;}
#         .modal-container {position: absolute; top: 0; left: 0; z-index: 20; width: 100%; height: 100%; pointer-events: auto;}
#         .modal-content {overflow-y: scroll; position:relative; height: 100%; margin: 0 auto; text-align: center;}
#         .modal-content:before {display: inline-block; vertical-align: middle; width:100%; height: 11%; content: "";}
#         .modal .close {position:absolute; top: -33px; right: -33px; width: 69px; height: 69px; background: url('../resources/images/sub/icon_close.png') 0 0 no-repeat; z-index: 10;}
#         .modal .modal__container {display:inline-block; position: relative;}
#
#         #tripPopImg {cursor: pointer;}
#         #openTripEventPop {cursor: pointer;}
#         .find-modal .item > img {position: absolute; bottom: 42%; left:50%; width:54.8%; transform: translateX(-50%);}
#         .find-modal .item button {position:absolute; bottom: 9%; left: 50%; width: 72%; height: 10.8%; transform: translateX(-50%);}
#
#        .information-modal .modal-content {
#     overflow-y: scroll;
#     color: #303030;
# }
#
# .information-modal form {
#     position: absolute;
#     top: 0;
#     left: 0;
#     width: 100%;
#     height: 100%;
#     box-sizing: border-box
# }
#
# .information-modal .name input, .information-modal .phone-number input, .information-modal .policy p, .information-modal .consignment p {
#     position: absolute;
#     padding: 0 18px;
#     font-size: 24px;
#     border: 3px solid #000000;
#     border-radius: 7px;
#     box-shadow: 10px 10px 0 0 rgba(206, 206, 206, .4);
# }
#
# .information-modal .name input {
#     width: 77.8%;
#     top: 28.7%;
#     left: 11%;
# }
#
# .information-modal .name input, .information-modal .phone-number input {
#     height: 5.8%;
# }
#
# .information-modal .number-first input {
#     width: 21%;
#     top: 40.8%;
#     left: 11%;
# }
#
# .information-modal .number-middle input {
#     top: 40.8%;
#     left: 34%;
# }
#
# .information-modal .number-middle input, .information-modal .number-last input {
#     width: 26.7%;
# }
#
# .information-modal .number-last input {
#     top: 40.8%;
#     left: 62%;
# }
#
# .information-modal .policy p {
#     top: 54%;
# }
#
# .information-modal .policy p, .information-modal .consignment p {
#     overflow-y: scroll;
#     left: 11%;
#     width: 77.8%;
#     height: 11%;
#     padding: 18px;
#     font-size: 15px;
#     line-height: 24px;
#     letter-spacing: -.03em;
#     text-align: left;
#     box-sizing: border-box;
# }
#
# .information-modal .policy p span, .information-modal .consignment p span {
#     font-size: 17px;
#     font-weight: 700;
# }
#
# .information-modal .consignment p {
#     top: 72.5%;
# }
#
# .information-modal .submit {
#     position: absolute;
#     bottom: 6.3%;
#     left: 14%;
#     width: 72.6%;
#     height: 7.3%;
# }
#
# .information-modal .checkbox {
#     position: absolute;
#     top: 50%;
#     left: 82%;
#     width: 6%;
#     height: 3.2%;
#     opacity: 0;
#     z-index: 10;
#     cursor: pointer;
#     margin: 0;
#     overflow: auto;
#     clip: auto;
# }
#
# .information-modal .checkbox + span:before {
#     display: block;
#     position: absolute;
#     top: 50%;
#     left: 82%;
#     width: 6%;
#     height: 3.2%;
#     border: 3px solid #000000;
#     border-radius: 7px;
#     box-shadow: 5px 5px 0 0 rgba(206, 206, 206, .4);
#     content: '';
#     cursor: pointer;
#     box-sizing: border-box
# }
#
# .information-modal .checkbox:checked + span:after {
#     display: block;
#     position: absolute;
#     top: 50%;
#     left: 82%;
#     width: 38px;
#     height: 38px;
#     background: url('../resources/images/sub/icon_checkbox.png') center center no-repeat;
#     content: '';
# }
#
#
#         .lottery-modal .checkbox, .lottery-modal .checkbox + span:before, .lottery-modal .checkbox:checked + span:after {height: 3%;}
#
#         .confirm-modal .checkbox {top: 46.2%;}
#         .confirm-modal .checkbox + span:before {top: 46.2%;}
#         .confirm-modal .checkbox:checked + span:after {top: 46.2%;}
#         .confirm-modal .name input {top: 22.2%;}
#         .confirm-modal .number-first input, .confirm-modal .number-middle input, .confirm-modal .number-last input {top: 35.8%;}
#         .confirm-modal .policy p {top: 51.1%;}
#         .confirm-modal .consignment p {top: 70.8%;}
#         .confirm-modal .submit {bottom: 7.9%;}
#
#         .giveaway-modal a {position: absolute; top: 81.5%; left: 9%; width: 82%; height: 10%; }
#
#         .winning-modal .item {position: absolute; top: 62.7%; width: 100%; text-align: center}
#         .winning-modal .item img {width: 60.2%;}
#
#         .accumulate-modal li {position: absolute;}
#         .accumulate-modal li .gray {display: block;}
#         .accumulate-modal li .color {display: none}
#         .accumulate-modal li.on .color {display: block}
#         .accumulate-modal li.on .gray {display: none}
#         .accumulate-modal li:nth-child(1), .accumulate-modal li:nth-child(2), .accumulate-modal li:nth-child(3) {top: 25.8%;}
#         .accumulate-modal li:nth-child(1) {left: 10%; width: 25.1%;}
#         .accumulate-modal li:nth-child(2) {left: 37.8%}
#         .accumulate-modal li:nth-child(2), .accumulate-modal li:nth-child(4), .accumulate-modal li:nth-child(5) {width: 24.8%;}
#         .accumulate-modal li:nth-child(3) {top: 26.1%; left: 64.6%; width: 25.4%;}
#         .accumulate-modal li:nth-child(4) {top: 61%; left: 24.5%;}
#         .accumulate-modal li:nth-child(5) {top: 60.5%; left: 52.8%;}
#
#         input {
# 		    margin: 0;
# 		    box-sizing: border-box;
# 		}
#
#         @media all and (max-width:1024px){
#                     /* 태블릿 */
#         }
#
#         @media all and (max-width: 767px) {
#             /* 모바일 최대 */
#             .content.term button {width: 56%;}
#             .content.term li {top: 19.9%}
#             .content.term li:nth-of-type(1) {left: 4.7%; width: 18%;}
#             .content.term li:nth-of-type(2) {left: 23.7%; width: 17.3%;}
#             .content.term li:nth-of-type(3) {width: 17.9%;}
#             .content.term li:nth-of-type(4) {top: 20%; left: 60.8%; width: 17.3%; }
#             .content.term li:nth-of-type(5) {top: 19.8%; left: 78.8%; width: 18.1%;}
#
#             .content.guide a {bottom: 5%; left: 49.5%; width: 80.5%; height: 11.3%;}
#
#
#
#             .modal-content img {width: 100%;}
#             .modal-content:before {height: 115px;}
#             .modal .close { top: -18px; right: 5px; width: 11.2%; height: 11.2%; background-size: contain}
#             .modal .modal__container {padding: 0 15px; box-sizing: border-box;}
#             .information-modal .name input, .information-modal .phone-number input, .information-modal .policy p, .information-modal .consignment p {padding:10px; font-size: 14px; line-height: 1.4; box-shadow: 5px 5px 0 0 rgba(206, 206, 206 , .4);}
#             .confirm-modal .number-first input, .confirm-modal .number-middle input, .confirm-modal .number-last input {padding: 0 10px;}
#             .confirm-modal .policy p, .confirm-modal .consignment p {font-size: 12px;}
#             .information-modal .policy p span, .information-modal .consignment p span {font-size: 14px;}
#             .find-modal__container figure {padding: 0 18px;}
#             .find-modal__container p > img {width: 50%;}
#             .find-modal__container .content a {width: 64%;}
#
#             .information-modal .name input {left: 7%; width: 85%;}
#             .information-modal .number-first input {left: 7%; width: 23.9%;}
#             .information-modal .number-middle input, .information-modal .number-last input {width: 28.7%;}
#             .information-modal .number-middle input {left: 33%;}
#             .information-modal .number-last input {left: 63.3%;}
#             .information-modal .policy p, .information-modal .consignment p {left: 7%; width: 85%;}
#             .information-modal .checkbox, .information-modal .checkbox + span:before, .information-modal .checkbox:checked + span:after {width: 7.6%; height: 3.8%; left: 83.7%; background-size: 65%;}
#
#             .lottery-modal .modal-content .checkbox, .lottery-modal .modal-content .checkbox + span:before, .lottery-modal .modal-content .checkbox:checked + span:after {height: 3.4%; left: 83.7%; top: 50.3%;}
#             .lottery-modal .policy p { top: 54.9%;}
#             .lottery-modal .submit {bottom: 6.2%; left: 10%; width: 79.6%;}
#
#             .accumulate-modal li:nth-child(4) {top: 58%;}
#             .accumulate-modal li:nth-child(5) {top: 57.5%;}
#         }
#
#
#         #tripPop, #findModal, #infoModal, #winningModal, #loseModal, #endModal, #beWinningModal, #finalWinningModal {
#         	display : none;
#         }
#
#         /* 여행재생 플로팅 배너 */
#         .main_floating_banner {
#              position: absolute;
#              top: 250px;
#              left: calc(50% + 495px);
#              width: 230px;
#          }
#
# 		.main_floating_banner img {
# 		    width: 100%;
# 		}
#
# 		.main_floating_banner p {
# 		    width: 100%;
# 		    height: 100%;
# 		}
#
# 		.main_floating_banner .close {
# 		    position: absolute;
# 		    top: 0;
# 		    right: 0;
# 		    width: 30px;
# 		    height: 30px;
# 		}
#
# 		.main_floating_banner .cookie_check {
# 		    position: absolute;
# 		    bottom: 0;
# 		    left: 0;
# 		    width: 230px;
# 		    height: 38px;
# 		}
#
# 		.main_floating_banner a {
# 		    position: absolute;
# 		    top: 7%;
# 		    left: 0;
# 		    width: 100%;
# 		    height: 85%;
# 		}
#
#          .main_floating_banner .screen_out {
#              position: absolute;
#              top: 0;
#              left: 0;
#              width: 0;
#              height: 0;
#              font-size: 0;
#              color: transparent;
#          }
#
# /*          .main_floating_banner .pc {
#              display: block;
#          }
#
#          .main_floating_banner .mo {
#              display: none;
#          } */
#
#          @media all and (max-width: 1450px) {
# 	         .main_floating_banner {
# 	             display: none;
#          }
#
#          .main_floating_modal {
# 		    display: none;
# 		    position: fixed;
# 		    top: 0;
# 		    left: 0;
# 		    width: 100%;
# 		    height: 100%;
# 		    z-index: 1000;
# 		}
# 		.main_floating_modal .modal--active .modal-content {
# 		    /*overflow-y: scroll;*/
# 		}
# 		.main_floating_modal .modal-backdrop,
# 		.main_floating_modal .modal-wrapper {
# 		    top: 0;
# 		    left: 0;
# 		    z-index: 10;
# 		    width: 100%;
# 		    min-height: 100%;
# 		    pointer-events: none;
# 		}
# 		.main_floating_modal .modal-wrapper {
# 		    overflow: auto;
# 		    position: absolute;
# 		    height: auto;
# 		}
# 		.main_floating_modal .modal-backdrop {
# 		    position: fixed;
# 		    height: 100%;
# 		    background: rgba(0, 0, 0, 0.6);
# 		    pointer-events: auto;
# 		}
# 		.main_floating_modal .modal-container {
# 		    position: absolute;
# 		    top: 0;
# 		    left: 0;
# 		    z-index: 20;
# 		    width: 100%;
# 		    height: 100%;
# 		    pointer-events: auto;
# 		}
# 		.main_floating_modal .modal-content {
# 		    position: relative;
# 		    height: 100%;
# 		    margin: 0 auto;
# 		    /*text-align: center;*/
# 		}
# 		.main_floating_modal .modal-content:before {
# 		    height: 115px;
# 		}
# 		.main_floating_modal .modal-content:before {
# 		    display: inline-block;
# 		    vertical-align: middle;
# 		    width: 100%;
# 		    height: 11%;
# 		    content: "";
# 		}
# 		.main_floating_modal .modal__container {
# 		    display: inline-block;
# 		    position: absolute;
# 		    right: 20px;
# 		    top: 115px;
# 		    width: 260px;
# 		    padding: 0 15px;
# 		    box-sizing: border-box;
# 		}
# 		.main_floating_modal img {
# 		    width: 100%;
# 		}
# 		.main_floating_modal .close {
# 		    position: absolute;
# 		    top: 0;
# 		    right: 3%;
# 		    width: 16%;
# 		    height: 6%;
# 		}
#
# 		.main_floating_modal .cookie_check {
# 		    position: absolute;
# 		    bottom: 0;
# 		    left: 0;
# 		    width: 100%;
# 		    height: 38px;
# 		}
#
# 		.main_floating_modal a {
# 		    position: absolute;
# 		    top: 5.8%;
# 		    left: calc(50% - 115px);
# 		    width: 230px;
# 		    height: 86%;
# 		}
#
# 	 	.main_floating_modal {
# 	        display: block;
# 	    }
#
#         .main_floating_modal .screen_out {
#            position: absolute;
#            top: 0;
#            left: 0;
#            width: 0;
#            height: 0;
#            font-size: 0;
#            color: transparent;
#        }
# 	</style>
# <script charset="UTF-8" type="text/javascript">
# var custInfo = {
# 		uuid : null, //SNS_ID
# 		loginYn : 'N', //로그인여부
# 		firstYn : 'N', //최초로그인여부
# 		gender : 'null', //성별
# 		grade : 'null', //여행구독레벨
# 		birthYr : 0, //생년월일
# 		rsdeNm : 'null', //거주지명
# 		favoriteCnt : null, //즐겨찾기수
# 		commentCnt : null, //댓글수
# 		joinYmd : null, //가입일
# 	    channel : null, //SNS채널구분
# 	    device : appYn == 'Y' ? device : mobileYn == 'Y' ? 'mobileweb' : 'pcweb', //device 구분
# 	    cardAreaNm : null //digitcard area Name
# }
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-LYY1LJZCC4"></script>
# <script charset="UTF-8" type="text/javascript">
# 	window.dataLayer = window.dataLayer || [];
# 	dataLayer.push({
# 		'user_id': custInfo.uuid,         //기본페이지뷰 시 호출되는 uuid값 활용
# 		'first_login': custInfo.firstYn,  //기본페이지뷰 시 호출되는 firstYn값 활용
# 		'gender_div': custInfo.gender,    //기본페이지뷰 시 호출되는 gender값 활용
# 		'birth_year': custInfo.birthYr,   //기본페이지뷰 시 호출되는 birthYr값 활용
# 		'city_name': custInfo.rsdeNm,     //기본페이지뷰 시 호출되는 rsdeNm값 활용
# 		'join_date': custInfo.joinYmd,    //기본페이지뷰 시 호출되는 joinYmd값 활용
# 		'method': custInfo.channel,        //기본페이지뷰 시 호출되는 channel값 활용
#
# 		'dimension7': custInfo.uuid,
# 		'dimension8': custInfo.joinYmd,
# 		'dimension9': custInfo.loginYn,
# 		'dimension10': custInfo.channel,
# 		'dimension11': custInfo.device,
# 	});
#
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
#
# 	gtag('config', 'G-LYY1LJZCC4', {
#
# 		otd_nm : "추천! 가볼만한곳"
# 	});
# </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PJVBVKB');</script>
# <!-- End Google Tag Manager -->
# <script src="https://www.googleoptimize.com/optimize.js?id=OPT-5JVS3BG"></script>
# <script src="https://www.googleoptimize.com/optimize.js?id=OPT-NQVD2Q2"></script>
# <script src="https://cdn.visitkorea.or.kr/resources/js/cdp/web/sphereAnalytics.min.js?v=fd60458b-6403-49eb-a01e-3abc95813187"></script>
# <script type="text/javascript">
# var otd_nm = "";
# if( appYn == 'N') {
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 		ga('create', 'UA-92880258-1', 'auto');
# 		ga('require', 'displayfeatures');
#
#         otd_nm = "추천! 가볼만한곳";
#         ga('set', 'dimension5', otd_nm);
# } else {
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 		ga('create', 'UA-92878657-1', 'auto');
# 		ga('require', 'displayfeatures');
# 		ga('send', 'pageview');
#         otd_nm = "추천! 가볼만한곳";
#         ga('set', 'dimension5', otd_nm);
# }
# </script>
# <meta content="unsafe-url" name="referrer"/>
# <script type="text/javascript">
# 		var cotid = 'be3db10c-b642-409c-81cc-c4cdecb5bd8b';
# 		if( cotid == '' || cotid == undefined ) alert('잘못된 호출입니다.');
# 		var ctitle = '향긋한 굴구이, 시원한 대구탕과 함께 하는 겨울 거제여행';
# 	</script>
# <link href="https://1330chat.visitkorea.or.kr/ttalk/css/ttalk-import.css" rel="stylesheet" type="text/css"/><meta content="" http-equiv="origin-trial"/><link href="https://code.tand.kr/msg/style/sa-campaign.css" id="sphereCss" rel="stylesheet" type="text/css"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/></head>
# <body id="body"><div class="search_index" style="display: none;">
# <div class="box">
# <div class="search_wrap">
# <button class="page_back" onclick="CloseSearchForm();" type="button">뒤로</button>
# <span class="logo"><a class="svgLogo" href="/main/main.do">대한민국 구석구석</a></span>
# <div class="wrap">
# <div class="form">
# <input id="inp_search_index" placeholder="어디로, 어떤 여행을 떠날 예정인가요?" title="검색" type="text"/>
# <button class="delete" onclick="DeleteKeyword();" style="display: none;" type="button">삭제</button>
# <button onclick="goSearchList();" type="button">검색</button>
# <span id="width_check" style="left: -10000px; top: -10000px; position: absolute;"></span>
# </div>
# <div class="related_search" style="display: none;">
# <ul>
# </ul>
# </div>
# <div class="recent_search">
# <h2>최근 검색어</h2>
# <ul>
# </ul>
# <button class="close" onclick="DeleteMySearchKeywords(1);" type="button">전체삭제</button>
# <p class="no_data">최근 검색어 내역이 없습니다.</p>
# </div>
# <div class="popular_search" style="display: none;">
# <h2>최근 인기 검색어</h2>
# <em>조회일 직전 7일간의 인기 검색어</em>
# <div class="popular">
# <ul id="popul1">
# </ul>
# <ul id="popul2">
# </ul>
# </div>
# </div>
# <div class="keyword" style="display: none;">
# <h2>추천 키워드</h2>
# <div class="inr">
# <ul>
# </ul>
# </div>
# <button onclick="recomkeywordMore(this);" style="display: none;" type="button">더보기</button><!-- 한줄 이상 아닐시 버튼 display:none 처리 해주세요.모바일은 두줄(개발) -->
# </div>
# <div class="popular_more" style="display: none;">
# <h2>인기 여행지 모아보기</h2>
# <div class="inr">
# <div class="swiper-container">
# <ul class="swiper-wrapper">
# </ul>
# <div class="swiper-button-prev">이전</div>
# <div class="swiper-button-next">다음</div>
# <div class="mo_page">
# <div class="swiper-pagination"></div>
# <div class="swiper-scrollbar"></div>
# </div>
# </div>
# </div>
# </div>
# <button class="layer_close" onclick="CloseSearchForm();" type="button">닫기</button>
# </div>
# </div>
# </div>
# <script src="../resources/js/search/searchIndex.js?v=20201028af9e4f23-62f5-4fac-a55e-ce8d4ec8c8f8"></script></div>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJVBVKB" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Facebook Pixel Code -->
# <!-- End Facebook Pixel Code -->
# <!-- Facebook Pixel Code Start 2021-02-16-->
# <!-- End Facebook Pixel Code -->
# <script type="text/javascript">
# 		//Kakao.init('7a11644ef91a3bf00391c557a463d167');	//rest 키
# 		Kakao.init('44732c3ca5b90a4f1f49c6b38df023d1');	//javascript키
# 		var ytPlayerList = [];
# 		var players = [];
# 		var createVideo = false;
# 	</script>
# <!-- 0604 수정 -->
# <!-- skip -->
# <div id="skipToContent">
# <a href="#contents">본문 바로가기</a>
# <!--<a href="#btnMenu">주메뉴 바로가기</a>-->
# </div>
# <!-- // skip -->
# <!-- // 0604 수정 -->
# <!-- header -->
# <header class="db_gnb trss_quick down" id="gnbCommon">
# <div class="gnb">
# <div class="search">
# <h1 class="logo">
# <a class="svgLogo" href="/main/main.do">대한민국구석구석<svg height="86px" id="pathicon1" style="enable-background:new 0 0 510 86;" version="1.1" viewbox="0 0 510 86" width="510px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"><path class="text-path" d="M483.7,49.5h-39.2c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h28.3v17c0,0.9,0.8,1.7,1.7,1.7c5.8,0,10.4-4.7,10.4-10.4V50.6C484.8,50,484.3,49.5,483.7,49.5z M453,41.3c3.3,3.8,8,5.4,13.7,5.4h1.8c0.9,0,1.7-0.7,1.7-1.7c0-0.9-0.7-1.7-1.7-1.7h0c-4.6,0-9.4-2.4-9.4-7.7V20.8c0-0.9-0.8-1.7-1.7-1.7h-8.7c-0.9,0-1.7,0.8-1.7,1.7v14.7c0,5.4-4.8,7.7-9.4,7.7h0c0,0-18.7,0-18.7,0c4.8-2,10.7-6.4,10.7-15.6v-6.8c0-0.9-0.8-1.7-1.7-1.7h-33.7c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h23.3v5.2c0,15.3-7.7,15.6-7.7,15.6h-24.5c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h19.7v23.2c0,0.9,0.8,1.7,1.7,1.7c5.8,0,10.4-4.7,10.4-10.4V46.6h22.3C445,46.6,449.7,45,453,41.3z M483.1,19.1h-8.7c-0.9,0-1.7,0.8-1.7,1.7v8.1h-4c-0.9,0-1.7,0.7-1.7,1.7s0.7,1.7,1.7,1.7h4v12.7c0,0.9,0.8,1.7,1.7,1.7h8.7c0.9,0,1.7-0.8,1.7-1.7V20.8C484.8,19.9,484.1,19.1,483.1,19.1z M467.1,0H351.6c-23.1,0-42,18.3-43,41.2H272C271,18.3,252.1,0,229,0c-23.7,0-43,19.3-43,43c0,23.7,19.3,43,43,43c23.1,0,42-18.3,43-41.2h36.6c1,22.9,19.9,41.2,43,41.2h115.5c23.7,0,43-19.3,43-43C510.1,19.3,490.8,0,467.1,0z M229,82.3c-21.7,0-39.3-17.6-39.3-39.3c0-21.7,17.6-39.3,39.3-39.3c21.7,0,39.3,17.6,39.3,39.3C268.3,64.7,250.7,82.3,229,82.3z M467.1,82.3H351.6c-21.7,0-39.3-17.6-39.3-39.3c0-21.7,17.6-39.3,39.3-39.3h115.5c21.7,0,39.3,17.6,39.3,39.3C506.4,64.7,488.7,82.3,467.1,82.3z M347.5,41.3c3.3,3.8,8,5.4,13.7,5.4h1.8c0.9,0,1.7-0.7,1.7-1.7c0-0.9-0.7-1.7-1.7-1.7h0c-4.6,0-9.4-2.4-9.4-7.7V20.8c0-0.9-0.8-1.7-1.7-1.7h-8.7c-0.9,0-1.7,0.8-1.7,1.7v14.7c0,5.4-4.8,7.7-9.4,7.7h0c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h1.8C339.4,46.6,344.1,45,347.5,41.3z M377.6,19.1h-8.7c-0.9,0-1.7,0.8-1.7,1.7v8.1h-4c-0.9,0-1.7,0.7-1.7,1.7s0.7,1.7,1.7,1.7h4v12.7c0,0.9,0.8,1.7,1.7,1.7h8.7c0.9,0,1.7-0.8,1.7-1.7V20.8C379.3,19.9,378.5,19.1,377.6,19.1z M254.8,43.3h-18c4.8-2,10.7-6.4,10.7-15.7v-6.8c0-0.9-0.8-1.7-1.7-1.7h-33.7c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h23.3v5.2c0,15.3-7.7,15.7-7.7,15.7h-24.5c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h19.7v23.2c0,0.9,0.8,1.7,1.7,1.7c5.8,0,10.4-4.7,10.4-10.4V46.6h19.7c0.9,0,1.7-0.7,1.7-1.7C256.4,44,255.7,43.3,254.8,43.3z M378.1,49.5h-39.2c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h28.3v17c0,0.9,0.8,1.7,1.7,1.7c5.8,0,10.4-4.7,10.4-10.4V50.6C379.3,50,378.8,49.5,378.1,49.5z" stroke="undefined" stroke-width="1"></path><path class="text-path" d="M66.2,35.2c0-3.3-1.4-6.2-4.2-8h4.1c0.8,0,1.5-0.7,1.5-1.5c0-0.8-0.7-1.5-1.5-1.5h-7.4v-4c0-0.6-0.5-1.1-1.1-1.1H53c-0.6,0-1.1,0.5-1.1,1.1v4h-7.4c-0.8,0-1.5,0.7-1.5,1.5c0,0.8,0.7,1.5,1.5,1.5h4.2c-2.7,1.8-4.2,4.7-4.2,8c0,5.4,3.9,9.8,10.9,9.8C62.4,45.1,66.2,40.7,66.2,35.2z M51.2,35.2c0-3.8,1.5-6.8,4.2-6.8c2.7,0,4.2,3.1,4.2,6.8c0,3.8-1.5,6.8-4.2,6.8C52.7,42.1,51.2,39,51.2,35.2z M35.4,19.6H31c-0.6,0-1.1,0.5-1.1,1.1v10.4h-4.2V21.1c0-0.6-0.5-1.1-1.1-1.1h-4.4c-0.6,0-1.1,0.5-1.1,1.1v21.8c-0.6,0.2-1.3,0.5-2.1,0.6c-0.9,0.2-1.9,0.3-3.1,0.3h-7V24.3H14c0.8,0,1.5-0.7,1.5-1.5c0-0.8-0.7-1.5-1.5-1.5H1c-0.6,0-1.1,0.5-1.1,1.1v23.4c0,0.6,0.5,1.1,1.1,1.1h12.6c1.3,0,2.4-0.1,3.3-0.4c0.9-0.3,1.6-0.6,2.2-1.1v15c0,0.6,0.5,1.1,1.1,1.1H22c2.1,0,3.7-1.6,3.7-3.7V35.1h4.2v25.9c0,0.6,0.5,1.1,1.1,1.1h1.8c2.1,0,3.7-1.6,3.7-3.7V20.7C36.5,20.1,36,19.6,35.4,19.6z M78.5,59H57.8v-9.6c0-0.6-0.5-1.1-1.1-1.1h-4.8c-0.6,0-1.1,0.5-1.1,1.1v11.5c0,0.6,0.5,1.1,1.1,1.1h26.6c0.8,0,1.5-0.7,1.5-1.5C80,59.7,79.3,59,78.5,59z M119,51h1.4c2.5,0,4.5-2,4.5-4.4V20.7c0-0.6-0.5-1.1-1.1-1.1H119c-0.6,0-1.1,0.5-1.1,1.1v29.1C117.9,50.5,118.4,51,119,51z M168.8,36h-5.3c0.5-0.6,0.9-1.6,1.2-3c0.3-1.4,0.5-2.6,0.5-3.8v-6.9c0-0.6-0.5-1.1-1.1-1.1h-27.3c-0.8,0-1.5,0.7-1.5,1.5c0,0.8,0.7,1.5,1.5,1.5h21.4v5.2c0,1.2-0.1,2.4-0.2,3.5c-0.1,1.2-0.3,2.2-0.7,3.1H132c-0.8,0-1.5,0.7-1.5,1.5c0,0.8,0.7,1.5,1.5,1.5h14.7v7.7h-10.1c-0.8,0-1.5,0. ...
# </h1>
# <button class="page_back" onclick="pagemove(1);" type="button">뒤로가기</button>
# <div class="mo">
# <button class="m_menu" type="button">메뉴</button>
# <div class="layer">
# <div class="cont">
# <strong class="logo svgLogo">대한민국구석구석<svg height="86px" id="pathicon1" style="enable-background:new 0 0 510 86;" version="1.1" viewbox="0 0 510 86" width="510px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"><path class="text-path" d="M483.7,49.5h-39.2c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h28.3v17c0,0.9,0.8,1.7,1.7,1.7c5.8,0,10.4-4.7,10.4-10.4V50.6C484.8,50,484.3,49.5,483.7,49.5z M453,41.3c3.3,3.8,8,5.4,13.7,5.4h1.8c0.9,0,1.7-0.7,1.7-1.7c0-0.9-0.7-1.7-1.7-1.7h0c-4.6,0-9.4-2.4-9.4-7.7V20.8c0-0.9-0.8-1.7-1.7-1.7h-8.7c-0.9,0-1.7,0.8-1.7,1.7v14.7c0,5.4-4.8,7.7-9.4,7.7h0c0,0-18.7,0-18.7,0c4.8-2,10.7-6.4,10.7-15.6v-6.8c0-0.9-0.8-1.7-1.7-1.7h-33.7c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h23.3v5.2c0,15.3-7.7,15.6-7.7,15.6h-24.5c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h19.7v23.2c0,0.9,0.8,1.7,1.7,1.7c5.8,0,10.4-4.7,10.4-10.4V46.6h22.3C445,46.6,449.7,45,453,41.3z M483.1,19.1h-8.7c-0.9,0-1.7,0.8-1.7,1.7v8.1h-4c-0.9,0-1.7,0.7-1.7,1.7s0.7,1.7,1.7,1.7h4v12.7c0,0.9,0.8,1.7,1.7,1.7h8.7c0.9,0,1.7-0.8,1.7-1.7V20.8C484.8,19.9,484.1,19.1,483.1,19.1z M467.1,0H351.6c-23.1,0-42,18.3-43,41.2H272C271,18.3,252.1,0,229,0c-23.7,0-43,19.3-43,43c0,23.7,19.3,43,43,43c23.1,0,42-18.3,43-41.2h36.6c1,22.9,19.9,41.2,43,41.2h115.5c23.7,0,43-19.3,43-43C510.1,19.3,490.8,0,467.1,0z M229,82.3c-21.7,0-39.3-17.6-39.3-39.3c0-21.7,17.6-39.3,39.3-39.3c21.7,0,39.3,17.6,39.3,39.3C268.3,64.7,250.7,82.3,229,82.3z M467.1,82.3H351.6c-21.7,0-39.3-17.6-39.3-39.3c0-21.7,17.6-39.3,39.3-39.3h115.5c21.7,0,39.3,17.6,39.3,39.3C506.4,64.7,488.7,82.3,467.1,82.3z M347.5,41.3c3.3,3.8,8,5.4,13.7,5.4h1.8c0.9,0,1.7-0.7,1.7-1.7c0-0.9-0.7-1.7-1.7-1.7h0c-4.6,0-9.4-2.4-9.4-7.7V20.8c0-0.9-0.8-1.7-1.7-1.7h-8.7c-0.9,0-1.7,0.8-1.7,1.7v14.7c0,5.4-4.8,7.7-9.4,7.7h0c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h1.8C339.4,46.6,344.1,45,347.5,41.3z M377.6,19.1h-8.7c-0.9,0-1.7,0.8-1.7,1.7v8.1h-4c-0.9,0-1.7,0.7-1.7,1.7s0.7,1.7,1.7,1.7h4v12.7c0,0.9,0.8,1.7,1.7,1.7h8.7c0.9,0,1.7-0.8,1.7-1.7V20.8C379.3,19.9,378.5,19.1,377.6,19.1z M254.8,43.3h-18c4.8-2,10.7-6.4,10.7-15.7v-6.8c0-0.9-0.8-1.7-1.7-1.7h-33.7c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h23.3v5.2c0,15.3-7.7,15.7-7.7,15.7h-24.5c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h19.7v23.2c0,0.9,0.8,1.7,1.7,1.7c5.8,0,10.4-4.7,10.4-10.4V46.6h19.7c0.9,0,1.7-0.7,1.7-1.7C256.4,44,255.7,43.3,254.8,43.3z M378.1,49.5h-39.2c-0.9,0-1.7,0.7-1.7,1.7c0,0.9,0.7,1.7,1.7,1.7h28.3v17c0,0.9,0.8,1.7,1.7,1.7c5.8,0,10.4-4.7,10.4-10.4V50.6C379.3,50,378.8,49.5,378.1,49.5z" stroke="undefined" stroke-width="1"></path><path class="text-path" d="M66.2,35.2c0-3.3-1.4-6.2-4.2-8h4.1c0.8,0,1.5-0.7,1.5-1.5c0-0.8-0.7-1.5-1.5-1.5h-7.4v-4c0-0.6-0.5-1.1-1.1-1.1H53c-0.6,0-1.1,0.5-1.1,1.1v4h-7.4c-0.8,0-1.5,0.7-1.5,1.5c0,0.8,0.7,1.5,1.5,1.5h4.2c-2.7,1.8-4.2,4.7-4.2,8c0,5.4,3.9,9.8,10.9,9.8C62.4,45.1,66.2,40.7,66.2,35.2z M51.2,35.2c0-3.8,1.5-6.8,4.2-6.8c2.7,0,4.2,3.1,4.2,6.8c0,3.8-1.5,6.8-4.2,6.8C52.7,42.1,51.2,39,51.2,35.2z M35.4,19.6H31c-0.6,0-1.1,0.5-1.1,1.1v10.4h-4.2V21.1c0-0.6-0.5-1.1-1.1-1.1h-4.4c-0.6,0-1.1,0.5-1.1,1.1v21.8c-0.6,0.2-1.3,0.5-2.1,0.6c-0.9,0.2-1.9,0.3-3.1,0.3h-7V24.3H14c0.8,0,1.5-0.7,1.5-1.5c0-0.8-0.7-1.5-1.5-1.5H1c-0.6,0-1.1,0.5-1.1,1.1v23.4c0,0.6,0.5,1.1,1.1,1.1h12.6c1.3,0,2.4-0.1,3.3-0.4c0.9-0.3,1.6-0.6,2.2-1.1v15c0,0.6,0.5,1.1,1.1,1.1H22c2.1,0,3.7-1.6,3.7-3.7V35.1h4.2v25.9c0,0.6,0.5,1.1,1.1,1.1h1.8c2.1,0,3.7-1.6,3.7-3.7V20.7C36.5,20.1,36,19.6,35.4,19.6z M78.5,59H57.8v-9.6c0-0.6-0.5-1.1-1.1-1.1h-4.8c-0.6,0-1.1,0.5-1.1,1.1v11.5c0,0.6,0.5,1.1,1.1,1.1h26.6c0.8,0,1.5-0.7,1.5-1.5C80,59.7,79.3,59,78.5,59z M119,51h1.4c2.5,0,4.5-2,4.5-4.4V20.7c0-0.6-0.5-1.1-1.1-1.1H119c-0.6,0-1.1,0.5-1.1,1.1v29.1C117.9,50.5,118.4,51,119,51z M168.8,36h-5.3c0.5-0.6,0.9-1.6,1.2-3c0.3-1.4,0.5-2.6,0.5-3.8v-6.9c0-0.6-0.5-1.1-1.1-1.1h-27.3c-0.8,0-1.5,0.7-1.5,1.5c0,0.8,0.7,1.5,1.5,1.5h21.4v5.2c0,1.2-0.1,2.4-0.2,3.5c-0.1,1.2-0.3,2.2-0.7,3.1H132c-0.8,0-1.5,0.7-1.5,1.5c0,0.8,0.7,1.5,1.5,1.5h14.7v7.7h-10.1c-0.8,0-1.5,0.7-1.5,1.5c0 ...
# <div class="profile" id="mo_profile"><div class="photo"></div><div class="info"><button onclick="showLogin(2);" type="button"><strong>로그인</strong> 하세요</button><p>로그인을 하시면 <br/>더많은서비스를 이용하실 수 있습니다. </p></div></div>
# <div class="s_menu">
# <ul>
# <li class="icon1"><a href="/main/main.do#home">홈</a></li>
# <li class="icon2"><a href="/main/theme.do">테마</a></li>
# <li class="icon3"><a href="/main/area.do">지역</a></li>
# <li class="icon4">
# <a class="on" href="javascript:;">여행콕콕</a>
# <ul style="display:block;">
# <li><a href="/main/cr_main.do?type=ai">AI콕콕</a></li>
# <li><a href="/main/cr_main.do?type=place">핫플콕콕</a></li>
# <li><a href="/main/cr_main.do?type=abc">AI콕콕 플래너</a></li>
# </ul>
# </li>
# <li class="icon5"><a href="/tgpr/tgpr_main.do">여행상품 홍보관</a></li>
# <li class="icon6 on">
# <a class="on" href="javascript:;">여행정보</a>
# <ul style="display:block;">
# <li><a href="/list/travelinfo.do?service=ms">여행지</a></li>
# <li><a href="/list/travelinfo.do?service=rem">여행기사</a></li>
# <li><a href="/list/travelinfo.do?service=cs">여행코스</a></li>
# <li><a href="https://korean.visitkorea.or.kr/kfes/list/wntyFstvlList.do">축제</a></li>
# <li><a href="/list/travelinfo.do?service=show">공연 / 행사</a></li>
# <li><a href="/list/travelinfo.do?service=event">이벤트</a></li>
# <li><a href="/list/travelinfo.do?service=trss">가볼래-터</a></li>
# <li><a href="/list/travelinfo.do?service=digt">디지털관광주민증</a></li>
# </ul>
# </li>
# <li class="icon7"><a href="/mylocation/mylocation.do">여행지도</a></li>
# </ul>
# </div>
# </div>
# <button class="close" type="button">닫기</button>
# ...
# "",protocol:c.protocol||"",fragment:c.hash||"",statusCode:a.status||"",statusText:a.statusText||"",headers:e,timestamp:b.timeStamp||"",contentType:f.contentType||"",response:a.responseJSON||a.responseXML||a.responseText||""}})})}function l(b,a,f,c){var g={};if(!b||!a||!f)return{};if(b=b.split(a))for(a=0;a<b.length;a++){var d=c?decodeURIComponent(b[a]):b[a],e=d.split(f);d=m(e[0]);e=m(e[1]);d&&e&&(g[d]=e)}return g}function m(b){if(b)return b.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g,"")}var k;h()})();</script><script id="" type="text/javascript">try{var sph_param_str=window.localStorage.getItem("sph_content_scroll");if(sph_param_str&&""!=sph_param_str){var sph_param=JSON.parse(sph_param_str);SphereAnalytics.logEvent("scroll_content",sph_param);window.localStorage.removeItem("sph_content_scroll")}}catch(a){console.log("sphereError : scroll_content_sending",a)}window.localStorage.removeItem("sph_content_scroll");</script><script id="" type="text/javascript">var $sph_common_loc_search=document.querySelector("#topAddr span"),$sph_common_loc=null;
# if($sph_common_loc_search){var $sph_common_loc_arr=$sph_common_loc_search.textContent.split(" "),$sph_common_1st_arrs="\uc11c\uc6b8 \ubd80\uc0b0 \ub300\uad6c \uc778\ucc9c \uad11\uc8fc \ub300\uc804 \uc6b8\uc0b0 \uc138\uc885 \uacbd\uae30 \uac15\uc6d0 \ucda9\ubd81 \ucda9\ub0a8 \uacbd\ubd81 \uacbd\ub0a8 \uc804\ubd81 \uc804\ub0a8 \uc81c\uc8fc".split(" ");$sph_common_loc=$sph_common_1st_arrs.includes($sph_common_loc_arr[0])?{loc1:$sph_common_loc_arr[0],loc2:$sph_common_loc_arr[1]}:{loc1:"\uc804\uad6d",
# loc2:""}}
# var $sph_common_refine_loc=function(a){a=a.split(" ");if(a[0]&&0<a[0].length){var b=a[0].replace("\uad11\uc5ed\uc2dc","").replace("\ud2b9\ubcc4\uc2dc","").replace("\uc9c1\ud560\uc2dc","").replace("\uc81c\uc8fc\ub3c4","\uc81c\uc8fc").replace("\uacbd\uae30\ub3c4","\uacbd\uae30").replace("\ucda9\uccad\ubd81\ub3c4","\ucda9\ubd81").replace("\ucda9\uccad\ub0a8\ub3c4","\ucda9\ub0a8").replace("\uc804\ub77c\ubd81\ub3c4","\uc804\ubd81").replace("\uc804\ub77c\ub0a8\ub3c4","\uc804\ub0a8").replace("\uacbd\uc0c1\ubd81\ub3c4","\uacbd\ubd81").replace("\uacbd\uc0c1\ub0a8\ub3c4",
# "\uacbd\ub0a8").replace("\uac15\uc6d0\ub3c4","\uac15\uc6d0");return{loc1:b,loc2:a[1]}}return null},$sph_common_category_info=function(){switch(document.location.pathname){case "/detail/ms_detail.do":return{code:"ms",name:"\uc5ec\ud589\uc9c0"};case "/detail/rem_detail.do":return{code:"rem",name:"\uae30\uc0ac"};case "/detail/cs_detail_cos.do":return{code:"cs",name:"\ucf54\uc2a4"};case "/detail/fes_detail.do":return{code:"show",name:"\uacf5\uc5f0/\ud589\uc0ac"};case "/kfes/detail/fstvlDetail.do":return{code:"fes",
# name:"\ucd95\uc81c"};case "/detail/event_detail.do":return{code:"event",name:"\uc774\ubca4\ud2b8"}}return null},$sph_common_is_mobile=function(){return!!document.querySelector("#gnbCommon \x3e div.gnb \x3e.search \x3e .form.mo \x3e.input")};</script><script id="" type="text/javascript">try{var sph_contentViewInterval=setInterval(function(){if(document.querySelector("#topTitle")&&document.querySelector("#topAddr span")){var b=(new URL(document.URL)).searchParams,a={sapContentId:b.get("cotid"),sapContentName:document.querySelector("#topTitle").textContent},c=$sph_common_category_info();c&&(a.sapContentCat1Id=c.code,a.sapContentCat1Name=c.name);var d=[];document.querySelectorAll("#contents .box_modInfo .tag a").forEach(function(e){d.push(e.textContent.replace("#",""))});0<d.length&&
# (a.sapContentFilter3=d);if(c=$sph_common_refine_loc(document.querySelector("#topAddr span").textContent))a.sapContentFilter4=c.loc1,c.loc2&&(a.sapContentFilter5=c.loc2);b.get("big_category")&&(a.sapContentCat2Name=b.get("big_category"));b.get("mid_category")&&(a.sapContentCat3Name=b.get("mid_category"));window.localStorage.getItem("_sph_save_path")&&(a.sapSourceName=window.localStorage.getItem("_sph_save_path"));SphereAnalytics.logEvent("sapContentDetail",a);window.localStorage.setItem("_sph_save_path",
# "\uc720\uc0ac \ucee8\ud150\uce20 \ucd94\ucc9c");clearInterval(sph_contentViewInterval)}},300)}catch(b){console.log("sphereError: sapContentDetail \uc5ec\ud589\uae30\uc0ac",b)};</script><script id="" type="text/javascript">try{window.$sph_common_detail||(window.$sph_common_detail={}),$sph_common_detail.like||($sph_common_detail.like={liked:!document.querySelector(".btn_good.on"),clicked:!1}),google_tag_manager["rm"]["6648892"](29)&&(google_tag_manager["rm"]["6648892"](30).closest(".btn_good")&&!google_tag_manager["rm"]["6648892"](31).closest(".btn_good.on")?$sph_common_detail.like.clicked=!0:$sph_common_detail.like.clicked=!1,$sph_common_detail.like.liked&&$sph_common_detail.like.clicked&&($sph_common_detail.like.liked=!1,$sph_common_detail.like.clicked=!1,SphereAnalytics.logEvent("like_content",
# {sapContentId:(new URL(document.URL)).searchParams.get("cotid")})))}catch(a){console.log("sphereError: like_content",a)};</script><script id="" type="text/javascript">try{window.$sph_common_detail||(window.$sph_common_detail={}),$sph_common_detail.like||($sph_common_detail.like={liked:!document.querySelector(".btn_good.on"),clicked:!1}),google_tag_manager["rm"]["6648892"](33)&&(google_tag_manager["rm"]["6648892"](34).closest(".btn_good")&&!google_tag_manager["rm"]["6648892"](35).closest(".btn_good.on")?$sph_common_detail.like.clicked=!0:$sph_common_detail.like.clicked=!1,$sph_common_detail.like.liked&&$sph_common_detail.like.clicked&&($sph_common_detail.like.liked=!1,$sph_common_detail.like.clicked=!1,SphereAnalytics.logEvent("like_content",
# {sapContentId:(new URL(document.URL)).searchParams.get("cotid")})))}catch(a){console.log("sphereError: like_content",a)};</script><script id="" type="text/javascript">try{window.$sph_common_detail||(window.$sph_common_detail={}),$sph_common_detail.like||($sph_common_detail.like={liked:!document.querySelector(".btn_good.on"),clicked:!1}),google_tag_manager["rm"]["6648892"](49)&&(google_tag_manager["rm"]["6648892"](50).closest(".btn_good")&&!google_tag_manager["rm"]["6648892"](51).closest(".btn_good.on")?$sph_common_detail.like.clicked=!0:$sph_common_detail.like.clicked=!1,$sph_common_detail.like.liked&&$sph_common_detail.like.clicked&&($sph_common_detail.like.liked=!1,$sph_common_detail.like.clicked=!1,SphereAnalytics.logEvent("like_content",
# {sapContentId:(new URL(document.URL)).searchParams.get("cotid")})))}catch(a){console.log("sphereError: like_content",a)};</script><script id="" type="text/javascript">try{window.$sph_common_detail||(window.$sph_common_detail={}),$sph_common_detail.like||($sph_common_detail.like={liked:!document.querySelector(".btn_good.on"),clicked:!1}),google_tag_manager["rm"]["6648892"](53)&&(google_tag_manager["rm"]["6648892"](54).closest(".btn_good")&&!google_tag_manager["rm"]["6648892"](55).closest(".btn_good.on")?$sph_common_detail.like.clicked=!0:$sph_common_detail.like.clicked=!1,$sph_common_detail.like.liked&&$sph_common_detail.like.clicked&&($sph_common_detail.like.liked=!1,$sph_common_detail.like.clicked=!1,SphereAnalytics.logEvent("like_content",
# {sapContentId:(new URL(document.URL)).searchParams.get("cotid")})))}catch(a){console.log("sphereError: like_content",a)};</script><div id="campaign-KTO-ebac3-5CuyRRUDnjHk7azc9_K1" style="position: relative; z-index: 100001; display: none;"><div class="_sa_dim _sa_dim_0" id="sa-campaign__v2"><div class="_sa_shape__box _sa_location__bottom_right"><button class="_sa_btn_close"><span class="_sa_icon_clear"></span></button><div class="_sa_campaign-wrapper"><div class="_sa_campaign-inner _sa_layout__image _sa_size__medium"><div class="_sa_image-area"><img alt="[페이지뷰] 첫방문자 안착유도) 대구석/첫방문자 A-1" class="_sa_img" src="https://image.tand.kr/msg/wkjGTTa4gvoXNE52Ae9j/campaign-KTO-ebac3-5CuyRRUDnjHk7azc9_K1/hw2-iHmhcgovsfnBTYXo.png"/></div><div class="_sa_bottom-group"><button class="_sa_button _sa_t-size__medium" style="color: rgb(0, 0, 0); background-color: rgb(255, 255, 255);">다시 보지 않기</button><button class="_sa_button _sa_t-size__medium" style="color: rgb(255, 255, 255); background-color: rgb(45, 37, 147);">자세히 보기</button></div></div></div></div></div></div><script id="" type="text/javascript">try{window.$sph_common_detail||(window.$sph_common_detail={}),$sph_common_detail.like||($sph_common_detail.like={liked:!document.querySelector(".btn_good.on"),clicked:!1}),google_tag_manager["rm"]["6648892"](58)&&(google_tag_manager["rm"]["6648892"](59).closest(".btn_good")&&!google_tag_manager["rm"]["6648892"](60).closest(".btn_good.on")?$sph_common_detail.like.clicked=!0:$sph_common_detail.like.clicked=!1,$sph_common_detail.like.liked&&$sph_common_detail.like.clicked&&($sph_common_detail.like.liked=!1,$sph_common_detail.like.clicked=!1,SphereAnalytics.logEvent("like_content",
# {sapContentId:(new URL(document.URL)).searchParams.get("cotid")})))}catch(a){console.log("sphereError: like_content",a)};</script><script id="" type="text/javascript">try{var _sph_login_timer=setTimeout(function(){if(window.custInfo&&!window.location.pathname.includes("travelweekend"))if(custInfo.uuid){SphereAnalytics.setUserId(custInfo.uuid).setBirthYear(parseInt(custInfo.birthYr)).setGender(custInfo.gender.toLowerCase());custInfo.grade&&SphereAnalytics.setGrade(custInfo.grade);custInfo.grade&&SphereAnalytics.setUserProperty("mission_stage",custInfo.grade);custInfo.joinYmd&&SphereAnalytics.setUserProperty("sapJoinDate",custInfo.joinYmd);custInfo.commentCnt&&SphereAnalytics.setUserProperty("comments",
# parseInt(custInfo.commentCnt));custInfo.favoriteCnt&&SphereAnalytics.setUserProperty("scraps",parseInt(custInfo.favoriteCnt));custInfo.rsdeNm&&SphereAnalytics.setUserProperty("address1",custInfo.rsdeNm);if(custInfo.cardAreaNm){var a=custInfo.cardAreaNm;a=a.split(",");SphereAnalytics.setUserProperty("digital_id_card",!0);SphereAnalytics.setUserPropertyArray("digital_id_address",a)}if(a=window.localStorage.getItem("_sph_login_popup"))SphereAnalytics.logEvent("sapLogin",{sapLoginFirst:google_tag_manager["rm"]["6648892"](62)}),
# window.localStorage.removeItem("_sph_login_popup")}else SphereAnalytics.setUserId(custInfo.uuid).resetPoints().resetUserProperties()},1200)}catch(a){window.localStorage.removeItem("_sph_login_popup")};</script><script id="" type="text/javascript">try{window.$sph_common_detail||(window.$sph_common_detail={}),$sph_common_detail.like||($sph_common_detail.like={liked:!document.querySelector(".btn_good.on"),clicked:!1}),google_tag_manager["rm"]["6648892"](64)&&(google_tag_manager["rm"]["6648892"](65).closest(".btn_good")&&!google_tag_manager["rm"]["6648892"](66).closest(".btn_good.on")?$sph_common_detail.like.clicked=!0:$sph_common_detail.like.clicked=!1,$sph_common_detail.like.liked&&$sph_common_detail.like.clicked&&($sph_common_detail.like.liked=!1,$sph_common_detail.like.clicked=!1,SphereAnalytics.logEvent("like_content",
# {sapContentId:(new URL(document.URL)).searchParams.get("cotid")})))}catch(a){console.log("sphereError: like_content",a)};</script><script id="" type="text/javascript">try{window.$sph_common_detail||(window.$sph_common_detail={}),$sph_common_detail.like||($sph_common_detail.like={liked:!document.querySelector(".btn_good.on"),clicked:!1}),google_tag_manager["rm"]["6648892"](68)&&(google_tag_manager["rm"]["6648892"](69).closest(".btn_good")&&!google_tag_manager["rm"]["6648892"](70).closest(".btn_good.on")?$sph_common_detail.like.clicked=!0:$sph_common_detail.like.clicked=!1,$sph_common_detail.like.liked&&$sph_common_detail.like.clicked&&($sph_common_detail.like.liked=!1,$sph_common_detail.like.clicked=!1,SphereAnalytics.logEvent("like_content",
# {sapContentId:(new URL(document.URL)).searchParams.get("cotid")})))}catch(a){console.log("sphereError: like_content",a)};</script><script id="" type="text/javascript">try{window.$sph_common_detail||(window.$sph_common_detail={}),$sph_common_detail.like||($sph_common_detail.like={liked:!document.querySelector(".btn_good.on"),clicked:!1}),google_tag_manager["rm"]["6648892"](72)&&(google_tag_manager["rm"]["6648892"](73).closest(".btn_good")&&!google_tag_manager["rm"]["6648892"](74).closest(".btn_good.on")?$sph_common_detail.like.clicked=!0:$sph_common_detail.like.clicked=!1,$sph_common_detail.like.liked&&$sph_common_detail.like.clicked&&($sph_common_detail.like.liked=!1,$sph_common_detail.like.clicked=!1,SphereAnalytics.logEvent("like_content",
# {sapContentId:(new URL(document.URL)).searchParams.get("cotid")})))}catch(a){console.log("sphereError: like_content",a)};</script><script id="" type="text/javascript">try{window.sph_content_scroll=window.sph_content_scroll||{};if(!sph_content_scroll.sapContentId){var sph_contId=(new URL(document.URL)).searchParams.get("cotid");sph_content_scroll.sapContentId=sph_contId}sph_content_scroll.scroll_percent=parseInt(google_tag_manager["rm"]["6648892"](93));window.localStorage.setItem("sph_content_scroll",JSON.stringify(sph_content_scroll))}catch(a){console.log("sphereError : scroll_contentt",a)};</script><script id="" type="text/javascript">try{window.sph_content_scroll=window.sph_content_scroll||{};if(!sph_content_scroll.sapContentId){var sph_contId=(new URL(document.URL)).searchParams.get("cotid");sph_content_scroll.sapContentId=sph_contId}sph_content_scroll.scroll_percent=parseInt(google_tag_manager["rm"]["6648892"](95));window.localStorage.setItem("sph_content_scroll",JSON.stringify(sph_content_scroll))}catch(a){console.log("sphereError : scroll_contentt",a)};</script><script id="" type="text/javascript">try{window.sph_content_scroll=window.sph_content_scroll||{};if(!sph_content_scroll.sapContentId){var sph_contId=(new URL(document.URL)).searchParams.get("cotid");sph_content_scroll.sapContentId=sph_contId}sph_content_scroll.scroll_percent=parseInt(google_tag_manager["rm"]["6648892"](97));window.localStorage.setItem("sph_content_scroll",JSON.stringify(sph_content_scroll))}catch(a){console.log("sphereError : scroll_contentt",a)};</script><script id="" type="text/javascript">try{window.sph_content_scroll=window.sph_content_scroll||{};if(!sph_content_scroll.sapContentId){var sph_contId=(new URL(document.URL)).searchParams.get("cotid");sph_content_scroll.sapContentId=sph_contId}sph_content_scroll.scroll_percent=parseInt(google_tag_manager["rm"]["6648892"](107));window.localStorage.setItem("sph_content_scroll",JSON.stringify(sph_content_scroll))}catch(a){console.log("sphereError : scroll_contentt",a)};</script><script id="" type="text/javascript">try{window.sph_content_scroll=window.sph_content_scroll||{};if(!sph_content_scroll.sapContentId){var sph_contId=(new URL(document.URL)).searchParams.get("cotid");sph_content_scroll.sapContentId=sph_contId}sph_content_scroll.scroll_percent=parseInt(google_tag_manager["rm"]["6648892"](109));window.localStorage.setItem("sph_content_scroll",JSON.stringify(sph_content_scroll))}catch(a){console.log("sphereError : scroll_contentt",a)};</script><script id="" type="text/javascript">try{window.sph_content_scroll=window.sph_content_scroll||{};if(!sph_content_scroll.sapContentId){var sph_contId=(new URL(document.URL)).searchParams.get("cotid");sph_content_scroll.sapContentId=sph_contId}sph_content_scroll.scroll_percent=parseInt(google_tag_manager["rm"]["6648892"](118));window.localStorage.setItem("sph_content_scroll",JSON.stringify(sph_content_scroll))}catch(a){console.log("sphereError : scroll_contentt",a)};</script></body></html>

# %%
#이미지 주소 뽑기

image = driver.find_elements(By.LINK_TEXT, 'src')
len(image)

#실패!
# Out:
# 0

# %%
mylist = html_dom.select('.img_typeBox img')
mylist
# Out:
# [<img alt="굴구이" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=7ee736d9-5afa-471a-976d-42da60a69a51"/>,
#  <img alt="거제에서 쉽게 볼 수 있는 굴 양식장" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=2498f000-e891-4fff-8f5c-f42feda60e6b"/>,
#  <img alt="굴무침" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=08ea1346-7aa5-4460-94aa-c262d05c0af8"/>,
#  <img alt="굴구이 먹을 때 사용하는 칼과 장갑" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=0501f778-7fef-44b4-b5b4-1714d8348c2a"/>,
#  <img alt="거제의 겨울 별미 굴구이" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=638ea611-96fe-465e-a3af-ee22710e8a3e"/>,
#  <img alt="대구회무침" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=fe302acf-edb3-41c0-92b7-6ab64da64f9d"/>,
#  <img alt="국물이 진한 대구탕" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=c3444011-2e4b-4fe1-98df-14384a4eacf1"/>,
#  <img alt="대구 말리기" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=df22aa2d-363c-4ac6-8496-2db36178fa62"/>,
#  <img alt="대구찜" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=4266d538-7467-4468-9a37-297b682c30cd"/>,
#  <img alt="신선대" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=faac52a9-e79e-4eb7-ae09-8222fa1c6a9c"/>,
#  <img alt="바람의 언덕" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=2c1069d4-fa23-4cf8-907f-8548a3189ea2"/>,
#  <img alt="그때 그 시절을 느낄 수 있는 해금강테마박물관" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=e941ef2c-8b0d-48b1-99fd-f78db726582a"/>,
#  <img alt="몽돌해변에서 즐거운 시간을 보내는 아이들" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=a72b5b95-0507-4059-bdb4-78b3af4d07f6"/>,
#  <img alt="거가대교" src="https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&amp;id=9eddb7dc-0860-43d2-a8f0-6688a78edefd"/>]

# %%
img_list = [item['src'] for item in mylist]
img_list
# Out:
# ['https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=7ee736d9-5afa-471a-976d-42da60a69a51',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=2498f000-e891-4fff-8f5c-f42feda60e6b',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=08ea1346-7aa5-4460-94aa-c262d05c0af8',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=0501f778-7fef-44b4-b5b4-1714d8348c2a',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=638ea611-96fe-465e-a3af-ee22710e8a3e',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=fe302acf-edb3-41c0-92b7-6ab64da64f9d',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=c3444011-2e4b-4fe1-98df-14384a4eacf1',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=df22aa2d-363c-4ac6-8496-2db36178fa62',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=4266d538-7467-4468-9a37-297b682c30cd',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=faac52a9-e79e-4eb7-ae09-8222fa1c6a9c',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=2c1069d4-fa23-4cf8-907f-8548a3189ea2',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=e941ef2c-8b0d-48b1-99fd-f78db726582a',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=a72b5b95-0507-4059-bdb4-78b3af4d07f6',
#  'https://cdn.visitkorea.or.kr/img/call?cmd=VIEW&id=9eddb7dc-0860-43d2-a8f0-6688a78edefd']

# %%
no = 0
for src in img_list:
    # 다운로드  (주소, 파일이름)
    urllib.request.urlretrieve(src, f'{f_dir}\\{no}.jpg') # request.urlretrieve 다운로드하는 메서드
    no += 1

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=953,0')
options.add_experimental_option("detach", True)

# %%
import os
f_dir = 'stock'
os.makedirs(os.getcwd()+'\\' + f_dir)

driver = webdriver.Chrome(options=options)
URL = 'http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0301'  
driver.get(URL)

# %%
driver.find_element(By.XPATH, '//*[@id="jsMdiMenu"]/div[4]/ul/li[5]/ul/li[2]/div/div[1]/ul/li[2]/a').click()
#실행됨!

# %%
driver.find_element(By.XPATH, '//*[@id="jsMdiMenu"]/div[4]/ul/li[5]/ul/li[2]/div/div[1]/ul/li[2]/ul/li[5]/a').click()
#실행됨!

# %%
driver.find_element(By.LINK_TEXT, '주식').click()

# %%
driver.find_element(By.LINK_TEXT, '상장종목 주요기록').click()

# %%
market = driver.find_element(By.ID, 'mktId_0_1')
market
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="889004a1150f4f300757b4b605334032", element="7B0F1553BDDC74B2894C5DA2E642288B_element_118248")>

# %%
market = driver.find_element(By.CSS_SELECTOR, "[for='mktId_0_1']")
market.click()

# %%
# 자바스크립트 명령을 써야 한다.
driver.execute_script('arguments[0].click()', market)

# %%
market.is_selected()
# Out:
# False

# %%
driver.find_element(By.ID, 'jsSearchButton').click()
#실행됨!

# %%
driver.find_element(By.CLASS_NAME, 'CI-MDI-UNIT-DOWNLOAD').click()

# %%
excel = driver.find_element(By.CSS_SELECTOR, 'div[data-type="excel"]')
excel.click()
# Out:
# 'Excel'

# %%
idx1 = int(input(' 0.전체      1.KOSPI     2.KOSDAQ    3.KONEX  ==> 시장 번호 선택:  '))
idx2 = int(input(' 0.Excel 파일로 저장      1. CSV 파일로 저장   ==> 파일 형식 선택:  '))
# Out:
#  0.전체      1.KOSPI     2.KOSDAQ    3.KONEX  ==> 시장 번호 선택:  1
#  0.Excel 파일로 저장      1. CSV 파일로 저장   ==> 파일 형식 선택:  0

# %%
market_type = ['mktId_0_0','mktId_0_1', 'mktId_0_2', 'mktId_0_3']
market = driver.find_element(By.ID, market_type[idx1])

# %%
driver.find_element(By.ID, 'jsSearchButton').click()

# %%
driver.find_element(By.CLASS_NAME, 'CI-MDI-UNIT-DOWNLOAD').click()

# %%
file_type =['Excel', 'CSV']
driver.find_element(By.LINK_TEXT, file_type[idx2]).click()

# %% [markdown]
# # 웹스크래핑프로그램 실습용
# >예제 페이지에서 여행기사를 추출한다.
# >https://korean.visitkorea.or.kr/main/main.do
# >검색어와 스크래핑 건수를 입력받는다.
# >페이지를 이동한다.
# >상세 페이지별로 여행기사 정보를 수집한다.
# >이미지와 텍스트를 추출해서 파일로 저장까지

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time, urllib.request

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=953,0')
options.add_experimental_option("detach", True)

# %%
search = input('검색어를 입력하세요.')
# Out:
# 검색어를 입력하세요.인천

# %%
URL = 'https://korean.visitkorea.or.kr/search/search_list.do?keyword='+search

driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(3)

# %%
import os
os.getcwd()
# Out:
# 'C:\\workspace\\python\\WASSUP'

# %%
f_dir = input("이미지 저장 폴더명 : ")
os.makedirs(os.getcwd()+'\\'+f_dir)
# Out:
# 이미지 저장 폴더명 : 실습실습

# %%
driver.find_element(By.CSS_SELECTOR, "#s_recommend > .more_view > a").click()

# %%
cnt = int(input('크롤링 할 건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt / 10) # 크롤링 할 전체 페이지 수 (올림)
print(page_cnt) #한 페이지에 10개의 콘텐츠가 나온다는 것을 알고 있음!
# Out:
# 크롤링 할 건수는 몇건입니까?: 35
# 4

# %%
tit_xpath = '//*[@id="search_result"]/ul/li[*]/div[1]/div[1]/a'
no = 0
title_list = []

for x in range(1, page_cnt+1):
    print(f'========= {x} 페이지 작업 =========')
    mylist = driver.find_elements(By.XPATH, tit_xpath)
    
    for item in mylist:
        no += 1
        if no > cnt:
            break
        print(no, item.text.replace('\n', ''))
        title_list.append(item.text.replace('\n', ''))
    
    if no <= cnt:
        a = f'/html/body/div[3]/div/div[1]/div[15]/a[{x+1}]'
        driver.find_element(By.XPATH, a).click()
        time.sleep(2)

print('========= 작업 완료 =========')
# Out:
# ========= 1 페이지 작업 =========
# 1 서울 근교 여행, 아이와 나들이 떠나는 인천 여행 코스
# 2 옛 감성 물씬, 인천 구도심(동인천) 테마여행
# 3 인천테마여행_긴 물길을 따라 이어지는 다채로운 여행 경인아라뱃길
# 4 인천 여행, 선선한 저녁에 즐기는 인천 야경 명소 4
# 5 짜장면이 태어난 차이나타운의 먹자골목, 인천 북성동원조자장면거리와 짜장면박물관
# 6 인천 근현대사 중심지, 시민의 공간이 되다! 인천시민애집
# 7 낭만과 그리움을 찾아서, 인천 경인아라뱃길 정서진 드라이브
# 8 견공의, 견공에 의한, 견공을 위한 놀이 공간 인천대공원 반려견놀이터
# 9 [인천] 도심 속 공원으로 떠나는 비대면 힐링여행인천 송도 센트럴파크 & 소래습지생태공원
# 10 우리나라 최초의 등대, 인천 팔미도등대
# ========= 2 페이지 작업 =========
# 11 인천의 핫한 거리 평리단길 카페
# 12 과거부터 현재까지,인천으로 떠나는 시간 여행
# 13 개항로라 쓰고 뉴트로라 읽는다! 스마트하게 즐기는 인천 Next Level 여행지 8
# 14 인천 여행, 아이들과 다녀오기 좋은 당일치기 코스
# 15 밤의 낭만과 바다의 설렘이 공존하는 곳, 영종도 야간 드라이브 코스
# 16 일몰이 아름다운 계절에는 인천 석모도에 간다
# 17 지금 기억하는 어제의 풍경, 인천 개항장 거리
# 18 당신만을 위한 프리미엄 요트 니드라, 현대요트 인천
# 19 신나게 놀고 즐기는 과학놀이터, 인천어린이과학관
# 20 2022 필더리듬오브코리아! 한국관광 홍보영상#인천 Feel the Rhythm of Korea - INCHEON
# ========= 3 페이지 작업 =========
# 21 낡을수록 빛나는 옛 건물의 재발견,인천 개항장 아날로그 산책
# 22 추억과 문화가 담긴 따뜻한 골목, 1호선 인천역과 개항장 문화지구
# 23 동화 속으로 떠나는 환상 여행, 인천 송월동
# 24 27년을 지켜온 추억의 맛, 인천 신포닭강정
# 25 뚜벅이로 떠나는 당일치기 인천 중구 인생샷 여행!
# 26 '소금꽃 피는 계절'엔, 시흥 & 인천 남동구
# 27 공항만 알면 섭섭한 인천 영종도&용유도 로맨틱 여행
# 28 개항장 인천의 랜드마크, 대불호텔의 화려한 변신
# 29 공항철도 타고 한나절 섬 여행, 인천 무의도와 장봉도
# 30 상상 이상의 스파, 인천 파라다이스시티 씨메르
# ========= 4 페이지 작업 =========
# 31 차를 타고 떠나는 매력적인 섬 여행, 인천 영흥도
# 32 세계 맛집 다 모아 놨다는 인천공항 제2터미널 맛집
# 33 [인천 당일치기 여행]부지런히 먹으러 가는 인천 개항장거리 먹투어
# 34 전통과 현대의 꼴라보! 인천 송도 여행코스
# 35 보는 재미, 먹는 즐거움 인천 명소에서 만나는 명물 빵
# ========= 작업 완료 =========

# %%
print(title_list)
# Out:
# ['서울 근교 여행, 아이와 나들이 떠나는 인천 여행 코스', '옛 감성 물씬, 인천 구도심(동인천) 테마여행', '인천테마여행_긴 물길을 따라 이어지는 다채로운 여행 경인아라뱃길', '인천 여행, 선선한 저녁에 즐기는 인천 야경 명소 4', '짜장면이 태어난 차이나타운의 먹자골목, 인천 북성동원조자장면거리와 짜장면박물관', '인천 근현대사 중심지, 시민의 공간이 되다! 인천시민애집', '낭만과 그리움을 찾아서, 인천 경인아라뱃길 정서진 드라이브', '견공의, 견공에 의한, 견공을 위한 놀이 공간 인천대공원 반려견놀이터', '[인천] 도심 속 공원으로 떠나는 비대면 힐링여행인천 송도 센트럴파크 & 소래습지생태공원', '우리나라 최초의 등대, 인천 팔미도등대', '인천의 핫한 거리 평리단길 카페', '과거부터 현재까지,인천으로 떠나는 시간 여행', '개항로라 쓰고 뉴트로라 읽는다! 스마트하게 즐기는 인천 Next Level 여행지 8', '인천 여행, 아이들과 다녀오기 좋은 당일치기 코스', '밤의 낭만과 바다의 설렘이 공존하는 곳, 영종도 야간 드라이브 코스', '일몰이 아름다운 계절에는 인천 석모도에 간다', '지금 기억하는 어제의 풍경, 인천 개항장 거리', '당신만을 위한 프리미엄 요트 니드라, 현대요트 인천', '신나게 놀고 즐기는 과학놀이터, 인천어린이과학관', '2022 필더리듬오브코리아! 한국관광 홍보영상#인천 Feel the Rhythm of Korea - INCHEON', '낡을수록 빛나는 옛 건물의 재발견,인천 개항장 아날로그 산책', '추억과 문화가 담긴 따뜻한 골목, 1호선 인천역과 개항장 문화지구', '동화 속으로 떠나는 환상 여행, 인천 송월동', '27년을 지켜온 추억의 맛, 인천 신포닭강정', '뚜벅이로 떠나는 당일치기 인천 중구 인생샷 여행!', "'소금꽃 피는 계절'엔, 시흥 & 인천 남동구", '공항만 알면 섭섭한 인천 영종도&용유도 로맨틱 여행', '개항장 인천의 랜드마크, 대불호텔의 화려한 변신', '공항철도 타고 한나절 섬 여행, 인천 무의도와 장봉도', '상상 이상의 스파, 인천 파라다이스시티 씨메르', '차를 타고 떠나는 매력적인 섬 여행, 인천 영흥도', '세계 맛집 다 모아 놨다는 인천공항 제2터미널 맛집', '[인천 당일치기 여행]부지런히 먹으러 가는 인천 개항장거리 먹투어', '전통과 현대의 꼴라보! 인천 송도 여행코스', '보는 재미, 먹는 즐거움 인천 명소에서 만나는 명물 빵']

# %%
import pandas as pd
df = pd.DataFrame(title_list)
df
# Out:
#                                                     0
# 0                      서울 근교 여행, 아이와 나들이 떠나는 인천 여행 코스
# 1                           옛 감성 물씬, 인천 구도심(동인천) 테마여행
# 2                 인천테마여행_긴 물길을 따라 이어지는 다채로운 여행 경인아라뱃길
# 3                       인천 여행, 선선한 저녁에 즐기는 인천 야경 명소 4
# 4         짜장면이 태어난 차이나타운의 먹자골목, 인천 북성동원조자장면거리와 짜장면박물관
# 5                     인천 근현대사 중심지, 시민의 공간이 되다! 인천시민애집
# 6                    낭만과 그리움을 찾아서, 인천 경인아라뱃길 정서진 드라이브
# 7              견공의, 견공에 의한, 견공을 위한 놀이 공간 인천대공원 반려견놀이터
# 8   [인천] 도심 속 공원으로 떠나는 비대면 힐링여행인천 송도 센트럴파크 & 소래습지생태공원
# 9                               우리나라 최초의 등대, 인천 팔미도등대
# 10                                  인천의 핫한 거리 평리단길 카페
# 11                           과거부터 현재까지,인천으로 떠나는 시간 여행
# 12    개항로라 쓰고 뉴트로라 읽는다! 스마트하게 즐기는 인천 Next Level 여행지 8
# 13                        인천 여행, 아이들과 다녀오기 좋은 당일치기 코스
# 14              밤의 낭만과 바다의 설렘이 공존하는 곳, 영종도 야간 드라이브 코스
# 15                           일몰이 아름다운 계절에는 인천 석모도에 간다
# 16                          지금 기억하는 어제의 풍경, 인천 개항장 거리
# 17                       당신만을 위한 프리미엄 요트 니드라, 현대요트 인천
# 18                         신나게 놀고 즐기는 과학놀이터, 인천어린이과학관
# 19  2022 필더리듬오브코리아! 한국관광 홍보영상#인천 Feel the Rhythm o...
# 20                  낡을수록 빛나는 옛 건물의 재발견,인천 개항장 아날로그 산책
# 21               추억과 문화가 담긴 따뜻한 골목, 1호선 인천역과 개항장 문화지구
# 22                           동화 속으로 떠나는 환상 여행, 인천 송월동
# 23                           27년을 지켜온 추억의 맛, 인천 신포닭강정
# 24                        뚜벅이로 떠나는 당일치기 인천 중구 인생샷 여행!
# 25                          '소금꽃 피는 계절'엔, 시흥 & 인천 남동구
# 26                       공항만 알면 섭섭한 인천 영종도&용유도 로맨틱 여행
# 27                         개항장 인천의 랜드마크, 대불호텔의 화려한 변신
# 28                      공항철도 타고 한나절 섬 여행, 인천 무의도와 장봉도
# 29                          상상 이상의 스파, 인천 파라다이스시티 씨메르
# 30                        차를 타고 떠나는 매력적인 섬 여행, 인천 영흥도
# 31                       세계 맛집 다 모아 놨다는 인천공항 제2터미널 맛집
# 32               [인천 당일치기 여행]부지런히 먹으러 가는 인천 개항장거리 먹투어
# 33                            전통과 현대의 꼴라보! 인천 송도 여행코스
# 34                     보는 재미, 먹는 즐거움 인천 명소에서 만나는 명물 빵
